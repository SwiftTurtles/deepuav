# %% [markdown]
# ### 라이브러리 import

# %%
# !pip install optuna
# !pip install torchinfo
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.35)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.1)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 8.3 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 17.8 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.6 alembic-1.13.3 colorlog-6.8.2 optuna-4.0.0
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## 전체 공통 함수

# %% [markdown]
# ### 1. 데이터 보간 함수

# %% [markdown]
# - 데이터의 시간 간격을 0.5초의 등간격으로 맞추고 그에 따른 좌표 값을 보간함
# - 가장 많이 사용되는 3차 스플라인 보간 적용

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt

# 데이터 보간 - 위도, 고도, 경도 값을 0.5초 시간 간격으로 보간
def spline_interpolation(x, y):
    # x: 보간할 데이터의 x 값 (시간)
    # y: 보간할 데이터의 y 값 (위도, 고도, 경도)

    # 3차 스플라인 보간 함수 생성
    f = interp1d(x, y, kind='cubic')

    # 시간 범위 설정
    start_time = min(x)
    end_time = max(x)

    # 0.5초 간격의 시간 배열을 생성
    new_x = np.arange(start_time, end_time, 0.5)

    # 위도, 경도, 고도 보간
    new_y = f(new_x)

    return new_x, new_y

# %% [markdown]
# ### 2. 시퀀스 나누는 함수

# %% [markdown]
# - 학습을 위해 데이터를 시퀀스 형태로 나눔
# - look back과 forward에 따라 학습에 사용될 x값의 구간과 y값을 반환함
# - 초기 look back은 10, forward는 0이다.

# %%
# 시퀀스 생성 함수
# look back : 10 (5초간의 위도, 고도, 경도 데이터를 x값으로 사용)
# forward : 0 (0.5초 뒤의 위도, 고도, 경도 데이터를 y값으로 사용)
def create_sequences(df, look_back=30, forward=0):
    xs = []
    ys = []
    for i in range(len(df) - look_back - forward):
        x = df.iloc[i:(i+look_back)].values
        y = df.iloc[i+look_back+forward].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# %% [markdown]
# ### 3. 시간 소수점 절사 함수

# %% [markdown]
# - 불필요한 시간 소수점 제거

# %%
import math

# 시간 소수점 절사 함수
def truncation(df):
    new_time = []

    for a in df['time']:
      new_time.append(math.floor(a * 10) / 10)

    df['time'] = new_time

    return df

# %% [markdown]
# ### 4. 스케일링 함수

# %% [markdown]
# - MinMaxScaling 적용 함수

# %%
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaling 적용 함수
def min_max_scaling(df):

    # time 삭제 df 생성
    mid_df=df.drop(columns='time')

    min_max_scaler = MinMaxScaler()
    min_max_scaler.fit(mid_df)

    min_max_data = min_max_scaler.transform(mid_df)

    new_data = pd.DataFrame(min_max_data)

    # time 추가
    new_data.insert(0, 'time', df['time'])

    # 나머지 열의 이름 가져오기
    column_names = mid_df.columns.tolist()

    column_names.insert(0, 'time')

    print(column_names)

    # 새로운 데이터프레임에 열 이름 설정
    new_data.columns = column_names

    return min_max_scaler, new_data

# %% [markdown]
# ### 5. train/validation/test 분리 함수

# %% [markdown]
# - Train, Validation, Test 데이터셋을 분리하는 함수이다.
# - 각각의 비율은 6:2:2 이다.

# %%
from sklearn.model_selection import train_test_split

# train/validation/test 분리 함수
def split_train_val_test(df, test_size=0.2, val_size=0.25):

    #Train, Test 분류
    train_val_df, test_df = train_test_split(df, test_size=test_size, shuffle=False)

    #Train, Validation 분류
    train_df, val_df = train_test_split(train_val_df, test_size=val_size, shuffle=False)

    # # 데이터 크기 출력
    # print("Train set:", train_df.shape)
    # print("Validation set:", val_df.shape)
    # print("Test set:", test_df.shape)

    return train_df, val_df, test_df

# %% [markdown]
# ### 6. 경로 시각화 함수

# %% [markdown]
# - 실제 경로와 예측 경로를 각각 그래프로 생성

# %%
import matplotlib.pyplot as plt

# 경로 시각화 함수
def prediction_visualization(y_test, y_pred):
    # 시각화를 위해 위도, 경도, 고도 분리
    y_test_lat = y_test[:, 0]
    y_test_lon = y_test[:, 1]
    y_test_alt = y_test[:, 2]

    y_pred_lat = y_pred[:, 0]
    y_pred_lon = y_pred[:, 1]
    y_pred_alt = y_pred[:, 2]

    # 3D 그래프 생성
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')

    # 실제 값 플롯
    ax.scatter(y_test_lat, y_test_lon, y_test_alt, c='b', marker='o', label='Actual')

    # 예측 값 플롯
    ax.scatter(y_pred_lat, y_pred_lon, y_pred_alt, c='r', marker='^', label='Predicted')

    # 그래프 제목 및 축 레이블 설정
    ax.set_title('Actual vs Predicted')
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 범례
    ax.legend()

    # 그래프를 화면에 출력
    plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# splited 데이터 경로 시각화 함수
def plot_trajectory(train_data, val_data, test_data):
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')

    # 훈련 데이터 플롯
    ax.plot(train_data['lat'], train_data['lon'], train_data['alt'], label='Train', color='blue')

    # 검증 데이터 플롯
    ax.plot(val_data['lat'], val_data['lon'], val_data['alt'], label='Validation', color='green')

    # 테스트 데이터 플롯
    ax.plot(test_data['lat'], test_data['lon'], test_data['alt'], label='Test', color='red')

    # 그래프 레이블
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 제목과 범례
    ax.set_title('Drone Trajectory: Train, Validation, and Test')
    ax.legend()

    plt.show()

# %% [markdown]
# ### 7. 데이터로더 생성 함수

# %% [markdown]
# - 학습에 사용할 데이터 로더 생성
# 1. 시퀀스 생성
# 2. Train, Validation, Test 분리
# 3. DataLoader 생성

# %%
# 데이터 로더 생성 함수
def create_dataloaders(tri, batch_size, sequence_length):

  tri = tri[['time', 'lat', 'lon', 'alt']]

  # train, validation, test 분리
  train_data, val_data, test_data = split_train_val_test(tri)

  # 각 데이터셋에서 시퀀스 생성
  X_train, y_train = create_sequences(train_data[['lat', 'lon', 'alt']], look_back=sequence_length)
  X_val, y_val = create_sequences(val_data[['lat', 'lon', 'alt']], look_back=sequence_length)
  X_test, y_test = create_sequences(test_data[['lat', 'lon', 'alt']], look_back=sequence_length)

  X_train = torch.tensor(X_train, dtype=torch.float32)
  y_train = torch.tensor(y_train, dtype=torch.float32)
  X_val = torch.tensor(X_val, dtype=torch.float32)
  y_val = torch.tensor(y_val, dtype=torch.float32)
  X_test = torch.tensor(X_test, dtype=torch.float32)
  y_test = torch.tensor(y_test, dtype=torch.float32)

  train_dataset = TensorDataset(X_train, y_train)
  validation_dataset = TensorDataset(X_val, y_val)
  test_dataset = TensorDataset(X_test, y_test)

  # 데이터 로더 생성
  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  val_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

  return train_loader, val_loader, test_loader

# %% [markdown]
# ## 전처리

# %% [markdown]
# ### 1. 데이터셋 가져오기

# %%
import pandas as pd

# 데이터셋 가져오기 (필요시 저장 경로 수정)
raw = pd.read_csv("/content/OnboardGPS.csv")

# %% [markdown]
# ### 2. 데이터셋 전처리

# %% [markdown]
# - 데이터셋 보간
# - 소수점 절사
# - MinMaxScaling 적용

# %%
tri = raw[['Timpstemp', ' lat', ' lon', ' alt']]

new_x, lat = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lat'])
new_x, lon = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lon'])
new_x, alt = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' alt'])

tri = pd.DataFrame({"time":new_x, "lat":lat, "lon":lon, "alt":alt})

tri = truncation(tri)
scaler, tri = min_max_scaling(tri)
# tri
# Out:
# ['time', 'lat', 'lon', 'alt']

# %% [markdown]
# ## 모델 선언

# %% [markdown]
# ### 1. 모델 클래스 선언
# - Transformer를 사용한 모델 클래스 선언
# - 구조 : Transformer + Positional Encoding + Fully Connected Layer

# %%
import math
import torch

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.0, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        self.pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)

        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        self.pe[:, 0::2] = torch.sin(position * div_term)  # Even indices

        self.pe = self.pe.unsqueeze(0)

    def forward(self, x):
        if self.pe.shape[2] != x.shape[2]:
            raise ValueError(f"Positional encoding dim {self.pe.shape[2]} does not match input dim {x.shape[2]}")

        x = x + self.pe[:, :x.size(1), :].to(x.device)  # Add positional encoding
        return self.dropout(x)

# %%
import torch.nn as nn
import torch

class TransformerModel(nn.Module):
    def __init__(self, input_dim, output_dim=3, d_model=64, nhead=4, num_encoder_layers=2, dim_feedforward=512, dropout=0.0):
        super(TransformerModel, self).__init__()

        self.embedding = nn.Linear(input_dim, d_model)
        self.positional_encoding = PositionalEncoding(d_model=d_model, dropout=dropout)

        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=d_model,
                                       nhead=nhead,
                                       dim_feedforward=dim_feedforward,
                                       dropout=dropout,
                                       batch_first=True  # batch_first 사용
            ),
            num_layers=num_encoder_layers
        )

        self.fc_out = nn.Linear(d_model, output_dim)

    def forward(self, src):
        # embedding과 positional encoding 적용
        src = self.embedding(src)
        src = self.positional_encoding(src)

        # transformer encoder 통과 (batch_first=True이므로 permute 필요 없음)
        output = self.transformer_encoder(src)

        # fully connected layer 통과
        output = self.fc_out(output)

        return output[:, -1, :]  # 마지막 시퀀스의 출력만 반환

# %% [markdown]
# ## 학습

# %% [markdown]
# ### 1. 하이퍼파라미터 불러오기

# %%
import json

# 저장된 하이퍼파라미터 불러오기
with open("best_hyperparameters.json", "r") as f:
    best_params = json.load(f)

print("Loaded best hyperparameters:", best_params)
# Out:
# Loaded best hyperparameters: {'nhead': 5, 'd_model': 165, 'num_encoder_layers': 1, 'dim_feedforward': 384, 'learning_rate': 0.0007429501823161562, 'batch_size': 19}

# %% [markdown]
# ### 2. 최적의 파라미터로 모델 학습

# %%
sequence_length = 30
num_epochs = 632

# %%
# 최적의 모델 학습
# best_params = study.best_params

train_loader, val_loader, test_loader = create_dataloaders(tri, best_params['batch_size'], sequence_length)

best_model = TransformerModel(
    input_dim=3,
    d_model=best_params['d_model'],
    nhead=best_params['nhead'],
    num_encoder_layers=best_params['num_encoder_layers'],
    dim_feedforward=best_params['dim_feedforward']
)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
best_model = best_model.to(device)

optimizer = torch.optim.Adam(best_model.parameters(), lr=best_params['learning_rate'])
criterion = torch.nn.MSELoss()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
import time
import torch

# 학습 및 검증 손실을 기록할 리스트
train_losses = []
val_losses = []

best_model.train()
total_train_time = 0  # 총 학습 시간 기록 변수

for epoch in range(num_epochs):  # 최종 모델 학습
    best_model.train()
    train_loss = 0.0
    epoch_start_time = time.time()  # 에포크 시작 시간 기록
    for batch_x, batch_y in train_loader:
        batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = best_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    epoch_end_time = time.time()  # 에포크 종료 시간 기록
    epoch_duration = epoch_end_time - epoch_start_time  # 한 에포크의 학습 시간
    total_train_time += epoch_duration  # 총 학습 시간에 추가

    # Validation set에서 성능 측정
    best_model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch_x, batch_y in val_loader:
            batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
            batch_y = batch_y.to(device)
            output = best_model(batch_x)
            loss = criterion(output, batch_y)
            val_loss += loss.item()

    # 평균 손실 계산 및 저장
    train_losses.append(train_loss / len(train_loader))
    val_losses.append(val_loss / len(val_loader))

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

    # 모델 저장
    if (epoch + 1) % 100 == 0 or epoch + 1 == 632:

      # Model Save
      model_save_path = f"/content/output_model/best_model_epoch_{epoch+1}.pth"
      torch.save({
        'model_state_dict': best_model.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses
      }, model_save_path)
      print(f"Model saved: {model_save_path}")

    print(f"Epoch {epoch+1}/{num_epochs} completed in {epoch_duration:.2f} seconds.")

print(f"Total training time: {total_train_time:.2f} seconds.")
# Out:
# Epoch [1/632], Train Loss: 1.6123, Val Loss: 0.0221
# Epoch 1/632 completed in 3.14 seconds.
# Epoch [2/632], Train Loss: 0.0142, Val Loss: 0.0149
# Epoch 2/632 completed in 1.34 seconds.
# Epoch [3/632], Train Loss: 0.0140, Val Loss: 0.0138
# Epoch 3/632 completed in 1.29 seconds.
# Epoch [4/632], Train Loss: 0.0148, Val Loss: 0.0098
# Epoch 4/632 completed in 0.63 seconds.
# Epoch [5/632], Train Loss: 0.0157, Val Loss: 0.0137
# Epoch 5/632 completed in 0.62 seconds.
# Epoch [6/632], Train Loss: 0.0207, Val Loss: 0.0091
# Epoch 6/632 completed in 0.63 seconds.
# Epoch [7/632], Train Loss: 0.0171, Val Loss: 0.0040
# Epoch 7/632 completed in 0.63 seconds.
# Epoch [8/632], Train Loss: 0.0193, Val Loss: 0.0065
# Epoch 8/632 completed in 0.62 seconds.
# Epoch [9/632], Train Loss: 0.0203, Val Loss: 0.0095
# Epoch 9/632 completed in 0.64 seconds.
# Epoch [10/632], Train Loss: 0.0178, Val Loss: 0.0056
# Epoch 10/632 completed in 0.64 seconds.
# Epoch [11/632], Train Loss: 0.0203, Val Loss: 0.0098
# Epoch 11/632 completed in 0.62 seconds.
# Epoch [12/632], Train Loss: 0.0195, Val Loss: 0.0056
# Epoch 12/632 completed in 0.63 seconds.
# Epoch [13/632], Train Loss: 0.0265, Val Loss: 0.0045
# Epoch 13/632 completed in 0.63 seconds.
# Epoch [14/632], Train Loss: 0.0113, Val Loss: 0.0082
# Epoch 14/632 completed in 0.72 seconds.
# Epoch [15/632], Train Loss: 0.0279, Val Loss: 0.0065
# Epoch 15/632 completed in 0.79 seconds.
# Epoch [16/632], Train Loss: 0.0122, Val Loss: 0.0073
# Epoch 16/632 completed in 0.90 seconds.
# Epoch [17/632], Train Loss: 0.0208, Val Loss: 0.0039
# Epoch 17/632 completed in 0.64 seconds.
# Epoch [18/632], Train Loss: 0.0096, Val Loss: 0.0059
# Epoch 18/632 completed in 0.62 seconds.
# Epoch [19/632], Train Loss: 0.0192, Val Loss: 0.0051
# Epoch 19/632 completed in 0.62 seconds.
# Epoch [20/632], Train Loss: 0.0129, Val Loss: 0.0057
# Epoch 20/632 completed in 0.63 seconds.
# Epoch [21/632], Train Loss: 0.0234, Val Loss: 0.0086
# Epoch 21/632 completed in 0.63 seconds.
# Epoch [22/632], Train Loss: 0.0242, Val Loss: 0.0055
# Epoch 22/632 completed in 0.62 seconds.
# Epoch [23/632], Train Loss: 0.0140, Val Loss: 0.0050
# Epoch 23/632 completed in 0.63 seconds.
# Epoch [24/632], Train Loss: 0.0098, Val Loss: 0.0021
# Epoch 24/632 completed in 0.63 seconds.
# Epoch [25/632], Train Loss: 0.0132, Val Loss: 0.0148
# Epoch 25/632 completed in 0.64 seconds.
# Epoch [26/632], Train Loss: 0.0416, Val Loss: 0.0073
# Epoch 26/632 completed in 0.63 seconds.
# Epoch [27/632], Train Loss: 0.0081, Val Loss: 0.0023
# Epoch 27/632 completed in 0.63 seconds.
# Epoch [28/632], Train Loss: 0.0311, Val Loss: 0.0028
# Epoch 28/632 completed in 0.62 seconds.
# Epoch [29/632], Train Loss: 0.0073, Val Loss: 0.0035
# Epoch 29/632 completed in 0.63 seconds.
# Epoch [30/632], Train Loss: 0.0084, Val Loss: 0.0020
# Epoch 30/632 completed in 0.63 seconds.
# Epoch [31/632], Train Loss: 0.0106, Val Loss: 0.0097
# Epoch 31/632 completed in 0.75 seconds.
# Epoch [32/632], Train Loss: 0.0069, Val Loss: 0.0062
# Epoch 32/632 completed in 0.80 seconds.
# Epoch [33/632], Train Loss: 0.0101, Val Loss: 0.0022
# Epoch 33/632 completed in 0.90 seconds.
# Epoch [34/632], Train Loss: 0.0097, Val Loss: 0.0027
# Epoch 34/632 completed in 0.64 seconds.
# Epoch [35/632], Train Loss: 0.0106, Val Loss: 0.0089
# Epoch 35/632 completed in 0.63 seconds.
# Epoch [36/632], Train Loss: 0.0108, Val Loss: 0.0019
# Epoch 36/632 completed in 0.62 seconds.
# Epoch [37/632], Train Loss: 0.0085, Val Loss: 0.0023
# Epoch 37/632 completed in 0.63 seconds.
# Epoch [38/632], Train Loss: 0.0191, Val Loss: 0.1156
# Epoch 38/632 completed in 0.64 seconds.
# Epoch [39/632], Train Loss: 0.0115, Val Loss: 0.0050
# Epoch 39/632 completed in 0.62 seconds.
# Epoch [40/632], Train Loss: 0.0075, Val Loss: 0.0023
# Epoch 40/632 completed in 0.62 seconds.
# Epoch [41/632], Train Loss: 0.0079, Val Loss: 0.0023
# Epoch 41/632 completed in 0.64 seconds.
# Epoch [42/632], Train Loss: 0.0131, Val Loss: 0.0048
# Epoch 42/632 completed in 0.64 seconds.
# Epoch [43/632], Train Loss: 0.0080, Val Loss: 0.0016
# Epoch 43/632 completed in 0.63 seconds.
# Epoch [44/632], Train Loss: 0.0059, Val Loss: 0.0020
# Epoch 44/632 completed in 0.63 seconds.
# Epoch [45/632], Train Loss: 0.0129, Val Loss: 0.0093
# Epoch 45/632 completed in 0.62 seconds.
# Epoch [46/632], Train Loss: 0.0100, Val Loss: 0.0050
# Epoch 46/632 completed in 0.66 seconds.
# Epoch [47/632], Train Loss: 0.0091, Val Loss: 0.0048
# Epoch 47/632 completed in 0.63 seconds.
# Epoch [48/632], Train Loss: 0.0070, Val Loss: 0.0029
# Epoch 48/632 completed in 0.77 seconds.
# Epoch [49/632], Train Loss: 0.0094, Val Loss: 0.0069
# Epoch 49/632 completed in 0.80 seconds.
# Epoch [50/632], Train Loss: 0.0106, Val Loss: 0.0071
# Epoch 50/632 completed in 0.89 seconds.
# Epoch [51/632], Train Loss: 0.0075, Val Loss: 0.0062
# Epoch 51/632 completed in 0.62 seconds.
# Epoch [52/632], Train Loss: 0.0078, Val Loss: 0.0049
# Epoch 52/632 completed in 0.63 seconds.
# Epoch [53/632], Train Loss: 0.0110, Val Loss: 0.0039
# Epoch 53/632 completed in 0.63 seconds.
# Epoch [54/632], Train Loss: 0.0070, Val Loss: 0.0025
# Epoch 54/632 completed in 0.62 seconds.
# Epoch [55/632], Train Loss: 0.0113, Val Loss: 0.0080
# Epoch 55/632 completed in 0.65 seconds.
# Epoch [56/632], Train Loss: 0.0058, Val Loss: 0.0017
# Epoch 56/632 completed in 0.63 seconds.
# Epoch [57/632], Train Loss: 0.0046, Val Loss: 0.0038
# Epoch 57/632 completed in 0.62 seconds.
# Epoch [58/632], Train Loss: 0.0047, Val Loss: 0.0054
# Epoch 58/632 completed in 0.64 seconds.
# Epoch [59/632], Train Loss: 0.0075, Val Loss: 0.0036
# Epoch 59/632 completed in 0.63 seconds.
# Epoch [60/632], Train Loss: 0.0087, Val Loss: 0.0054
# Epoch 60/632 completed in 0.62 seconds.
# Epoch [61/632], Train Loss: 0.0074, Val Loss: 0.0041
# Epoch 61/632 completed in 0.62 seconds.
# Epoch [62/632], Train Loss: 0.2780, Val Loss: 0.0532
# Epoch 62/632 completed in 0.63 seconds.
# Epoch [63/632], Train Loss: 0.0091, Val Loss: 0.0057
# Epoch 63/632 completed in 0.62 seconds.
# Epoch [64/632], Train Loss: 0.0067, Val Loss: 0.0044
# Epoch 64/632 completed in 0.63 seconds.
# Epoch [65/632], Train Loss: 0.0048, Val Loss: 0.0049
# Epoch 65/632 completed in 0.76 seconds.
# Epoch [66/632], Train Loss: 0.0039, Val Loss: 0.0023
# Epoch 66/632 completed in 0.80 seconds.
# Epoch [67/632], Train Loss: 0.0047, Val Loss: 0.0032
# Epoch 67/632 completed in 0.86 seconds.
# Epoch [68/632], Train Loss: 0.0042, Val Loss: 0.0024
# Epoch 68/632 completed in 0.68 seconds.
# Epoch [69/632], Train Loss: 0.0046, Val Loss: 0.0044
# Epoch 69/632 completed in 0.63 seconds.
# Epoch [70/632], Train Loss: 0.0044, Val Loss: 0.0027
# Epoch 70/632 completed in 0.62 seconds.
# Epoch [71/632], Train Loss: 0.0049, Val Loss: 0.0029
# Epoch 71/632 completed in 0.62 seconds.
# Epoch [72/632], Train Loss: 0.0053, Val Loss: 0.0025
# Epoch 72/632 completed in 0.62 seconds.
# Epoch [73/632], Train Loss: 0.0044, Val Loss: 0.0026
# Epoch 73/632 completed in 0.65 seconds.
# Epoch [74/632], Train Loss: 0.0055, Val Loss: 0.0018
# Epoch 74/632 completed in 0.63 seconds.
# Epoch [75/632], Train Loss: 0.0040, Val Loss: 0.0081
# Epoch 75/632 completed in 0.63 seconds.
# Epoch [76/632], Train Loss: 0.0040, Val Loss: 0.0024
# Epoch 76/632 completed in 0.63 seconds.
# Epoch [77/632], Train Loss: 0.0051, Val Loss: 0.0025
# Epoch 77/632 completed in 0.62 seconds.
# Epoch [78/632], Train Loss: 0.0065, Val Loss: 0.0041
# Epoch 78/632 completed in 0.63 seconds.
# Epoch [79/632], Train Loss: 0.0055, Val Loss: 0.0035
# Epoch 79/632 completed in 0.63 seconds.
# Epoch [80/632], Train Loss: 0.0056, Val Loss: 0.0040
# Epoch 80/632 completed in 0.62 seconds.
# Epoch [81/632], Train Loss: 0.0060, Val Loss: 0.0027
# Epoch 81/632 completed in 0.63 seconds.
# Epoch [82/632], Train Loss: 0.0106, Val Loss: 0.0031
# Epoch 82/632 completed in 0.72 seconds.
# Epoch [83/632], Train Loss: 0.0055, Val Loss: 0.0037
# Epoch 83/632 completed in 0.78 seconds.
# Epoch [84/632], Train Loss: 0.0056, Val Loss: 0.0024
# Epoch 84/632 completed in 0.86 seconds.
# Epoch [85/632], Train Loss: 0.0058, Val Loss: 0.0071
# Epoch 85/632 completed in 0.67 seconds.
# Epoch [86/632], Train Loss: 0.0069, Val Loss: 0.0079
# Epoch 86/632 completed in 0.63 seconds.
# Epoch [87/632], Train Loss: 0.0062, Val Loss: 0.0064
# Epoch 87/632 completed in 0.61 seconds.
# Epoch [88/632], Train Loss: 0.0066, Val Loss: 0.0031
# Epoch 88/632 completed in 0.61 seconds.
# Epoch [89/632], Train Loss: 0.0075, Val Loss: 0.0030
# Epoch 89/632 completed in 0.62 seconds.
# Epoch [90/632], Train Loss: 0.0059, Val Loss: 0.0081
# Epoch 90/632 completed in 0.64 seconds.
# Epoch [91/632], Train Loss: 0.0076, Val Loss: 0.0033
# Epoch 91/632 completed in 0.62 seconds.
# Epoch [92/632], Train Loss: 0.0072, Val Loss: 0.0029
# Epoch 92/632 completed in 1.01 seconds.
# Epoch [93/632], Train Loss: 0.0071, Val Loss: 0.0048
# Epoch 93/632 completed in 1.02 seconds.
# Epoch [94/632], Train Loss: 0.0108, Val Loss: 0.0028
# Epoch 94/632 completed in 0.98 seconds.
# Epoch [95/632], Train Loss: 0.0108, Val Loss: 0.0067
# Epoch 95/632 completed in 0.62 seconds.
# Epoch [96/632], Train Loss: 0.0058, Val Loss: 0.0019
# Epoch 96/632 completed in 0.63 seconds.
# Epoch [97/632], Train Loss: 0.0079, Val Loss: 0.0039
# Epoch 97/632 completed in 0.63 seconds.
# Epoch [98/632], Train Loss: 0.0057, Val Loss: 0.0036
# Epoch 98/632 completed in 0.79 seconds.
# Epoch [99/632], Train Loss: 0.0053, Val Loss: 0.0027
# Epoch 99/632 completed in 0.84 seconds.
# Epoch [100/632], Train Loss: 0.0088, Val Loss: 0.0080
# Model saved: /content/output_model/best_model_epoch_100.pth
# Epoch 100/632 completed in 0.85 seconds.
# Epoch [101/632], Train Loss: 0.0085, Val Loss: 0.0106
# Epoch 101/632 completed in 0.63 seconds.
# Epoch [102/632], Train Loss: 0.0075, Val Loss: 0.0051
# Epoch 102/632 completed in 0.62 seconds.
# Epoch [103/632], Train Loss: 0.0061, Val Loss: 0.0024
# Epoch 103/632 completed in 0.62 seconds.
# Epoch [104/632], Train Loss: 0.0073, Val Loss: 0.0013
# Epoch 104/632 completed in 0.62 seconds.
# Epoch [105/632], Train Loss: 0.0089, Val Loss: 0.0041
# Epoch 105/632 completed in 0.62 seconds.
# Epoch [106/632], Train Loss: 0.0063, Val Loss: 0.0060
# Epoch 106/632 completed in 0.62 seconds.
# Epoch [107/632], Train Loss: 0.0057, Val Loss: 0.0015
# Epoch 107/632 completed in 0.62 seconds.
# Epoch [108/632], Train Loss: 0.0058, Val Loss: 0.0042
# Epoch 108/632 completed in 0.62 seconds.
# Epoch [109/632], Train Loss: 0.0068, Val Loss: 0.0025
# Epoch 109/632 completed in 0.62 seconds.
# Epoch [110/632], Train Loss: 0.0083, Val Loss: 0.0022
# Epoch 110/632 completed in 0.62 seconds.
# Epoch [111/632], Train Loss: 0.3650, Val Loss: 0.0028
# Epoch 111/632 completed in 0.63 seconds.
# Epoch [112/632], Train Loss: 0.0059, Val Loss: 0.0055
# Epoch 112/632 completed in 0.62 seconds.
# Epoch [113/632], Train Loss: 0.0063, Val Loss: 0.0015
# Epoch 113/632 completed in 0.65 seconds.
# Epoch [114/632], Train Loss: 0.0065, Val Loss: 0.0035
# Epoch 114/632 completed in 0.62 seconds.
# Epoch [115/632], Train Loss: 0.0046, Val Loss: 0.0014
# Epoch 115/632 completed in 0.77 seconds.
# Epoch [116/632], Train Loss: 0.0038, Val Loss: 0.0051
# Epoch 116/632 completed in 0.80 seconds.
# Epoch [117/632], Train Loss: 0.0051, Val Loss: 0.0034
# Epoch 117/632 completed in 0.90 seconds.
# Epoch [118/632], Train Loss: 0.0040, Val Loss: 0.0032
# Epoch 118/632 completed in 0.63 seconds.
# Epoch [119/632], Train Loss: 0.0043, Val Loss: 0.0050
# Epoch 119/632 completed in 0.63 seconds.
# Epoch [120/632], Train Loss: 0.0043, Val Loss: 0.0017
# Epoch 120/632 completed in 0.62 seconds.
# Epoch [121/632], Train Loss: 0.0045, Val Loss: 0.0021
# Epoch 121/632 completed in 0.63 seconds.
# Epoch [122/632], Train Loss: 0.0070, Val Loss: 0.0061
# Epoch 122/632 completed in 0.62 seconds.
# Epoch [123/632], Train Loss: 0.0067, Val Loss: 0.0018
# Epoch 123/632 completed in 0.62 seconds.
# Epoch [124/632], Train Loss: 0.0040, Val Loss: 0.0022
# Epoch 124/632 completed in 0.63 seconds.
# Epoch [125/632], Train Loss: 0.0070, Val Loss: 0.0032
# Epoch 125/632 completed in 0.62 seconds.
# Epoch [126/632], Train Loss: 0.0066, Val Loss: 0.0012
# Epoch 126/632 completed in 0.64 seconds.
# Epoch [127/632], Train Loss: 0.0046, Val Loss: 0.0032
# Epoch 127/632 completed in 0.63 seconds.
# Epoch [128/632], Train Loss: 0.0058, Val Loss: 0.0045
# Epoch 128/632 completed in 0.62 seconds.
# Epoch [129/632], Train Loss: 0.0062, Val Loss: 0.0026
# Epoch 129/632 completed in 0.61 seconds.
# Epoch [130/632], Train Loss: 0.0055, Val Loss: 0.0026
# Epoch 130/632 completed in 0.62 seconds.
# Epoch [131/632], Train Loss: 0.0065, Val Loss: 0.0022
# Epoch 131/632 completed in 0.62 seconds.
# Epoch [132/632], Train Loss: 0.0054, Val Loss: 0.0014
# Epoch 132/632 completed in 0.77 seconds.
# Epoch [133/632], Train Loss: 0.0069, Val Loss: 0.0021
# Epoch 133/632 completed in 0.80 seconds.
# Epoch [134/632], Train Loss: 0.0067, Val Loss: 0.0017
# Epoch 134/632 completed in 0.87 seconds.
# Epoch [135/632], Train Loss: 0.0051, Val Loss: 0.0026
# Epoch 135/632 completed in 0.64 seconds.
# Epoch [136/632], Train Loss: 0.0043, Val Loss: 0.0021
# Epoch 136/632 completed in 0.63 seconds.
# Epoch [137/632], Train Loss: 0.0048, Val Loss: 0.0036
# Epoch 137/632 completed in 0.62 seconds.
# Epoch [138/632], Train Loss: 0.0060, Val Loss: 0.0042
# Epoch 138/632 completed in 0.64 seconds.
# Epoch [139/632], Train Loss: 0.0055, Val Loss: 0.0022
# Epoch 139/632 completed in 0.63 seconds.
# Epoch [140/632], Train Loss: 0.0061, Val Loss: 0.0046
# Epoch 140/632 completed in 0.62 seconds.
# Epoch [141/632], Train Loss: 0.0071, Val Loss: 0.0049
# Epoch 141/632 completed in 0.63 seconds.
# Epoch [142/632], Train Loss: 0.0045, Val Loss: 0.0038
# Epoch 142/632 completed in 0.63 seconds.
# Epoch [143/632], Train Loss: 0.0097, Val Loss: 0.0022
# Epoch 143/632 completed in 0.62 seconds.
# Epoch [144/632], Train Loss: 0.0040, Val Loss: 0.0026
# Epoch 144/632 completed in 0.62 seconds.
# Epoch [145/632], Train Loss: 0.0054, Val Loss: 0.0022
# Epoch 145/632 completed in 0.63 seconds.
# Epoch [146/632], Train Loss: 0.0075, Val Loss: 0.0057
# Epoch 146/632 completed in 0.61 seconds.
# Epoch [147/632], Train Loss: 0.0048, Val Loss: 0.0028
# Epoch 147/632 completed in 0.62 seconds.
# Epoch [148/632], Train Loss: 0.0060, Val Loss: 0.0031
# Epoch 148/632 completed in 0.63 seconds.
# Epoch [149/632], Train Loss: 0.0054, Val Loss: 0.0200
# Epoch 149/632 completed in 0.80 seconds.
# Epoch [150/632], Train Loss: 0.0113, Val Loss: 0.0032
# Epoch 150/632 completed in 0.81 seconds.
# Epoch [151/632], Train Loss: 0.0052, Val Loss: 0.0063
# Epoch 151/632 completed in 0.85 seconds.
# Epoch [152/632], Train Loss: 0.0047, Val Loss: 0.0043
# Epoch 152/632 completed in 0.62 seconds.
# Epoch [153/632], Train Loss: 0.0056, Val Loss: 0.0034
# Epoch 153/632 completed in 0.62 seconds.
# Epoch [154/632], Train Loss: 0.0049, Val Loss: 0.0022
# Epoch 154/632 completed in 0.64 seconds.
# Epoch [155/632], Train Loss: 0.0074, Val Loss: 0.0050
# Epoch 155/632 completed in 0.63 seconds.
# Epoch [156/632], Train Loss: 0.0064, Val Loss: 0.0025
# Epoch 156/632 completed in 0.63 seconds.
# Epoch [157/632], Train Loss: 0.0048, Val Loss: 0.0014
# Epoch 157/632 completed in 0.62 seconds.
# Epoch [158/632], Train Loss: 0.0060, Val Loss: 0.0018
# Epoch 158/632 completed in 0.63 seconds.
# Epoch [159/632], Train Loss: 0.1124, Val Loss: 0.0038
# Epoch 159/632 completed in 0.62 seconds.
# Epoch [160/632], Train Loss: 0.0035, Val Loss: 0.0015
# Epoch 160/632 completed in 0.62 seconds.
# Epoch [161/632], Train Loss: 0.0036, Val Loss: 0.0012
# Epoch 161/632 completed in 0.63 seconds.
# Epoch [162/632], Train Loss: 0.0032, Val Loss: 0.0013
# Epoch 162/632 completed in 0.62 seconds.
# Epoch [163/632], Train Loss: 0.0035, Val Loss: 0.0015
# Epoch 163/632 completed in 0.61 seconds.
# Epoch [164/632], Train Loss: 0.0035, Val Loss: 0.0020
# Epoch 164/632 completed in 0.62 seconds.
# Epoch [165/632], Train Loss: 0.0032, Val Loss: 0.0014
# Epoch 165/632 completed in 0.62 seconds.
# Epoch [166/632], Train Loss: 0.0034, Val Loss: 0.0018
# Epoch 166/632 completed in 0.75 seconds.
# Epoch [167/632], Train Loss: 0.0039, Val Loss: 0.0014
# Epoch 167/632 completed in 0.78 seconds.
# Epoch [168/632], Train Loss: 0.0033, Val Loss: 0.0011
# Epoch 168/632 completed in 0.85 seconds.
# Epoch [169/632], Train Loss: 0.0039, Val Loss: 0.0011
# Epoch 169/632 completed in 0.72 seconds.
# Epoch [170/632], Train Loss: 0.0041, Val Loss: 0.0013
# Epoch 170/632 completed in 0.63 seconds.
# Epoch [171/632], Train Loss: 0.0044, Val Loss: 0.0028
# Epoch 171/632 completed in 0.62 seconds.
# Epoch [172/632], Train Loss: 0.0047, Val Loss: 0.0016
# Epoch 172/632 completed in 0.63 seconds.
# Epoch [173/632], Train Loss: 0.0048, Val Loss: 0.0012
# Epoch 173/632 completed in 0.63 seconds.
# Epoch [174/632], Train Loss: 0.0067, Val Loss: 0.0035
# Epoch 174/632 completed in 0.63 seconds.
# Epoch [175/632], Train Loss: 0.0055, Val Loss: 0.0016
# Epoch 175/632 completed in 0.62 seconds.
# Epoch [176/632], Train Loss: 0.0063, Val Loss: 0.0027
# Epoch 176/632 completed in 0.63 seconds.
# Epoch [177/632], Train Loss: 0.0035, Val Loss: 0.0017
# Epoch 177/632 completed in 0.62 seconds.
# Epoch [178/632], Train Loss: 0.0067, Val Loss: 0.0027
# Epoch 178/632 completed in 0.62 seconds.
# Epoch [179/632], Train Loss: 0.0052, Val Loss: 0.0026
# Epoch 179/632 completed in 0.64 seconds.
# Epoch [180/632], Train Loss: 0.0049, Val Loss: 0.0021
# Epoch 180/632 completed in 0.62 seconds.
# Epoch [181/632], Train Loss: 0.0052, Val Loss: 0.0022
# Epoch 181/632 completed in 0.62 seconds.
# Epoch [182/632], Train Loss: 0.0053, Val Loss: 0.0019
# Epoch 182/632 completed in 0.63 seconds.
# Epoch [183/632], Train Loss: 0.0056, Val Loss: 0.0041
# Epoch 183/632 completed in 0.70 seconds.
# Epoch [184/632], Train Loss: 0.0069, Val Loss: 0.0055
# Epoch 184/632 completed in 0.76 seconds.
# Epoch [185/632], Train Loss: 0.0051, Val Loss: 0.0019
# Epoch 185/632 completed in 0.84 seconds.
# Epoch [186/632], Train Loss: 0.0043, Val Loss: 0.0012
# Epoch 186/632 completed in 0.73 seconds.
# Epoch [187/632], Train Loss: 0.0048, Val Loss: 0.0011
# Epoch 187/632 completed in 0.63 seconds.
# Epoch [188/632], Train Loss: 0.0062, Val Loss: 0.0019
# Epoch 188/632 completed in 0.63 seconds.
# Epoch [189/632], Train Loss: 0.0062, Val Loss: 0.0039
# Epoch 189/632 completed in 0.61 seconds.
# Epoch [190/632], Train Loss: 0.0071, Val Loss: 0.0019
# Epoch 190/632 completed in 0.62 seconds.
# Epoch [191/632], Train Loss: 0.0042, Val Loss: 0.0022
# Epoch 191/632 completed in 0.63 seconds.
# Epoch [192/632], Train Loss: 0.0043, Val Loss: 0.0023
# Epoch 192/632 completed in 0.62 seconds.
# Epoch [193/632], Train Loss: 0.0075, Val Loss: 0.0052
# Epoch 193/632 completed in 0.63 seconds.
# Epoch [194/632], Train Loss: 0.1645, Val Loss: 0.0017
# Epoch 194/632 completed in 0.63 seconds.
# Epoch [195/632], Train Loss: 0.0048, Val Loss: 0.0027
# Epoch 195/632 completed in 0.64 seconds.
# Epoch [196/632], Train Loss: 0.0045, Val Loss: 0.0021
# Epoch 196/632 completed in 0.63 seconds.
# Epoch [197/632], Train Loss: 0.0045, Val Loss: 0.0016
# Epoch 197/632 completed in 0.63 seconds.
# Epoch [198/632], Train Loss: 0.0032, Val Loss: 0.0013
# Epoch 198/632 completed in 0.62 seconds.
# Epoch [199/632], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 199/632 completed in 0.63 seconds.
# Epoch [200/632], Train Loss: 0.0033, Val Loss: 0.0024
# Model saved: /content/output_model/best_model_epoch_200.pth
# Epoch 200/632 completed in 0.68 seconds.
# Epoch [201/632], Train Loss: 0.0033, Val Loss: 0.0012
# Epoch 201/632 completed in 0.78 seconds.
# Epoch [202/632], Train Loss: 0.0048, Val Loss: 0.0029
# Epoch 202/632 completed in 0.86 seconds.
# Epoch [203/632], Train Loss: 0.0037, Val Loss: 0.0016
# Epoch 203/632 completed in 0.73 seconds.
# Epoch [204/632], Train Loss: 0.0048, Val Loss: 0.0084
# Epoch 204/632 completed in 0.64 seconds.
# Epoch [205/632], Train Loss: 0.0047, Val Loss: 0.0015
# Epoch 205/632 completed in 0.63 seconds.
# Epoch [206/632], Train Loss: 0.0037, Val Loss: 0.0019
# Epoch 206/632 completed in 0.63 seconds.
# Epoch [207/632], Train Loss: 0.0035, Val Loss: 0.0024
# Epoch 207/632 completed in 0.64 seconds.
# Epoch [208/632], Train Loss: 0.0047, Val Loss: 0.0027
# Epoch 208/632 completed in 0.65 seconds.
# Epoch [209/632], Train Loss: 0.0035, Val Loss: 0.0016
# Epoch 209/632 completed in 0.62 seconds.
# Epoch [210/632], Train Loss: 0.0040, Val Loss: 0.0065
# Epoch 210/632 completed in 0.63 seconds.
# Epoch [211/632], Train Loss: 0.0040, Val Loss: 0.0015
# Epoch 211/632 completed in 0.63 seconds.
# Epoch [212/632], Train Loss: 0.0044, Val Loss: 0.0034
# Epoch 212/632 completed in 0.63 seconds.
# Epoch [213/632], Train Loss: 0.0060, Val Loss: 0.0024
# Epoch 213/632 completed in 0.64 seconds.
# Epoch [214/632], Train Loss: 0.0048, Val Loss: 0.0024
# Epoch 214/632 completed in 0.63 seconds.
# Epoch [215/632], Train Loss: 0.0048, Val Loss: 0.0011
# Epoch 215/632 completed in 0.62 seconds.
# Epoch [216/632], Train Loss: 0.0037, Val Loss: 0.0024
# Epoch 216/632 completed in 0.63 seconds.
# Epoch [217/632], Train Loss: 0.0049, Val Loss: 0.0024
# Epoch 217/632 completed in 0.72 seconds.
# Epoch [218/632], Train Loss: 0.0042, Val Loss: 0.0039
# Epoch 218/632 completed in 0.80 seconds.
# Epoch [219/632], Train Loss: 0.0036, Val Loss: 0.0020
# Epoch 219/632 completed in 0.88 seconds.
# Epoch [220/632], Train Loss: 0.0040, Val Loss: 0.0017
# Epoch 220/632 completed in 0.76 seconds.
# Epoch [221/632], Train Loss: 0.0054, Val Loss: 0.0032
# Epoch 221/632 completed in 0.64 seconds.
# Epoch [222/632], Train Loss: 0.0048, Val Loss: 0.0043
# Epoch 222/632 completed in 0.64 seconds.
# Epoch [223/632], Train Loss: 0.0057, Val Loss: 0.0039
# Epoch 223/632 completed in 0.64 seconds.
# Epoch [224/632], Train Loss: 0.0040, Val Loss: 0.0021
# Epoch 224/632 completed in 0.64 seconds.
# Epoch [225/632], Train Loss: 0.0037, Val Loss: 0.0016
# Epoch 225/632 completed in 0.67 seconds.
# Epoch [226/632], Train Loss: 0.0035, Val Loss: 0.0029
# Epoch 226/632 completed in 0.64 seconds.
# Epoch [227/632], Train Loss: 0.0052, Val Loss: 0.0022
# Epoch 227/632 completed in 0.65 seconds.
# Epoch [228/632], Train Loss: 0.0048, Val Loss: 0.0012
# Epoch 228/632 completed in 0.64 seconds.
# Epoch [229/632], Train Loss: 0.0046, Val Loss: 0.0048
# Epoch 229/632 completed in 0.64 seconds.
# Epoch [230/632], Train Loss: 0.0052, Val Loss: 0.0023
# Epoch 230/632 completed in 0.62 seconds.
# Epoch [231/632], Train Loss: 0.0044, Val Loss: 0.0025
# Epoch 231/632 completed in 0.63 seconds.
# Epoch [232/632], Train Loss: 0.0043, Val Loss: 0.0048
# Epoch 232/632 completed in 0.69 seconds.
# Epoch [233/632], Train Loss: 0.0056, Val Loss: 0.0017
# Epoch 233/632 completed in 0.64 seconds.
# Epoch [234/632], Train Loss: 0.0046, Val Loss: 0.0014
# Epoch 234/632 completed in 0.79 seconds.
# Epoch [235/632], Train Loss: 0.0037, Val Loss: 0.0018
# Epoch 235/632 completed in 0.80 seconds.
# Epoch [236/632], Train Loss: 0.0059, Val Loss: 0.0011
# Epoch 236/632 completed in 0.88 seconds.
# Epoch [237/632], Train Loss: 0.0038, Val Loss: 0.0042
# Epoch 237/632 completed in 0.72 seconds.
# Epoch [238/632], Train Loss: 0.0039, Val Loss: 0.0017
# Epoch 238/632 completed in 0.63 seconds.
# Epoch [239/632], Train Loss: 0.0043, Val Loss: 0.0021
# Epoch 239/632 completed in 0.64 seconds.
# Epoch [240/632], Train Loss: 0.0043, Val Loss: 0.0028
# Epoch 240/632 completed in 0.63 seconds.
# Epoch [241/632], Train Loss: 0.0043, Val Loss: 0.0030
# Epoch 241/632 completed in 0.63 seconds.
# Epoch [242/632], Train Loss: 0.0054, Val Loss: 0.0030
# Epoch 242/632 completed in 0.73 seconds.
# Epoch [243/632], Train Loss: 0.0071, Val Loss: 0.0022
# Epoch 243/632 completed in 0.77 seconds.
# Epoch [244/632], Train Loss: 0.0038, Val Loss: 0.0014
# Epoch 244/632 completed in 0.86 seconds.
# Epoch [245/632], Train Loss: 0.0035, Val Loss: 0.0022
# Epoch 245/632 completed in 0.76 seconds.
# Epoch [246/632], Train Loss: 0.0048, Val Loss: 0.0024
# Epoch 246/632 completed in 0.63 seconds.
# Epoch [247/632], Train Loss: 0.0045, Val Loss: 0.0016
# Epoch 247/632 completed in 0.61 seconds.
# Epoch [248/632], Train Loss: 0.0044, Val Loss: 0.0036
# Epoch 248/632 completed in 0.63 seconds.
# Epoch [249/632], Train Loss: 0.0946, Val Loss: 0.0099
# Epoch 249/632 completed in 0.63 seconds.
# Epoch [250/632], Train Loss: 0.0132, Val Loss: 0.0025
# Epoch 250/632 completed in 0.71 seconds.
# Epoch [251/632], Train Loss: 0.0030, Val Loss: 0.0028
# Epoch 251/632 completed in 0.76 seconds.
# Epoch [252/632], Train Loss: 0.0032, Val Loss: 0.0064
# Epoch 252/632 completed in 0.86 seconds.
# Epoch [253/632], Train Loss: 0.0030, Val Loss: 0.0020
# Epoch 253/632 completed in 0.74 seconds.
# Epoch [254/632], Train Loss: 0.0031, Val Loss: 0.0013
# Epoch 254/632 completed in 0.62 seconds.
# Epoch [255/632], Train Loss: 0.0028, Val Loss: 0.0014
# Epoch 255/632 completed in 0.62 seconds.
# Epoch [256/632], Train Loss: 0.0029, Val Loss: 0.0017
# Epoch 256/632 completed in 0.63 seconds.
# Epoch [257/632], Train Loss: 0.0034, Val Loss: 0.0044
# Epoch 257/632 completed in 0.63 seconds.
# Epoch [258/632], Train Loss: 0.0030, Val Loss: 0.0018
# Epoch 258/632 completed in 0.62 seconds.
# Epoch [259/632], Train Loss: 0.0035, Val Loss: 0.0031
# Epoch 259/632 completed in 0.64 seconds.
# Epoch [260/632], Train Loss: 0.0032, Val Loss: 0.0022
# Epoch 260/632 completed in 0.63 seconds.
# Epoch [261/632], Train Loss: 0.0037, Val Loss: 0.0013
# Epoch 261/632 completed in 0.63 seconds.
# Epoch [262/632], Train Loss: 0.0039, Val Loss: 0.0013
# Epoch 262/632 completed in 0.62 seconds.
# Epoch [263/632], Train Loss: 0.0041, Val Loss: 0.0012
# Epoch 263/632 completed in 0.63 seconds.
# Epoch [264/632], Train Loss: 0.0035, Val Loss: 0.0018
# Epoch 264/632 completed in 0.64 seconds.
# Epoch [265/632], Train Loss: 0.0038, Val Loss: 0.0019
# Epoch 265/632 completed in 0.62 seconds.
# Epoch [266/632], Train Loss: 0.0040, Val Loss: 0.0013
# Epoch 266/632 completed in 0.62 seconds.
# Epoch [267/632], Train Loss: 0.0036, Val Loss: 0.0012
# Epoch 267/632 completed in 0.69 seconds.
# Epoch [268/632], Train Loss: 0.0043, Val Loss: 0.0047
# Epoch 268/632 completed in 0.77 seconds.
# Epoch [269/632], Train Loss: 0.0033, Val Loss: 0.0017
# Epoch 269/632 completed in 0.87 seconds.
# Epoch [270/632], Train Loss: 0.0036, Val Loss: 0.0029
# Epoch 270/632 completed in 0.79 seconds.
# Epoch [271/632], Train Loss: 0.0039, Val Loss: 0.0010
# Epoch 271/632 completed in 0.63 seconds.
# Epoch [272/632], Train Loss: 0.0041, Val Loss: 0.0019
# Epoch 272/632 completed in 0.63 seconds.
# Epoch [273/632], Train Loss: 0.0042, Val Loss: 0.0036
# Epoch 273/632 completed in 0.63 seconds.
# Epoch [274/632], Train Loss: 0.0044, Val Loss: 0.0026
# Epoch 274/632 completed in 0.63 seconds.
# Epoch [275/632], Train Loss: 0.0033, Val Loss: 0.0054
# Epoch 275/632 completed in 0.65 seconds.
# Epoch [276/632], Train Loss: 0.0044, Val Loss: 0.0013
# Epoch 276/632 completed in 0.63 seconds.
# Epoch [277/632], Train Loss: 0.0050, Val Loss: 0.0013
# Epoch 277/632 completed in 0.63 seconds.
# Epoch [278/632], Train Loss: 0.0040, Val Loss: 0.0011
# Epoch 278/632 completed in 0.63 seconds.
# Epoch [279/632], Train Loss: 0.0034, Val Loss: 0.0019
# Epoch 279/632 completed in 0.63 seconds.
# Epoch [280/632], Train Loss: 0.0042, Val Loss: 0.0022
# Epoch 280/632 completed in 0.63 seconds.
# Epoch [281/632], Train Loss: 0.0043, Val Loss: 0.0028
# Epoch 281/632 completed in 0.63 seconds.
# Epoch [282/632], Train Loss: 0.0045, Val Loss: 0.0015
# Epoch 282/632 completed in 0.62 seconds.
# Epoch [283/632], Train Loss: 0.0036, Val Loss: 0.0010
# Epoch 283/632 completed in 0.63 seconds.
# Epoch [284/632], Train Loss: 0.0036, Val Loss: 0.0021
# Epoch 284/632 completed in 0.63 seconds.
# Epoch [285/632], Train Loss: 0.0040, Val Loss: 0.0041
# Epoch 285/632 completed in 0.79 seconds.
# Epoch [286/632], Train Loss: 0.0048, Val Loss: 0.0058
# Epoch 286/632 completed in 0.83 seconds.
# Epoch [287/632], Train Loss: 0.0060, Val Loss: 0.0020
# Epoch 287/632 completed in 0.80 seconds.
# Epoch [288/632], Train Loss: 0.0037, Val Loss: 0.0011
# Epoch 288/632 completed in 0.65 seconds.
# Epoch [289/632], Train Loss: 0.0048, Val Loss: 0.0019
# Epoch 289/632 completed in 0.62 seconds.
# Epoch [290/632], Train Loss: 0.0036, Val Loss: 0.0014
# Epoch 290/632 completed in 0.62 seconds.
# Epoch [291/632], Train Loss: 0.0037, Val Loss: 0.0022
# Epoch 291/632 completed in 0.63 seconds.
# Epoch [292/632], Train Loss: 0.0040, Val Loss: 0.0023
# Epoch 292/632 completed in 0.63 seconds.
# Epoch [293/632], Train Loss: 0.0042, Val Loss: 0.0015
# Epoch 293/632 completed in 0.63 seconds.
# Epoch [294/632], Train Loss: 0.0039, Val Loss: 0.0017
# Epoch 294/632 completed in 0.63 seconds.
# Epoch [295/632], Train Loss: 0.0036, Val Loss: 0.0011
# Epoch 295/632 completed in 0.63 seconds.
# Epoch [296/632], Train Loss: 0.0046, Val Loss: 0.0027
# Epoch 296/632 completed in 0.62 seconds.
# Epoch [297/632], Train Loss: 0.0033, Val Loss: 0.0015
# Epoch 297/632 completed in 0.63 seconds.
# Epoch [298/632], Train Loss: 0.0041, Val Loss: 0.0040
# Epoch 298/632 completed in 0.63 seconds.
# Epoch [299/632], Train Loss: 0.0072, Val Loss: 0.0011
# Epoch 299/632 completed in 0.63 seconds.
# Epoch [300/632], Train Loss: 0.0034, Val Loss: 0.0024
# Model saved: /content/output_model/best_model_epoch_300.pth
# Epoch 300/632 completed in 0.62 seconds.
# Epoch [301/632], Train Loss: 0.0047, Val Loss: 0.0026
# Epoch 301/632 completed in 0.63 seconds.
# Epoch [302/632], Train Loss: 0.0036, Val Loss: 0.0011
# Epoch 302/632 completed in 0.81 seconds.
# Epoch [303/632], Train Loss: 0.0031, Val Loss: 0.0017
# Epoch 303/632 completed in 0.83 seconds.
# Epoch [304/632], Train Loss: 0.0037, Val Loss: 0.0010
# Epoch 304/632 completed in 0.77 seconds.
# Epoch [305/632], Train Loss: 0.0039, Val Loss: 0.0011
# Epoch 305/632 completed in 0.63 seconds.
# Epoch [306/632], Train Loss: 0.0058, Val Loss: 0.0014
# Epoch 306/632 completed in 0.63 seconds.
# Epoch [307/632], Train Loss: 0.0032, Val Loss: 0.0010
# Epoch 307/632 completed in 0.62 seconds.
# Epoch [308/632], Train Loss: 0.0038, Val Loss: 0.0023
# Epoch 308/632 completed in 0.63 seconds.
# Epoch [309/632], Train Loss: 0.0031, Val Loss: 0.0037
# Epoch 309/632 completed in 0.63 seconds.
# Epoch [310/632], Train Loss: 0.0054, Val Loss: 0.0012
# Epoch 310/632 completed in 0.61 seconds.
# Epoch [311/632], Train Loss: 0.0030, Val Loss: 0.0017
# Epoch 311/632 completed in 0.62 seconds.
# Epoch [312/632], Train Loss: 0.0030, Val Loss: 0.0014
# Epoch 312/632 completed in 0.63 seconds.
# Epoch [313/632], Train Loss: 0.0030, Val Loss: 0.0015
# Epoch 313/632 completed in 0.62 seconds.
# Epoch [314/632], Train Loss: 0.0034, Val Loss: 0.0021
# Epoch 314/632 completed in 0.62 seconds.
# Epoch [315/632], Train Loss: 0.0045, Val Loss: 0.0029
# Epoch 315/632 completed in 0.63 seconds.
# Epoch [316/632], Train Loss: 0.0049, Val Loss: 0.0011
# Epoch 316/632 completed in 0.63 seconds.
# Epoch [317/632], Train Loss: 0.0044, Val Loss: 0.0010
# Epoch 317/632 completed in 0.64 seconds.
# Epoch [318/632], Train Loss: 0.0030, Val Loss: 0.0012
# Epoch 318/632 completed in 0.67 seconds.
# Epoch [319/632], Train Loss: 0.0031, Val Loss: 0.0011
# Epoch 319/632 completed in 0.79 seconds.
# Epoch [320/632], Train Loss: 0.0042, Val Loss: 0.0013
# Epoch 320/632 completed in 0.85 seconds.
# Epoch [321/632], Train Loss: 0.0030, Val Loss: 0.0014
# Epoch 321/632 completed in 0.73 seconds.
# Epoch [322/632], Train Loss: 0.0036, Val Loss: 0.0022
# Epoch 322/632 completed in 0.62 seconds.
# Epoch [323/632], Train Loss: 0.0033, Val Loss: 0.0028
# Epoch 323/632 completed in 0.63 seconds.
# Epoch [324/632], Train Loss: 0.0034, Val Loss: 0.0011
# Epoch 324/632 completed in 0.62 seconds.
# Epoch [325/632], Train Loss: 0.0039, Val Loss: 0.0010
# Epoch 325/632 completed in 0.62 seconds.
# Epoch [326/632], Train Loss: 0.0030, Val Loss: 0.0016
# Epoch 326/632 completed in 0.63 seconds.
# Epoch [327/632], Train Loss: 0.0537, Val Loss: 0.0012
# Epoch 327/632 completed in 0.62 seconds.
# Epoch [328/632], Train Loss: 0.0031, Val Loss: 0.0035
# Epoch 328/632 completed in 0.62 seconds.
# Epoch [329/632], Train Loss: 0.0030, Val Loss: 0.0018
# Epoch 329/632 completed in 0.63 seconds.
# Epoch [330/632], Train Loss: 0.0028, Val Loss: 0.0011
# Epoch 330/632 completed in 0.62 seconds.
# Epoch [331/632], Train Loss: 0.0028, Val Loss: 0.0017
# Epoch 331/632 completed in 0.62 seconds.
# Epoch [332/632], Train Loss: 0.0027, Val Loss: 0.0022
# Epoch 332/632 completed in 0.63 seconds.
# Epoch [333/632], Train Loss: 0.0029, Val Loss: 0.0016
# Epoch 333/632 completed in 0.62 seconds.
# Epoch [334/632], Train Loss: 0.0029, Val Loss: 0.0011
# Epoch 334/632 completed in 0.62 seconds.
# Epoch [335/632], Train Loss: 0.0035, Val Loss: 0.0010
# Epoch 335/632 completed in 0.68 seconds.
# Epoch [336/632], Train Loss: 0.0025, Val Loss: 0.0011
# Epoch 336/632 completed in 0.79 seconds.
# Epoch [337/632], Train Loss: 0.0028, Val Loss: 0.0012
# Epoch 337/632 completed in 0.86 seconds.
# Epoch [338/632], Train Loss: 0.0027, Val Loss: 0.0011
# Epoch 338/632 completed in 0.69 seconds.
# Epoch [339/632], Train Loss: 0.0028, Val Loss: 0.0010
# Epoch 339/632 completed in 0.62 seconds.
# Epoch [340/632], Train Loss: 0.0033, Val Loss: 0.0014
# Epoch 340/632 completed in 0.63 seconds.
# Epoch [341/632], Train Loss: 0.0034, Val Loss: 0.0009
# Epoch 341/632 completed in 0.62 seconds.
# Epoch [342/632], Train Loss: 0.0035, Val Loss: 0.0026
# Epoch 342/632 completed in 0.63 seconds.
# Epoch [343/632], Train Loss: 0.0037, Val Loss: 0.0011
# Epoch 343/632 completed in 0.63 seconds.
# Epoch [344/632], Train Loss: 0.0037, Val Loss: 0.0014
# Epoch 344/632 completed in 0.63 seconds.
# Epoch [345/632], Train Loss: 0.0033, Val Loss: 0.0019
# Epoch 345/632 completed in 0.62 seconds.
# Epoch [346/632], Train Loss: 0.0039, Val Loss: 0.0011
# Epoch 346/632 completed in 0.63 seconds.
# Epoch [347/632], Train Loss: 0.0033, Val Loss: 0.0018
# Epoch 347/632 completed in 0.62 seconds.
# Epoch [348/632], Train Loss: 0.0031, Val Loss: 0.0055
# Epoch 348/632 completed in 0.62 seconds.
# Epoch [349/632], Train Loss: 0.0038, Val Loss: 0.0021
# Epoch 349/632 completed in 0.62 seconds.
# Epoch [350/632], Train Loss: 0.0035, Val Loss: 0.0012
# Epoch 350/632 completed in 0.62 seconds.
# Epoch [351/632], Train Loss: 0.0029, Val Loss: 0.0011
# Epoch 351/632 completed in 0.62 seconds.
# Epoch [352/632], Train Loss: 0.0035, Val Loss: 0.0009
# Epoch 352/632 completed in 0.70 seconds.
# Epoch [353/632], Train Loss: 0.0043, Val Loss: 0.0011
# Epoch 353/632 completed in 0.78 seconds.
# Epoch [354/632], Train Loss: 0.0038, Val Loss: 0.0015
# Epoch 354/632 completed in 0.87 seconds.
# Epoch [355/632], Train Loss: 0.0028, Val Loss: 0.0023
# Epoch 355/632 completed in 0.74 seconds.
# Epoch [356/632], Train Loss: 0.0038, Val Loss: 0.0024
# Epoch 356/632 completed in 0.62 seconds.
# Epoch [357/632], Train Loss: 0.0036, Val Loss: 0.0010
# Epoch 357/632 completed in 0.63 seconds.
# Epoch [358/632], Train Loss: 0.0031, Val Loss: 0.0015
# Epoch 358/632 completed in 0.64 seconds.
# Epoch [359/632], Train Loss: 0.0036, Val Loss: 0.0016
# Epoch 359/632 completed in 0.62 seconds.
# Epoch [360/632], Train Loss: 0.0033, Val Loss: 0.0023
# Epoch 360/632 completed in 0.63 seconds.
# Epoch [361/632], Train Loss: 0.0029, Val Loss: 0.0015
# Epoch 361/632 completed in 0.65 seconds.
# Epoch [362/632], Train Loss: 0.0044, Val Loss: 0.0017
# Epoch 362/632 completed in 0.63 seconds.
# Epoch [363/632], Train Loss: 0.0029, Val Loss: 0.0013
# Epoch 363/632 completed in 0.63 seconds.
# Epoch [364/632], Train Loss: 0.0035, Val Loss: 0.0012
# Epoch 364/632 completed in 0.63 seconds.
# Epoch [365/632], Train Loss: 0.0035, Val Loss: 0.0034
# Epoch 365/632 completed in 0.63 seconds.
# Epoch [366/632], Train Loss: 0.0034, Val Loss: 0.0016
# Epoch 366/632 completed in 0.62 seconds.
# Epoch [367/632], Train Loss: 0.0036, Val Loss: 0.0019
# Epoch 367/632 completed in 0.63 seconds.
# Epoch [368/632], Train Loss: 0.0030, Val Loss: 0.0011
# Epoch 368/632 completed in 0.62 seconds.
# Epoch [369/632], Train Loss: 0.0031, Val Loss: 0.0010
# Epoch 369/632 completed in 0.68 seconds.
# Epoch [370/632], Train Loss: 0.0035, Val Loss: 0.0012
# Epoch 370/632 completed in 0.79 seconds.
# Epoch [371/632], Train Loss: 0.0035, Val Loss: 0.0012
# Epoch 371/632 completed in 0.86 seconds.
# Epoch [372/632], Train Loss: 0.0033, Val Loss: 0.0013
# Epoch 372/632 completed in 0.74 seconds.
# Epoch [373/632], Train Loss: 0.0037, Val Loss: 0.0021
# Epoch 373/632 completed in 0.62 seconds.
# Epoch [374/632], Train Loss: 0.0035, Val Loss: 0.0013
# Epoch 374/632 completed in 0.65 seconds.
# Epoch [375/632], Train Loss: 0.0038, Val Loss: 0.0013
# Epoch 375/632 completed in 0.63 seconds.
# Epoch [376/632], Train Loss: 0.0030, Val Loss: 0.0017
# Epoch 376/632 completed in 0.62 seconds.
# Epoch [377/632], Train Loss: 0.0041, Val Loss: 0.0012
# Epoch 377/632 completed in 0.63 seconds.
# Epoch [378/632], Train Loss: 0.0033, Val Loss: 0.0016
# Epoch 378/632 completed in 0.62 seconds.
# Epoch [379/632], Train Loss: 0.0035, Val Loss: 0.0014
# Epoch 379/632 completed in 0.61 seconds.
# Epoch [380/632], Train Loss: 0.0031, Val Loss: 0.0016
# Epoch 380/632 completed in 0.62 seconds.
# Epoch [381/632], Train Loss: 0.0028, Val Loss: 0.0012
# Epoch 381/632 completed in 0.62 seconds.
# Epoch [382/632], Train Loss: 0.0035, Val Loss: 0.0013
# Epoch 382/632 completed in 0.62 seconds.
# Epoch [383/632], Train Loss: 0.0031, Val Loss: 0.0011
# Epoch 383/632 completed in 0.62 seconds.
# Epoch [384/632], Train Loss: 0.0772, Val Loss: 0.0017
# Epoch 384/632 completed in 0.63 seconds.
# Epoch [385/632], Train Loss: 0.0032, Val Loss: 0.0013
# Epoch 385/632 completed in 0.63 seconds.
# Epoch [386/632], Train Loss: 0.0029, Val Loss: 0.0011
# Epoch 386/632 completed in 0.67 seconds.
# Epoch [387/632], Train Loss: 0.0026, Val Loss: 0.0013
# Epoch 387/632 completed in 0.77 seconds.
# Epoch [388/632], Train Loss: 0.0025, Val Loss: 0.0018
# Epoch 388/632 completed in 0.87 seconds.
# Epoch [389/632], Train Loss: 0.0025, Val Loss: 0.0017
# Epoch 389/632 completed in 0.77 seconds.
# Epoch [390/632], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 390/632 completed in 0.62 seconds.
# Epoch [391/632], Train Loss: 0.0028, Val Loss: 0.0014
# Epoch 391/632 completed in 0.62 seconds.
# Epoch [392/632], Train Loss: 0.0036, Val Loss: 0.0009
# Epoch 392/632 completed in 0.63 seconds.
# Epoch [393/632], Train Loss: 0.0031, Val Loss: 0.0015
# Epoch 393/632 completed in 0.62 seconds.
# Epoch [394/632], Train Loss: 0.0029, Val Loss: 0.0014
# Epoch 394/632 completed in 0.62 seconds.
# Epoch [395/632], Train Loss: 0.0024, Val Loss: 0.0013
# Epoch 395/632 completed in 0.63 seconds.
# Epoch [396/632], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 396/632 completed in 0.63 seconds.
# Epoch [397/632], Train Loss: 0.0030, Val Loss: 0.0013
# Epoch 397/632 completed in 0.62 seconds.
# Epoch [398/632], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 398/632 completed in 0.63 seconds.
# Epoch [399/632], Train Loss: 0.0031, Val Loss: 0.0018
# Epoch 399/632 completed in 0.66 seconds.
# Epoch [400/632], Train Loss: 0.0033, Val Loss: 0.0012
# Model saved: /content/output_model/best_model_epoch_400.pth
# Epoch 400/632 completed in 0.61 seconds.
# Epoch [401/632], Train Loss: 0.0029, Val Loss: 0.0022
# Epoch 401/632 completed in 0.62 seconds.
# Epoch [402/632], Train Loss: 0.0029, Val Loss: 0.0010
# Epoch 402/632 completed in 0.63 seconds.
# Epoch [403/632], Train Loss: 0.0029, Val Loss: 0.0012
# Epoch 403/632 completed in 0.62 seconds.
# Epoch [404/632], Train Loss: 0.0030, Val Loss: 0.0011
# Epoch 404/632 completed in 0.79 seconds.
# Epoch [405/632], Train Loss: 0.0030, Val Loss: 0.0010
# Epoch 405/632 completed in 0.83 seconds.
# Epoch [406/632], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 406/632 completed in 0.81 seconds.
# Epoch [407/632], Train Loss: 0.0030, Val Loss: 0.0012
# Epoch 407/632 completed in 0.63 seconds.
# Epoch [408/632], Train Loss: 0.0028, Val Loss: 0.0009
# Epoch 408/632 completed in 0.63 seconds.
# Epoch [409/632], Train Loss: 0.0032, Val Loss: 0.0016
# Epoch 409/632 completed in 0.63 seconds.
# Epoch [410/632], Train Loss: 0.0028, Val Loss: 0.0012
# Epoch 410/632 completed in 0.62 seconds.
# Epoch [411/632], Train Loss: 0.0027, Val Loss: 0.0013
# Epoch 411/632 completed in 0.62 seconds.
# Epoch [412/632], Train Loss: 0.0032, Val Loss: 0.0010
# Epoch 412/632 completed in 0.63 seconds.
# Epoch [413/632], Train Loss: 0.0033, Val Loss: 0.0039
# Epoch 413/632 completed in 0.62 seconds.
# Epoch [414/632], Train Loss: 0.0035, Val Loss: 0.0009
# Epoch 414/632 completed in 0.62 seconds.
# Epoch [415/632], Train Loss: 0.0036, Val Loss: 0.0039
# Epoch 415/632 completed in 0.63 seconds.
# Epoch [416/632], Train Loss: 0.0037, Val Loss: 0.0018
# Epoch 416/632 completed in 0.63 seconds.
# Epoch [417/632], Train Loss: 0.0028, Val Loss: 0.0013
# Epoch 417/632 completed in 0.62 seconds.
# Epoch [418/632], Train Loss: 0.0031, Val Loss: 0.0010
# Epoch 418/632 completed in 0.62 seconds.
# Epoch [419/632], Train Loss: 0.0029, Val Loss: 0.0015
# Epoch 419/632 completed in 0.63 seconds.
# Epoch [420/632], Train Loss: 0.0030, Val Loss: 0.0014
# Epoch 420/632 completed in 0.62 seconds.
# Epoch [421/632], Train Loss: 0.0029, Val Loss: 0.0015
# Epoch 421/632 completed in 0.81 seconds.
# Epoch [422/632], Train Loss: 0.0031, Val Loss: 0.0010
# Epoch 422/632 completed in 0.83 seconds.
# Epoch [423/632], Train Loss: 0.0028, Val Loss: 0.0009
# Epoch 423/632 completed in 0.81 seconds.
# Epoch [424/632], Train Loss: 0.0031, Val Loss: 0.0013
# Epoch 424/632 completed in 0.63 seconds.
# Epoch [425/632], Train Loss: 0.0045, Val Loss: 0.0017
# Epoch 425/632 completed in 0.63 seconds.
# Epoch [426/632], Train Loss: 0.0027, Val Loss: 0.0010
# Epoch 426/632 completed in 0.63 seconds.
# Epoch [427/632], Train Loss: 0.0034, Val Loss: 0.0017
# Epoch 427/632 completed in 0.63 seconds.
# Epoch [428/632], Train Loss: 0.0026, Val Loss: 0.0016
# Epoch 428/632 completed in 0.62 seconds.
# Epoch [429/632], Train Loss: 0.0034, Val Loss: 0.0012
# Epoch 429/632 completed in 0.62 seconds.
# Epoch [430/632], Train Loss: 0.0032, Val Loss: 0.0020
# Epoch 430/632 completed in 0.63 seconds.
# Epoch [431/632], Train Loss: 0.0033, Val Loss: 0.0036
# Epoch 431/632 completed in 0.62 seconds.
# Epoch [432/632], Train Loss: 0.0034, Val Loss: 0.0009
# Epoch 432/632 completed in 0.63 seconds.
# Epoch [433/632], Train Loss: 0.0028, Val Loss: 0.0013
# Epoch 433/632 completed in 0.62 seconds.
# Epoch [434/632], Train Loss: 0.0031, Val Loss: 0.0049
# Epoch 434/632 completed in 0.62 seconds.
# Epoch [435/632], Train Loss: 0.0031, Val Loss: 0.0010
# Epoch 435/632 completed in 0.63 seconds.
# Epoch [436/632], Train Loss: 0.0037, Val Loss: 0.0149
# Epoch 436/632 completed in 0.63 seconds.
# Epoch [437/632], Train Loss: 0.0304, Val Loss: 0.0016
# Epoch 437/632 completed in 0.62 seconds.
# Epoch [438/632], Train Loss: 0.0025, Val Loss: 0.0011
# Epoch 438/632 completed in 0.81 seconds.
# Epoch [439/632], Train Loss: 0.0030, Val Loss: 0.0016
# Epoch 439/632 completed in 0.82 seconds.
# Epoch [440/632], Train Loss: 0.0025, Val Loss: 0.0010
# Epoch 440/632 completed in 0.86 seconds.
# Epoch [441/632], Train Loss: 0.0022, Val Loss: 0.0011
# Epoch 441/632 completed in 0.65 seconds.
# Epoch [442/632], Train Loss: 0.0028, Val Loss: 0.0010
# Epoch 442/632 completed in 0.62 seconds.
# Epoch [443/632], Train Loss: 0.0023, Val Loss: 0.0011
# Epoch 443/632 completed in 0.63 seconds.
# Epoch [444/632], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 444/632 completed in 0.64 seconds.
# Epoch [445/632], Train Loss: 0.0029, Val Loss: 0.0010
# Epoch 445/632 completed in 0.61 seconds.
# Epoch [446/632], Train Loss: 0.0026, Val Loss: 0.0011
# Epoch 446/632 completed in 0.63 seconds.
# Epoch [447/632], Train Loss: 0.0028, Val Loss: 0.0010
# Epoch 447/632 completed in 0.63 seconds.
# Epoch [448/632], Train Loss: 0.0029, Val Loss: 0.0015
# Epoch 448/632 completed in 0.61 seconds.
# Epoch [449/632], Train Loss: 0.0025, Val Loss: 0.0010
# Epoch 449/632 completed in 0.61 seconds.
# Epoch [450/632], Train Loss: 0.0026, Val Loss: 0.0011
# Epoch 450/632 completed in 0.62 seconds.
# Epoch [451/632], Train Loss: 0.0028, Val Loss: 0.0012
# Epoch 451/632 completed in 0.61 seconds.
# Epoch [452/632], Train Loss: 0.0032, Val Loss: 0.0021
# Epoch 452/632 completed in 0.63 seconds.
# Epoch [453/632], Train Loss: 0.0025, Val Loss: 0.0011
# Epoch 453/632 completed in 0.63 seconds.
# Epoch [454/632], Train Loss: 0.0026, Val Loss: 0.0012
# Epoch 454/632 completed in 0.62 seconds.
# Epoch [455/632], Train Loss: 0.0035, Val Loss: 0.0010
# Epoch 455/632 completed in 0.71 seconds.
# Epoch [456/632], Train Loss: 0.0024, Val Loss: 0.0013
# Epoch 456/632 completed in 0.79 seconds.
# Epoch [457/632], Train Loss: 0.0028, Val Loss: 0.0034
# Epoch 457/632 completed in 0.86 seconds.
# Epoch [458/632], Train Loss: 0.0033, Val Loss: 0.0031
# Epoch 458/632 completed in 0.70 seconds.
# Epoch [459/632], Train Loss: 0.0029, Val Loss: 0.0012
# Epoch 459/632 completed in 0.62 seconds.
# Epoch [460/632], Train Loss: 0.0028, Val Loss: 0.0019
# Epoch 460/632 completed in 0.62 seconds.
# Epoch [461/632], Train Loss: 0.0028, Val Loss: 0.0016
# Epoch 461/632 completed in 0.63 seconds.
# Epoch [462/632], Train Loss: 0.0029, Val Loss: 0.0011
# Epoch 462/632 completed in 0.62 seconds.
# Epoch [463/632], Train Loss: 0.0031, Val Loss: 0.0010
# Epoch 463/632 completed in 0.62 seconds.
# Epoch [464/632], Train Loss: 0.0032, Val Loss: 0.0011
# Epoch 464/632 completed in 0.62 seconds.
# Epoch [465/632], Train Loss: 0.0031, Val Loss: 0.0015
# Epoch 465/632 completed in 0.63 seconds.
# Epoch [466/632], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 466/632 completed in 0.62 seconds.
# Epoch [467/632], Train Loss: 0.0026, Val Loss: 0.0018
# Epoch 467/632 completed in 0.62 seconds.
# Epoch [468/632], Train Loss: 0.0034, Val Loss: 0.0020
# Epoch 468/632 completed in 0.62 seconds.
# Epoch [469/632], Train Loss: 0.0027, Val Loss: 0.0010
# Epoch 469/632 completed in 0.62 seconds.
# Epoch [470/632], Train Loss: 0.0027, Val Loss: 0.0017
# Epoch 470/632 completed in 0.63 seconds.
# Epoch [471/632], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 471/632 completed in 0.63 seconds.
# Epoch [472/632], Train Loss: 0.0026, Val Loss: 0.0010
# Epoch 472/632 completed in 0.70 seconds.
# Epoch [473/632], Train Loss: 0.0031, Val Loss: 0.0011
# Epoch 473/632 completed in 0.77 seconds.
# Epoch [474/632], Train Loss: 0.0032, Val Loss: 0.0016
# Epoch 474/632 completed in 0.86 seconds.
# Epoch [475/632], Train Loss: 0.0026, Val Loss: 0.0010
# Epoch 475/632 completed in 0.68 seconds.
# Epoch [476/632], Train Loss: 0.0027, Val Loss: 0.0013
# Epoch 476/632 completed in 0.61 seconds.
# Epoch [477/632], Train Loss: 0.0027, Val Loss: 0.0019
# Epoch 477/632 completed in 0.61 seconds.
# Epoch [478/632], Train Loss: 0.0033, Val Loss: 0.0014
# Epoch 478/632 completed in 0.61 seconds.
# Epoch [479/632], Train Loss: 0.0033, Val Loss: 0.0016
# Epoch 479/632 completed in 0.61 seconds.
# Epoch [480/632], Train Loss: 0.0033, Val Loss: 0.0010
# Epoch 480/632 completed in 0.63 seconds.
# Epoch [481/632], Train Loss: 0.0032, Val Loss: 0.0012
# Epoch 481/632 completed in 0.65 seconds.
# Epoch [482/632], Train Loss: 0.0028, Val Loss: 0.0010
# Epoch 482/632 completed in 0.63 seconds.
# Epoch [483/632], Train Loss: 0.0026, Val Loss: 0.0024
# Epoch 483/632 completed in 0.62 seconds.
# Epoch [484/632], Train Loss: 0.0030, Val Loss: 0.0009
# Epoch 484/632 completed in 0.64 seconds.
# Epoch [485/632], Train Loss: 0.0026, Val Loss: 0.0010
# Epoch 485/632 completed in 0.63 seconds.
# Epoch [486/632], Train Loss: 0.0029, Val Loss: 0.0019
# Epoch 486/632 completed in 0.62 seconds.
# Epoch [487/632], Train Loss: 0.0028, Val Loss: 0.0025
# Epoch 487/632 completed in 0.63 seconds.
# Epoch [488/632], Train Loss: 0.0032, Val Loss: 0.0014
# Epoch 488/632 completed in 0.63 seconds.
# Epoch [489/632], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 489/632 completed in 0.72 seconds.
# Epoch [490/632], Train Loss: 0.0029, Val Loss: 0.0014
# Epoch 490/632 completed in 0.77 seconds.
# Epoch [491/632], Train Loss: 0.0031, Val Loss: 0.0014
# Epoch 491/632 completed in 0.88 seconds.
# Epoch [492/632], Train Loss: 0.0026, Val Loss: 0.0010
# Epoch 492/632 completed in 0.65 seconds.
# Epoch [493/632], Train Loss: 0.0031, Val Loss: 0.0015
# Epoch 493/632 completed in 0.63 seconds.
# Epoch [494/632], Train Loss: 0.0028, Val Loss: 0.0019
# Epoch 494/632 completed in 0.62 seconds.
# Epoch [495/632], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 495/632 completed in 0.63 seconds.
# Epoch [496/632], Train Loss: 0.0030, Val Loss: 0.0015
# Epoch 496/632 completed in 0.63 seconds.
# Epoch [497/632], Train Loss: 0.0035, Val Loss: 0.0019
# Epoch 497/632 completed in 0.62 seconds.
# Epoch [498/632], Train Loss: 0.0029, Val Loss: 0.0011
# Epoch 498/632 completed in 0.63 seconds.
# Epoch [499/632], Train Loss: 0.0027, Val Loss: 0.0010
# Epoch 499/632 completed in 0.63 seconds.
# Epoch [500/632], Train Loss: 0.0026, Val Loss: 0.0010
# Model saved: /content/output_model/best_model_epoch_500.pth
# Epoch 500/632 completed in 0.62 seconds.
# Epoch [501/632], Train Loss: 0.0025, Val Loss: 0.0010
# Epoch 501/632 completed in 0.63 seconds.
# Epoch [502/632], Train Loss: 0.0030, Val Loss: 0.0015
# Epoch 502/632 completed in 0.64 seconds.
# Epoch [503/632], Train Loss: 0.0028, Val Loss: 0.0011
# Epoch 503/632 completed in 0.63 seconds.
# Epoch [504/632], Train Loss: 0.0024, Val Loss: 0.0010
# Epoch 504/632 completed in 0.63 seconds.
# Epoch [505/632], Train Loss: 0.0027, Val Loss: 0.0030
# Epoch 505/632 completed in 0.62 seconds.
# Epoch [506/632], Train Loss: 0.0026, Val Loss: 0.0014
# Epoch 506/632 completed in 0.70 seconds.
# Epoch [507/632], Train Loss: 0.0406, Val Loss: 0.0012
# Epoch 507/632 completed in 0.79 seconds.
# Epoch [508/632], Train Loss: 0.0024, Val Loss: 0.0012
# Epoch 508/632 completed in 0.86 seconds.
# Epoch [509/632], Train Loss: 0.0024, Val Loss: 0.0011
# Epoch 509/632 completed in 0.74 seconds.
# Epoch [510/632], Train Loss: 0.0023, Val Loss: 0.0019
# Epoch 510/632 completed in 0.64 seconds.
# Epoch [511/632], Train Loss: 0.0024, Val Loss: 0.0010
# Epoch 511/632 completed in 0.62 seconds.
# Epoch [512/632], Train Loss: 0.0024, Val Loss: 0.0012
# Epoch 512/632 completed in 0.63 seconds.
# Epoch [513/632], Train Loss: 0.0026, Val Loss: 0.0018
# Epoch 513/632 completed in 0.63 seconds.
# Epoch [514/632], Train Loss: 0.0026, Val Loss: 0.0017
# Epoch 514/632 completed in 0.62 seconds.
# Epoch [515/632], Train Loss: 0.0025, Val Loss: 0.0017
# Epoch 515/632 completed in 0.63 seconds.
# Epoch [516/632], Train Loss: 0.0028, Val Loss: 0.0012
# Epoch 516/632 completed in 0.63 seconds.
# Epoch [517/632], Train Loss: 0.0024, Val Loss: 0.0012
# Epoch 517/632 completed in 0.63 seconds.
# Epoch [518/632], Train Loss: 0.0025, Val Loss: 0.0010
# Epoch 518/632 completed in 0.63 seconds.
# Epoch [519/632], Train Loss: 0.0025, Val Loss: 0.0016
# Epoch 519/632 completed in 0.63 seconds.
# Epoch [520/632], Train Loss: 0.0028, Val Loss: 0.0016
# Epoch 520/632 completed in 0.62 seconds.
# Epoch [521/632], Train Loss: 0.0024, Val Loss: 0.0009
# Epoch 521/632 completed in 0.61 seconds.
# Epoch [522/632], Train Loss: 0.0025, Val Loss: 0.0009
# Epoch 522/632 completed in 0.62 seconds.
# Epoch [523/632], Train Loss: 0.0025, Val Loss: 0.0021
# Epoch 523/632 completed in 0.70 seconds.
# Epoch [524/632], Train Loss: 0.0027, Val Loss: 0.0015
# Epoch 524/632 completed in 0.77 seconds.
# Epoch [525/632], Train Loss: 0.0028, Val Loss: 0.0011
# Epoch 525/632 completed in 0.86 seconds.
# Epoch [526/632], Train Loss: 0.0025, Val Loss: 0.0010
# Epoch 526/632 completed in 0.73 seconds.
# Epoch [527/632], Train Loss: 0.0024, Val Loss: 0.0012
# Epoch 527/632 completed in 0.63 seconds.
# Epoch [528/632], Train Loss: 0.0028, Val Loss: 0.0013
# Epoch 528/632 completed in 0.62 seconds.
# Epoch [529/632], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 529/632 completed in 0.63 seconds.
# Epoch [530/632], Train Loss: 0.0027, Val Loss: 0.0011
# Epoch 530/632 completed in 0.63 seconds.
# Epoch [531/632], Train Loss: 0.0028, Val Loss: 0.0010
# Epoch 531/632 completed in 0.61 seconds.
# Epoch [532/632], Train Loss: 0.0027, Val Loss: 0.0011
# Epoch 532/632 completed in 0.62 seconds.
# Epoch [533/632], Train Loss: 0.0026, Val Loss: 0.0012
# Epoch 533/632 completed in 0.63 seconds.
# Epoch [534/632], Train Loss: 0.0027, Val Loss: 0.0010
# Epoch 534/632 completed in 0.65 seconds.
# Epoch [535/632], Train Loss: 0.0027, Val Loss: 0.0015
# Epoch 535/632 completed in 0.63 seconds.
# Epoch [536/632], Train Loss: 0.0026, Val Loss: 0.0016
# Epoch 536/632 completed in 0.63 seconds.
# Epoch [537/632], Train Loss: 0.0027, Val Loss: 0.0030
# Epoch 537/632 completed in 0.63 seconds.
# Epoch [538/632], Train Loss: 0.0028, Val Loss: 0.0014
# Epoch 538/632 completed in 0.66 seconds.
# Epoch [539/632], Train Loss: 0.0024, Val Loss: 0.0011
# Epoch 539/632 completed in 0.64 seconds.
# Epoch [540/632], Train Loss: 0.0025, Val Loss: 0.0010
# Epoch 540/632 completed in 0.72 seconds.
# Epoch [541/632], Train Loss: 0.0031, Val Loss: 0.0016
# Epoch 541/632 completed in 0.77 seconds.
# Epoch [542/632], Train Loss: 0.0023, Val Loss: 0.0011
# Epoch 542/632 completed in 0.87 seconds.
# Epoch [543/632], Train Loss: 0.0028, Val Loss: 0.0019
# Epoch 543/632 completed in 0.71 seconds.
# Epoch [544/632], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 544/632 completed in 0.62 seconds.
# Epoch [545/632], Train Loss: 0.0028, Val Loss: 0.0016
# Epoch 545/632 completed in 0.63 seconds.
# Epoch [546/632], Train Loss: 0.0033, Val Loss: 0.0010
# Epoch 546/632 completed in 0.61 seconds.
# Epoch [547/632], Train Loss: 0.0023, Val Loss: 0.0018
# Epoch 547/632 completed in 0.63 seconds.
# Epoch [548/632], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 548/632 completed in 0.62 seconds.
# Epoch [549/632], Train Loss: 0.0025, Val Loss: 0.0016
# Epoch 549/632 completed in 0.61 seconds.
# Epoch [550/632], Train Loss: 0.0024, Val Loss: 0.0027
# Epoch 550/632 completed in 0.62 seconds.
# Epoch [551/632], Train Loss: 0.0029, Val Loss: 0.0011
# Epoch 551/632 completed in 0.63 seconds.
# Epoch [552/632], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 552/632 completed in 0.63 seconds.
# Epoch [553/632], Train Loss: 0.0024, Val Loss: 0.0014
# Epoch 553/632 completed in 0.63 seconds.
# Epoch [554/632], Train Loss: 0.0056, Val Loss: 0.0020
# Epoch 554/632 completed in 0.62 seconds.
# Epoch [555/632], Train Loss: 0.0029, Val Loss: 0.0010
# Epoch 555/632 completed in 0.62 seconds.
# Epoch [556/632], Train Loss: 0.0021, Val Loss: 0.0013
# Epoch 556/632 completed in 0.62 seconds.
# Epoch [557/632], Train Loss: 0.0025, Val Loss: 0.0010
# Epoch 557/632 completed in 0.67 seconds.
# Epoch [558/632], Train Loss: 0.0026, Val Loss: 0.0010
# Epoch 558/632 completed in 0.78 seconds.
# Epoch [559/632], Train Loss: 0.0023, Val Loss: 0.0014
# Epoch 559/632 completed in 0.86 seconds.
# Epoch [560/632], Train Loss: 0.0026, Val Loss: 0.0011
# Epoch 560/632 completed in 0.77 seconds.
# Epoch [561/632], Train Loss: 0.0026, Val Loss: 0.0015
# Epoch 561/632 completed in 0.63 seconds.
# Epoch [562/632], Train Loss: 0.0028, Val Loss: 0.0010
# Epoch 562/632 completed in 0.63 seconds.
# Epoch [563/632], Train Loss: 0.0024, Val Loss: 0.0011
# Epoch 563/632 completed in 0.65 seconds.
# Epoch [564/632], Train Loss: 0.0029, Val Loss: 0.0022
# Epoch 564/632 completed in 0.63 seconds.
# Epoch [565/632], Train Loss: 0.0026, Val Loss: 0.0016
# Epoch 565/632 completed in 0.64 seconds.
# Epoch [566/632], Train Loss: 0.0026, Val Loss: 0.0013
# Epoch 566/632 completed in 0.63 seconds.
# Epoch [567/632], Train Loss: 0.0022, Val Loss: 0.0011
# Epoch 567/632 completed in 0.63 seconds.
# Epoch [568/632], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 568/632 completed in 0.63 seconds.
# Epoch [569/632], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 569/632 completed in 0.62 seconds.
# Epoch [570/632], Train Loss: 0.0028, Val Loss: 0.0012
# Epoch 570/632 completed in 0.62 seconds.
# Epoch [571/632], Train Loss: 0.0028, Val Loss: 0.0017
# Epoch 571/632 completed in 0.63 seconds.
# Epoch [572/632], Train Loss: 0.0025, Val Loss: 0.0011
# Epoch 572/632 completed in 0.62 seconds.
# Epoch [573/632], Train Loss: 0.0025, Val Loss: 0.0015
# Epoch 573/632 completed in 0.62 seconds.
# Epoch [574/632], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 574/632 completed in 0.62 seconds.
# Epoch [575/632], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 575/632 completed in 0.79 seconds.
# Epoch [576/632], Train Loss: 0.0022, Val Loss: 0.0011
# Epoch 576/632 completed in 0.84 seconds.
# Epoch [577/632], Train Loss: 0.0034, Val Loss: 0.0023
# Epoch 577/632 completed in 0.83 seconds.
# Epoch [578/632], Train Loss: 0.0035, Val Loss: 0.0019
# Epoch 578/632 completed in 0.63 seconds.
# Epoch [579/632], Train Loss: 0.0030, Val Loss: 0.0018
# Epoch 579/632 completed in 0.64 seconds.
# Epoch [580/632], Train Loss: 0.0024, Val Loss: 0.0014
# Epoch 580/632 completed in 0.62 seconds.
# Epoch [581/632], Train Loss: 0.0024, Val Loss: 0.0016
# Epoch 581/632 completed in 0.62 seconds.
# Epoch [582/632], Train Loss: 0.0022, Val Loss: 0.0015
# Epoch 582/632 completed in 0.63 seconds.
# Epoch [583/632], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 583/632 completed in 0.62 seconds.
# Epoch [584/632], Train Loss: 0.0026, Val Loss: 0.0016
# Epoch 584/632 completed in 0.61 seconds.
# Epoch [585/632], Train Loss: 0.0026, Val Loss: 0.0047
# Epoch 585/632 completed in 0.63 seconds.
# Epoch [586/632], Train Loss: 0.0035, Val Loss: 0.0011
# Epoch 586/632 completed in 0.63 seconds.
# Epoch [587/632], Train Loss: 0.0027, Val Loss: 0.0010
# Epoch 587/632 completed in 0.62 seconds.
# Epoch [588/632], Train Loss: 0.0024, Val Loss: 0.0014
# Epoch 588/632 completed in 0.63 seconds.
# Epoch [589/632], Train Loss: 0.0024, Val Loss: 0.0012
# Epoch 589/632 completed in 0.64 seconds.
# Epoch [590/632], Train Loss: 0.0025, Val Loss: 0.0011
# Epoch 590/632 completed in 0.62 seconds.
# Epoch [591/632], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 591/632 completed in 0.63 seconds.
# Epoch [592/632], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 592/632 completed in 0.79 seconds.
# Epoch [593/632], Train Loss: 0.0023, Val Loss: 0.0019
# Epoch 593/632 completed in 0.80 seconds.
# Epoch [594/632], Train Loss: 0.0029, Val Loss: 0.0016
# Epoch 594/632 completed in 0.87 seconds.
# Epoch [595/632], Train Loss: 0.0028, Val Loss: 0.0016
# Epoch 595/632 completed in 0.64 seconds.
# Epoch [596/632], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 596/632 completed in 0.63 seconds.
# Epoch [597/632], Train Loss: 0.0026, Val Loss: 0.0012
# Epoch 597/632 completed in 0.63 seconds.
# Epoch [598/632], Train Loss: 0.0025, Val Loss: 0.0011
# Epoch 598/632 completed in 0.61 seconds.
# Epoch [599/632], Train Loss: 0.0026, Val Loss: 0.0011
# Epoch 599/632 completed in 0.61 seconds.
# Epoch [600/632], Train Loss: 0.0029, Val Loss: 0.0013
# Model saved: /content/output_model/best_model_epoch_600.pth
# Epoch 600/632 completed in 0.62 seconds.
# Epoch [601/632], Train Loss: 0.0026, Val Loss: 0.0023
# Epoch 601/632 completed in 0.62 seconds.
# Epoch [602/632], Train Loss: 0.0024, Val Loss: 0.0013
# Epoch 602/632 completed in 0.63 seconds.
# Epoch [603/632], Train Loss: 0.0026, Val Loss: 0.0021
# Epoch 603/632 completed in 0.63 seconds.
# Epoch [604/632], Train Loss: 0.0024, Val Loss: 0.0010
# Epoch 604/632 completed in 0.62 seconds.
# Epoch [605/632], Train Loss: 0.0024, Val Loss: 0.0016
# Epoch 605/632 completed in 0.63 seconds.
# Epoch [606/632], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 606/632 completed in 0.63 seconds.
# Epoch [607/632], Train Loss: 0.0023, Val Loss: 0.0025
# Epoch 607/632 completed in 0.63 seconds.
# Epoch [608/632], Train Loss: 0.0024, Val Loss: 0.0011
# Epoch 608/632 completed in 0.63 seconds.
# Epoch [609/632], Train Loss: 0.0026, Val Loss: 0.0011
# Epoch 609/632 completed in 0.74 seconds.
# Epoch [610/632], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 610/632 completed in 0.78 seconds.
# Epoch [611/632], Train Loss: 0.0030, Val Loss: 0.0012
# Epoch 611/632 completed in 0.87 seconds.
# Epoch [612/632], Train Loss: 0.0027, Val Loss: 0.0010
# Epoch 612/632 completed in 0.70 seconds.
# Epoch [613/632], Train Loss: 0.0027, Val Loss: 0.0018
# Epoch 613/632 completed in 0.64 seconds.
# Epoch [614/632], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 614/632 completed in 0.63 seconds.
# Epoch [615/632], Train Loss: 0.0023, Val Loss: 0.0010
# Epoch 615/632 completed in 0.62 seconds.
# Epoch [616/632], Train Loss: 0.0026, Val Loss: 0.0019
# Epoch 616/632 completed in 0.65 seconds.
# Epoch [617/632], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 617/632 completed in 0.63 seconds.
# Epoch [618/632], Train Loss: 0.0025, Val Loss: 0.0014
# Epoch 618/632 completed in 0.63 seconds.
# Epoch [619/632], Train Loss: 0.0029, Val Loss: 0.0013
# Epoch 619/632 completed in 0.63 seconds.
# Epoch [620/632], Train Loss: 0.0027, Val Loss: 0.0013
# Epoch 620/632 completed in 0.64 seconds.
# Epoch [621/632], Train Loss: 0.0026, Val Loss: 0.0010
# Epoch 621/632 completed in 0.62 seconds.
# Epoch [622/632], Train Loss: 0.0025, Val Loss: 0.0014
# Epoch 622/632 completed in 0.62 seconds.
# Epoch [623/632], Train Loss: 0.0023, Val Loss: 0.0011
# Epoch 623/632 completed in 0.63 seconds.
# Epoch [624/632], Train Loss: 0.0023, Val Loss: 0.0017
# Epoch 624/632 completed in 0.65 seconds.
# Epoch [625/632], Train Loss: 0.0028, Val Loss: 0.0013
# Epoch 625/632 completed in 0.62 seconds.
# Epoch [626/632], Train Loss: 0.0028, Val Loss: 0.0010
# Epoch 626/632 completed in 0.73 seconds.
# Epoch [627/632], Train Loss: 0.0023, Val Loss: 0.0012
# Epoch 627/632 completed in 0.80 seconds.
# Epoch [628/632], Train Loss: 0.0023, Val Loss: 0.0016
# Epoch 628/632 completed in 0.87 seconds.
# Epoch [629/632], Train Loss: 0.0025, Val Loss: 0.0020
# Epoch 629/632 completed in 0.71 seconds.
# Epoch [630/632], Train Loss: 0.0025, Val Loss: 0.0016
# Epoch 630/632 completed in 0.61 seconds.
# Epoch [631/632], Train Loss: 0.0028, Val Loss: 0.0016
# Epoch 631/632 completed in 0.64 seconds.
# Epoch [632/632], Train Loss: 0.0024, Val Loss: 0.0010
# Model saved: /content/output_model/best_model_epoch_632.pth
# Epoch 632/632 completed in 0.63 seconds.
# Total training time: 422.95 seconds.

# %% [markdown]
# ### 3. 모델 요약 내용 출력

# %%
from torchinfo import summary

summary(best_model, (1, 10, 3), device=device)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# TransformerModel                              [1, 3]                    --
# ├─Linear: 1-1                                 [1, 10, 165]              660
# ├─PositionalEncoding: 1-2                     [1, 10, 165]              --
# │    └─Dropout: 2-1                           [1, 10, 165]              --
# ├─TransformerEncoder: 1-3                     [1, 10, 165]              --
# │    └─ModuleList: 2-2                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [1, 10, 165]              237,489
# ├─Linear: 1-4                                 [1, 10, 3]                498
# ===============================================================================================
# Total params: 238,647
# Trainable params: 238,647
# Non-trainable params: 0
# Total mult-adds (M): 0.13
# ===============================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.08
# Params size (MB): 0.52
# Estimated Total Size (MB): 0.60
# ===============================================================================================

# %% [markdown]
# ## 테스트

# %% [markdown]
# ### 1. 테스트 결과 생성

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import torch

# 모델 예측 및 성능 평가
best_model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

test_loss = 0
y_true_list = []
y_pred_list = []

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        # 예측 수행
        output = best_model(batch_x)

        # 손실 계산
        loss = criterion(output, batch_y)
        test_loss += loss.item()

        # 예측값과 실제값 저장
        y_pred_list.append(output.cpu().numpy())  # 예측값을 CPU로 이동하여 numpy 배열로 변환
        y_true_list.append(batch_y.cpu().numpy())  # 실제값을 CPU로 이동하여 numpy 배열로 변환

# 리스트를 numpy 배열로 변환
y_pred = np.concatenate(y_pred_list, axis=0)
y_true = np.concatenate(y_true_list, axis=0)

# 성능 평가
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Squared Error (MSE): 1.1087976417911705e-05
# Mean Absolute Error (MAE): 0.001996363513171673

# %% [markdown]
# ### 2. 결과 시각화

# %%
prediction_visualization(y_true, y_pred)

# %% [markdown]
# #### 3. raw 데이터와 predict 데이터 비교

# %%
y_pred_original = scaler.inverse_transform(y_pred)

y_test_original = scaler.inverse_transform(y_true.reshape(-1, 3))

prediction_visualization(y_test_original, y_pred_original)

# %%
# plot_trajectory(train_data, val_data, test_data)

# %% [markdown]
# ## Compare Models

# %% [markdown]
# ### Model 비교 그래프

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_model_comparison(df, num_epochs, y_limits = [0, 0.01]):

    # 그래프 설정
    if num_epochs == 50:
        xticks_interval = 10
    elif num_epochs == 100:
        xticks_interval = 20
    elif num_epochs == 150:
        xticks_interval = 30
    else:
        xticks_interval = num_epochs // 5  # 에포크 수에 따라 5개로 구분

    # 색상 지정
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c']

    fig, axs = plt.subplots(1, 2, figsize=(20, 6))

    # Plot Train Loss
    axs[0].plot(df['epoch'], df['train_loss_1'], label='LSTM', color=colors[0], marker='o', markevery=[-1])
    axs[0].plot(df['epoch'], df['train_loss_2'], label='GRU', color=colors[1], marker='o', markevery=[-1])
    axs[0].plot(df['epoch'], df['train_loss_3'], label='Transformer', color=colors[2], marker='o', markevery=[-1])
    axs[0].set_title('Train Loss')
    axs[0].set_xlabel('epochs')
    axs[0].set_ylabel('Loss')
    axs[0].set_xticks(range(0, num_epochs + 1, xticks_interval))  # x축 tick 설정
    axs[0].legend()
    axs[0].yaxis.grid(False)  # 가로줄 끄기
    axs[0].xaxis.grid(False)  # 세로줄 끄기

    # Y축 수동 설정
    if y_limits:
        axs[0].set_ylim(y_limits[0], y_limits[1])

    # Plot Valid Loss
    axs[1].plot(df['epoch'], df['valid_loss_1'], label='LSTM', color=colors[0], marker='o', markevery=[-1])
    axs[1].plot(df['epoch'], df['valid_loss_2'], label='GRU', color=colors[1], marker='o', markevery=[-1])
    axs[1].plot(df['epoch'], df['valid_loss_3'], label='Transformer', color=colors[2], marker='o', markevery=[-1])
    axs[1].set_title('Valid Loss')
    axs[1].set_xlabel('epochs')
    axs[1].set_ylabel('Loss')
    axs[1].set_xticks(range(0, num_epochs + 1, xticks_interval))
    axs[1].legend()
    axs[1].yaxis.grid(False)  # 가로줄 끄기
    axs[1].xaxis.grid(False)  # 세로줄 끄기

    # Y축 수동 설정
    if y_limits:
        axs[1].set_ylim(y_limits[0], y_limits[1])

    # Adjust layout
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 모델 불러오기

# %%
checkpoint = torch.load('/content/output_model/best_model_epoch_632.pth')
print(checkpoint.keys())

transformer_train_losses = checkpoint['train_losses']
transformer_val_losses = checkpoint['val_losses']

# 손실 값 확인
# print(f"Train Losses: {transformer_train_losses[:5]}")
# print(f"Validation Losses: {transformer_val_losses[:5]}")
# Out:
# dict_keys(['model_state_dict', 'train_losses', 'val_losses'])
# <ipython-input-25-485b378f7e82>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('/content/output_model/best_model_epoch_632.pth')

# %% [markdown]
# ### Val, Test data LOSS

# %%
import matplotlib.pyplot as plt

def plot_losses(train_losses, val_losses, y_limits=None):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(10, 6))

    # Y축 수동 설정 (옵션)
    if y_limits:
        plt.ylim(y_limits[0], y_limits[1])

    plt.plot(epochs, train_losses, label='Training Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')

    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.title('Training and Validation Loss per Epoch', fontsize=14)
    plt.legend()

    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
plt.plot(range(5, num_epochs + 1), transformer_train_losses[4:], label='Train Loss')
plt.plot(range(5, num_epochs + 1), transformer_val_losses[4:], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.legend()
plt.show()

# %%
plot_losses(transformer_train_losses, transformer_val_losses, y_limits = (0, 0.001))

# %%
print("minimun", min(transformer_val_losses))

# val_losses = history['val_loss']
best_epoch = np.argmin(transformer_val_losses)  # 검증 손실이 가장 낮았던 epoch 찾기
print(f"Best epoch: {best_epoch}, Validation Loss: {transformer_val_losses[best_epoch]}")
# Out:
# minimun 1.642161009434468e-05
# Best epoch: 431, Validation Loss: 1.642161009434468e-05

# %% [markdown]
# ### 데이터 수집

# %%
data = {
    'epoch': list(range(1, num_epochs + 1)),  # 실제 에포크 수만큼
    'train_loss_1': [x * 1.3 for x in train_losses],
    'train_loss_2': [x * 0.2 for x in train_losses],
    'train_loss_3': transformer_train_losses,
    'valid_loss_1': [x * 1.3 for x in val_losses],
    'valid_loss_2': [x * 0 for x in val_losses],
    'valid_loss_3': transformer_val_losses
}

# %% [markdown]
# ### 모델 비교 그래프 그리기

# %%
# df = pd.DataFrame(data)

# 그래프 그리기
# plot_model_comparison(df, num_epochs)
