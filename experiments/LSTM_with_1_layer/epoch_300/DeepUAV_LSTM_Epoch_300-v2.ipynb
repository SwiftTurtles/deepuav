# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### 패키지 설치 & 라이브러리 import

# %%
# !pip install optuna
# !pip install torchinfo
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.35)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 12.9 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 17.4 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.3 colorlog-6.8.2 optuna-4.0.0
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## 전체 공통 함수

# %% [markdown]
# ### 1. 데이터 보간 함수

# %% [markdown]
# - 데이터의 시간 간격을 0.5초의 등간격으로 맞추고 그에 따른 좌표 값을 보간함
# - 가장 많이 사용되는 3차 스플라인 보간 적용

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt

# 데이터 보간 - 위도, 고도, 경도 값을 0.5초 시간 간격으로 보간
def spline_interpolation(x, y):
    # x: 보간할 데이터의 x 값 (시간)
    # y: 보간할 데이터의 y 값 (위도, 고도, 경도)

    # 3차 스플라인 보간 함수 생성
    f = interp1d(x, y, kind='cubic')

    # 시간 범위 설정
    start_time = min(x)
    end_time = max(x)

    # 0.5초 간격의 시간 배열을 생성
    new_x = np.arange(start_time, end_time, 0.5)

    # 위도, 경도, 고도 보간
    new_y = f(new_x)

    return new_x, new_y

# %% [markdown]
# ### 2. 시퀀스 나누는 함수

# %% [markdown]
# - 학습을 위해 데이터를 시퀀스 형태로 나눔
# - look back과 forward에 따라 학습에 사용될 x값의 구간과 y값을 반환함
# - 초기 look back은 10, forward는 0이다.

# %%
# 시퀀스 생성 함수
# look back : 10 (5초간의 위도, 고도, 경도 데이터를 x값으로 사용)
# forward : 0 (0.5초 뒤의 위도, 고도, 경도 데이터를 y값으로 사용)
def create_sequences(df, look_back=10, forward=0):
    xs = []
    ys = []
    for i in range(len(df) - look_back - forward):
        x = df.iloc[i:(i+look_back)].values
        y = df.iloc[i+look_back+forward].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# %% [markdown]
# ### 3. 시간 소수점 절사 함수

# %% [markdown]
# - 불필요한 시간 소수점 제거

# %%
import math

# 시간 소수점 절사 함수
def truncation(df):
    new_time = []

    for a in df['time']:
      new_time.append(math.floor(a * 10) / 10)

    df['time'] = new_time

    return df

# %% [markdown]
# ### 4. 스케일링 함수

# %% [markdown]
# - MinMaxScaling 적용 함수

# %%
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaling 적용 함수
def min_max_scaling(df):

    # time 삭제 df 생성
    mid_df=df.drop(columns='time')

    min_max_scaler = MinMaxScaler()
    min_max_scaler.fit(mid_df)

    min_max_data = min_max_scaler.transform(mid_df)

    new_data = pd.DataFrame(min_max_data)

    # time 추가
    new_data.insert(0, 'time', df['time'])

    # 나머지 열의 이름 가져오기
    column_names = mid_df.columns.tolist()

    column_names.insert(0, 'time')

    print(column_names)

    # 새로운 데이터프레임에 열 이름 설정
    new_data.columns = column_names

    return min_max_scaler, new_data

# %% [markdown]
# ### 5. train/validation/test 분리 함수

# %% [markdown]
# - Train, Validation, Test 데이터셋을 분리하는 함수이다.
# - 각각의 비율은 6:2:2 이다.

# %%
from sklearn.model_selection import train_test_split

# train/validation/test 분리 함수
def split_train_val_test(df, test_size=0.2, val_size=0.25):

    #Train, Test 분류
    train_val_df, test_df = train_test_split(df, test_size=test_size, shuffle=False)

    #Train, Validation 분류
    train_df, val_df = train_test_split(train_val_df, test_size=val_size, shuffle=False)

    # # 데이터 크기 출력
    # print("Train set:", train_df.shape)
    # print("Validation set:", val_df.shape)
    # print("Test set:", test_df.shape)

    return train_df, val_df, test_df

# %% [markdown]
# ### 6. 경로 시각화 함수

# %% [markdown]
# - 실제 경로와 예측 경로를 각각 그래프로 생성

# %%
import matplotlib.pyplot as plt

# 경로 시각화 함수
def prediction_visualization(y_test, y_pred):
    # 시각화를 위해 위도, 경도, 고도 분리
    y_test_lat = y_test[:, 0]
    y_test_lon = y_test[:, 1]
    y_test_alt = y_test[:, 2]

    y_pred_lat = y_pred[:, 0]
    y_pred_lon = y_pred[:, 1]
    y_pred_alt = y_pred[:, 2]

    # 3D 그래프 생성
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')

    # 실제 값 플롯
    ax.scatter(y_test_lat, y_test_lon, y_test_alt, c='b', marker='o', label='Actual')

    # 예측 값 플롯
    ax.scatter(y_pred_lat, y_pred_lon, y_pred_alt, c='r', marker='^', label='Predicted')

    # 그래프 제목 및 축 레이블 설정
    ax.set_title('Actual vs Predicted')
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 범례
    ax.legend()

    # 그래프를 화면에 출력
    plt.show()

# %% [markdown]
# ### 7. 데이터로더 생성 함수

# %% [markdown]
# - 학습에 사용할 데이터 로더 생성
# 1. 시퀀스 생성
# 2. Train, Validation, Test 분리
# 3. DataLoader 생성

# %%
# 데이터 로더 생성 함수
def create_dataloaders(tri, batch_size, sequence_length):

  tri = tri[['time', 'lat', 'lon', 'alt']]

  # train, validation, test 분리
  train_data, val_data, test_data = split_train_val_test(tri)

  # 각 데이터셋에서 시퀀스 생성
  X_train, y_train = create_sequences(train_data[['lat', 'lon', 'alt']], look_back=sequence_length)
  X_val, y_val = create_sequences(val_data[['lat', 'lon', 'alt']], look_back=sequence_length)
  X_test, y_test = create_sequences(test_data[['lat', 'lon', 'alt']], look_back=sequence_length)

  X_train = torch.tensor(X_train, dtype=torch.float32)
  y_train = torch.tensor(y_train, dtype=torch.float32)
  X_val = torch.tensor(X_val, dtype=torch.float32)
  y_val = torch.tensor(y_val, dtype=torch.float32)
  X_test = torch.tensor(X_test, dtype=torch.float32)
  y_test = torch.tensor(y_test, dtype=torch.float32)

  train_dataset = TensorDataset(X_train, y_train)
  validation_dataset = TensorDataset(X_val, y_val)
  test_dataset = TensorDataset(X_test, y_test)

  # 데이터 로더 생성
  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  val_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

  return train_loader, val_loader, test_loader

# %% [markdown]
# ## 전처리

# %% [markdown]
# ### 1. 데이터셋 가져오기

# %%
import pandas as pd

# 데이터셋 가져오기 (필요시 저장 경로 수정)
raw = pd.read_csv("/content/OnboardGPS.csv")

# %%
# 데이터셋 출력
# raw

# %% [markdown]
# ### 2. 데이터셋 전처리

# %% [markdown]
# - 데이터셋 보간
# - 소수점 절사
# - MinMaxScaling 적용

# %%
tri = raw[['Timpstemp', ' lat', ' lon', ' alt']]

new_x, lat = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lat'])
new_x, lon = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lon'])
new_x, alt = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' alt'])

tri = pd.DataFrame({"time":new_x, "lat":lat, "lon":lon, "alt":alt})

tri = truncation(tri)
scaler, tri = min_max_scaling(tri)
# tri
# Out:
# ['time', 'lat', 'lon', 'alt']

# %% [markdown]
# #### 3. 나뉜된 데이터셋 구조 확인

# %%
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D

# # splited 데이터 경로 시각화 함수
# def plot_trajectory(train_data, val_data, test_data):
#     fig = plt.figure(figsize=(10, 7))
#     ax = fig.add_subplot(111, projection='3d')

#     # 훈련 데이터 플롯
#     ax.plot(train_data['lat'], train_data['lon'], train_data['alt'], label='Train', color='blue')

#     # 검증 데이터 플롯
#     ax.plot(val_data['lat'], val_data['lon'], val_data['alt'], label='Validation', color='green')

#     # 테스트 데이터 플롯
#     ax.plot(test_data['lat'], test_data['lon'], test_data['alt'], label='Test', color='red')

#     # 그래프 레이블
#     ax.set_xlabel('Latitude')
#     ax.set_ylabel('Longitude')
#     ax.set_zlabel('Altitude')

#     # 제목과 범례
#     ax.set_title('Drone Trajectory: Train, Validation, and Test')
#     ax.legend()

#     plt.show()

# %%
# # ############## 예시: 함수 사용
# train_data, val_data, test_data = split_train_val_test(tri)
# print(train_data.shape)
# print(val_data.shape)
# print(test_data.shape)

# plot_trajectory(train_data, val_data, test_data)

# X_train, y_train = create_sequences(train_data[['lat', 'lon', 'alt']], look_back=10)
# print(X_train[0])
# print(y_train[0])

# # ######################

# %% [markdown]
# ## 모델 선언

# %% [markdown]
# ### 1. 모델 클래스 선언

# %% [markdown]
# - LSTM을 사용한 모델 클래스 선언
# - 구조 : LSTM + Fully Connected Layer

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import optuna

# LSTM 모델 클래스 정의
class LSTM_Model(nn.Module):
    def __init__(self, input_size=3, hidden_size=128, num_layers=2, output_size=3):
        super(LSTM_Model, self).__init__()

        # hidden state size
        self.hidden_size = hidden_size

        # LSTM layer 수
        self.num_layers = num_layers

        # LSTM 레이어
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)

        # Fully Connected Layer
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):


        # LSTM hidden state, cell state 초기화
        # 초기 hidden state와 cell state 정의
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        # LSTM 레이어를 통과
        out, _ = self.lstm(x, (h0, c0))

        # 마지막 시점의 hidden state에서 Fully Connected Layer를 통과
        out = self.fc(out[:, -1, :])

        return out

# %% [markdown]
# ## 하이퍼파라미터 탐색

# %% [markdown]
# ### 1. Optuna의 objective 함수 선언

# %% [markdown]
# - 최적의 하이퍼파라미터 탐색을 위해 optuna 사용
# - objective 함수 선언

# %%
import optuna
import torch

def objective(trial, tri, sequence_length):
    # 탐색할 하이퍼파라미터 값 결정
    hidden_size = trial.suggest_int("hidden_size", 32, 256)
    num_layers = trial.suggest_int("num_layers", 1, 5)
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1e-2, log=True)
    batch_size = trial.suggest_int("batch_size", 16, 128)

    num_epochs = 300
    input_size = 3  # lat, lon, alt
    output_size = 3  # lat, lon, alt

    # 데이터셋 가져오기
    train_loader, val_loader, _ = create_dataloaders(tri, batch_size, sequence_length)

    # 모델 정의: LSTMModel
    model = LSTM_Model(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, output_size=output_size)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    criterion = torch.nn.MSELoss()

    total_val_loss = 0.0  # 모든 epoch에서의 validation loss의 합
    val_loss_count = 0    # 평균을 계산하기 위한 epoch 수

    # 모델 학습
    for epoch in range(num_epochs):

        # Train set으로 학습
        model.train()
        train_loss = 0.0
        for batch_x, batch_y in train_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)

            optimizer.zero_grad()
            output = model(batch_x)
            loss = criterion(output, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        # Validation set에서 성능 측정
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x = batch_x.to(device)
                batch_y = batch_y.to(device)
                output = model(batch_x)
                loss = criterion(output, batch_y)
                val_loss += loss.item()

        # 배치 수로 나눠서 평균 validation 손실 계산
        val_loss_avg = val_loss / len(val_loader)

        # Optuna에 중간 값 보고
        trial.report(val_loss_avg, epoch)

        # 총 validation 손실 계산
        total_val_loss += val_loss_avg
        val_loss_count += 1

        # Pruning 조건 확인
        if trial.should_prune():
            print(f"Trial {trial.number} pruned at epoch {epoch}")
            print(f"Validation Loss at prune: {val_loss_avg:.4f}")  # Prune 시점에서 validation loss 출력

            raise optuna.TrialPruned()

    # 모든 epoch에서의 validation 손실 평균을 반환
    return total_val_loss / val_loss_count

# %% [markdown]
# ### 2. early stopping 함수 선언

# %% [markdown]
# - optuna에서 하이퍼파라미터 탐색 중 early stopping 적용

# %%
#  # https://github.com/optuna/optuna/issues/1001

# def early_stopping_check(study, trial, early_stopping_rounds=10):
#   current_trial_number = trial.number
#   best_trial_number = study.best_trial.number
#   should_stop = (current_trial_number - best_trial_number) >= early_stopping_rounds
#   if should_stop:
#       print(f"Early stopping detected: stopping trial {current_trial_number} (best trial {best_trial_number}) at epoch {epoch}")
#       study.stop()

# %% [markdown]
# ### 3. 탐색 범위 외의 하이퍼파라미터 선언

# %%
sequence_length = 10
early_stopping_rounds = 10
n_trials = 100

# %% [markdown]
# ### 4. 하이퍼 파라미터 탐색

# %%
import optuna
from functools import partial

# Optuna 스터디 생성 및 최적화 실행
study = optuna.create_study(direction="minimize", pruner=optuna.pruners.MedianPruner(n_warmup_steps=10))
study.optimize(lambda trial: objective(trial, tri, sequence_length), n_trials=n_trials)

# 최적의 하이퍼파라미터 출력
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2024-10-07 14:12:24,637] A new study created in memory with name: no-name-3a5911da-c6d4-4fcb-b3d8-eaec983ef879
# [I 2024-10-07 14:13:39,851] Trial 0 finished with value: 0.002011951477178138 and parameters: {'hidden_size': 234, 'num_layers': 3, 'learning_rate': 0.006506994355818873, 'batch_size': 87}. Best is trial 0 with value: 0.002011951477178138.
# [I 2024-10-07 14:14:40,068] Trial 1 finished with value: 0.0003342654946382702 and parameters: {'hidden_size': 111, 'num_layers': 2, 'learning_rate': 0.0015187196505828421, 'batch_size': 62}. Best is trial 1 with value: 0.0003342654946382702.
# [I 2024-10-07 14:18:22,094] Trial 2 finished with value: 0.0011907964825491719 and parameters: {'hidden_size': 67, 'num_layers': 3, 'learning_rate': 9.480875649418714e-05, 'batch_size': 16}. Best is trial 1 with value: 0.0003342654946382702.
# [I 2024-10-07 14:19:02,382] Trial 3 finished with value: 0.0015742312819778225 and parameters: {'hidden_size': 105, 'num_layers': 3, 'learning_rate': 0.001294002539385152, 'batch_size': 118}. Best is trial 1 with value: 0.0003342654946382702.
# [I 2024-10-07 14:19:52,853] Trial 4 finished with value: 0.0004010661715258519 and parameters: {'hidden_size': 115, 'num_layers': 2, 'learning_rate': 0.0013985378583855168, 'batch_size': 74}. Best is trial 1 with value: 0.0003342654946382702.
# [I 2024-10-07 14:19:58,953] Trial 5 pruned.
# Trial 5 pruned at epoch 23
# Validation Loss at prune: 0.0009
# [I 2024-10-07 14:20:02,506] Trial 6 pruned.
# Trial 6 pruned at epoch 10
# Validation Loss at prune: 0.0049
# [I 2024-10-07 14:20:04,606] Trial 7 pruned.
# Trial 7 pruned at epoch 10
# Validation Loss at prune: 0.0041
# [I 2024-10-07 14:20:05,857] Trial 8 pruned.
# Trial 8 pruned at epoch 10
# Validation Loss at prune: 0.2486
# [I 2024-10-07 14:20:07,841] Trial 9 pruned.
# Trial 9 pruned at epoch 10
# Validation Loss at prune: 0.0179
# [I 2024-10-07 14:20:11,751] Trial 10 pruned.
# Trial 10 pruned at epoch 10
# Validation Loss at prune: 0.0067
# [I 2024-10-07 14:20:58,846] Trial 11 finished with value: 0.0004497510583203807 and parameters: {'hidden_size': 114, 'num_layers': 2, 'learning_rate': 0.0019913771083375493, 'batch_size': 83}. Best is trial 1 with value: 0.0003342654946382702.
# [I 2024-10-07 14:22:12,067] Trial 12 finished with value: 0.00016058781905409596 and parameters: {'hidden_size': 120, 'num_layers': 2, 'learning_rate': 0.0024457195731404026, 'batch_size': 48}. Best is trial 12 with value: 0.00016058781905409596.
# [I 2024-10-07 14:23:26,746] Trial 13 finished with value: 0.000161322251444092 and parameters: {'hidden_size': 193, 'num_layers': 1, 'learning_rate': 0.0030332302613316374, 'batch_size': 43}. Best is trial 12 with value: 0.00016058781905409596.
# [I 2024-10-07 14:24:44,135] Trial 14 finished with value: 0.00011226621067089306 and parameters: {'hidden_size': 197, 'num_layers': 1, 'learning_rate': 0.004397445379902527, 'batch_size': 41}. Best is trial 14 with value: 0.00011226621067089306.
# [I 2024-10-07 14:26:17,322] Trial 15 finished with value: 6.583269049682751e-05 and parameters: {'hidden_size': 213, 'num_layers': 1, 'learning_rate': 0.004672420526588498, 'batch_size': 33}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:26:22,603] Trial 16 pruned.
# Trial 16 pruned at epoch 10
# Validation Loss at prune: 0.0009
# [I 2024-10-07 14:26:29,280] Trial 17 pruned.
# Trial 17 pruned at epoch 10
# Validation Loss at prune: 0.0072
# [I 2024-10-07 14:26:33,821] Trial 18 pruned.
# Trial 18 pruned at epoch 10
# Validation Loss at prune: 0.0014
# [I 2024-10-07 14:26:46,041] Trial 19 pruned.
# Trial 19 pruned at epoch 10
# Validation Loss at prune: 0.0068
# [I 2024-10-07 14:26:48,187] Trial 20 pruned.
# Trial 20 pruned at epoch 10
# Validation Loss at prune: 0.0015
# [I 2024-10-07 14:28:12,504] Trial 21 finished with value: 0.00021213019598141482 and parameters: {'hidden_size': 136, 'num_layers': 2, 'learning_rate': 0.003291675139180441, 'batch_size': 48}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:29:23,528] Trial 22 finished with value: 9.75335299620751e-05 and parameters: {'hidden_size': 148, 'num_layers': 1, 'learning_rate': 0.00869740119156138, 'batch_size': 47}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:30:46,547] Trial 23 finished with value: 0.00010826822420131318 and parameters: {'hidden_size': 198, 'num_layers': 1, 'learning_rate': 0.008942989197429802, 'batch_size': 38}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:31:49,230] Trial 24 finished with value: 0.00014659360978383048 and parameters: {'hidden_size': 161, 'num_layers': 1, 'learning_rate': 0.008469829978712396, 'batch_size': 55}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:33:41,430] Trial 25 finished with value: 0.0001984033576241017 and parameters: {'hidden_size': 255, 'num_layers': 1, 'learning_rate': 0.008556371740050198, 'batch_size': 27}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:33:46,042] Trial 26 pruned.
# Trial 26 pruned at epoch 11
# Validation Loss at prune: 0.0002
# [I 2024-10-07 14:33:51,028] Trial 27 pruned.
# Trial 27 pruned at epoch 10
# Validation Loss at prune: 0.0068
# [I 2024-10-07 14:33:54,093] Trial 28 pruned.
# Trial 28 pruned at epoch 11
# Validation Loss at prune: 0.0004
# [I 2024-10-07 14:34:17,215] Trial 29 pruned.
# Trial 29 pruned at epoch 31
# Validation Loss at prune: 0.0006
# [I 2024-10-07 14:34:20,536] Trial 30 pruned.
# Trial 30 pruned at epoch 10
# Validation Loss at prune: 0.0005
# [I 2024-10-07 14:35:38,121] Trial 31 finished with value: 7.400861990721927e-05 and parameters: {'hidden_size': 198, 'num_layers': 1, 'learning_rate': 0.004055713525488126, 'batch_size': 41}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:35:40,285] Trial 32 pruned.
# Trial 32 pruned at epoch 10
# Validation Loss at prune: 0.0006
# [I 2024-10-07 14:35:43,266] Trial 33 pruned.
# Trial 33 pruned at epoch 10
# Validation Loss at prune: 0.0007
# [I 2024-10-07 14:35:47,360] Trial 34 pruned.
# Trial 34 pruned at epoch 10
# Validation Loss at prune: 0.0025
# [I 2024-10-07 14:36:50,054] Trial 35 pruned.
# Trial 35 pruned at epoch 86
# Validation Loss at prune: 0.0000
# [I 2024-10-07 14:36:53,100] Trial 36 pruned.
# Trial 36 pruned at epoch 11
# Validation Loss at prune: 0.0010
# [I 2024-10-07 14:37:41,288] Trial 37 finished with value: 0.00012411790586323453 and parameters: {'hidden_size': 221, 'num_layers': 1, 'learning_rate': 0.004006625715924062, 'batch_size': 73}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:37:44,663] Trial 38 pruned.
# Trial 38 pruned at epoch 11
# Validation Loss at prune: 0.0003
# [I 2024-10-07 14:38:44,528] Trial 39 finished with value: 8.246112883571137e-05 and parameters: {'hidden_size': 189, 'num_layers': 1, 'learning_rate': 0.006922834381156409, 'batch_size': 67}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:38:46,613] Trial 40 pruned.
# Trial 40 pruned at epoch 10
# Validation Loss at prune: 0.0018
# [I 2024-10-07 14:39:46,243] Trial 41 finished with value: 9.776727990730945e-05 and parameters: {'hidden_size': 186, 'num_layers': 1, 'learning_rate': 0.00764329767496057, 'batch_size': 66}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:40:45,129] Trial 42 finished with value: 7.12446510795407e-05 and parameters: {'hidden_size': 185, 'num_layers': 1, 'learning_rate': 0.006786043087986728, 'batch_size': 67}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:40:48,559] Trial 43 pruned.
# Trial 43 pruned at epoch 15
# Validation Loss at prune: 0.0002
# [I 2024-10-07 14:40:50,949] Trial 44 pruned.
# Trial 44 pruned at epoch 10
# Validation Loss at prune: 0.0009
# [I 2024-10-07 14:40:53,381] Trial 45 pruned.
# Trial 45 pruned at epoch 10
# Validation Loss at prune: 0.0740
# [I 2024-10-07 14:40:55,432] Trial 46 pruned.
# Trial 46 pruned at epoch 10
# Validation Loss at prune: 0.0003
# [I 2024-10-07 14:40:57,437] Trial 47 pruned.
# Trial 47 pruned at epoch 10
# Validation Loss at prune: 0.0004
# [I 2024-10-07 14:40:59,347] Trial 48 pruned.
# Trial 48 pruned at epoch 10
# Validation Loss at prune: 0.0006
# [I 2024-10-07 14:42:20,418] Trial 49 finished with value: 9.945683923535934e-05 and parameters: {'hidden_size': 128, 'num_layers': 2, 'learning_rate': 0.0018655860709912684, 'batch_size': 43}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:43:12,900] Trial 50 finished with value: 0.0001052200072101208 and parameters: {'hidden_size': 169, 'num_layers': 1, 'learning_rate': 0.007129679585007234, 'batch_size': 78}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:43:15,224] Trial 51 pruned.
# Trial 51 pruned at epoch 10
# Validation Loss at prune: 0.0009
# [I 2024-10-07 14:43:17,976] Trial 52 pruned.
# Trial 52 pruned at epoch 10
# Validation Loss at prune: 0.0007
# [I 2024-10-07 14:43:20,246] Trial 53 pruned.
# Trial 53 pruned at epoch 10
# Validation Loss at prune: 0.0003
# [I 2024-10-07 14:44:13,355] Trial 54 finished with value: 9.205456289449986e-05 and parameters: {'hidden_size': 183, 'num_layers': 1, 'learning_rate': 0.006759136157301238, 'batch_size': 88}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:44:15,021] Trial 55 pruned.
# Trial 55 pruned at epoch 10
# Validation Loss at prune: 0.0004
# [I 2024-10-07 14:44:18,323] Trial 56 pruned.
# Trial 56 pruned at epoch 10
# Validation Loss at prune: 0.0003
# [I 2024-10-07 14:44:20,754] Trial 57 pruned.
# Trial 57 pruned at epoch 10
# Validation Loss at prune: 0.0006
# [I 2024-10-07 14:44:23,892] Trial 58 pruned.
# Trial 58 pruned at epoch 10
# Validation Loss at prune: 0.0060
# [I 2024-10-07 14:45:32,364] Trial 59 finished with value: 0.00018736863326183467 and parameters: {'hidden_size': 193, 'num_layers': 1, 'learning_rate': 0.007137648670642379, 'batch_size': 47}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:47:22,364] Trial 60 finished with value: 8.447808955314908e-05 and parameters: {'hidden_size': 168, 'num_layers': 1, 'learning_rate': 0.0038198150415474853, 'batch_size': 27}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:49:12,435] Trial 61 finished with value: 6.599227731714066e-05 and parameters: {'hidden_size': 166, 'num_layers': 1, 'learning_rate': 0.005374141954499434, 'batch_size': 27}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:50:53,230] Trial 62 finished with value: 8.993221808268523e-05 and parameters: {'hidden_size': 165, 'num_layers': 1, 'learning_rate': 0.003715359572583444, 'batch_size': 30}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:52:46,112] Trial 63 finished with value: 7.620046851124175e-05 and parameters: {'hidden_size': 164, 'num_layers': 1, 'learning_rate': 0.003565601746268506, 'batch_size': 26}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:52:50,619] Trial 64 pruned.
# Trial 64 pruned at epoch 11
# Validation Loss at prune: 0.0003
# [I 2024-10-07 14:55:13,830] Trial 65 finished with value: 8.857683819443267e-05 and parameters: {'hidden_size': 164, 'num_layers': 1, 'learning_rate': 0.00215775503569257, 'batch_size': 20}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:55:26,666] Trial 66 pruned.
# Trial 66 pruned at epoch 10
# Validation Loss at prune: 0.0138
# [I 2024-10-07 14:55:29,599] Trial 67 pruned.
# Trial 67 pruned at epoch 10
# Validation Loss at prune: 0.0010
# [I 2024-10-07 14:55:34,037] Trial 68 pruned.
# Trial 68 pruned at epoch 10
# Validation Loss at prune: 0.0004
# [I 2024-10-07 14:57:33,001] Trial 69 finished with value: 8.652306210977529e-05 and parameters: {'hidden_size': 189, 'num_layers': 1, 'learning_rate': 0.003836711866465102, 'batch_size': 25}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 14:59:14,448] Trial 70 finished with value: 8.283252138817766e-05 and parameters: {'hidden_size': 198, 'num_layers': 1, 'learning_rate': 0.0016994182722981019, 'batch_size': 30}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:01:01,443] Trial 71 finished with value: 9.22854874092175e-05 and parameters: {'hidden_size': 180, 'num_layers': 1, 'learning_rate': 0.005013171973819276, 'batch_size': 28}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:01:06,090] Trial 72 pruned.
# Trial 72 pruned at epoch 12
# Validation Loss at prune: 0.0002
# [I 2024-10-07 15:01:11,663] Trial 73 pruned.
# Trial 73 pruned at epoch 12
# Validation Loss at prune: 0.0002
# [I 2024-10-07 15:01:15,899] Trial 74 pruned.
# Trial 74 pruned at epoch 12
# Validation Loss at prune: 0.0001
# [I 2024-10-07 15:03:52,805] Trial 75 finished with value: 6.914791948237409e-05 and parameters: {'hidden_size': 174, 'num_layers': 1, 'learning_rate': 0.0011254126270606247, 'batch_size': 18}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:06:23,014] Trial 76 finished with value: 7.116235990106919e-05 and parameters: {'hidden_size': 192, 'num_layers': 1, 'learning_rate': 0.0011788968955215606, 'batch_size': 19}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:06:32,290] Trial 77 pruned.
# Trial 77 pruned at epoch 12
# Validation Loss at prune: 0.0001
# [I 2024-10-07 15:06:37,824] Trial 78 pruned.
# Trial 78 pruned at epoch 10
# Validation Loss at prune: 0.0004
# [I 2024-10-07 15:06:44,708] Trial 79 pruned.
# Trial 79 pruned at epoch 10
# Validation Loss at prune: 0.0007
# [I 2024-10-07 15:06:47,950] Trial 80 pruned.
# Trial 80 pruned at epoch 10
# Validation Loss at prune: 0.0004
# [I 2024-10-07 15:06:51,748] Trial 81 pruned.
# Trial 81 pruned at epoch 10
# Validation Loss at prune: 0.0002
# [I 2024-10-07 15:06:57,100] Trial 82 pruned.
# Trial 82 pruned at epoch 10
# Validation Loss at prune: 0.0002
# [I 2024-10-07 15:07:00,710] Trial 83 pruned.
# Trial 83 pruned at epoch 10
# Validation Loss at prune: 0.0006
# [I 2024-10-07 15:09:56,373] Trial 84 finished with value: 7.941989158106652e-05 and parameters: {'hidden_size': 184, 'num_layers': 1, 'learning_rate': 0.0018580138210635608, 'batch_size': 16}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:12:51,134] Trial 85 finished with value: 9.784486140872851e-05 and parameters: {'hidden_size': 161, 'num_layers': 1, 'learning_rate': 0.002300144904296931, 'batch_size': 16}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:12:57,030] Trial 86 pruned.
# Trial 86 pruned at epoch 11
# Validation Loss at prune: 0.0004
# [I 2024-10-07 15:14:47,412] Trial 87 finished with value: 0.0004470869601895494 and parameters: {'hidden_size': 57, 'num_layers': 1, 'learning_rate': 0.005662989009931844, 'batch_size': 24}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:14:58,112] Trial 88 pruned.
# Trial 88 pruned at epoch 10
# Validation Loss at prune: 0.0011
# [I 2024-10-07 15:17:51,277] Trial 89 finished with value: 0.00013171849518523493 and parameters: {'hidden_size': 153, 'num_layers': 1, 'learning_rate': 0.00205643659105545, 'batch_size': 16}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:17:55,248] Trial 90 pruned.
# Trial 90 pruned at epoch 10
# Validation Loss at prune: 0.0046
# [I 2024-10-07 15:19:23,751] Trial 91 finished with value: 8.849530668946439e-05 and parameters: {'hidden_size': 202, 'num_layers': 1, 'learning_rate': 0.0016071228429970516, 'batch_size': 35}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:21:41,176] Trial 92 finished with value: 8.789519869646381e-05 and parameters: {'hidden_size': 189, 'num_layers': 1, 'learning_rate': 0.0011628627799476193, 'batch_size': 21}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:21:43,214] Trial 93 pruned.
# Trial 93 pruned at epoch 10
# Validation Loss at prune: 0.0007
# [I 2024-10-07 15:23:39,199] Trial 94 finished with value: 7.033291984656544e-05 and parameters: {'hidden_size': 197, 'num_layers': 1, 'learning_rate': 0.0017457829994533963, 'batch_size': 26}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:23:43,384] Trial 95 pruned.
# Trial 95 pruned at epoch 10
# Validation Loss at prune: 0.0004
# [I 2024-10-07 15:23:48,024] Trial 96 pruned.
# Trial 96 pruned at epoch 10
# Validation Loss at prune: 0.0008
# [I 2024-10-07 15:25:12,570] Trial 97 finished with value: 8.702470780738765e-05 and parameters: {'hidden_size': 192, 'num_layers': 1, 'learning_rate': 0.0032937117833392775, 'batch_size': 38}. Best is trial 15 with value: 6.583269049682751e-05.
# [I 2024-10-07 15:25:14,776] Trial 98 pruned.
# Trial 98 pruned at epoch 10
# Validation Loss at prune: 0.0009
# [I 2024-10-07 15:25:21,218] Trial 99 pruned.
# Trial 99 pruned at epoch 10
# Validation Loss at prune: 0.0002
# Best hyperparameters:  {'hidden_size': 213, 'num_layers': 1, 'learning_rate': 0.004672420526588498, 'batch_size': 33}

# %% [markdown]
# ### 5. 하이퍼파라미터 저장

# %%
import json

### 하이퍼 파라미터 저장

# 최적의 하이퍼파라미터를 JSON 파일로 저장
with open("best_hyperparameters.json", "w") as f:
    json.dump(study.best_params, f, indent=4)

print("Best hyperparameters have been saved to 'best_hyperparameters.json'")
# Out:
# Best hyperparameters have been saved to 'best_hyperparameters.json'

# %% [markdown]
# ## 학습

# %% [markdown]
# ### 1. 하이퍼파라미터 불러오기

# %%
import json

# 저장된 하이퍼파라미터 불러오기
with open("best_hyperparameters.json", "r") as f:
    best_params = json.load(f)

print("Loaded best hyperparameters:", best_params)
# Out:
# Loaded best hyperparameters: {'hidden_size': 213, 'num_layers': 1, 'learning_rate': 0.004672420526588498, 'batch_size': 33}

# %% [markdown]
# ### 2. 최적의 파라미터로 모델 학습

# %%
sequence_length = 10
num_epochs = 300

# %%
# 최적의 모델 학습

train_loader, val_loader, test_loader = create_dataloaders(tri, best_params['batch_size'], sequence_length)

best_model = LSTM_Model(input_size=3, hidden_size=best_params['hidden_size'],
                      num_layers=best_params['num_layers'], output_size=3)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
best_model = best_model.to(device)

optimizer = torch.optim.Adam(best_model.parameters(), lr=best_params['learning_rate'])
criterion = torch.nn.MSELoss()

# %%
import time
import torch

# 학습 및 검증 손실을 기록할 리스트
train_losses = []
val_losses = []

best_model.train()
total_train_time = 0  # 총 학습 시간 기록 변수

for epoch in range(num_epochs):  # 최종 모델 학습
    best_model.train()
    train_loss = 0.0
    epoch_start_time = time.time()  # 에포크 시작 시간 기록
    for batch_x, batch_y in train_loader:
        batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = best_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    epoch_end_time = time.time()  # 에포크 종료 시간 기록
    epoch_duration = epoch_end_time - epoch_start_time  # 한 에포크의 학습 시간
    total_train_time += epoch_duration  # 총 학습 시간에 추가

    # Validation set에서 성능 측정
    best_model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch_x, batch_y in val_loader:
            batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
            batch_y = batch_y.to(device)
            output = best_model(batch_x)
            loss = criterion(output, batch_y)
            val_loss += loss.item()

    # 평균 손실 계산 및 저장
    train_losses.append(train_loss / len(train_loader))
    val_losses.append(val_loss / len(val_loader))

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

    # 모델 저장
    if (epoch + 1) % 100 == 0:

      # Model Save
      model_save_path = f"best_model_epoch_{epoch+1}.pth"
      torch.save({
        'model_state_dict': best_model.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses
      }, model_save_path)
      print(f"Model saved: {model_save_path}")

    print(f"Epoch {epoch+1}/{num_epochs} completed in {epoch_duration:.2f} seconds.")

print(f"Total training time: {total_train_time:.2f} seconds.")
# Out:
# Epoch [1/300], Train Loss: 4.6332, Val Loss: 0.3111
# Epoch 1/300 completed in 1.55 seconds.
# Epoch [2/300], Train Loss: 0.1972, Val Loss: 0.0657
# Epoch 2/300 completed in 0.45 seconds.
# Epoch [3/300], Train Loss: 0.0364, Val Loss: 0.0370
# Epoch 3/300 completed in 0.61 seconds.
# Epoch [4/300], Train Loss: 0.0264, Val Loss: 0.0222
# Epoch 4/300 completed in 0.58 seconds.
# Epoch [5/300], Train Loss: 0.0237, Val Loss: 0.0270
# Epoch 5/300 completed in 0.62 seconds.
# Epoch [6/300], Train Loss: 0.0253, Val Loss: 0.0147
# Epoch 6/300 completed in 0.72 seconds.
# Epoch [7/300], Train Loss: 0.0188, Val Loss: 0.0140
# Epoch 7/300 completed in 0.56 seconds.
# Epoch [8/300], Train Loss: 0.0205, Val Loss: 0.0095
# Epoch 8/300 completed in 0.50 seconds.
# Epoch [9/300], Train Loss: 0.0149, Val Loss: 0.0097
# Epoch 9/300 completed in 0.56 seconds.
# Epoch [10/300], Train Loss: 0.0130, Val Loss: 0.0101
# Epoch 10/300 completed in 0.48 seconds.
# Epoch [11/300], Train Loss: 0.0158, Val Loss: 0.0104
# Epoch 11/300 completed in 0.46 seconds.
# Epoch [12/300], Train Loss: 0.0094, Val Loss: 0.0100
# Epoch 12/300 completed in 0.49 seconds.
# Epoch [13/300], Train Loss: 0.0087, Val Loss: 0.0084
# Epoch 13/300 completed in 0.48 seconds.
# Epoch [14/300], Train Loss: 0.0080, Val Loss: 0.0056
# Epoch 14/300 completed in 0.40 seconds.
# Epoch [15/300], Train Loss: 0.0102, Val Loss: 0.0067
# Epoch 15/300 completed in 0.41 seconds.
# Epoch [16/300], Train Loss: 0.0069, Val Loss: 0.0043
# Epoch 16/300 completed in 0.63 seconds.
# Epoch [17/300], Train Loss: 0.0059, Val Loss: 0.0044
# Epoch 17/300 completed in 0.49 seconds.
# Epoch [18/300], Train Loss: 0.0092, Val Loss: 0.0049
# Epoch 18/300 completed in 0.39 seconds.
# Epoch [19/300], Train Loss: 0.0062, Val Loss: 0.0068
# Epoch 19/300 completed in 0.45 seconds.
# Epoch [20/300], Train Loss: 0.0089, Val Loss: 0.0050
# Epoch 20/300 completed in 0.52 seconds.
# Epoch [21/300], Train Loss: 0.0067, Val Loss: 0.0081
# Epoch 21/300 completed in 0.53 seconds.
# Epoch [22/300], Train Loss: 0.0068, Val Loss: 0.0033
# Epoch 22/300 completed in 0.41 seconds.
# Epoch [23/300], Train Loss: 0.0062, Val Loss: 0.0059
# Epoch 23/300 completed in 0.27 seconds.
# Epoch [24/300], Train Loss: 0.0074, Val Loss: 0.0040
# Epoch 24/300 completed in 0.27 seconds.
# Epoch [25/300], Train Loss: 0.0052, Val Loss: 0.0037
# Epoch 25/300 completed in 0.27 seconds.
# Epoch [26/300], Train Loss: 0.0052, Val Loss: 0.0029
# Epoch 26/300 completed in 0.26 seconds.
# Epoch [27/300], Train Loss: 0.0064, Val Loss: 0.0049
# Epoch 27/300 completed in 0.27 seconds.
# Epoch [28/300], Train Loss: 0.0069, Val Loss: 0.0042
# Epoch 28/300 completed in 0.34 seconds.
# Epoch [29/300], Train Loss: 0.0055, Val Loss: 0.0035
# Epoch 29/300 completed in 0.34 seconds.
# Epoch [30/300], Train Loss: 0.0068, Val Loss: 0.0062
# Epoch 30/300 completed in 0.34 seconds.
# Epoch [31/300], Train Loss: 0.0092, Val Loss: 0.0102
# Epoch 31/300 completed in 0.34 seconds.
# Epoch [32/300], Train Loss: 0.0106, Val Loss: 0.0026
# Epoch 32/300 completed in 0.36 seconds.
# Epoch [33/300], Train Loss: 0.0048, Val Loss: 0.0028
# Epoch 33/300 completed in 0.36 seconds.
# Epoch [34/300], Train Loss: 0.0039, Val Loss: 0.0028
# Epoch 34/300 completed in 0.38 seconds.
# Epoch [35/300], Train Loss: 0.0040, Val Loss: 0.0040
# Epoch 35/300 completed in 0.29 seconds.
# Epoch [36/300], Train Loss: 0.0067, Val Loss: 0.0044
# Epoch 36/300 completed in 0.27 seconds.
# Epoch [37/300], Train Loss: 0.0076, Val Loss: 0.0025
# Epoch 37/300 completed in 0.26 seconds.
# Epoch [38/300], Train Loss: 0.0057, Val Loss: 0.0030
# Epoch 38/300 completed in 0.25 seconds.
# Epoch [39/300], Train Loss: 0.0042, Val Loss: 0.0036
# Epoch 39/300 completed in 0.27 seconds.
# Epoch [40/300], Train Loss: 0.0040, Val Loss: 0.0031
# Epoch 40/300 completed in 0.26 seconds.
# Epoch [41/300], Train Loss: 0.0037, Val Loss: 0.0030
# Epoch 41/300 completed in 0.26 seconds.
# Epoch [42/300], Train Loss: 0.0063, Val Loss: 0.0046
# Epoch 42/300 completed in 0.26 seconds.
# Epoch [43/300], Train Loss: 0.0049, Val Loss: 0.0011
# Epoch 43/300 completed in 0.27 seconds.
# Epoch [44/300], Train Loss: 0.0040, Val Loss: 0.0029
# Epoch 44/300 completed in 0.26 seconds.
# Epoch [45/300], Train Loss: 0.0071, Val Loss: 0.0030
# Epoch 45/300 completed in 0.26 seconds.
# Epoch [46/300], Train Loss: 0.0036, Val Loss: 0.0015
# Epoch 46/300 completed in 0.27 seconds.
# Epoch [47/300], Train Loss: 0.0070, Val Loss: 0.0038
# Epoch 47/300 completed in 0.31 seconds.
# Epoch [48/300], Train Loss: 0.0049, Val Loss: 0.0031
# Epoch 48/300 completed in 0.34 seconds.
# Epoch [49/300], Train Loss: 0.0037, Val Loss: 0.0026
# Epoch 49/300 completed in 0.26 seconds.
# Epoch [50/300], Train Loss: 0.0042, Val Loss: 0.0034
# Epoch 50/300 completed in 0.26 seconds.
# Epoch [51/300], Train Loss: 0.0039, Val Loss: 0.0023
# Epoch 51/300 completed in 0.26 seconds.
# Epoch [52/300], Train Loss: 0.0047, Val Loss: 0.0030
# Epoch 52/300 completed in 0.26 seconds.
# Epoch [53/300], Train Loss: 0.0048, Val Loss: 0.0015
# Epoch 53/300 completed in 0.26 seconds.
# Epoch [54/300], Train Loss: 0.0162, Val Loss: 0.0021
# Epoch 54/300 completed in 0.26 seconds.
# Epoch [55/300], Train Loss: 0.0021, Val Loss: 0.0020
# Epoch 55/300 completed in 0.26 seconds.
# Epoch [56/300], Train Loss: 0.0024, Val Loss: 0.0025
# Epoch 56/300 completed in 0.27 seconds.
# Epoch [57/300], Train Loss: 0.0033, Val Loss: 0.0015
# Epoch 57/300 completed in 0.26 seconds.
# Epoch [58/300], Train Loss: 0.0032, Val Loss: 0.0025
# Epoch 58/300 completed in 0.26 seconds.
# Epoch [59/300], Train Loss: 0.0026, Val Loss: 0.0019
# Epoch 59/300 completed in 0.26 seconds.
# Epoch [60/300], Train Loss: 0.0025, Val Loss: 0.0019
# Epoch 60/300 completed in 0.27 seconds.
# Epoch [61/300], Train Loss: 0.0027, Val Loss: 0.0027
# Epoch 61/300 completed in 0.26 seconds.
# Epoch [62/300], Train Loss: 0.0027, Val Loss: 0.0009
# Epoch 62/300 completed in 0.25 seconds.
# Epoch [63/300], Train Loss: 0.0137, Val Loss: 0.0084
# Epoch 63/300 completed in 0.26 seconds.
# Epoch [64/300], Train Loss: 0.0043, Val Loss: 0.0016
# Epoch 64/300 completed in 0.26 seconds.
# Epoch [65/300], Train Loss: 0.0026, Val Loss: 0.0052
# Epoch 65/300 completed in 0.25 seconds.
# Epoch [66/300], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 66/300 completed in 0.25 seconds.
# Epoch [67/300], Train Loss: 0.0025, Val Loss: 0.0018
# Epoch 67/300 completed in 0.27 seconds.
# Epoch [68/300], Train Loss: 0.0034, Val Loss: 0.0017
# Epoch 68/300 completed in 0.27 seconds.
# Epoch [69/300], Train Loss: 0.0034, Val Loss: 0.0013
# Epoch 69/300 completed in 0.35 seconds.
# Epoch [70/300], Train Loss: 0.0025, Val Loss: 0.0015
# Epoch 70/300 completed in 0.35 seconds.
# Epoch [71/300], Train Loss: 0.0026, Val Loss: 0.0009
# Epoch 71/300 completed in 0.34 seconds.
# Epoch [72/300], Train Loss: 0.0022, Val Loss: 0.0024
# Epoch 72/300 completed in 0.36 seconds.
# Epoch [73/300], Train Loss: 0.0027, Val Loss: 0.0033
# Epoch 73/300 completed in 0.37 seconds.
# Epoch [74/300], Train Loss: 0.0041, Val Loss: 0.0008
# Epoch 74/300 completed in 0.36 seconds.
# Epoch [75/300], Train Loss: 0.0024, Val Loss: 0.0016
# Epoch 75/300 completed in 0.29 seconds.
# Epoch [76/300], Train Loss: 0.0037, Val Loss: 0.0014
# Epoch 76/300 completed in 0.26 seconds.
# Epoch [77/300], Train Loss: 0.0034, Val Loss: 0.0019
# Epoch 77/300 completed in 0.26 seconds.
# Epoch [78/300], Train Loss: 0.0026, Val Loss: 0.0021
# Epoch 78/300 completed in 0.26 seconds.
# Epoch [79/300], Train Loss: 0.0044, Val Loss: 0.0010
# Epoch 79/300 completed in 0.26 seconds.
# Epoch [80/300], Train Loss: 0.0022, Val Loss: 0.0013
# Epoch 80/300 completed in 0.26 seconds.
# Epoch [81/300], Train Loss: 0.0019, Val Loss: 0.0010
# Epoch 81/300 completed in 0.25 seconds.
# Epoch [82/300], Train Loss: 0.0024, Val Loss: 0.0031
# Epoch 82/300 completed in 0.27 seconds.
# Epoch [83/300], Train Loss: 0.0023, Val Loss: 0.0013
# Epoch 83/300 completed in 0.26 seconds.
# Epoch [84/300], Train Loss: 0.0029, Val Loss: 0.0009
# Epoch 84/300 completed in 0.26 seconds.
# Epoch [85/300], Train Loss: 0.0024, Val Loss: 0.0013
# Epoch 85/300 completed in 0.26 seconds.
# Epoch [86/300], Train Loss: 0.0028, Val Loss: 0.0015
# Epoch 86/300 completed in 0.26 seconds.
# Epoch [87/300], Train Loss: 0.0032, Val Loss: 0.0019
# Epoch 87/300 completed in 0.26 seconds.
# Epoch [88/300], Train Loss: 0.0023, Val Loss: 0.0013
# Epoch 88/300 completed in 0.26 seconds.
# Epoch [89/300], Train Loss: 0.0024, Val Loss: 0.0019
# Epoch 89/300 completed in 0.27 seconds.
# Epoch [90/300], Train Loss: 0.0025, Val Loss: 0.0007
# Epoch 90/300 completed in 0.26 seconds.
# Epoch [91/300], Train Loss: 0.0028, Val Loss: 0.0020
# Epoch 91/300 completed in 0.26 seconds.
# Epoch [92/300], Train Loss: 0.0053, Val Loss: 0.0026
# Epoch 92/300 completed in 0.26 seconds.
# Epoch [93/300], Train Loss: 0.0025, Val Loss: 0.0021
# Epoch 93/300 completed in 0.26 seconds.
# Epoch [94/300], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 94/300 completed in 0.26 seconds.
# Epoch [95/300], Train Loss: 0.0021, Val Loss: 0.0024
# Epoch 95/300 completed in 0.26 seconds.
# Epoch [96/300], Train Loss: 0.0034, Val Loss: 0.0011
# Epoch 96/300 completed in 0.27 seconds.
# Epoch [97/300], Train Loss: 0.0029, Val Loss: 0.0009
# Epoch 97/300 completed in 0.26 seconds.
# Epoch [98/300], Train Loss: 0.0024, Val Loss: 0.0017
# Epoch 98/300 completed in 0.26 seconds.
# Epoch [99/300], Train Loss: 0.0018, Val Loss: 0.0008
# Epoch 99/300 completed in 0.26 seconds.
# Epoch [100/300], Train Loss: 0.0019, Val Loss: 0.0014
# Model saved: best_model_epoch_100.pth
# Epoch 100/300 completed in 0.26 seconds.
# Epoch [101/300], Train Loss: 0.0051, Val Loss: 0.0016
# Epoch 101/300 completed in 0.26 seconds.
# Epoch [102/300], Train Loss: 0.0022, Val Loss: 0.0012
# Epoch 102/300 completed in 0.25 seconds.
# Epoch [103/300], Train Loss: 0.0022, Val Loss: 0.0011
# Epoch 103/300 completed in 0.27 seconds.
# Epoch [104/300], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 104/300 completed in 0.26 seconds.
# Epoch [105/300], Train Loss: 0.0024, Val Loss: 0.0009
# Epoch 105/300 completed in 0.26 seconds.
# Epoch [106/300], Train Loss: 0.0020, Val Loss: 0.0009
# Epoch 106/300 completed in 0.27 seconds.
# Epoch [107/300], Train Loss: 0.0022, Val Loss: 0.0014
# Epoch 107/300 completed in 0.27 seconds.
# Epoch [108/300], Train Loss: 0.0021, Val Loss: 0.0008
# Epoch 108/300 completed in 0.26 seconds.
# Epoch [109/300], Train Loss: 0.0020, Val Loss: 0.0017
# Epoch 109/300 completed in 0.38 seconds.
# Epoch [110/300], Train Loss: 0.0033, Val Loss: 0.0010
# Epoch 110/300 completed in 0.34 seconds.
# Epoch [111/300], Train Loss: 0.0022, Val Loss: 0.0010
# Epoch 111/300 completed in 0.34 seconds.
# Epoch [112/300], Train Loss: 0.0022, Val Loss: 0.0012
# Epoch 112/300 completed in 0.38 seconds.
# Epoch [113/300], Train Loss: 0.0021, Val Loss: 0.0030
# Epoch 113/300 completed in 0.37 seconds.
# Epoch [114/300], Train Loss: 0.0031, Val Loss: 0.0044
# Epoch 114/300 completed in 0.36 seconds.
# Epoch [115/300], Train Loss: 0.0022, Val Loss: 0.0011
# Epoch 115/300 completed in 0.35 seconds.
# Epoch [116/300], Train Loss: 0.0017, Val Loss: 0.0013
# Epoch 116/300 completed in 0.26 seconds.
# Epoch [117/300], Train Loss: 0.0016, Val Loss: 0.0019
# Epoch 117/300 completed in 0.26 seconds.
# Epoch [118/300], Train Loss: 0.0018, Val Loss: 0.0011
# Epoch 118/300 completed in 0.27 seconds.
# Epoch [119/300], Train Loss: 0.0030, Val Loss: 0.0007
# Epoch 119/300 completed in 0.26 seconds.
# Epoch [120/300], Train Loss: 0.0035, Val Loss: 0.0010
# Epoch 120/300 completed in 0.26 seconds.
# Epoch [121/300], Train Loss: 0.0017, Val Loss: 0.0024
# Epoch 121/300 completed in 0.26 seconds.
# Epoch [122/300], Train Loss: 0.0022, Val Loss: 0.0015
# Epoch 122/300 completed in 0.26 seconds.
# Epoch [123/300], Train Loss: 0.0019, Val Loss: 0.0009
# Epoch 123/300 completed in 0.26 seconds.
# Epoch [124/300], Train Loss: 0.0019, Val Loss: 0.0014
# Epoch 124/300 completed in 0.26 seconds.
# Epoch [125/300], Train Loss: 0.0016, Val Loss: 0.0008
# Epoch 125/300 completed in 0.27 seconds.
# Epoch [126/300], Train Loss: 0.0021, Val Loss: 0.0020
# Epoch 126/300 completed in 0.27 seconds.
# Epoch [127/300], Train Loss: 0.0022, Val Loss: 0.0010
# Epoch 127/300 completed in 0.27 seconds.
# Epoch [128/300], Train Loss: 0.0020, Val Loss: 0.0013
# Epoch 128/300 completed in 0.27 seconds.
# Epoch [129/300], Train Loss: 0.0018, Val Loss: 0.0018
# Epoch 129/300 completed in 0.26 seconds.
# Epoch [130/300], Train Loss: 0.0027, Val Loss: 0.0026
# Epoch 130/300 completed in 0.26 seconds.
# Epoch [131/300], Train Loss: 0.0023, Val Loss: 0.0009
# Epoch 131/300 completed in 0.27 seconds.
# Epoch [132/300], Train Loss: 0.0024, Val Loss: 0.0015
# Epoch 132/300 completed in 0.27 seconds.
# Epoch [133/300], Train Loss: 0.0018, Val Loss: 0.0010
# Epoch 133/300 completed in 0.28 seconds.
# Epoch [134/300], Train Loss: 0.0016, Val Loss: 0.0014
# Epoch 134/300 completed in 0.26 seconds.
# Epoch [135/300], Train Loss: 0.0021, Val Loss: 0.0012
# Epoch 135/300 completed in 0.27 seconds.
# Epoch [136/300], Train Loss: 0.0028, Val Loss: 0.0016
# Epoch 136/300 completed in 0.27 seconds.
# Epoch [137/300], Train Loss: 0.0017, Val Loss: 0.0009
# Epoch 137/300 completed in 0.27 seconds.
# Epoch [138/300], Train Loss: 0.0019, Val Loss: 0.0008
# Epoch 138/300 completed in 0.27 seconds.
# Epoch [139/300], Train Loss: 0.0020, Val Loss: 0.0016
# Epoch 139/300 completed in 0.28 seconds.
# Epoch [140/300], Train Loss: 0.0016, Val Loss: 0.0011
# Epoch 140/300 completed in 0.27 seconds.
# Epoch [141/300], Train Loss: 0.0019, Val Loss: 0.0010
# Epoch 141/300 completed in 0.27 seconds.
# Epoch [142/300], Train Loss: 0.0016, Val Loss: 0.0016
# Epoch 142/300 completed in 0.28 seconds.
# Epoch [143/300], Train Loss: 0.0021, Val Loss: 0.0009
# Epoch 143/300 completed in 0.26 seconds.
# Epoch [144/300], Train Loss: 0.0022, Val Loss: 0.0012
# Epoch 144/300 completed in 0.27 seconds.
# Epoch [145/300], Train Loss: 0.0030, Val Loss: 0.0010
# Epoch 145/300 completed in 0.28 seconds.
# Epoch [146/300], Train Loss: 0.0016, Val Loss: 0.0018
# Epoch 146/300 completed in 0.27 seconds.
# Epoch [147/300], Train Loss: 0.0018, Val Loss: 0.0012
# Epoch 147/300 completed in 0.26 seconds.
# Epoch [148/300], Train Loss: 0.0018, Val Loss: 0.0009
# Epoch 148/300 completed in 0.26 seconds.
# Epoch [149/300], Train Loss: 0.0015, Val Loss: 0.0010
# Epoch 149/300 completed in 0.38 seconds.
# Epoch [150/300], Train Loss: 0.0016, Val Loss: 0.0010
# Epoch 150/300 completed in 0.35 seconds.
# Epoch [151/300], Train Loss: 0.0018, Val Loss: 0.0012
# Epoch 151/300 completed in 0.33 seconds.
# Epoch [152/300], Train Loss: 0.0017, Val Loss: 0.0011
# Epoch 152/300 completed in 0.36 seconds.
# Epoch [153/300], Train Loss: 0.0018, Val Loss: 0.0011
# Epoch 153/300 completed in 0.36 seconds.
# Epoch [154/300], Train Loss: 0.0024, Val Loss: 0.0012
# Epoch 154/300 completed in 0.38 seconds.
# Epoch [155/300], Train Loss: 0.0016, Val Loss: 0.0012
# Epoch 155/300 completed in 0.27 seconds.
# Epoch [156/300], Train Loss: 0.0019, Val Loss: 0.0009
# Epoch 156/300 completed in 0.26 seconds.
# Epoch [157/300], Train Loss: 0.0019, Val Loss: 0.0010
# Epoch 157/300 completed in 0.28 seconds.
# Epoch [158/300], Train Loss: 0.0019, Val Loss: 0.0009
# Epoch 158/300 completed in 0.26 seconds.
# Epoch [159/300], Train Loss: 0.0017, Val Loss: 0.0011
# Epoch 159/300 completed in 0.26 seconds.
# Epoch [160/300], Train Loss: 0.0015, Val Loss: 0.0009
# Epoch 160/300 completed in 0.26 seconds.
# Epoch [161/300], Train Loss: 0.0017, Val Loss: 0.0014
# Epoch 161/300 completed in 0.27 seconds.
# Epoch [162/300], Train Loss: 0.0016, Val Loss: 0.0018
# Epoch 162/300 completed in 0.26 seconds.
# Epoch [163/300], Train Loss: 0.0015, Val Loss: 0.0014
# Epoch 163/300 completed in 0.27 seconds.
# Epoch [164/300], Train Loss: 0.0015, Val Loss: 0.0013
# Epoch 164/300 completed in 0.29 seconds.
# Epoch [165/300], Train Loss: 0.0021, Val Loss: 0.0015
# Epoch 165/300 completed in 0.26 seconds.
# Epoch [166/300], Train Loss: 0.0020, Val Loss: 0.0011
# Epoch 166/300 completed in 0.26 seconds.
# Epoch [167/300], Train Loss: 0.0017, Val Loss: 0.0010
# Epoch 167/300 completed in 0.26 seconds.
# Epoch [168/300], Train Loss: 0.0035, Val Loss: 0.0017
# Epoch 168/300 completed in 0.27 seconds.
# Epoch [169/300], Train Loss: 0.0014, Val Loss: 0.0011
# Epoch 169/300 completed in 0.26 seconds.
# Epoch [170/300], Train Loss: 0.0016, Val Loss: 0.0010
# Epoch 170/300 completed in 0.26 seconds.
# Epoch [171/300], Train Loss: 0.0015, Val Loss: 0.0013
# Epoch 171/300 completed in 0.27 seconds.
# Epoch [172/300], Train Loss: 0.0017, Val Loss: 0.0017
# Epoch 172/300 completed in 0.26 seconds.
# Epoch [173/300], Train Loss: 0.0020, Val Loss: 0.0012
# Epoch 173/300 completed in 0.26 seconds.
# Epoch [174/300], Train Loss: 0.0016, Val Loss: 0.0011
# Epoch 174/300 completed in 0.26 seconds.
# Epoch [175/300], Train Loss: 0.0018, Val Loss: 0.0011
# Epoch 175/300 completed in 0.26 seconds.
# Epoch [176/300], Train Loss: 0.0017, Val Loss: 0.0009
# Epoch 176/300 completed in 0.26 seconds.
# Epoch [177/300], Train Loss: 0.0016, Val Loss: 0.0010
# Epoch 177/300 completed in 0.26 seconds.
# Epoch [178/300], Train Loss: 0.0018, Val Loss: 0.0010
# Epoch 178/300 completed in 0.27 seconds.
# Epoch [179/300], Train Loss: 0.0015, Val Loss: 0.0010
# Epoch 179/300 completed in 0.26 seconds.
# Epoch [180/300], Train Loss: 0.0017, Val Loss: 0.0014
# Epoch 180/300 completed in 0.26 seconds.
# Epoch [181/300], Train Loss: 0.0017, Val Loss: 0.0015
# Epoch 181/300 completed in 0.26 seconds.
# Epoch [182/300], Train Loss: 0.0014, Val Loss: 0.0011
# Epoch 182/300 completed in 0.27 seconds.
# Epoch [183/300], Train Loss: 0.0015, Val Loss: 0.0011
# Epoch 183/300 completed in 0.26 seconds.
# Epoch [184/300], Train Loss: 0.0015, Val Loss: 0.0010
# Epoch 184/300 completed in 0.25 seconds.
# Epoch [185/300], Train Loss: 0.0017, Val Loss: 0.0013
# Epoch 185/300 completed in 0.26 seconds.
# Epoch [186/300], Train Loss: 0.0017, Val Loss: 0.0012
# Epoch 186/300 completed in 0.25 seconds.
# Epoch [187/300], Train Loss: 0.0017, Val Loss: 0.0014
# Epoch 187/300 completed in 0.25 seconds.
# Epoch [188/300], Train Loss: 0.0029, Val Loss: 0.0013
# Epoch 188/300 completed in 0.28 seconds.
# Epoch [189/300], Train Loss: 0.0015, Val Loss: 0.0010
# Epoch 189/300 completed in 0.35 seconds.
# Epoch [190/300], Train Loss: 0.0016, Val Loss: 0.0010
# Epoch 190/300 completed in 0.35 seconds.
# Epoch [191/300], Train Loss: 0.0018, Val Loss: 0.0019
# Epoch 191/300 completed in 0.35 seconds.
# Epoch [192/300], Train Loss: 0.0015, Val Loss: 0.0011
# Epoch 192/300 completed in 0.36 seconds.
# Epoch [193/300], Train Loss: 0.0019, Val Loss: 0.0012
# Epoch 193/300 completed in 0.37 seconds.
# Epoch [194/300], Train Loss: 0.0016, Val Loss: 0.0013
# Epoch 194/300 completed in 0.37 seconds.
# Epoch [195/300], Train Loss: 0.0015, Val Loss: 0.0028
# Epoch 195/300 completed in 0.31 seconds.
# Epoch [196/300], Train Loss: 0.0018, Val Loss: 0.0013
# Epoch 196/300 completed in 0.26 seconds.
# Epoch [197/300], Train Loss: 0.0017, Val Loss: 0.0011
# Epoch 197/300 completed in 0.27 seconds.
# Epoch [198/300], Train Loss: 0.0017, Val Loss: 0.0015
# Epoch 198/300 completed in 0.25 seconds.
# Epoch [199/300], Train Loss: 0.0014, Val Loss: 0.0011
# Epoch 199/300 completed in 0.26 seconds.
# Epoch [200/300], Train Loss: 0.0024, Val Loss: 0.0018
# Model saved: best_model_epoch_200.pth
# Epoch 200/300 completed in 0.28 seconds.
# Epoch [201/300], Train Loss: 0.0018, Val Loss: 0.0011
# Epoch 201/300 completed in 0.26 seconds.
# Epoch [202/300], Train Loss: 0.0014, Val Loss: 0.0012
# Epoch 202/300 completed in 0.25 seconds.
# Epoch [203/300], Train Loss: 0.0016, Val Loss: 0.0014
# Epoch 203/300 completed in 0.26 seconds.
# Epoch [204/300], Train Loss: 0.0025, Val Loss: 0.0015
# Epoch 204/300 completed in 0.27 seconds.
# Epoch [205/300], Train Loss: 0.0014, Val Loss: 0.0015
# Epoch 205/300 completed in 0.26 seconds.
# Epoch [206/300], Train Loss: 0.0015, Val Loss: 0.0011
# Epoch 206/300 completed in 0.26 seconds.
# Epoch [207/300], Train Loss: 0.0013, Val Loss: 0.0011
# Epoch 207/300 completed in 0.27 seconds.
# Epoch [208/300], Train Loss: 0.0016, Val Loss: 0.0013
# Epoch 208/300 completed in 0.26 seconds.
# Epoch [209/300], Train Loss: 0.0015, Val Loss: 0.0016
# Epoch 209/300 completed in 0.26 seconds.
# Epoch [210/300], Train Loss: 0.0014, Val Loss: 0.0023
# Epoch 210/300 completed in 0.26 seconds.
# Epoch [211/300], Train Loss: 0.0017, Val Loss: 0.0019
# Epoch 211/300 completed in 0.27 seconds.
# Epoch [212/300], Train Loss: 0.0016, Val Loss: 0.0011
# Epoch 212/300 completed in 0.26 seconds.
# Epoch [213/300], Train Loss: 0.0016, Val Loss: 0.0018
# Epoch 213/300 completed in 0.27 seconds.
# Epoch [214/300], Train Loss: 0.0020, Val Loss: 0.0011
# Epoch 214/300 completed in 0.27 seconds.
# Epoch [215/300], Train Loss: 0.0016, Val Loss: 0.0011
# Epoch 215/300 completed in 0.26 seconds.
# Epoch [216/300], Train Loss: 0.0015, Val Loss: 0.0011
# Epoch 216/300 completed in 0.26 seconds.
# Epoch [217/300], Train Loss: 0.0015, Val Loss: 0.0012
# Epoch 217/300 completed in 0.26 seconds.
# Epoch [218/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 218/300 completed in 0.27 seconds.
# Epoch [219/300], Train Loss: 0.0016, Val Loss: 0.0015
# Epoch 219/300 completed in 0.26 seconds.
# Epoch [220/300], Train Loss: 0.0015, Val Loss: 0.0026
# Epoch 220/300 completed in 0.26 seconds.
# Epoch [221/300], Train Loss: 0.0019, Val Loss: 0.0016
# Epoch 221/300 completed in 0.27 seconds.
# Epoch [222/300], Train Loss: 0.0022, Val Loss: 0.0023
# Epoch 222/300 completed in 0.26 seconds.
# Epoch [223/300], Train Loss: 0.0014, Val Loss: 0.0012
# Epoch 223/300 completed in 0.26 seconds.
# Epoch [224/300], Train Loss: 0.0016, Val Loss: 0.0013
# Epoch 224/300 completed in 0.26 seconds.
# Epoch [225/300], Train Loss: 0.0015, Val Loss: 0.0014
# Epoch 225/300 completed in 0.26 seconds.
# Epoch [226/300], Train Loss: 0.0015, Val Loss: 0.0012
# Epoch 226/300 completed in 0.26 seconds.
# Epoch [227/300], Train Loss: 0.0018, Val Loss: 0.0018
# Epoch 227/300 completed in 0.26 seconds.
# Epoch [228/300], Train Loss: 0.0016, Val Loss: 0.0016
# Epoch 228/300 completed in 0.26 seconds.
# Epoch [229/300], Train Loss: 0.0014, Val Loss: 0.0014
# Epoch 229/300 completed in 0.32 seconds.
# Epoch [230/300], Train Loss: 0.0018, Val Loss: 0.0019
# Epoch 230/300 completed in 0.34 seconds.
# Epoch [231/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 231/300 completed in 0.35 seconds.
# Epoch [232/300], Train Loss: 0.0017, Val Loss: 0.0014
# Epoch 232/300 completed in 0.35 seconds.
# Epoch [233/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 233/300 completed in 0.37 seconds.
# Epoch [234/300], Train Loss: 0.0016, Val Loss: 0.0016
# Epoch 234/300 completed in 0.38 seconds.
# Epoch [235/300], Train Loss: 0.0019, Val Loss: 0.0017
# Epoch 235/300 completed in 0.34 seconds.
# Epoch [236/300], Train Loss: 0.0014, Val Loss: 0.0020
# Epoch 236/300 completed in 0.26 seconds.
# Epoch [237/300], Train Loss: 0.0018, Val Loss: 0.0017
# Epoch 237/300 completed in 0.28 seconds.
# Epoch [238/300], Train Loss: 0.0014, Val Loss: 0.0016
# Epoch 238/300 completed in 0.26 seconds.
# Epoch [239/300], Train Loss: 0.0015, Val Loss: 0.0018
# Epoch 239/300 completed in 0.26 seconds.
# Epoch [240/300], Train Loss: 0.0017, Val Loss: 0.0026
# Epoch 240/300 completed in 0.29 seconds.
# Epoch [241/300], Train Loss: 0.0016, Val Loss: 0.0017
# Epoch 241/300 completed in 0.26 seconds.
# Epoch [242/300], Train Loss: 0.0017, Val Loss: 0.0013
# Epoch 242/300 completed in 0.26 seconds.
# Epoch [243/300], Train Loss: 0.0015, Val Loss: 0.0019
# Epoch 243/300 completed in 0.27 seconds.
# Epoch [244/300], Train Loss: 0.0014, Val Loss: 0.0014
# Epoch 244/300 completed in 0.26 seconds.
# Epoch [245/300], Train Loss: 0.0016, Val Loss: 0.0017
# Epoch 245/300 completed in 0.26 seconds.
# Epoch [246/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 246/300 completed in 0.26 seconds.
# Epoch [247/300], Train Loss: 0.0016, Val Loss: 0.0015
# Epoch 247/300 completed in 0.27 seconds.
# Epoch [248/300], Train Loss: 0.0013, Val Loss: 0.0021
# Epoch 248/300 completed in 0.26 seconds.
# Epoch [249/300], Train Loss: 0.0014, Val Loss: 0.0014
# Epoch 249/300 completed in 0.26 seconds.
# Epoch [250/300], Train Loss: 0.0015, Val Loss: 0.0018
# Epoch 250/300 completed in 0.27 seconds.
# Epoch [251/300], Train Loss: 0.0016, Val Loss: 0.0020
# Epoch 251/300 completed in 0.26 seconds.
# Epoch [252/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 252/300 completed in 0.26 seconds.
# Epoch [253/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 253/300 completed in 0.26 seconds.
# Epoch [254/300], Train Loss: 0.0013, Val Loss: 0.0014
# Epoch 254/300 completed in 0.26 seconds.
# Epoch [255/300], Train Loss: 0.0014, Val Loss: 0.0018
# Epoch 255/300 completed in 0.26 seconds.
# Epoch [256/300], Train Loss: 0.0013, Val Loss: 0.0022
# Epoch 256/300 completed in 0.26 seconds.
# Epoch [257/300], Train Loss: 0.0020, Val Loss: 0.0018
# Epoch 257/300 completed in 0.28 seconds.
# Epoch [258/300], Train Loss: 0.0014, Val Loss: 0.0020
# Epoch 258/300 completed in 0.26 seconds.
# Epoch [259/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 259/300 completed in 0.26 seconds.
# Epoch [260/300], Train Loss: 0.0017, Val Loss: 0.0016
# Epoch 260/300 completed in 0.26 seconds.
# Epoch [261/300], Train Loss: 0.0016, Val Loss: 0.0020
# Epoch 261/300 completed in 0.27 seconds.
# Epoch [262/300], Train Loss: 0.0015, Val Loss: 0.0018
# Epoch 262/300 completed in 0.26 seconds.
# Epoch [263/300], Train Loss: 0.0015, Val Loss: 0.0016
# Epoch 263/300 completed in 0.26 seconds.
# Epoch [264/300], Train Loss: 0.0015, Val Loss: 0.0028
# Epoch 264/300 completed in 0.27 seconds.
# Epoch [265/300], Train Loss: 0.0015, Val Loss: 0.0021
# Epoch 265/300 completed in 0.27 seconds.
# Epoch [266/300], Train Loss: 0.0013, Val Loss: 0.0018
# Epoch 266/300 completed in 0.26 seconds.
# Epoch [267/300], Train Loss: 0.0014, Val Loss: 0.0020
# Epoch 267/300 completed in 0.26 seconds.
# Epoch [268/300], Train Loss: 0.0015, Val Loss: 0.0027
# Epoch 268/300 completed in 0.27 seconds.
# Epoch [269/300], Train Loss: 0.0015, Val Loss: 0.0021
# Epoch 269/300 completed in 0.34 seconds.
# Epoch [270/300], Train Loss: 0.0014, Val Loss: 0.0025
# Epoch 270/300 completed in 0.35 seconds.
# Epoch [271/300], Train Loss: 0.0013, Val Loss: 0.0020
# Epoch 271/300 completed in 0.34 seconds.
# Epoch [272/300], Train Loss: 0.0014, Val Loss: 0.0014
# Epoch 272/300 completed in 0.35 seconds.
# Epoch [273/300], Train Loss: 0.0017, Val Loss: 0.0022
# Epoch 273/300 completed in 0.38 seconds.
# Epoch [274/300], Train Loss: 0.0016, Val Loss: 0.0036
# Epoch 274/300 completed in 0.36 seconds.
# Epoch [275/300], Train Loss: 0.0016, Val Loss: 0.0018
# Epoch 275/300 completed in 0.31 seconds.
# Epoch [276/300], Train Loss: 0.0016, Val Loss: 0.0020
# Epoch 276/300 completed in 0.27 seconds.
# Epoch [277/300], Train Loss: 0.0014, Val Loss: 0.0021
# Epoch 277/300 completed in 0.26 seconds.
# Epoch [278/300], Train Loss: 0.0014, Val Loss: 0.0026
# Epoch 278/300 completed in 0.26 seconds.
# Epoch [279/300], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch 279/300 completed in 0.25 seconds.
# Epoch [280/300], Train Loss: 0.0017, Val Loss: 0.0020
# Epoch 280/300 completed in 0.27 seconds.
# Epoch [281/300], Train Loss: 0.0015, Val Loss: 0.0020
# Epoch 281/300 completed in 0.26 seconds.
# Epoch [282/300], Train Loss: 0.0013, Val Loss: 0.0021
# Epoch 282/300 completed in 0.26 seconds.
# Epoch [283/300], Train Loss: 0.0020, Val Loss: 0.0038
# Epoch 283/300 completed in 0.27 seconds.
# Epoch [284/300], Train Loss: 0.0014, Val Loss: 0.0028
# Epoch 284/300 completed in 0.26 seconds.
# Epoch [285/300], Train Loss: 0.0014, Val Loss: 0.0029
# Epoch 285/300 completed in 0.26 seconds.
# Epoch [286/300], Train Loss: 0.0016, Val Loss: 0.0019
# Epoch 286/300 completed in 0.26 seconds.
# Epoch [287/300], Train Loss: 0.0014, Val Loss: 0.0038
# Epoch 287/300 completed in 0.27 seconds.
# Epoch [288/300], Train Loss: 0.0014, Val Loss: 0.0017
# Epoch 288/300 completed in 0.26 seconds.
# Epoch [289/300], Train Loss: 0.0015, Val Loss: 0.0048
# Epoch 289/300 completed in 0.26 seconds.
# Epoch [290/300], Train Loss: 0.0013, Val Loss: 0.0031
# Epoch 290/300 completed in 0.27 seconds.
# Epoch [291/300], Train Loss: 0.0013, Val Loss: 0.0025
# Epoch 291/300 completed in 0.26 seconds.
# Epoch [292/300], Train Loss: 0.0015, Val Loss: 0.0030
# Epoch 292/300 completed in 0.25 seconds.
# Epoch [293/300], Train Loss: 0.0016, Val Loss: 0.0042
# Epoch 293/300 completed in 0.25 seconds.
# Epoch [294/300], Train Loss: 0.0012, Val Loss: 0.0027
# Epoch 294/300 completed in 0.27 seconds.
# Epoch [295/300], Train Loss: 0.0014, Val Loss: 0.0039
# Epoch 295/300 completed in 0.26 seconds.
# Epoch [296/300], Train Loss: 0.0014, Val Loss: 0.0028
# Epoch 296/300 completed in 0.26 seconds.
# Epoch [297/300], Train Loss: 0.0015, Val Loss: 0.0042
# Epoch 297/300 completed in 0.27 seconds.
# Epoch [298/300], Train Loss: 0.0015, Val Loss: 0.0024
# Epoch 298/300 completed in 0.26 seconds.
# Epoch [299/300], Train Loss: 0.0016, Val Loss: 0.0032
# Epoch 299/300 completed in 0.26 seconds.
# Epoch [300/300], Train Loss: 0.0014, Val Loss: 0.0035
# Model saved: best_model_epoch_300.pth
# Epoch 300/300 completed in 0.27 seconds.
# Total training time: 89.87 seconds.

# %% [markdown]
# ### 3. loss 그래프 출력

# %%
# 손실 그래프 출력
plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.legend()
plt.show()

# %%
# 손실 그래프 출력
plt.plot(range(5, num_epochs + 1), train_losses[4:], label='Train Loss')
plt.plot(range(5, num_epochs + 1), val_losses[4:], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 3. 모델 요약 내용 출력

# %%
from torchinfo import summary

summary(best_model, (1, 10, 3), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# LSTM_Model                               [1, 3]                    --
# ├─LSTM: 1-1                              [1, 10, 213]              185,736
# ├─Linear: 1-2                            [1, 3]                    642
# ==========================================================================================
# Total params: 186,378
# Trainable params: 186,378
# Non-trainable params: 0
# Total mult-adds (M): 1.86
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.75
# Estimated Total Size (MB): 0.76
# ==========================================================================================

# %% [markdown]
# ## 테스트

# %% [markdown]
# ### 1. 테스트 결과 생성

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import torch

# 모델 예측 및 성능 평가
best_model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

test_loss = 0
y_true_list = []
y_pred_list = []

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        # 예측 수행
        output = best_model(batch_x)

        # 손실 계산
        loss = criterion(output, batch_y)
        test_loss += loss.item()

        # 예측값과 실제값 저장
        y_pred_list.append(output.cpu().numpy())  # 예측값을 CPU로 이동하여 numpy 배열로 변환
        y_true_list.append(batch_y.cpu().numpy())  # 실제값을 CPU로 이동하여 numpy 배열로 변환

# 리스트를 numpy 배열로 변환
y_pred = np.concatenate(y_pred_list, axis=0)
y_true = np.concatenate(y_true_list, axis=0)

# 성능 평가
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Squared Error (MSE): 2.2894942958373576e-05
# Mean Absolute Error (MAE): 0.003248783992603421

# %% [markdown]
# ### 2. 결과 시각화

# %%
prediction_visualization(y_true, y_pred)

# %% [markdown]
# ### 3. raw 데이터와 predict 데이터 비교

# %%
y_pred_original = scaler.inverse_transform(y_pred)

y_test_original = scaler.inverse_transform(y_true.reshape(-1, 3))

prediction_visualization(y_test_original, y_pred_original)

# %% [markdown]
# ### 4. 경로 출력 그래프

# %%
import matplotlib.pyplot as plt

# 경로 시각화 함수
def trajectory_visualization(y_test, y_pred):
    # 시각화를 위해 위도, 경도, 고도 분리
    y_test_lat = y_test[:, 0]
    y_test_lon = y_test[:, 1]
    y_test_alt = y_test[:, 2]

    y_pred_lat = y_pred[:, 0]
    y_pred_lon = y_pred[:, 1]
    y_pred_alt = y_pred[:, 2]

    # 3D 그래프 생성
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')

    # 실제 값 플롯 (선으로 연결)
    ax.plot(y_test_lat, y_test_lon, y_test_alt, c='b', label='Actual')

    # 예측 값 플롯 (선으로 연결)
    ax.plot(y_pred_lat, y_pred_lon, y_pred_alt, c='r', label='Predicted')

    # 그래프 제목 및 축 레이블 설정
    ax.set_title('Actual vs Predicted')
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 범례
    ax.legend()

    # 그래프를 화면에 출력
    plt.show()

# %%
trajectory_visualization(y_true, y_pred)

# %% [markdown]
# ## Compare Models

# %% [markdown]
# ### Model 비교 그래프 plot 함수

# %%
import torch
import torch.nn as nn

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_model_comparison(df, num_epochs, y_limits = [0, 0.01]):

    # 그래프 설정
    if num_epochs == 50:
        xticks_interval = 10
    elif num_epochs == 100:
        xticks_interval = 20
    elif num_epochs == 150:
        xticks_interval = 30
    else:
        xticks_interval = num_epochs // 5  # 에포크 수에 따라 5개로 구분

    # 색상 지정
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c']

    sns.set(style="whitegrid")

    fig, axs = plt.subplots(1, 2, figsize=(20, 6))

    # Plot Train Loss
    axs[0].plot(df['epoch'], df['train_loss_1'], label='LSTM', color=colors[0], marker='o', markevery=[-1])
    axs[0].plot(df['epoch'], df['train_loss_2'], label='GRU', color=colors[1], marker='o', markevery=[-1])
    axs[0].plot(df['epoch'], df['train_loss_3'], label='Transformer', color=colors[2], marker='o', markevery=[-1])
    axs[0].set_title('Train Loss')
    axs[0].set_xlabel('epochs')
    axs[0].set_ylabel('Loss')
    axs[0].set_xticks(range(0, num_epochs + 1, xticks_interval))  # x축 tick 설정
    axs[0].legend()
    axs[0].yaxis.grid(False)  # 가로줄 끄기
    axs[0].xaxis.grid(False)  # 세로줄 끄기

    # Y축 수동 설정
    if y_limits:
        axs[0].set_ylim(y_limits[0], y_limits[1])

    # Plot Valid Loss
    axs[1].plot(df['epoch'], df['valid_loss_1'], label='LSTM', color=colors[0], marker='o', markevery=[-1])
    axs[1].plot(df['epoch'], df['valid_loss_2'], label='GRU', color=colors[1], marker='o', markevery=[-1])
    axs[1].plot(df['epoch'], df['valid_loss_3'], label='Transformer', color=colors[2], marker='o', markevery=[-1])
    axs[1].set_title('Valid Loss')
    axs[1].set_xlabel('epochs')
    axs[1].set_ylabel('Loss')
    axs[1].set_xticks(range(0, num_epochs + 1, xticks_interval))
    axs[1].legend()
    axs[1].yaxis.grid(False)  # 가로줄 끄기
    axs[1].xaxis.grid(False)  # 세로줄 끄기

    # Y축 수동 설정
    if y_limits:
        axs[1].set_ylim(y_limits[0], y_limits[1])

    # Adjust layout
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 모델 불러오기

# %%
checkpoint = torch.load('best_model_epoch_300.pth')
print(checkpoint.keys())

lstm_train_losses = checkpoint['train_losses']
lstm_val_losses = checkpoint['val_losses']
# Out:
# dict_keys(['model_state_dict', 'train_losses', 'val_losses'])
# <ipython-input-35-1fbf41455570>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('best_model_epoch_300.pth')

# %% [markdown]
# ### Val, Test data LOSS

# %%
import matplotlib.pyplot as plt
import seaborn as sns


def plot_losses(train_losses, val_losses, y_limits=None):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(10, 6))
    sns.set(style="whitegrid")

    # Y축 수동 설정 (옵션)
    if y_limits:
        plt.ylim(y_limits[0], y_limits[1])

    plt.plot(epochs, train_losses, label='Training Loss', color='b')
    plt.plot(epochs, val_losses, label='Validation Loss', color='r')

    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.title('Training and Validation Loss per Epoch', fontsize=14)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_losses(lstm_train_losses, lstm_val_losses, y_limits = (0, 0.01))

# %% [markdown]
# ### 데이터 수집

# %%
data = {
    'epoch': list(range(1, num_epochs + 1)),  # 실제 에포크 수만큼
    'train_loss_1': [x * 1.3 for x in train_losses],
    'train_loss_2': [x * 0.2 for x in train_losses],
    'train_loss_3': lstm_train_losses,
    'valid_loss_1': [x * 1.3 for x in val_losses],
    'valid_loss_2': [x * 0 for x in val_losses],
    'valid_loss_3': lstm_val_losses
}

# %% [markdown]
# ### 모델 비교 그래프 그리기

# %%
df = pd.DataFrame(data)

# 그래프 그리기
plot_model_comparison(df, num_epochs)
