# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### 패키지 설치 & 라이브러리 import

# %%
# !pip install optuna
# !pip install torchinfo
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.35)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 12.0 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 19.5 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.3 colorlog-6.8.2 optuna-4.0.0
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## 전체 공통 함수

# %% [markdown]
# ### 1. 데이터 보간 함수

# %% [markdown]
# - 데이터의 시간 간격을 0.5초의 등간격으로 맞추고 그에 따른 좌표 값을 보간함
# - 가장 많이 사용되는 3차 스플라인 보간 적용

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt

# 데이터 보간 - 위도, 고도, 경도 값을 0.5초 시간 간격으로 보간
def spline_interpolation(x, y):
    # x: 보간할 데이터의 x 값 (시간)
    # y: 보간할 데이터의 y 값 (위도, 고도, 경도)

    # 3차 스플라인 보간 함수 생성
    f = interp1d(x, y, kind='cubic')

    # 시간 범위 설정
    start_time = min(x)
    end_time = max(x)

    # 0.5초 간격의 시간 배열을 생성
    new_x = np.arange(start_time, end_time, 0.5)

    # 위도, 경도, 고도 보간
    new_y = f(new_x)

    return new_x, new_y

# %% [markdown]
# ### 2. 시퀀스 나누는 함수

# %% [markdown]
# - 학습을 위해 데이터를 시퀀스 형태로 나눔
# - look back과 forward에 따라 학습에 사용될 x값의 구간과 y값을 반환함
# - 초기 look back은 10, forward는 0이다.

# %%
# 시퀀스 생성 함수
# look back : 10 (5초간의 위도, 고도, 경도 데이터를 x값으로 사용)
# forward : 0 (0.5초 뒤의 위도, 고도, 경도 데이터를 y값으로 사용)
def create_sequences(df, look_back=10, forward=0):
    xs = []
    ys = []
    for i in range(len(df) - look_back - forward):
        x = df.iloc[i:(i+look_back)].values
        y = df.iloc[i+look_back+forward].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# %% [markdown]
# ### 3. 시간 소수점 절사 함수

# %% [markdown]
# - 불필요한 시간 소수점 제거

# %%
import math

# 시간 소수점 절사 함수
def truncation(df):
    new_time = []

    for a in df['time']:
      new_time.append(math.floor(a * 10) / 10)

    df['time'] = new_time

    return df

# %% [markdown]
# ### 4. 스케일링 함수

# %% [markdown]
# - MinMaxScaling 적용 함수

# %%
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaling 적용 함수
def min_max_scaling(df):

    # time 삭제 df 생성
    mid_df=df.drop(columns='time')

    min_max_scaler = MinMaxScaler()
    min_max_scaler.fit(mid_df)

    min_max_data = min_max_scaler.transform(mid_df)

    new_data = pd.DataFrame(min_max_data)

    # time 추가
    new_data.insert(0, 'time', df['time'])

    # 나머지 열의 이름 가져오기
    column_names = mid_df.columns.tolist()

    column_names.insert(0, 'time')

    print(column_names)

    # 새로운 데이터프레임에 열 이름 설정
    new_data.columns = column_names

    return min_max_scaler, new_data

# %% [markdown]
# ### 5. train/validation/test 분리 함수

# %% [markdown]
# - Train, Validation, Test 데이터셋을 분리하는 함수이다.
# - 각각의 비율은 6:2:2 이다.

# %%
# train/validation/test 분리 함수 (시계열 데이터용, 6:2:2 비율)
def split_train_val_test(df):
    n = len(df)

    # 데이터셋 크기 계산
    train_end = int(0.6 * n)
    val_end = int(0.8 * n)  # 0.6 + 0.2

    # 순차적으로 데이터 분할
    train_data = df[:train_end]     # 처음 60%는 train 데이터
    val_data = df[train_end:val_end] # 그 다음 20%는 validation 데이터
    test_data = df[val_end:]        # 마지막 20%는 test 데이터

    # 데이터 크기 출력 (원한다면)
    # print("Train set:", train_data.shape)
    # print("Validation set:", val_data.shape)
    # print("Test set:", test_data.shape)

    return train_data, val_data, test_data

# %% [markdown]
# ### 6. 경로 시각화 함수

# %% [markdown]
# - 실제 경로와 예측 경로를 각각 그래프로 생성

# %%
import matplotlib.pyplot as plt

# 경로 시각화 함수
def prediction_visualization(y_test, y_pred):
    # 시각화를 위해 위도, 경도, 고도 분리
    y_test_lat = y_test[:, 0]
    y_test_lon = y_test[:, 1]
    y_test_alt = y_test[:, 2]

    y_pred_lat = y_pred[:, 0]
    y_pred_lon = y_pred[:, 1]
    y_pred_alt = y_pred[:, 2]

    # 3D 그래프 생성
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')

    # 실제 값 플롯
    ax.scatter(y_test_lat, y_test_lon, y_test_alt, c='b', marker='o', label='Actual')

    # 예측 값 플롯
    ax.scatter(y_pred_lat, y_pred_lon, y_pred_alt, c='r', marker='^', label='Predicted')

    # 그래프 제목 및 축 레이블 설정
    ax.set_title('Actual vs Predicted')
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 범례
    ax.legend()

    # 그래프를 화면에 출력
    plt.show()

# %% [markdown]
# ### 7. 데이터로더 생성 함수

# %% [markdown]
# - 학습에 사용할 데이터 로더 생성
# 1. 시퀀스 생성
# 2. Train, Validation, Test 분리
# 3. DataLoader 생성

# %%
# 데이터 로더 생성 함수
def create_dataloaders(tri, batch_size, sequence_length):

  tri = tri[['time', 'lat', 'lon', 'alt']]

  # train, validation, test 분리
  train_data, val_data, test_data = split_train_val_test(tri)

  # 각 데이터셋에서 시퀀스 생성
  X_train, y_train = create_sequences(train_data[['lat', 'lon', 'alt']], look_back=sequence_length)
  X_val, y_val = create_sequences(val_data[['lat', 'lon', 'alt']], look_back=sequence_length)
  X_test, y_test = create_sequences(test_data[['lat', 'lon', 'alt']], look_back=sequence_length)

  X_train = torch.tensor(X_train, dtype=torch.float32)
  y_train = torch.tensor(y_train, dtype=torch.float32)
  X_val = torch.tensor(X_val, dtype=torch.float32)
  y_val = torch.tensor(y_val, dtype=torch.float32)
  X_test = torch.tensor(X_test, dtype=torch.float32)
  y_test = torch.tensor(y_test, dtype=torch.float32)

  train_dataset = TensorDataset(X_train, y_train)
  validation_dataset = TensorDataset(X_val, y_val)
  test_dataset = TensorDataset(X_test, y_test)

  # 데이터 로더 생성
  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  val_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

  return train_loader, val_loader, test_loader

# %% [markdown]
# ## 전처리

# %% [markdown]
# ### 1. 데이터셋 가져오기

# %%
import pandas as pd

# 데이터셋 가져오기 (필요시 저장 경로 수정)
raw = pd.read_csv("/content/OnboardGPS.csv")

# %%
# 데이터셋 출력
# raw

# %% [markdown]
# ### 2. 데이터셋 전처리

# %% [markdown]
# - 데이터셋 보간
# - 소수점 절사
# - MinMaxScaling 적용

# %%
tri = raw[['Timpstemp', ' lat', ' lon', ' alt']]

new_x, lat = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lat'])
new_x, lon = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lon'])
new_x, alt = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' alt'])

tri = pd.DataFrame({"time":new_x, "lat":lat, "lon":lon, "alt":alt})

tri = truncation(tri)
scaler, tri = min_max_scaling(tri)
# tri
# Out:
# ['time', 'lat', 'lon', 'alt']

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# splited 데이터 경로 시각화 함수
def plot_trajectory(train_data, val_data, test_data):
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')

    # 훈련 데이터 플롯
    ax.plot(train_data['lat'], train_data['lon'], train_data['alt'], label='Train', color='blue')

    # 검증 데이터 플롯
    ax.plot(val_data['lat'], val_data['lon'], val_data['alt'], label='Validation', color='green')

    # 테스트 데이터 플롯
    ax.plot(test_data['lat'], test_data['lon'], test_data['alt'], label='Test', color='red')

    # 그래프 레이블
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 제목과 범례
    ax.set_title('Drone Trajectory: Train, Validation, and Test')
    ax.legend()

    plt.show()

# %%
# ############## 예시: 함수 사용
# train_data, val_data, test_data = split_train_val_test(tri)
# print(train_data[0:30])

# # plot_trajectory(train_data, val_data, test_data)

# X_train, y_train = create_sequences(train_data[['lat', 'lon', 'alt']], look_back=10)
# print(X_train[0].shape)
# print(y_train[0].shape)

# ######################

# %% [markdown]
# ## 모델 선언

# %% [markdown]
# ### 1. 모델 클래스 선언

# %% [markdown]
# - LSTM을 사용한 모델 클래스 선언
# - 구조 : LSTM + Fully Connected Layer

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import optuna

# LSTM 모델 클래스 정의
class LSTM_Model(nn.Module):
    def __init__(self, input_size=3, hidden_size=128, num_layers=2, output_size=3):
        super(LSTM_Model, self).__init__()

        # hidden state size
        self.hidden_size = hidden_size

        # LSTM layer 수
        self.num_layers = num_layers

        # LSTM 레이어
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)

        # Fully Connected Layer
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):


        # LSTM hidden state, cell state 초기화
        # 초기 hidden state와 cell state 정의
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        # LSTM 레이어를 통과
        out, _ = self.lstm(x, (h0, c0))

        # 마지막 시점의 hidden state에서 Fully Connected Layer를 통과
        out = self.fc(out[:, -1, :])

        return out

# %% [markdown]
# ## 하이퍼파라미터 탐색

# %% [markdown]
# ### 1. Optuna의 objective 함수 선언

# %% [markdown]
# - 최적의 하이퍼파라미터 탐색을 위해 optuna 사용
# - objective 함수 선언

# %%
import optuna
import torch

def objective(trial, tri, sequence_length):
    # 탐색할 하이퍼파라미터 값 결정
    hidden_size = trial.suggest_int("hidden_size", 32, 256)
    num_layers = trial.suggest_int("num_layers", 1, 5)
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1e-2, log=True)
    batch_size = trial.suggest_int("batch_size", 16, 128)

    num_epochs = 300
    input_size = 3  # lat, lon, alt
    output_size = 3  # lat, lon, alt

    # 데이터셋 가져오기
    train_loader, val_loader, _ = create_dataloaders(tri, batch_size, sequence_length)

    # 모델 정의: LSTMModel
    model = LSTM_Model(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, output_size=output_size)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    criterion = torch.nn.MSELoss()

    total_val_loss = 0.0  # 모든 epoch에서의 validation loss의 합
    val_loss_count = 0    # 평균을 계산하기 위한 epoch 수

    # 모델 학습
    for epoch in range(num_epochs):

        # Train set으로 학습
        model.train()
        train_loss = 0.0
        for batch_x, batch_y in train_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)

            optimizer.zero_grad()
            output = model(batch_x)
            loss = criterion(output, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        # Validation set에서 성능 측정
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x = batch_x.to(device)
                batch_y = batch_y.to(device)
                output = model(batch_x)
                loss = criterion(output, batch_y)
                val_loss += loss.item()

        # 배치 수로 나눠서 평균 validation 손실 계산
        val_loss_avg = val_loss / len(val_loader)

        # Optuna에 중간 값 보고
        trial.report(val_loss_avg, epoch)

        # 총 validation 손실 계산
        total_val_loss += val_loss_avg
        val_loss_count += 1

        # Pruning 조건 확인
        if trial.should_prune():
            print(f"Trial {trial.number} pruned at epoch {epoch}")
            print(f"Validation Loss at prune: {val_loss_avg:.4f}")  # Prune 시점에서 validation loss 출력

            raise optuna.TrialPruned()

    # 모든 epoch에서의 validation 손실 평균을 반환
    return total_val_loss / val_loss_count

# %% [markdown]
# ### 2. early stopping 함수 선언

# %% [markdown]
# - optuna에서 하이퍼파라미터 탐색 중 early stopping 적용

# %%
#  # https://github.com/optuna/optuna/issues/1001

# def early_stopping_check(study, trial, early_stopping_rounds=10):
#   current_trial_number = trial.number
#   best_trial_number = study.best_trial.number
#   should_stop = (current_trial_number - best_trial_number) >= early_stopping_rounds
#   if should_stop:
#       print(f"Early stopping detected: stopping trial {current_trial_number} (best trial {best_trial_number}) at epoch {epoch}")
#       study.stop()

# %% [markdown]
# ### 3. 탐색 범위 외의 하이퍼파라미터 선언

# %%
sequence_length = 10
early_stopping_rounds = 10
n_trials = 20

# %% [markdown]
# ### 4. 하이퍼 파라미터 탐색

# %%
import optuna
from functools import partial

# Optuna 스터디 생성 및 최적화 실행
study = optuna.create_study(direction="minimize", pruner=optuna.pruners.MedianPruner(n_warmup_steps=10))
# study.optimize(lambda trial: objective(trial, tri, sequence_length), callbacks=[partial(early_stopping_check, early_stopping_rounds=early_stopping_rounds)], n_trials=n_trials)
study.optimize(lambda trial: objective(trial, tri, sequence_length), n_trials=n_trials)

# 최적의 하이퍼파라미터 출력
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2024-10-07 06:30:26,104] A new study created in memory with name: no-name-67ae2571-2619-436a-8fc6-ad56c2764e75
# [I 2024-10-07 06:31:51,659] Trial 0 finished with value: 0.0004565495687192986 and parameters: {'hidden_size': 241, 'num_layers': 3, 'learning_rate': 0.0007688240935611235, 'batch_size': 63}. Best is trial 0 with value: 0.0004565495687192986.
# [I 2024-10-07 06:33:22,724] Trial 1 finished with value: 0.0028082068726020754 and parameters: {'hidden_size': 178, 'num_layers': 2, 'learning_rate': 6.016822520806631e-05, 'batch_size': 70}. Best is trial 0 with value: 0.0004565495687192986.
# [I 2024-10-07 06:34:59,330] Trial 2 finished with value: 0.0052627590596539585 and parameters: {'hidden_size': 86, 'num_layers': 5, 'learning_rate': 0.0005116769869387645, 'batch_size': 52}. Best is trial 0 with value: 0.0004565495687192986.
# [I 2024-10-07 06:37:44,557] Trial 3 finished with value: 0.007319697100419806 and parameters: {'hidden_size': 72, 'num_layers': 4, 'learning_rate': 0.008673696587232637, 'batch_size': 25}. Best is trial 0 with value: 0.0004565495687192986.
# [I 2024-10-07 06:38:38,827] Trial 4 finished with value: 0.00020101314959099565 and parameters: {'hidden_size': 78, 'num_layers': 2, 'learning_rate': 0.004493508419309723, 'batch_size': 67}. Best is trial 4 with value: 0.00020101314959099565.
# [I 2024-10-07 06:38:41,245] Trial 5 pruned.
# Trial 5 pruned at epoch 10
# Validation Loss at prune: 0.0055
# [I 2024-10-07 06:38:42,574] Trial 6 pruned.
# Trial 6 pruned at epoch 10
# Validation Loss at prune: 0.0064
# [I 2024-10-07 06:38:47,138] Trial 7 pruned.
# Trial 7 pruned at epoch 10
# Validation Loss at prune: 0.0079
# [I 2024-10-07 06:38:50,642] Trial 8 pruned.
# Trial 8 pruned at epoch 10
# Validation Loss at prune: 0.0053
# [I 2024-10-07 06:38:54,893] Trial 9 pruned.
# Trial 9 pruned at epoch 10
# Validation Loss at prune: 0.0038
# [I 2024-10-07 06:38:57,720] Trial 10 pruned.
# Trial 10 pruned at epoch 10
# Validation Loss at prune: 0.2144
# [I 2024-10-07 06:40:37,216] Trial 11 finished with value: 0.005809991574648007 and parameters: {'hidden_size': 254, 'num_layers': 3, 'learning_rate': 0.00407228033641088, 'batch_size': 53}. Best is trial 4 with value: 0.00020101314959099565.
# [I 2024-10-07 06:41:40,661] Trial 12 finished with value: 0.0001600109253844525 and parameters: {'hidden_size': 126, 'num_layers': 2, 'learning_rate': 0.0017154673619624362, 'batch_size': 57}. Best is trial 12 with value: 0.0001600109253844525.
# [I 2024-10-07 06:43:15,878] Trial 13 finished with value: 0.00012119477440961016 and parameters: {'hidden_size': 118, 'num_layers': 2, 'learning_rate': 0.002553237389032067, 'batch_size': 36}. Best is trial 13 with value: 0.00012119477440961016.
# [I 2024-10-07 06:46:10,320] Trial 14 finished with value: 0.00010969308363623517 and parameters: {'hidden_size': 118, 'num_layers': 2, 'learning_rate': 0.0016725381567507648, 'batch_size': 18}. Best is trial 14 with value: 0.00010969308363623517.
# [I 2024-10-07 06:48:36,847] Trial 15 finished with value: 7.526848833523702e-05 and parameters: {'hidden_size': 116, 'num_layers': 1, 'learning_rate': 0.0017148435050232092, 'batch_size': 18}. Best is trial 15 with value: 7.526848833523702e-05.
# [I 2024-10-07 06:51:03,375] Trial 16 finished with value: 8.120938189610644e-05 and parameters: {'hidden_size': 114, 'num_layers': 1, 'learning_rate': 0.0015874037526516674, 'batch_size': 18}. Best is trial 15 with value: 7.526848833523702e-05.
# [I 2024-10-07 06:52:25,189] Trial 17 finished with value: 0.00010590760803410149 and parameters: {'hidden_size': 35, 'num_layers': 1, 'learning_rate': 0.008314572091309388, 'batch_size': 34}. Best is trial 15 with value: 7.526848833523702e-05.
# [I 2024-10-07 06:52:27,249] Trial 18 pruned.
# Trial 18 pruned at epoch 10
# Validation Loss at prune: 0.0013
# [I 2024-10-07 06:55:01,356] Trial 19 finished with value: 0.00010652406038712907 and parameters: {'hidden_size': 102, 'num_layers': 1, 'learning_rate': 0.0033591892552901873, 'batch_size': 17}. Best is trial 15 with value: 7.526848833523702e-05.
# Best hyperparameters:  {'hidden_size': 116, 'num_layers': 1, 'learning_rate': 0.0017148435050232092, 'batch_size': 18}

# %% [markdown]
# ### 5. 하이퍼파라미터 저장

# %%
import json

### 하이퍼 파라미터 저장

# 최적의 하이퍼파라미터를 JSON 파일로 저장
with open("best_hyperparameters.json", "w") as f:
    json.dump(study.best_params, f, indent=4)

print("Best hyperparameters have been saved to 'best_hyperparameters.json'")
# Out:
# Best hyperparameters have been saved to 'best_hyperparameters.json'

# %% [markdown]
# ## 학습

# %% [markdown]
# ### 1. 하이퍼파라미터 불러오기

# %%
import json

# 저장된 하이퍼파라미터 불러오기
with open("best_hyperparameters.json", "r") as f:
    best_params = json.load(f)

print("Loaded best hyperparameters:", best_params)
# Out:
# Loaded best hyperparameters: {'hidden_size': 116, 'num_layers': 1, 'learning_rate': 0.0017148435050232092, 'batch_size': 18}

# %% [markdown]
# ### 2. 최적의 파라미터로 모델 학습

# %%
sequence_length = 10
num_epochs = 500

# %%
# 최적의 모델 학습
# study = optuna.create_study(direction="minimize", pruner=optuna.pruners.MedianPruner(n_warmup_steps=10))
# best_params = study.best_params

train_loader, val_loader, test_loader = create_dataloaders(tri, best_params['batch_size'], sequence_length)

best_model = LSTM_Model(input_size=3, hidden_size=best_params['hidden_size'],
                      num_layers=best_params['num_layers'], output_size=3)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
best_model = best_model.to(device)

optimizer = torch.optim.Adam(best_model.parameters(), lr=best_params['learning_rate'])
criterion = torch.nn.MSELoss()

# %%
import time
import torch

# 학습 및 검증 손실을 기록할 리스트
train_losses = []
val_losses = []


best_model.train()
total_train_time = 0  # 총 학습 시간 기록 변수

for epoch in range(num_epochs):  # 최종 모델 학습
    best_model.train()
    train_loss = 0.0
    epoch_start_time = time.time()  # 에포크 시작 시간 기록
    for batch_x, batch_y in train_loader:
        batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = best_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    epoch_end_time = time.time()  # 에포크 종료 시간 기록
    epoch_duration = epoch_end_time - epoch_start_time  # 한 에포크의 학습 시간
    total_train_time += epoch_duration  # 총 학습 시간에 추가

    # Validation set에서 성능 측정
    best_model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch_x, batch_y in val_loader:
            batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
            batch_y = batch_y.to(device)
            output = best_model(batch_x)
            loss = criterion(output, batch_y)
            val_loss += loss.item()

    # 평균 손실 계산 및 저장
    train_losses.append(train_loss / len(train_loader))
    val_losses.append(val_loss / len(val_loader))

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

    # 모델 저장
    if (epoch + 1) % 50 == 0:
      model_save_path = f"best_model_epoch_{epoch+1}.pth"
      torch.save(best_model.state_dict(), model_save_path)
      print(f"Model saved: {model_save_path}")

    print(f"Epoch {epoch+1}/{num_epochs} completed in {epoch_duration:.2f} seconds.")

print(f"Total training time: {total_train_time:.2f} seconds.")
# Out:
# Epoch [1/500], Train Loss: 3.4882, Val Loss: 0.2765
# Epoch 1/500 completed in 0.45 seconds.
# Epoch [2/500], Train Loss: 0.0919, Val Loss: 0.1241
# Epoch 2/500 completed in 0.42 seconds.
# Epoch [3/500], Train Loss: 0.0611, Val Loss: 0.0910
# Epoch 3/500 completed in 0.43 seconds.
# Epoch [4/500], Train Loss: 0.0484, Val Loss: 0.0801
# Epoch 4/500 completed in 0.43 seconds.
# Epoch [5/500], Train Loss: 0.0377, Val Loss: 0.0370
# Epoch 5/500 completed in 0.42 seconds.
# Epoch [6/500], Train Loss: 0.0343, Val Loss: 0.0237
# Epoch 6/500 completed in 0.45 seconds.
# Epoch [7/500], Train Loss: 0.0298, Val Loss: 0.0269
# Epoch 7/500 completed in 0.42 seconds.
# Epoch [8/500], Train Loss: 0.0285, Val Loss: 0.0285
# Epoch 8/500 completed in 0.44 seconds.
# Epoch [9/500], Train Loss: 0.0233, Val Loss: 0.0184
# Epoch 9/500 completed in 0.43 seconds.
# Epoch [10/500], Train Loss: 0.0230, Val Loss: 0.0126
# Epoch 10/500 completed in 0.43 seconds.
# Epoch [11/500], Train Loss: 0.0217, Val Loss: 0.0107
# Epoch 11/500 completed in 0.42 seconds.
# Epoch [12/500], Train Loss: 0.0177, Val Loss: 0.0087
# Epoch 12/500 completed in 0.49 seconds.
# Epoch [13/500], Train Loss: 0.0178, Val Loss: 0.0077
# Epoch 13/500 completed in 0.55 seconds.
# Epoch [14/500], Train Loss: 0.0151, Val Loss: 0.0075
# Epoch 14/500 completed in 0.56 seconds.
# Epoch [15/500], Train Loss: 0.0141, Val Loss: 0.0046
# Epoch 15/500 completed in 0.59 seconds.
# Epoch [16/500], Train Loss: 0.0129, Val Loss: 0.0093
# Epoch 16/500 completed in 0.61 seconds.
# Epoch [17/500], Train Loss: 0.0128, Val Loss: 0.0062
# Epoch 17/500 completed in 0.42 seconds.
# Epoch [18/500], Train Loss: 0.0114, Val Loss: 0.0289
# Epoch 18/500 completed in 0.42 seconds.
# Epoch [19/500], Train Loss: 0.0176, Val Loss: 0.0050
# Epoch 19/500 completed in 0.41 seconds.
# Epoch [20/500], Train Loss: 0.0120, Val Loss: 0.0048
# Epoch 20/500 completed in 0.44 seconds.
# Epoch [21/500], Train Loss: 0.0095, Val Loss: 0.0041
# Epoch 21/500 completed in 0.42 seconds.
# Epoch [22/500], Train Loss: 0.0082, Val Loss: 0.0024
# Epoch 22/500 completed in 0.43 seconds.
# Epoch [23/500], Train Loss: 0.0112, Val Loss: 0.0034
# Epoch 23/500 completed in 0.43 seconds.
# Epoch [24/500], Train Loss: 0.0101, Val Loss: 0.0070
# Epoch 24/500 completed in 0.44 seconds.
# Epoch [25/500], Train Loss: 0.0113, Val Loss: 0.0075
# Epoch 25/500 completed in 0.42 seconds.
# Epoch [26/500], Train Loss: 0.0083, Val Loss: 0.0038
# Epoch 26/500 completed in 0.43 seconds.
# Epoch [27/500], Train Loss: 0.0100, Val Loss: 0.0089
# Epoch 27/500 completed in 0.43 seconds.
# Epoch [28/500], Train Loss: 0.0067, Val Loss: 0.0025
# Epoch 28/500 completed in 0.43 seconds.
# Epoch [29/500], Train Loss: 0.0094, Val Loss: 0.0102
# Epoch 29/500 completed in 0.42 seconds.
# Epoch [30/500], Train Loss: 0.0109, Val Loss: 0.0047
# Epoch 30/500 completed in 0.42 seconds.
# Epoch [31/500], Train Loss: 0.0081, Val Loss: 0.0054
# Epoch 31/500 completed in 0.44 seconds.
# Epoch [32/500], Train Loss: 0.0073, Val Loss: 0.0076
# Epoch 32/500 completed in 0.42 seconds.
# Epoch [33/500], Train Loss: 0.0075, Val Loss: 0.0032
# Epoch 33/500 completed in 0.44 seconds.
# Epoch [34/500], Train Loss: 0.0078, Val Loss: 0.0028
# Epoch 34/500 completed in 0.42 seconds.
# Epoch [35/500], Train Loss: 0.0238, Val Loss: 0.0026
# Epoch 35/500 completed in 0.43 seconds.
# Epoch [36/500], Train Loss: 0.0056, Val Loss: 0.0034
# Epoch 36/500 completed in 0.43 seconds.
# Epoch [37/500], Train Loss: 0.0061, Val Loss: 0.0036
# Epoch 37/500 completed in 0.45 seconds.
# Epoch [38/500], Train Loss: 0.0055, Val Loss: 0.0029
# Epoch 38/500 completed in 0.56 seconds.
# Epoch [39/500], Train Loss: 0.0084, Val Loss: 0.0083
# Epoch 39/500 completed in 0.55 seconds.
# Epoch [40/500], Train Loss: 0.0060, Val Loss: 0.0035
# Epoch 40/500 completed in 0.59 seconds.
# Epoch [41/500], Train Loss: 0.0056, Val Loss: 0.0039
# Epoch 41/500 completed in 0.58 seconds.
# Epoch [42/500], Train Loss: 0.0059, Val Loss: 0.0046
# Epoch 42/500 completed in 0.48 seconds.
# Epoch [43/500], Train Loss: 0.0051, Val Loss: 0.0075
# Epoch 43/500 completed in 0.42 seconds.
# Epoch [44/500], Train Loss: 0.0069, Val Loss: 0.0041
# Epoch 44/500 completed in 0.42 seconds.
# Epoch [45/500], Train Loss: 0.0052, Val Loss: 0.0030
# Epoch 45/500 completed in 0.42 seconds.
# Epoch [46/500], Train Loss: 0.0057, Val Loss: 0.0031
# Epoch 46/500 completed in 0.42 seconds.
# Epoch [47/500], Train Loss: 0.0061, Val Loss: 0.0023
# Epoch 47/500 completed in 0.43 seconds.
# Epoch [48/500], Train Loss: 0.0065, Val Loss: 0.0042
# Epoch 48/500 completed in 0.42 seconds.
# Epoch [49/500], Train Loss: 0.0051, Val Loss: 0.0031
# Epoch 49/500 completed in 0.43 seconds.
# Epoch [50/500], Train Loss: 0.0058, Val Loss: 0.0034
# Model saved: best_model_epoch_50.pth
# Epoch 50/500 completed in 0.42 seconds.
# Epoch [51/500], Train Loss: 0.0049, Val Loss: 0.0028
# Epoch 51/500 completed in 0.44 seconds.
# Epoch [52/500], Train Loss: 0.0047, Val Loss: 0.0028
# Epoch 52/500 completed in 0.42 seconds.
# Epoch [53/500], Train Loss: 0.0039, Val Loss: 0.0057
# Epoch 53/500 completed in 0.44 seconds.
# Epoch [54/500], Train Loss: 0.0056, Val Loss: 0.0027
# Epoch 54/500 completed in 0.42 seconds.
# Epoch [55/500], Train Loss: 0.0055, Val Loss: 0.0019
# Epoch 55/500 completed in 0.42 seconds.
# Epoch [56/500], Train Loss: 0.0043, Val Loss: 0.0040
# Epoch 56/500 completed in 0.42 seconds.
# Epoch [57/500], Train Loss: 0.0113, Val Loss: 0.0016
# Epoch 57/500 completed in 0.43 seconds.
# Epoch [58/500], Train Loss: 0.0034, Val Loss: 0.0042
# Epoch 58/500 completed in 0.43 seconds.
# Epoch [59/500], Train Loss: 0.0045, Val Loss: 0.0018
# Epoch 59/500 completed in 0.43 seconds.
# Epoch [60/500], Train Loss: 0.0039, Val Loss: 0.0029
# Epoch 60/500 completed in 0.43 seconds.
# Epoch [61/500], Train Loss: 0.0049, Val Loss: 0.0032
# Epoch 61/500 completed in 0.42 seconds.
# Epoch [62/500], Train Loss: 0.0045, Val Loss: 0.0015
# Epoch 62/500 completed in 0.44 seconds.
# Epoch [63/500], Train Loss: 0.0035, Val Loss: 0.0013
# Epoch 63/500 completed in 0.50 seconds.
# Epoch [64/500], Train Loss: 0.0046, Val Loss: 0.0021
# Epoch 64/500 completed in 0.56 seconds.
# Epoch [65/500], Train Loss: 0.0041, Val Loss: 0.0031
# Epoch 65/500 completed in 0.57 seconds.
# Epoch [66/500], Train Loss: 0.0055, Val Loss: 0.0020
# Epoch 66/500 completed in 0.58 seconds.
# Epoch [67/500], Train Loss: 0.0050, Val Loss: 0.0021
# Epoch 67/500 completed in 0.55 seconds.
# Epoch [68/500], Train Loss: 0.0033, Val Loss: 0.0014
# Epoch 68/500 completed in 0.42 seconds.
# Epoch [69/500], Train Loss: 0.0036, Val Loss: 0.0018
# Epoch 69/500 completed in 0.43 seconds.
# Epoch [70/500], Train Loss: 0.0042, Val Loss: 0.0028
# Epoch 70/500 completed in 0.42 seconds.
# Epoch [71/500], Train Loss: 0.0036, Val Loss: 0.0030
# Epoch 71/500 completed in 0.42 seconds.
# Epoch [72/500], Train Loss: 0.0044, Val Loss: 0.0018
# Epoch 72/500 completed in 0.42 seconds.
# Epoch [73/500], Train Loss: 0.0034, Val Loss: 0.0060
# Epoch 73/500 completed in 0.42 seconds.
# Epoch [74/500], Train Loss: 0.0054, Val Loss: 0.0017
# Epoch 74/500 completed in 0.42 seconds.
# Epoch [75/500], Train Loss: 0.0036, Val Loss: 0.0019
# Epoch 75/500 completed in 0.42 seconds.
# Epoch [76/500], Train Loss: 0.0038, Val Loss: 0.0012
# Epoch 76/500 completed in 0.42 seconds.
# Epoch [77/500], Train Loss: 0.0052, Val Loss: 0.0017
# Epoch 77/500 completed in 0.44 seconds.
# Epoch [78/500], Train Loss: 0.0034, Val Loss: 0.0014
# Epoch 78/500 completed in 0.43 seconds.
# Epoch [79/500], Train Loss: 0.0037, Val Loss: 0.0022
# Epoch 79/500 completed in 0.43 seconds.
# Epoch [80/500], Train Loss: 0.0034, Val Loss: 0.0023
# Epoch 80/500 completed in 0.43 seconds.
# Epoch [81/500], Train Loss: 0.0066, Val Loss: 0.0030
# Epoch 81/500 completed in 0.43 seconds.
# Epoch [82/500], Train Loss: 0.0033, Val Loss: 0.0031
# Epoch 82/500 completed in 0.44 seconds.
# Epoch [83/500], Train Loss: 0.0036, Val Loss: 0.0017
# Epoch 83/500 completed in 0.44 seconds.
# Epoch [84/500], Train Loss: 0.0037, Val Loss: 0.0013
# Epoch 84/500 completed in 0.41 seconds.
# Epoch [85/500], Train Loss: 0.0035, Val Loss: 0.0010
# Epoch 85/500 completed in 0.42 seconds.
# Epoch [86/500], Train Loss: 0.0035, Val Loss: 0.0013
# Epoch 86/500 completed in 0.42 seconds.
# Epoch [87/500], Train Loss: 0.0033, Val Loss: 0.0030
# Epoch 87/500 completed in 0.43 seconds.
# Epoch [88/500], Train Loss: 0.0035, Val Loss: 0.0021
# Epoch 88/500 completed in 0.42 seconds.
# Epoch [89/500], Train Loss: 0.0040, Val Loss: 0.0017
# Epoch 89/500 completed in 0.56 seconds.
# Epoch [90/500], Train Loss: 0.0037, Val Loss: 0.0013
# Epoch 90/500 completed in 0.53 seconds.
# Epoch [91/500], Train Loss: 0.0037, Val Loss: 0.0017
# Epoch 91/500 completed in 0.59 seconds.
# Epoch [92/500], Train Loss: 0.0045, Val Loss: 0.0013
# Epoch 92/500 completed in 0.58 seconds.
# Epoch [93/500], Train Loss: 0.0033, Val Loss: 0.0016
# Epoch 93/500 completed in 0.45 seconds.
# Epoch [94/500], Train Loss: 0.0030, Val Loss: 0.0010
# Epoch 94/500 completed in 0.42 seconds.
# Epoch [95/500], Train Loss: 0.0035, Val Loss: 0.0012
# Epoch 95/500 completed in 0.42 seconds.
# Epoch [96/500], Train Loss: 0.0031, Val Loss: 0.0017
# Epoch 96/500 completed in 0.42 seconds.
# Epoch [97/500], Train Loss: 0.0037, Val Loss: 0.0014
# Epoch 97/500 completed in 0.42 seconds.
# Epoch [98/500], Train Loss: 0.0033, Val Loss: 0.0016
# Epoch 98/500 completed in 0.42 seconds.
# Epoch [99/500], Train Loss: 0.0039, Val Loss: 0.0025
# Epoch 99/500 completed in 0.43 seconds.
# Epoch [100/500], Train Loss: 0.0034, Val Loss: 0.0014
# Model saved: best_model_epoch_100.pth
# Epoch 100/500 completed in 0.40 seconds.
# Epoch [101/500], Train Loss: 0.0032, Val Loss: 0.0011
# Epoch 101/500 completed in 0.43 seconds.
# Epoch [102/500], Train Loss: 0.0034, Val Loss: 0.0018
# Epoch 102/500 completed in 0.42 seconds.
# Epoch [103/500], Train Loss: 0.0031, Val Loss: 0.0016
# Epoch 103/500 completed in 0.44 seconds.
# Epoch [104/500], Train Loss: 0.0029, Val Loss: 0.0013
# Epoch 104/500 completed in 0.43 seconds.
# Epoch [105/500], Train Loss: 0.0035, Val Loss: 0.0019
# Epoch 105/500 completed in 0.43 seconds.
# Epoch [106/500], Train Loss: 0.0037, Val Loss: 0.0011
# Epoch 106/500 completed in 0.42 seconds.
# Epoch [107/500], Train Loss: 0.0038, Val Loss: 0.0018
# Epoch 107/500 completed in 0.43 seconds.
# Epoch [108/500], Train Loss: 0.0035, Val Loss: 0.0015
# Epoch 108/500 completed in 0.42 seconds.
# Epoch [109/500], Train Loss: 0.0030, Val Loss: 0.0014
# Epoch 109/500 completed in 0.42 seconds.
# Epoch [110/500], Train Loss: 0.0034, Val Loss: 0.0025
# Epoch 110/500 completed in 0.43 seconds.
# Epoch [111/500], Train Loss: 0.0029, Val Loss: 0.0016
# Epoch 111/500 completed in 0.42 seconds.
# Epoch [112/500], Train Loss: 0.0028, Val Loss: 0.0019
# Epoch 112/500 completed in 0.43 seconds.
# Epoch [113/500], Train Loss: 0.0038, Val Loss: 0.0025
# Epoch 113/500 completed in 0.41 seconds.
# Epoch [114/500], Train Loss: 0.0041, Val Loss: 0.0011
# Epoch 114/500 completed in 0.49 seconds.
# Epoch [115/500], Train Loss: 0.0032, Val Loss: 0.0015
# Epoch 115/500 completed in 0.54 seconds.
# Epoch [116/500], Train Loss: 0.0034, Val Loss: 0.0021
# Epoch 116/500 completed in 0.55 seconds.
# Epoch [117/500], Train Loss: 0.0033, Val Loss: 0.0032
# Epoch 117/500 completed in 0.59 seconds.
# Epoch [118/500], Train Loss: 0.0032, Val Loss: 0.0012
# Epoch 118/500 completed in 0.57 seconds.
# Epoch [119/500], Train Loss: 0.0027, Val Loss: 0.0011
# Epoch 119/500 completed in 0.43 seconds.
# Epoch [120/500], Train Loss: 0.0031, Val Loss: 0.0015
# Epoch 120/500 completed in 0.42 seconds.
# Epoch [121/500], Train Loss: 0.0034, Val Loss: 0.0015
# Epoch 121/500 completed in 0.44 seconds.
# Epoch [122/500], Train Loss: 0.0034, Val Loss: 0.0011
# Epoch 122/500 completed in 0.43 seconds.
# Epoch [123/500], Train Loss: 0.0035, Val Loss: 0.0013
# Epoch 123/500 completed in 0.43 seconds.
# Epoch [124/500], Train Loss: 0.0031, Val Loss: 0.0024
# Epoch 124/500 completed in 0.43 seconds.
# Epoch [125/500], Train Loss: 0.0027, Val Loss: 0.0015
# Epoch 125/500 completed in 0.42 seconds.
# Epoch [126/500], Train Loss: 0.0030, Val Loss: 0.0020
# Epoch 126/500 completed in 0.42 seconds.
# Epoch [127/500], Train Loss: 0.0029, Val Loss: 0.0021
# Epoch 127/500 completed in 0.42 seconds.
# Epoch [128/500], Train Loss: 0.0029, Val Loss: 0.0011
# Epoch 128/500 completed in 0.43 seconds.
# Epoch [129/500], Train Loss: 0.0030, Val Loss: 0.0010
# Epoch 129/500 completed in 0.42 seconds.
# Epoch [130/500], Train Loss: 0.0029, Val Loss: 0.0017
# Epoch 130/500 completed in 0.43 seconds.
# Epoch [131/500], Train Loss: 0.0033, Val Loss: 0.0015
# Epoch 131/500 completed in 0.41 seconds.
# Epoch [132/500], Train Loss: 0.0032, Val Loss: 0.0020
# Epoch 132/500 completed in 0.42 seconds.
# Epoch [133/500], Train Loss: 0.0026, Val Loss: 0.0011
# Epoch 133/500 completed in 0.42 seconds.
# Epoch [134/500], Train Loss: 0.0029, Val Loss: 0.0017
# Epoch 134/500 completed in 0.42 seconds.
# Epoch [135/500], Train Loss: 0.0029, Val Loss: 0.0012
# Epoch 135/500 completed in 0.42 seconds.
# Epoch [136/500], Train Loss: 0.0030, Val Loss: 0.0010
# Epoch 136/500 completed in 0.42 seconds.
# Epoch [137/500], Train Loss: 0.0033, Val Loss: 0.0021
# Epoch 137/500 completed in 0.43 seconds.
# Epoch [138/500], Train Loss: 0.0035, Val Loss: 0.0012
# Epoch 138/500 completed in 0.43 seconds.
# Epoch [139/500], Train Loss: 0.0031, Val Loss: 0.0011
# Epoch 139/500 completed in 0.45 seconds.
# Epoch [140/500], Train Loss: 0.0028, Val Loss: 0.0034
# Epoch 140/500 completed in 0.54 seconds.
# Epoch [141/500], Train Loss: 0.0031, Val Loss: 0.0018
# Epoch 141/500 completed in 0.54 seconds.
# Epoch [142/500], Train Loss: 0.0029, Val Loss: 0.0011
# Epoch 142/500 completed in 0.58 seconds.
# Epoch [143/500], Train Loss: 0.0033, Val Loss: 0.0018
# Epoch 143/500 completed in 0.59 seconds.
# Epoch [144/500], Train Loss: 0.0035, Val Loss: 0.0028
# Epoch 144/500 completed in 0.51 seconds.
# Epoch [145/500], Train Loss: 0.0029, Val Loss: 0.0013
# Epoch 145/500 completed in 0.44 seconds.
# Epoch [146/500], Train Loss: 0.0030, Val Loss: 0.0013
# Epoch 146/500 completed in 0.43 seconds.
# Epoch [147/500], Train Loss: 0.0033, Val Loss: 0.0018
# Epoch 147/500 completed in 0.43 seconds.
# Epoch [148/500], Train Loss: 0.0026, Val Loss: 0.0015
# Epoch 148/500 completed in 0.43 seconds.
# Epoch [149/500], Train Loss: 0.0037, Val Loss: 0.0021
# Epoch 149/500 completed in 0.42 seconds.
# Epoch [150/500], Train Loss: 0.0029, Val Loss: 0.0011
# Model saved: best_model_epoch_150.pth
# Epoch 150/500 completed in 0.42 seconds.
# Epoch [151/500], Train Loss: 0.0030, Val Loss: 0.0011
# Epoch 151/500 completed in 0.42 seconds.
# Epoch [152/500], Train Loss: 0.0028, Val Loss: 0.0022
# Epoch 152/500 completed in 0.42 seconds.
# Epoch [153/500], Train Loss: 0.0028, Val Loss: 0.0023
# Epoch 153/500 completed in 0.43 seconds.
# Epoch [154/500], Train Loss: 0.0029, Val Loss: 0.0025
# Epoch 154/500 completed in 0.41 seconds.
# Epoch [155/500], Train Loss: 0.0035, Val Loss: 0.0013
# Epoch 155/500 completed in 0.42 seconds.
# Epoch [156/500], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 156/500 completed in 0.43 seconds.
# Epoch [157/500], Train Loss: 0.0029, Val Loss: 0.0023
# Epoch 157/500 completed in 0.43 seconds.
# Epoch [158/500], Train Loss: 0.0029, Val Loss: 0.0015
# Epoch 158/500 completed in 0.42 seconds.
# Epoch [159/500], Train Loss: 0.0027, Val Loss: 0.0011
# Epoch 159/500 completed in 0.42 seconds.
# Epoch [160/500], Train Loss: 0.0029, Val Loss: 0.0012
# Epoch 160/500 completed in 0.43 seconds.
# Epoch [161/500], Train Loss: 0.0026, Val Loss: 0.0018
# Epoch 161/500 completed in 0.43 seconds.
# Epoch [162/500], Train Loss: 0.0031, Val Loss: 0.0019
# Epoch 162/500 completed in 0.43 seconds.
# Epoch [163/500], Train Loss: 0.0027, Val Loss: 0.0016
# Epoch 163/500 completed in 0.42 seconds.
# Epoch [164/500], Train Loss: 0.0029, Val Loss: 0.0012
# Epoch 164/500 completed in 0.43 seconds.
# Epoch [165/500], Train Loss: 0.0026, Val Loss: 0.0012
# Epoch 165/500 completed in 0.43 seconds.
# Epoch [166/500], Train Loss: 0.0029, Val Loss: 0.0016
# Epoch 166/500 completed in 0.56 seconds.
# Epoch [167/500], Train Loss: 0.0028, Val Loss: 0.0012
# Epoch 167/500 completed in 0.55 seconds.
# Epoch [168/500], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 168/500 completed in 0.58 seconds.
# Epoch [169/500], Train Loss: 0.0030, Val Loss: 0.0012
# Epoch 169/500 completed in 0.60 seconds.
# Epoch [170/500], Train Loss: 0.0029, Val Loss: 0.0019
# Epoch 170/500 completed in 0.42 seconds.
# Epoch [171/500], Train Loss: 0.0026, Val Loss: 0.0011
# Epoch 171/500 completed in 0.44 seconds.
# Epoch [172/500], Train Loss: 0.0027, Val Loss: 0.0013
# Epoch 172/500 completed in 0.43 seconds.
# Epoch [173/500], Train Loss: 0.0027, Val Loss: 0.0011
# Epoch 173/500 completed in 0.43 seconds.
# Epoch [174/500], Train Loss: 0.0026, Val Loss: 0.0015
# Epoch 174/500 completed in 0.42 seconds.
# Epoch [175/500], Train Loss: 0.0030, Val Loss: 0.0012
# Epoch 175/500 completed in 0.44 seconds.
# Epoch [176/500], Train Loss: 0.0027, Val Loss: 0.0016
# Epoch 176/500 completed in 0.42 seconds.
# Epoch [177/500], Train Loss: 0.0027, Val Loss: 0.0020
# Epoch 177/500 completed in 0.42 seconds.
# Epoch [178/500], Train Loss: 0.0027, Val Loss: 0.0021
# Epoch 178/500 completed in 0.42 seconds.
# Epoch [179/500], Train Loss: 0.0030, Val Loss: 0.0015
# Epoch 179/500 completed in 0.42 seconds.
# Epoch [180/500], Train Loss: 0.0027, Val Loss: 0.0030
# Epoch 180/500 completed in 0.44 seconds.
# Epoch [181/500], Train Loss: 0.0026, Val Loss: 0.0025
# Epoch 181/500 completed in 0.42 seconds.
# Epoch [182/500], Train Loss: 0.0026, Val Loss: 0.0020
# Epoch 182/500 completed in 0.43 seconds.
# Epoch [183/500], Train Loss: 0.0030, Val Loss: 0.0012
# Epoch 183/500 completed in 0.43 seconds.
# Epoch [184/500], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 184/500 completed in 0.44 seconds.
# Epoch [185/500], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 185/500 completed in 0.42 seconds.
# Epoch [186/500], Train Loss: 0.0028, Val Loss: 0.0013
# Epoch 186/500 completed in 0.43 seconds.
# Epoch [187/500], Train Loss: 0.0027, Val Loss: 0.0013
# Epoch 187/500 completed in 0.42 seconds.
# Epoch [188/500], Train Loss: 0.0036, Val Loss: 0.0012
# Epoch 188/500 completed in 0.43 seconds.
# Epoch [189/500], Train Loss: 0.0023, Val Loss: 0.0014
# Epoch 189/500 completed in 0.42 seconds.
# Epoch [190/500], Train Loss: 0.0028, Val Loss: 0.0016
# Epoch 190/500 completed in 0.43 seconds.
# Epoch [191/500], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 191/500 completed in 0.53 seconds.
# Epoch [192/500], Train Loss: 0.0026, Val Loss: 0.0013
# Epoch 192/500 completed in 0.56 seconds.
# Epoch [193/500], Train Loss: 0.0029, Val Loss: 0.0013
# Epoch 193/500 completed in 0.57 seconds.
# Epoch [194/500], Train Loss: 0.0026, Val Loss: 0.0016
# Epoch 194/500 completed in 0.58 seconds.
# Epoch [195/500], Train Loss: 0.0030, Val Loss: 0.0015
# Epoch 195/500 completed in 0.52 seconds.
# Epoch [196/500], Train Loss: 0.0025, Val Loss: 0.0021
# Epoch 196/500 completed in 0.43 seconds.
# Epoch [197/500], Train Loss: 0.0025, Val Loss: 0.0011
# Epoch 197/500 completed in 0.42 seconds.
# Epoch [198/500], Train Loss: 0.0028, Val Loss: 0.0011
# Epoch 198/500 completed in 0.42 seconds.
# Epoch [199/500], Train Loss: 0.0026, Val Loss: 0.0015
# Epoch 199/500 completed in 0.44 seconds.
# Epoch [200/500], Train Loss: 0.0027, Val Loss: 0.0012
# Model saved: best_model_epoch_200.pth
# Epoch 200/500 completed in 0.43 seconds.
# Epoch [201/500], Train Loss: 0.0026, Val Loss: 0.0012
# Epoch 201/500 completed in 0.41 seconds.
# Epoch [202/500], Train Loss: 0.0024, Val Loss: 0.0013
# Epoch 202/500 completed in 0.42 seconds.
# Epoch [203/500], Train Loss: 0.0028, Val Loss: 0.0030
# Epoch 203/500 completed in 0.42 seconds.
# Epoch [204/500], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 204/500 completed in 0.42 seconds.
# Epoch [205/500], Train Loss: 0.0025, Val Loss: 0.0037
# Epoch 205/500 completed in 0.42 seconds.
# Epoch [206/500], Train Loss: 0.0027, Val Loss: 0.0016
# Epoch 206/500 completed in 0.42 seconds.
# Epoch [207/500], Train Loss: 0.0029, Val Loss: 0.0012
# Epoch 207/500 completed in 0.43 seconds.
# Epoch [208/500], Train Loss: 0.0026, Val Loss: 0.0018
# Epoch 208/500 completed in 0.42 seconds.
# Epoch [209/500], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 209/500 completed in 0.42 seconds.
# Epoch [210/500], Train Loss: 0.0027, Val Loss: 0.0013
# Epoch 210/500 completed in 0.41 seconds.
# Epoch [211/500], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 211/500 completed in 0.43 seconds.
# Epoch [212/500], Train Loss: 0.0027, Val Loss: 0.0013
# Epoch 212/500 completed in 0.41 seconds.
# Epoch [213/500], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 213/500 completed in 0.43 seconds.
# Epoch [214/500], Train Loss: 0.0026, Val Loss: 0.0023
# Epoch 214/500 completed in 0.42 seconds.
# Epoch [215/500], Train Loss: 0.0026, Val Loss: 0.0014
# Epoch 215/500 completed in 0.42 seconds.
# Epoch [216/500], Train Loss: 0.0024, Val Loss: 0.0017
# Epoch 216/500 completed in 0.43 seconds.
# Epoch [217/500], Train Loss: 0.0028, Val Loss: 0.0016
# Epoch 217/500 completed in 0.56 seconds.
# Epoch [218/500], Train Loss: 0.0024, Val Loss: 0.0015
# Epoch 218/500 completed in 0.53 seconds.
# Epoch [219/500], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 219/500 completed in 0.59 seconds.
# Epoch [220/500], Train Loss: 0.0026, Val Loss: 0.0016
# Epoch 220/500 completed in 0.57 seconds.
# Epoch [221/500], Train Loss: 0.0024, Val Loss: 0.0024
# Epoch 221/500 completed in 0.47 seconds.
# Epoch [222/500], Train Loss: 0.0026, Val Loss: 0.0012
# Epoch 222/500 completed in 0.42 seconds.
# Epoch [223/500], Train Loss: 0.0030, Val Loss: 0.0024
# Epoch 223/500 completed in 0.43 seconds.
# Epoch [224/500], Train Loss: 0.0029, Val Loss: 0.0015
# Epoch 224/500 completed in 0.42 seconds.
# Epoch [225/500], Train Loss: 0.0028, Val Loss: 0.0011
# Epoch 225/500 completed in 0.43 seconds.
# Epoch [226/500], Train Loss: 0.0023, Val Loss: 0.0019
# Epoch 226/500 completed in 0.43 seconds.
# Epoch [227/500], Train Loss: 0.0025, Val Loss: 0.0022
# Epoch 227/500 completed in 0.42 seconds.
# Epoch [228/500], Train Loss: 0.0029, Val Loss: 0.0025
# Epoch 228/500 completed in 0.42 seconds.
# Epoch [229/500], Train Loss: 0.0025, Val Loss: 0.0011
# Epoch 229/500 completed in 0.42 seconds.
# Epoch [230/500], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 230/500 completed in 0.43 seconds.
# Epoch [231/500], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 231/500 completed in 0.44 seconds.
# Epoch [232/500], Train Loss: 0.0024, Val Loss: 0.0016
# Epoch 232/500 completed in 0.43 seconds.
# Epoch [233/500], Train Loss: 0.0030, Val Loss: 0.0015
# Epoch 233/500 completed in 0.41 seconds.
# Epoch [234/500], Train Loss: 0.0029, Val Loss: 0.0017
# Epoch 234/500 completed in 0.42 seconds.
# Epoch [235/500], Train Loss: 0.0023, Val Loss: 0.0013
# Epoch 235/500 completed in 0.42 seconds.
# Epoch [236/500], Train Loss: 0.0023, Val Loss: 0.0015
# Epoch 236/500 completed in 0.44 seconds.
# Epoch [237/500], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 237/500 completed in 0.42 seconds.
# Epoch [238/500], Train Loss: 0.0024, Val Loss: 0.0019
# Epoch 238/500 completed in 0.42 seconds.
# Epoch [239/500], Train Loss: 0.0025, Val Loss: 0.0015
# Epoch 239/500 completed in 0.42 seconds.
# Epoch [240/500], Train Loss: 0.0024, Val Loss: 0.0013
# Epoch 240/500 completed in 0.41 seconds.
# Epoch [241/500], Train Loss: 0.0027, Val Loss: 0.0012
# Epoch 241/500 completed in 0.42 seconds.
# Epoch [242/500], Train Loss: 0.0024, Val Loss: 0.0011
# Epoch 242/500 completed in 0.48 seconds.
# Epoch [243/500], Train Loss: 0.0025, Val Loss: 0.0014
# Epoch 243/500 completed in 0.55 seconds.
# Epoch [244/500], Train Loss: 0.0024, Val Loss: 0.0018
# Epoch 244/500 completed in 0.55 seconds.
# Epoch [245/500], Train Loss: 0.0024, Val Loss: 0.0015
# Epoch 245/500 completed in 0.58 seconds.
# Epoch [246/500], Train Loss: 0.0025, Val Loss: 0.0017
# Epoch 246/500 completed in 0.60 seconds.
# Epoch [247/500], Train Loss: 0.0023, Val Loss: 0.0017
# Epoch 247/500 completed in 0.42 seconds.
# Epoch [248/500], Train Loss: 0.0027, Val Loss: 0.0021
# Epoch 248/500 completed in 0.43 seconds.
# Epoch [249/500], Train Loss: 0.0027, Val Loss: 0.0014
# Epoch 249/500 completed in 0.44 seconds.
# Epoch [250/500], Train Loss: 0.0023, Val Loss: 0.0013
# Model saved: best_model_epoch_250.pth
# Epoch 250/500 completed in 0.42 seconds.
# Epoch [251/500], Train Loss: 0.0026, Val Loss: 0.0012
# Epoch 251/500 completed in 0.42 seconds.
# Epoch [252/500], Train Loss: 0.0024, Val Loss: 0.0025
# Epoch 252/500 completed in 0.44 seconds.
# Epoch [253/500], Train Loss: 0.0027, Val Loss: 0.0018
# Epoch 253/500 completed in 0.42 seconds.
# Epoch [254/500], Train Loss: 0.0023, Val Loss: 0.0019
# Epoch 254/500 completed in 0.42 seconds.
# Epoch [255/500], Train Loss: 0.0027, Val Loss: 0.0017
# Epoch 255/500 completed in 0.42 seconds.
# Epoch [256/500], Train Loss: 0.0023, Val Loss: 0.0020
# Epoch 256/500 completed in 0.42 seconds.
# Epoch [257/500], Train Loss: 0.0027, Val Loss: 0.0019
# Epoch 257/500 completed in 0.42 seconds.
# Epoch [258/500], Train Loss: 0.0023, Val Loss: 0.0019
# Epoch 258/500 completed in 0.41 seconds.
# Epoch [259/500], Train Loss: 0.0025, Val Loss: 0.0019
# Epoch 259/500 completed in 0.42 seconds.
# Epoch [260/500], Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 260/500 completed in 0.42 seconds.
# Epoch [261/500], Train Loss: 0.0026, Val Loss: 0.0030
# Epoch 261/500 completed in 0.42 seconds.
# Epoch [262/500], Train Loss: 0.0026, Val Loss: 0.0013
# Epoch 262/500 completed in 0.41 seconds.
# Epoch [263/500], Train Loss: 0.0025, Val Loss: 0.0020
# Epoch 263/500 completed in 0.43 seconds.
# Epoch [264/500], Train Loss: 0.0024, Val Loss: 0.0016
# Epoch 264/500 completed in 0.43 seconds.
# Epoch [265/500], Train Loss: 0.0025, Val Loss: 0.0015
# Epoch 265/500 completed in 0.45 seconds.
# Epoch [266/500], Train Loss: 0.0022, Val Loss: 0.0026
# Epoch 266/500 completed in 0.42 seconds.
# Epoch [267/500], Train Loss: 0.0023, Val Loss: 0.0027
# Epoch 267/500 completed in 0.42 seconds.
# Epoch [268/500], Train Loss: 0.0024, Val Loss: 0.0016
# Epoch 268/500 completed in 0.56 seconds.
# Epoch [269/500], Train Loss: 0.0024, Val Loss: 0.0021
# Epoch 269/500 completed in 0.56 seconds.
# Epoch [270/500], Train Loss: 0.0026, Val Loss: 0.0017
# Epoch 270/500 completed in 0.58 seconds.
# Epoch [271/500], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch 271/500 completed in 0.59 seconds.
# Epoch [272/500], Train Loss: 0.0027, Val Loss: 0.0020
# Epoch 272/500 completed in 0.51 seconds.
# Epoch [273/500], Train Loss: 0.0028, Val Loss: 0.0038
# Epoch 273/500 completed in 0.42 seconds.
# Epoch [274/500], Train Loss: 0.0027, Val Loss: 0.0027
# Epoch 274/500 completed in 0.41 seconds.
# Epoch [275/500], Train Loss: 0.0025, Val Loss: 0.0019
# Epoch 275/500 completed in 0.43 seconds.
# Epoch [276/500], Train Loss: 0.0024, Val Loss: 0.0020
# Epoch 276/500 completed in 0.42 seconds.
# Epoch [277/500], Train Loss: 0.0023, Val Loss: 0.0015
# Epoch 277/500 completed in 0.43 seconds.
# Epoch [278/500], Train Loss: 0.0024, Val Loss: 0.0027
# Epoch 278/500 completed in 0.43 seconds.
# Epoch [279/500], Train Loss: 0.0026, Val Loss: 0.0016
# Epoch 279/500 completed in 0.43 seconds.
# Epoch [280/500], Train Loss: 0.0025, Val Loss: 0.0022
# Epoch 280/500 completed in 0.42 seconds.
# Epoch [281/500], Train Loss: 0.0025, Val Loss: 0.0021
# Epoch 281/500 completed in 0.43 seconds.
# Epoch [282/500], Train Loss: 0.0024, Val Loss: 0.0020
# Epoch 282/500 completed in 0.42 seconds.
# Epoch [283/500], Train Loss: 0.0025, Val Loss: 0.0026
# Epoch 283/500 completed in 0.43 seconds.
# Epoch [284/500], Train Loss: 0.0025, Val Loss: 0.0021
# Epoch 284/500 completed in 0.43 seconds.
# Epoch [285/500], Train Loss: 0.0023, Val Loss: 0.0018
# Epoch 285/500 completed in 0.43 seconds.
# Epoch [286/500], Train Loss: 0.0023, Val Loss: 0.0020
# Epoch 286/500 completed in 0.43 seconds.
# Epoch [287/500], Train Loss: 0.0026, Val Loss: 0.0021
# Epoch 287/500 completed in 0.43 seconds.
# Epoch [288/500], Train Loss: 0.0022, Val Loss: 0.0021
# Epoch 288/500 completed in 0.43 seconds.
# Epoch [289/500], Train Loss: 0.0026, Val Loss: 0.0024
# Epoch 289/500 completed in 0.43 seconds.
# Epoch [290/500], Train Loss: 0.0023, Val Loss: 0.0039
# Epoch 290/500 completed in 0.43 seconds.
# Epoch [291/500], Train Loss: 0.0024, Val Loss: 0.0028
# Epoch 291/500 completed in 0.43 seconds.
# Epoch [292/500], Train Loss: 0.0025, Val Loss: 0.0017
# Epoch 292/500 completed in 0.43 seconds.
# Epoch [293/500], Train Loss: 0.0025, Val Loss: 0.0019
# Epoch 293/500 completed in 0.46 seconds.
# Epoch [294/500], Train Loss: 0.0023, Val Loss: 0.0027
# Epoch 294/500 completed in 0.56 seconds.
# Epoch [295/500], Train Loss: 0.0023, Val Loss: 0.0021
# Epoch 295/500 completed in 0.56 seconds.
# Epoch [296/500], Train Loss: 0.0023, Val Loss: 0.0024
# Epoch 296/500 completed in 0.58 seconds.
# Epoch [297/500], Train Loss: 0.0023, Val Loss: 0.0025
# Epoch 297/500 completed in 0.59 seconds.
# Epoch [298/500], Train Loss: 0.0023, Val Loss: 0.0023
# Epoch 298/500 completed in 0.42 seconds.
# Epoch [299/500], Train Loss: 0.0022, Val Loss: 0.0057
# Epoch 299/500 completed in 0.43 seconds.
# Epoch [300/500], Train Loss: 0.0026, Val Loss: 0.0022
# Model saved: best_model_epoch_300.pth
# Epoch 300/500 completed in 0.43 seconds.
# Epoch [301/500], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch 301/500 completed in 0.44 seconds.
# Epoch [302/500], Train Loss: 0.0024, Val Loss: 0.0031
# Epoch 302/500 completed in 0.44 seconds.
# Epoch [303/500], Train Loss: 0.0026, Val Loss: 0.0035
# Epoch 303/500 completed in 0.42 seconds.
# Epoch [304/500], Train Loss: 0.0025, Val Loss: 0.0057
# Epoch 304/500 completed in 0.43 seconds.
# Epoch [305/500], Train Loss: 0.0023, Val Loss: 0.0033
# Epoch 305/500 completed in 0.42 seconds.
# Epoch [306/500], Train Loss: 0.0022, Val Loss: 0.0032
# Epoch 306/500 completed in 0.43 seconds.
# Epoch [307/500], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch 307/500 completed in 0.42 seconds.
# Epoch [308/500], Train Loss: 0.0022, Val Loss: 0.0033
# Epoch 308/500 completed in 0.43 seconds.
# Epoch [309/500], Train Loss: 0.0022, Val Loss: 0.0046
# Epoch 309/500 completed in 0.43 seconds.
# Epoch [310/500], Train Loss: 0.0025, Val Loss: 0.0022
# Epoch 310/500 completed in 0.43 seconds.
# Epoch [311/500], Train Loss: 0.0024, Val Loss: 0.0043
# Epoch 311/500 completed in 0.43 seconds.
# Epoch [312/500], Train Loss: 0.0028, Val Loss: 0.0030
# Epoch 312/500 completed in 0.42 seconds.
# Epoch [313/500], Train Loss: 0.0022, Val Loss: 0.0048
# Epoch 313/500 completed in 0.44 seconds.
# Epoch [314/500], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch 314/500 completed in 0.43 seconds.
# Epoch [315/500], Train Loss: 0.0027, Val Loss: 0.0034
# Epoch 315/500 completed in 0.44 seconds.
# Epoch [316/500], Train Loss: 0.0025, Val Loss: 0.0025
# Epoch 316/500 completed in 0.44 seconds.
# Epoch [317/500], Train Loss: 0.0023, Val Loss: 0.0033
# Epoch 317/500 completed in 0.44 seconds.
# Epoch [318/500], Train Loss: 0.0023, Val Loss: 0.0026
# Epoch 318/500 completed in 0.42 seconds.
# Epoch [319/500], Train Loss: 0.0023, Val Loss: 0.0036
# Epoch 319/500 completed in 0.58 seconds.
# Epoch [320/500], Train Loss: 0.0024, Val Loss: 0.0040
# Epoch 320/500 completed in 0.53 seconds.
# Epoch [321/500], Train Loss: 0.0024, Val Loss: 0.0038
# Epoch 321/500 completed in 0.61 seconds.
# Epoch [322/500], Train Loss: 0.0024, Val Loss: 0.0036
# Epoch 322/500 completed in 0.60 seconds.
# Epoch [323/500], Train Loss: 0.0023, Val Loss: 0.0035
# Epoch 323/500 completed in 0.46 seconds.
# Epoch [324/500], Train Loss: 0.0025, Val Loss: 0.0061
# Epoch 324/500 completed in 0.45 seconds.
# Epoch [325/500], Train Loss: 0.0025, Val Loss: 0.0037
# Epoch 325/500 completed in 0.42 seconds.
# Epoch [326/500], Train Loss: 0.0022, Val Loss: 0.0049
# Epoch 326/500 completed in 0.42 seconds.
# Epoch [327/500], Train Loss: 0.0025, Val Loss: 0.0052
# Epoch 327/500 completed in 0.42 seconds.
# Epoch [328/500], Train Loss: 0.0023, Val Loss: 0.0047
# Epoch 328/500 completed in 0.42 seconds.
# Epoch [329/500], Train Loss: 0.0025, Val Loss: 0.0064
# Epoch 329/500 completed in 0.43 seconds.
# Epoch [330/500], Train Loss: 0.0022, Val Loss: 0.0033
# Epoch 330/500 completed in 0.43 seconds.
# Epoch [331/500], Train Loss: 0.0025, Val Loss: 0.0050
# Epoch 331/500 completed in 0.43 seconds.
# Epoch [332/500], Train Loss: 0.0025, Val Loss: 0.0043
# Epoch 332/500 completed in 0.43 seconds.
# Epoch [333/500], Train Loss: 0.0023, Val Loss: 0.0033
# Epoch 333/500 completed in 0.43 seconds.
# Epoch [334/500], Train Loss: 0.0025, Val Loss: 0.0052
# Epoch 334/500 completed in 0.43 seconds.
# Epoch [335/500], Train Loss: 0.0023, Val Loss: 0.0054
# Epoch 335/500 completed in 0.44 seconds.
# Epoch [336/500], Train Loss: 0.0023, Val Loss: 0.0035
# Epoch 336/500 completed in 0.42 seconds.
# Epoch [337/500], Train Loss: 0.0025, Val Loss: 0.0051
# Epoch 337/500 completed in 0.44 seconds.
# Epoch [338/500], Train Loss: 0.0022, Val Loss: 0.0053
# Epoch 338/500 completed in 0.43 seconds.
# Epoch [339/500], Train Loss: 0.0021, Val Loss: 0.0047
# Epoch 339/500 completed in 0.42 seconds.
# Epoch [340/500], Train Loss: 0.0025, Val Loss: 0.0073
# Epoch 340/500 completed in 0.41 seconds.
# Epoch [341/500], Train Loss: 0.0024, Val Loss: 0.0050
# Epoch 341/500 completed in 0.42 seconds.
# Epoch [342/500], Train Loss: 0.0023, Val Loss: 0.0086
# Epoch 342/500 completed in 0.42 seconds.
# Epoch [343/500], Train Loss: 0.0026, Val Loss: 0.0046
# Epoch 343/500 completed in 0.42 seconds.
# Epoch [344/500], Train Loss: 0.0024, Val Loss: 0.0074
# Epoch 344/500 completed in 0.52 seconds.
# Epoch [345/500], Train Loss: 0.0022, Val Loss: 0.0066
# Epoch 345/500 completed in 0.55 seconds.
# Epoch [346/500], Train Loss: 0.0024, Val Loss: 0.0118
# Epoch 346/500 completed in 0.58 seconds.
# Epoch [347/500], Train Loss: 0.0023, Val Loss: 0.0065
# Epoch 347/500 completed in 0.60 seconds.
# Epoch [348/500], Train Loss: 0.0024, Val Loss: 0.0063
# Epoch 348/500 completed in 0.46 seconds.
# Epoch [349/500], Train Loss: 0.0022, Val Loss: 0.0053
# Epoch 349/500 completed in 0.44 seconds.
# Epoch [350/500], Train Loss: 0.0022, Val Loss: 0.0073
# Model saved: best_model_epoch_350.pth
# Epoch 350/500 completed in 0.43 seconds.
# Epoch [351/500], Train Loss: 0.0025, Val Loss: 0.0114
# Epoch 351/500 completed in 0.43 seconds.
# Epoch [352/500], Train Loss: 0.0022, Val Loss: 0.0089
# Epoch 352/500 completed in 0.43 seconds.
# Epoch [353/500], Train Loss: 0.0022, Val Loss: 0.0054
# Epoch 353/500 completed in 0.42 seconds.
# Epoch [354/500], Train Loss: 0.0023, Val Loss: 0.0068
# Epoch 354/500 completed in 0.42 seconds.
# Epoch [355/500], Train Loss: 0.0023, Val Loss: 0.0083
# Epoch 355/500 completed in 0.42 seconds.
# Epoch [356/500], Train Loss: 0.0023, Val Loss: 0.0069
# Epoch 356/500 completed in 0.43 seconds.
# Epoch [357/500], Train Loss: 0.0025, Val Loss: 0.0057
# Epoch 357/500 completed in 0.43 seconds.
# Epoch [358/500], Train Loss: 0.0023, Val Loss: 0.0106
# Epoch 358/500 completed in 0.43 seconds.
# Epoch [359/500], Train Loss: 0.0025, Val Loss: 0.0082
# Epoch 359/500 completed in 0.42 seconds.
# Epoch [360/500], Train Loss: 0.0023, Val Loss: 0.0136
# Epoch 360/500 completed in 0.42 seconds.
# Epoch [361/500], Train Loss: 0.0022, Val Loss: 0.0166
# Epoch 361/500 completed in 0.42 seconds.
# Epoch [362/500], Train Loss: 0.0026, Val Loss: 0.0108
# Epoch 362/500 completed in 0.42 seconds.
# Epoch [363/500], Train Loss: 0.0023, Val Loss: 0.0131
# Epoch 363/500 completed in 0.43 seconds.
# Epoch [364/500], Train Loss: 0.0023, Val Loss: 0.0096
# Epoch 364/500 completed in 0.43 seconds.
# Epoch [365/500], Train Loss: 0.0024, Val Loss: 0.0100
# Epoch 365/500 completed in 0.43 seconds.
# Epoch [366/500], Train Loss: 0.0026, Val Loss: 0.0078
# Epoch 366/500 completed in 0.42 seconds.
# Epoch [367/500], Train Loss: 0.0021, Val Loss: 0.0106
# Epoch 367/500 completed in 0.42 seconds.
# Epoch [368/500], Train Loss: 0.0024, Val Loss: 0.0105
# Epoch 368/500 completed in 0.42 seconds.
# Epoch [369/500], Train Loss: 0.0021, Val Loss: 0.0096
# Epoch 369/500 completed in 0.52 seconds.
# Epoch [370/500], Train Loss: 0.0022, Val Loss: 0.0104
# Epoch 370/500 completed in 0.55 seconds.
# Epoch [371/500], Train Loss: 0.0023, Val Loss: 0.0111
# Epoch 371/500 completed in 0.56 seconds.
# Epoch [372/500], Train Loss: 0.0022, Val Loss: 0.0128
# Epoch 372/500 completed in 0.59 seconds.
# Epoch [373/500], Train Loss: 0.0023, Val Loss: 0.0108
# Epoch 373/500 completed in 0.55 seconds.
# Epoch [374/500], Train Loss: 0.0024, Val Loss: 0.0148
# Epoch 374/500 completed in 0.43 seconds.
# Epoch [375/500], Train Loss: 0.0021, Val Loss: 0.0124
# Epoch 375/500 completed in 0.42 seconds.
# Epoch [376/500], Train Loss: 0.0024, Val Loss: 0.0071
# Epoch 376/500 completed in 0.44 seconds.
# Epoch [377/500], Train Loss: 0.0026, Val Loss: 0.0091
# Epoch 377/500 completed in 0.42 seconds.
# Epoch [378/500], Train Loss: 0.0021, Val Loss: 0.0141
# Epoch 378/500 completed in 0.43 seconds.
# Epoch [379/500], Train Loss: 0.0022, Val Loss: 0.0179
# Epoch 379/500 completed in 0.42 seconds.
# Epoch [380/500], Train Loss: 0.0023, Val Loss: 0.0130
# Epoch 380/500 completed in 0.42 seconds.
# Epoch [381/500], Train Loss: 0.0024, Val Loss: 0.0123
# Epoch 381/500 completed in 0.47 seconds.
# Epoch [382/500], Train Loss: 0.0022, Val Loss: 0.0109
# Epoch 382/500 completed in 0.43 seconds.
# Epoch [383/500], Train Loss: 0.0023, Val Loss: 0.0083
# Epoch 383/500 completed in 0.43 seconds.
# Epoch [384/500], Train Loss: 0.0021, Val Loss: 0.0093
# Epoch 384/500 completed in 0.43 seconds.
# Epoch [385/500], Train Loss: 0.0024, Val Loss: 0.0104
# Epoch 385/500 completed in 0.43 seconds.
# Epoch [386/500], Train Loss: 0.0022, Val Loss: 0.0223
# Epoch 386/500 completed in 0.43 seconds.
# Epoch [387/500], Train Loss: 0.0027, Val Loss: 0.0107
# Epoch 387/500 completed in 0.44 seconds.
# Epoch [388/500], Train Loss: 0.0025, Val Loss: 0.0139
# Epoch 388/500 completed in 0.42 seconds.
# Epoch [389/500], Train Loss: 0.0023, Val Loss: 0.0117
# Epoch 389/500 completed in 0.44 seconds.
# Epoch [390/500], Train Loss: 0.0021, Val Loss: 0.0113
# Epoch 390/500 completed in 0.42 seconds.
# Epoch [391/500], Train Loss: 0.0022, Val Loss: 0.0081
# Epoch 391/500 completed in 0.42 seconds.
# Epoch [392/500], Train Loss: 0.0021, Val Loss: 0.0115
# Epoch 392/500 completed in 0.41 seconds.
# Epoch [393/500], Train Loss: 0.0024, Val Loss: 0.0108
# Epoch 393/500 completed in 0.43 seconds.
# Epoch [394/500], Train Loss: 0.0023, Val Loss: 0.0121
# Epoch 394/500 completed in 0.44 seconds.
# Epoch [395/500], Train Loss: 0.0021, Val Loss: 0.0119
# Epoch 395/500 completed in 0.56 seconds.
# Epoch [396/500], Train Loss: 0.0023, Val Loss: 0.0109
# Epoch 396/500 completed in 0.56 seconds.
# Epoch [397/500], Train Loss: 0.0021, Val Loss: 0.0112
# Epoch 397/500 completed in 0.60 seconds.
# Epoch [398/500], Train Loss: 0.0024, Val Loss: 0.0111
# Epoch 398/500 completed in 0.57 seconds.
# Epoch [399/500], Train Loss: 0.0024, Val Loss: 0.0125
# Epoch 399/500 completed in 0.43 seconds.
# Epoch [400/500], Train Loss: 0.0023, Val Loss: 0.0119
# Model saved: best_model_epoch_400.pth
# Epoch 400/500 completed in 0.43 seconds.
# Epoch [401/500], Train Loss: 0.0023, Val Loss: 0.0134
# Epoch 401/500 completed in 0.43 seconds.
# Epoch [402/500], Train Loss: 0.0022, Val Loss: 0.0113
# Epoch 402/500 completed in 0.41 seconds.
# Epoch [403/500], Train Loss: 0.0023, Val Loss: 0.0100
# Epoch 403/500 completed in 0.43 seconds.
# Epoch [404/500], Train Loss: 0.0026, Val Loss: 0.0104
# Epoch 404/500 completed in 0.43 seconds.
# Epoch [405/500], Train Loss: 0.0022, Val Loss: 0.0110
# Epoch 405/500 completed in 0.44 seconds.
# Epoch [406/500], Train Loss: 0.0023, Val Loss: 0.0110
# Epoch 406/500 completed in 0.43 seconds.
# Epoch [407/500], Train Loss: 0.0023, Val Loss: 0.0121
# Epoch 407/500 completed in 0.44 seconds.
# Epoch [408/500], Train Loss: 0.0023, Val Loss: 0.0104
# Epoch 408/500 completed in 0.42 seconds.
# Epoch [409/500], Train Loss: 0.0022, Val Loss: 0.0151
# Epoch 409/500 completed in 0.43 seconds.
# Epoch [410/500], Train Loss: 0.0022, Val Loss: 0.0152
# Epoch 410/500 completed in 0.42 seconds.
# Epoch [411/500], Train Loss: 0.0022, Val Loss: 0.0144
# Epoch 411/500 completed in 0.43 seconds.
# Epoch [412/500], Train Loss: 0.0023, Val Loss: 0.0112
# Epoch 412/500 completed in 0.43 seconds.
# Epoch [413/500], Train Loss: 0.0023, Val Loss: 0.0107
# Epoch 413/500 completed in 0.43 seconds.
# Epoch [414/500], Train Loss: 0.0023, Val Loss: 0.0106
# Epoch 414/500 completed in 0.42 seconds.
# Epoch [415/500], Train Loss: 0.0022, Val Loss: 0.0142
# Epoch 415/500 completed in 0.41 seconds.
# Epoch [416/500], Train Loss: 0.0026, Val Loss: 0.0144
# Epoch 416/500 completed in 0.42 seconds.
# Epoch [417/500], Train Loss: 0.0022, Val Loss: 0.0163
# Epoch 417/500 completed in 0.42 seconds.
# Epoch [418/500], Train Loss: 0.0022, Val Loss: 0.0126
# Epoch 418/500 completed in 0.44 seconds.
# Epoch [419/500], Train Loss: 0.0023, Val Loss: 0.0125
# Epoch 419/500 completed in 0.43 seconds.
# Epoch [420/500], Train Loss: 0.0023, Val Loss: 0.0124
# Epoch 420/500 completed in 0.58 seconds.
# Epoch [421/500], Train Loss: 0.0021, Val Loss: 0.0115
# Epoch 421/500 completed in 0.54 seconds.
# Epoch [422/500], Train Loss: 0.0022, Val Loss: 0.0122
# Epoch 422/500 completed in 0.59 seconds.
# Epoch [423/500], Train Loss: 0.0024, Val Loss: 0.0122
# Epoch 423/500 completed in 0.60 seconds.
# Epoch [424/500], Train Loss: 0.0023, Val Loss: 0.0176
# Epoch 424/500 completed in 0.51 seconds.
# Epoch [425/500], Train Loss: 0.0021, Val Loss: 0.0122
# Epoch 425/500 completed in 0.42 seconds.
# Epoch [426/500], Train Loss: 0.0022, Val Loss: 0.0138
# Epoch 426/500 completed in 0.43 seconds.
# Epoch [427/500], Train Loss: 0.0022, Val Loss: 0.0138
# Epoch 427/500 completed in 0.43 seconds.
# Epoch [428/500], Train Loss: 0.0022, Val Loss: 0.0185
# Epoch 428/500 completed in 0.44 seconds.
# Epoch [429/500], Train Loss: 0.0022, Val Loss: 0.0146
# Epoch 429/500 completed in 0.44 seconds.
# Epoch [430/500], Train Loss: 0.0023, Val Loss: 0.0118
# Epoch 430/500 completed in 0.43 seconds.
# Epoch [431/500], Train Loss: 0.0022, Val Loss: 0.0143
# Epoch 431/500 completed in 0.43 seconds.
# Epoch [432/500], Train Loss: 0.0021, Val Loss: 0.0213
# Epoch 432/500 completed in 0.44 seconds.
# Epoch [433/500], Train Loss: 0.0022, Val Loss: 0.0117
# Epoch 433/500 completed in 0.43 seconds.
# Epoch [434/500], Train Loss: 0.0024, Val Loss: 0.0110
# Epoch 434/500 completed in 0.43 seconds.
# Epoch [435/500], Train Loss: 0.0020, Val Loss: 0.0140
# Epoch 435/500 completed in 0.43 seconds.
# Epoch [436/500], Train Loss: 0.0023, Val Loss: 0.0122
# Epoch 436/500 completed in 0.42 seconds.
# Epoch [437/500], Train Loss: 0.0021, Val Loss: 0.0099
# Epoch 437/500 completed in 0.43 seconds.
# Epoch [438/500], Train Loss: 0.0021, Val Loss: 0.0112
# Epoch 438/500 completed in 0.43 seconds.
# Epoch [439/500], Train Loss: 0.0023, Val Loss: 0.0129
# Epoch 439/500 completed in 0.43 seconds.
# Epoch [440/500], Train Loss: 0.0021, Val Loss: 0.0093
# Epoch 440/500 completed in 0.43 seconds.
# Epoch [441/500], Train Loss: 0.0026, Val Loss: 0.0097
# Epoch 441/500 completed in 0.43 seconds.
# Epoch [442/500], Train Loss: 0.0022, Val Loss: 0.0148
# Epoch 442/500 completed in 0.44 seconds.
# Epoch [443/500], Train Loss: 0.0023, Val Loss: 0.0131
# Epoch 443/500 completed in 0.44 seconds.
# Epoch [444/500], Train Loss: 0.0022, Val Loss: 0.0135
# Epoch 444/500 completed in 0.44 seconds.
# Epoch [445/500], Train Loss: 0.0022, Val Loss: 0.0112
# Epoch 445/500 completed in 0.50 seconds.
# Epoch [446/500], Train Loss: 0.0022, Val Loss: 0.0107
# Epoch 446/500 completed in 0.54 seconds.
# Epoch [447/500], Train Loss: 0.0021, Val Loss: 0.0141
# Epoch 447/500 completed in 0.58 seconds.
# Epoch [448/500], Train Loss: 0.0022, Val Loss: 0.0112
# Epoch 448/500 completed in 0.60 seconds.
# Epoch [449/500], Train Loss: 0.0022, Val Loss: 0.0119
# Epoch 449/500 completed in 0.53 seconds.
# Epoch [450/500], Train Loss: 0.0022, Val Loss: 0.0118
# Model saved: best_model_epoch_450.pth
# Epoch 450/500 completed in 0.43 seconds.
# Epoch [451/500], Train Loss: 0.0023, Val Loss: 0.0127
# Epoch 451/500 completed in 0.43 seconds.
# Epoch [452/500], Train Loss: 0.0022, Val Loss: 0.0088
# Epoch 452/500 completed in 0.44 seconds.
# Epoch [453/500], Train Loss: 0.0023, Val Loss: 0.0116
# Epoch 453/500 completed in 0.42 seconds.
# Epoch [454/500], Train Loss: 0.0022, Val Loss: 0.0069
# Epoch 454/500 completed in 0.42 seconds.
# Epoch [455/500], Train Loss: 0.0021, Val Loss: 0.0085
# Epoch 455/500 completed in 0.42 seconds.
# Epoch [456/500], Train Loss: 0.0023, Val Loss: 0.0101
# Epoch 456/500 completed in 0.42 seconds.
# Epoch [457/500], Train Loss: 0.0023, Val Loss: 0.0110
# Epoch 457/500 completed in 0.43 seconds.
# Epoch [458/500], Train Loss: 0.0021, Val Loss: 0.0141
# Epoch 458/500 completed in 0.42 seconds.
# Epoch [459/500], Train Loss: 0.0023, Val Loss: 0.0091
# Epoch 459/500 completed in 0.43 seconds.
# Epoch [460/500], Train Loss: 0.0023, Val Loss: 0.0113
# Epoch 460/500 completed in 0.42 seconds.
# Epoch [461/500], Train Loss: 0.0025, Val Loss: 0.0134
# Epoch 461/500 completed in 0.43 seconds.
# Epoch [462/500], Train Loss: 0.0024, Val Loss: 0.0147
# Epoch 462/500 completed in 0.43 seconds.
# Epoch [463/500], Train Loss: 0.0021, Val Loss: 0.0122
# Epoch 463/500 completed in 0.43 seconds.
# Epoch [464/500], Train Loss: 0.0020, Val Loss: 0.0149
# Epoch 464/500 completed in 0.42 seconds.
# Epoch [465/500], Train Loss: 0.0022, Val Loss: 0.0126
# Epoch 465/500 completed in 0.43 seconds.
# Epoch [466/500], Train Loss: 0.0023, Val Loss: 0.0103
# Epoch 466/500 completed in 0.43 seconds.
# Epoch [467/500], Train Loss: 0.0021, Val Loss: 0.0117
# Epoch 467/500 completed in 0.43 seconds.
# Epoch [468/500], Train Loss: 0.0023, Val Loss: 0.0128
# Epoch 468/500 completed in 0.43 seconds.
# Epoch [469/500], Train Loss: 0.0021, Val Loss: 0.0132
# Epoch 469/500 completed in 0.42 seconds.
# Epoch [470/500], Train Loss: 0.0024, Val Loss: 0.0110
# Epoch 470/500 completed in 0.42 seconds.
# Epoch [471/500], Train Loss: 0.0022, Val Loss: 0.0100
# Epoch 471/500 completed in 0.56 seconds.
# Epoch [472/500], Train Loss: 0.0022, Val Loss: 0.0128
# Epoch 472/500 completed in 0.55 seconds.
# Epoch [473/500], Train Loss: 0.0022, Val Loss: 0.0129
# Epoch 473/500 completed in 0.59 seconds.
# Epoch [474/500], Train Loss: 0.0021, Val Loss: 0.0110
# Epoch 474/500 completed in 0.57 seconds.
# Epoch [475/500], Train Loss: 0.0022, Val Loss: 0.0106
# Epoch 475/500 completed in 0.51 seconds.
# Epoch [476/500], Train Loss: 0.0022, Val Loss: 0.0166
# Epoch 476/500 completed in 0.42 seconds.
# Epoch [477/500], Train Loss: 0.0021, Val Loss: 0.0164
# Epoch 477/500 completed in 0.43 seconds.
# Epoch [478/500], Train Loss: 0.0023, Val Loss: 0.0111
# Epoch 478/500 completed in 0.42 seconds.
# Epoch [479/500], Train Loss: 0.0020, Val Loss: 0.0104
# Epoch 479/500 completed in 0.43 seconds.
# Epoch [480/500], Train Loss: 0.0023, Val Loss: 0.0135
# Epoch 480/500 completed in 0.42 seconds.
# Epoch [481/500], Train Loss: 0.0022, Val Loss: 0.0177
# Epoch 481/500 completed in 0.41 seconds.
# Epoch [482/500], Train Loss: 0.0023, Val Loss: 0.0139
# Epoch 482/500 completed in 0.43 seconds.
# Epoch [483/500], Train Loss: 0.0021, Val Loss: 0.0143
# Epoch 483/500 completed in 0.42 seconds.
# Epoch [484/500], Train Loss: 0.0020, Val Loss: 0.0127
# Epoch 484/500 completed in 0.43 seconds.
# Epoch [485/500], Train Loss: 0.0022, Val Loss: 0.0097
# Epoch 485/500 completed in 0.42 seconds.
# Epoch [486/500], Train Loss: 0.0021, Val Loss: 0.0110
# Epoch 486/500 completed in 0.42 seconds.
# Epoch [487/500], Train Loss: 0.0023, Val Loss: 0.0141
# Epoch 487/500 completed in 0.42 seconds.
# Epoch [488/500], Train Loss: 0.0022, Val Loss: 0.0154
# Epoch 488/500 completed in 0.44 seconds.
# Epoch [489/500], Train Loss: 0.0023, Val Loss: 0.0144
# Epoch 489/500 completed in 0.43 seconds.
# Epoch [490/500], Train Loss: 0.0022, Val Loss: 0.0123
# Epoch 490/500 completed in 0.42 seconds.
# Epoch [491/500], Train Loss: 0.0022, Val Loss: 0.0124
# Epoch 491/500 completed in 0.42 seconds.
# Epoch [492/500], Train Loss: 0.0021, Val Loss: 0.0120
# Epoch 492/500 completed in 0.42 seconds.
# Epoch [493/500], Train Loss: 0.0023, Val Loss: 0.0118
# Epoch 493/500 completed in 0.43 seconds.
# Epoch [494/500], Train Loss: 0.0022, Val Loss: 0.0144
# Epoch 494/500 completed in 0.42 seconds.
# Epoch [495/500], Train Loss: 0.0022, Val Loss: 0.0129
# Epoch 495/500 completed in 0.43 seconds.
# Epoch [496/500], Train Loss: 0.0022, Val Loss: 0.0138
# Epoch 496/500 completed in 0.44 seconds.
# Epoch [497/500], Train Loss: 0.0021, Val Loss: 0.0158
# Epoch 497/500 completed in 0.55 seconds.
# Epoch [498/500], Train Loss: 0.0022, Val Loss: 0.0139
# Epoch 498/500 completed in 0.54 seconds.
# Epoch [499/500], Train Loss: 0.0023, Val Loss: 0.0148
# Epoch 499/500 completed in 0.60 seconds.
# Epoch [500/500], Train Loss: 0.0023, Val Loss: 0.0163
# Model saved: best_model_epoch_500.pth
# Epoch 500/500 completed in 0.59 seconds.
# Total training time: 225.46 seconds.

# %% [markdown]
# ### 3. loss 그래프 출력

# %%
# 손실 그래프 출력
plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.legend()
plt.show()

# %%
# 손실 그래프 출력
plt.plot(range(5, num_epochs + 1), train_losses[4:], label='Train Loss')
plt.plot(range(5, num_epochs + 1), val_losses[4:], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 3. 모델 요약 내용 출력

# %%
from torchinfo import summary

summary(best_model, (1, 10, 3), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# LSTM_Model                               [1, 3]                    --
# ├─LSTM: 1-1                              [1, 10, 116]              56,144
# ├─Linear: 1-2                            [1, 3]                    351
# ==========================================================================================
# Total params: 56,495
# Trainable params: 56,495
# Non-trainable params: 0
# Total mult-adds (M): 0.56
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.23
# Estimated Total Size (MB): 0.24
# ==========================================================================================

# %% [markdown]
# ## 테스트

# %% [markdown]
# ### 1. 테스트 결과 생성

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import torch

# 모델 예측 및 성능 평가
best_model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

test_loss = 0
y_true_list = []
y_pred_list = []

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        # 예측 수행
        output = best_model(batch_x)

        # 손실 계산
        loss = criterion(output, batch_y)
        test_loss += loss.item()

        # 예측값과 실제값 저장
        y_pred_list.append(output.cpu().numpy())  # 예측값을 CPU로 이동하여 numpy 배열로 변환
        y_true_list.append(batch_y.cpu().numpy())  # 실제값을 CPU로 이동하여 numpy 배열로 변환

# 리스트를 numpy 배열로 변환
y_pred = np.concatenate(y_pred_list, axis=0)
y_true = np.concatenate(y_true_list, axis=0)

# 성능 평가
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Squared Error (MSE): 1.731720294628758e-05
# Mean Absolute Error (MAE): 0.002338590333238244

# %% [markdown]
# ### 2. 결과 시각화

# %%
prediction_visualization(y_true, y_pred)

# %% [markdown]
# ### 3. raw 데이터와 predict 데이터 비교

# %%
y_pred_original = scaler.inverse_transform(y_pred)

y_test_original = scaler.inverse_transform(y_true.reshape(-1, 3))

prediction_visualization(y_test_original, y_pred_original)

# %% [markdown]
# Todo
# - train, validation, test shuffle안하고 학습 & 데이터 구조 찍어보기
# - device 찍어보기
# - 부족한 부분 찾아보기
