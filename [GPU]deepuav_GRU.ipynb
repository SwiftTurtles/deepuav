# %% [markdown]
# ## 전체 공통 함수

# %% [markdown]
# ### 1. 데이터 보간 함수

# %% [markdown]
# - 데이터의 시간 간격을 0.5초의 등간격으로 맞추고 그에 따른 좌표 값을 보간함
# - 가장 많이 사용되는 3차 스플라인 보간 적용

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt

# 데이터 보간 - 위도, 고도, 경도 값을 0.5초 시간 간격으로 보간
def spline_interpolation(x, y):
    # x: 보간할 데이터의 x 값 (시간)
    # y: 보간할 데이터의 y 값 (위도, 고도, 경도)

    # 3차 스플라인 보간 함수 생성
    f = interp1d(x, y, kind='cubic')

    # 시간 범위 설정
    start_time = min(x)
    end_time = max(x)

    # 0.5초 간격의 시간 배열을 생성
    new_x = np.arange(start_time, end_time, 0.5)

    # 위도, 경도, 고도 보간
    new_y = f(new_x)

    return new_x, new_y

# %% [markdown]
# ### 2. 시퀀스 나누는 함수

# %% [markdown]
# - 학습을 위해 데이터를 시퀀스 형태로 나눔
# - look back과 forward에 따라 학습에 사용될 x값의 구간과 y값을 반환함
# - 초기 look back은 10, forward는 0이다.

# %%
# 시퀀스 생성 함수
# look back : 10 (5초간의 위도, 고도, 경도 데이터를 x값으로 사용)
# forward : 0 (0.5초 뒤의 위도, 고도, 경도 데이터를 y값으로 사용)
def create_sequences(df, look_back=30, forward=0):
    xs = []
    ys = []
    for i in range(len(df) - look_back - forward):
        x = df.iloc[i:(i+look_back)].values
        y = df.iloc[i+look_back+forward].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# %% [markdown]
# ### 3. 시간 소수점 절사 함수

# %% [markdown]
# - 불필요한 시간 소수점 제거

# %%
import math

# 시간 소수점 절사 함수
def truncation(df):
    new_time = []

    for a in df['time']:
      new_time.append(math.floor(a * 10) / 10)

    df['time'] = new_time

    return df

# %% [markdown]
# ### 4. 스케일링 함수

# %% [markdown]
# - MinMaxScaling 적용 함수

# %%
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaling 적용 함수
def min_max_scaling(df):

    # time 삭제 df 생성
    mid_df=df.drop(columns='time')

    min_max_scaler = MinMaxScaler()
    min_max_scaler.fit(mid_df)

    min_max_data = min_max_scaler.transform(mid_df)

    new_data = pd.DataFrame(min_max_data)

    # time 추가
    new_data.insert(0, 'time', df['time'])

    # 나머지 열의 이름 가져오기
    column_names = mid_df.columns.tolist()

    column_names.insert(0, 'time')

    print(column_names)

    # 새로운 데이터프레임에 열 이름 설정
    new_data.columns = column_names

    return min_max_scaler, new_data

# %% [markdown]
# ### 5. train/validation/test 분리 함수

# %% [markdown]
# - Train, Validation, Test 데이터셋을 분리하는 함수이다.
# - 각각의 비율은 6:2:2 이다.

# %%
# train/validation/test 분리 함수 (시계열 데이터용, 6:2:2 비율)
def split_train_val_test(df):
    n = len(df)

    # 데이터셋 크기 계산
    train_end = int(0.6 * n)
    val_end = int(0.8 * n)  # 0.6 + 0.2

    # 순차적으로 데이터 분할
    train_data = df[:train_end]     # 처음 60%는 train 데이터
    val_data = df[train_end:val_end] # 그 다음 20%는 validation 데이터
    test_data = df[val_end:]        # 마지막 20%는 test 데이터

    # 데이터 크기 출력 (원한다면)
    # print("Train set:", train_data.shape)
    # print("Validation set:", val_data.shape)
    # print("Test set:", test_data.shape)

    return train_data, val_data, test_data

# %% [markdown]
# ### 6. 경로 시각화 함수

# %% [markdown]
# - 실제 경로와 예측 경로를 각각 그래프로 생성

# %%
import matplotlib.pyplot as plt

# 경로 시각화 함수
def prediction_visualization(y_test, y_pred):
    # 시각화를 위해 위도, 경도, 고도 분리
    y_test_lat = y_test[:, 0]
    y_test_lon = y_test[:, 1]
    y_test_alt = y_test[:, 2]

    y_pred_lat = y_pred[:, 0]
    y_pred_lon = y_pred[:, 1]
    y_pred_alt = y_pred[:, 2]

    # 3D 그래프 생성
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')

    # 실제 값 플롯
    ax.scatter(y_test_lat, y_test_lon, y_test_alt, c='b', marker='o', label='Actual')

    # 예측 값 플롯
    ax.scatter(y_pred_lat, y_pred_lon, y_pred_alt, c='r', marker='^', label='Predicted')

    # 그래프 제목 및 축 레이블 설정
    ax.set_title('Actual vs Predicted')
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 범례
    ax.legend()

    # 그래프를 화면에 출력
    plt.show()

# %% [markdown]
# ### 성능 테스트 함수

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

def evaluation(y_test, y_pred):

    # MSE (Mean Squared Error) 계산
    mse = mean_squared_error(y_test, y_pred)
    print(f"Mean Squared Error: {mse}")

    # MAE (Mean Absolute Error) 계산
    mae = mean_absolute_error(y_test, y_pred)
    print(f"Mean Absolute Error: {mae}")

    # 예측 결과와 실제 값을 비교하는 샘플 출력
    for i in range(5):  # 예시로 첫 5개만 출력
        print(f"Actual: {y_test[i]}, Predicted: {y_pred[i]}")

# %% [markdown]
# ## 전처리

# %% [markdown]
# ### 1. 데이터셋 가져오기

# %%
import pandas as pd

# 데이터셋 가져오기 (필요시 저장 경로 수정)
raw = pd.read_csv("/content/drive/MyDrive/deep-uav/OnboardGPS.csv")

# %% [markdown]
# ### 2. 데이터셋 전처리

# %% [markdown]
# - 데이터셋 보간
# - 소수점 절사
# - MinMaxScaling 적용

# %%
df = raw[['Timpstemp', ' lat', ' lon', ' alt']]

new_x, lat = spline_interpolation(df['Timpstemp'] / 1e6 , df[' lat'])
new_x, lon = spline_interpolation(df['Timpstemp'] / 1e6 , df[' lon'])
new_x, alt = spline_interpolation(df['Timpstemp'] / 1e6 , df[' alt'])

df = pd.DataFrame({"time":new_x, "lat":lat, "lon":lon, "alt":alt})

df = truncation(df)
scaler, df = min_max_scaling(df)
# Out:
# ['time', 'lat', 'lon', 'alt']

# %% [markdown]
# ## 모델 선언

# %% [markdown]
# ### 1. 모델 클래스 선언
# - GRU를 사용한 모델 클래스 선언
# - 구조 : GRU + Fully Connected Layer

# %%
import torch
import time
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split

# 하이퍼파라미터와 모델 정의
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_units, output_size, num_layers):
        super(GRUModel, self).__init__()
        self.gru = nn.GRU(input_size, hidden_units, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_units, output_size)

    def forward(self, x):
        out, _ = self.gru(x)
        out = self.fc(out[:, -1, :])  # 마지막 타임스텝의 출력만 사용
        return out

# %%
# 모델 학습 함수
def train_model(model, criterion, optimizer, loader, device, history):
    model.train()
    total_loss = 0
    for batch_x, batch_y in loader:
        batch_x, batch_y = batch_x.to(device), batch_y.to(device)
        optimizer.zero_grad()
        output = model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    avg_loss = total_loss / len(loader)

    # history가 주어지면 학습 손실 기록
    if history is not None:
        history['train_loss'].append(avg_loss)

    return avg_loss

# %%
# 검증 및 테스트 함수
def evaluate_model(model, criterion, loader, device, history):
    model.eval()
    total_loss = 0
    true_values = []
    predictions = []

    start_time = time.time()  # 예측 시작 시간 기록

    with torch.no_grad():
        for batch_x, batch_y in loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            output = model(batch_x)
            loss = criterion(output, batch_y)
            total_loss += loss.item()
            true_values.append(batch_y.cpu().numpy())
            predictions.append(output.cpu().numpy())

    end_time = time.time()  # 예측 종료 시간 기록
    total_inference_time = end_time - start_time

    # print(f"Total Inference Time: {total_inference_time:.2f} seconds")

    avg_loss = total_loss / len(loader)

    # history가 주어지면 검증 손실 기록
    if history is not None:
        history['val_loss'].append(avg_loss)

    return avg_loss, true_values, predictions

# %%
# 데이터 로더 생성 함수
def prepare_dataloader(df, batch_size, look_back=30, forward=0):

  # train, validation, test 분리
  train_data, val_data, test_data = split_train_val_test(df)

  # 각 데이터셋에서 시퀀스 생성
  X_train, y_train = create_sequences(train_data[['lat', 'lon', 'alt']], look_back, forward)
  X_val, y_val = create_sequences(val_data[['lat', 'lon', 'alt']], look_back, forward)
  X_test, y_test = create_sequences(test_data[['lat', 'lon', 'alt']], look_back, forward)

  X_train = torch.tensor(X_train, dtype=torch.float32)
  y_train = torch.tensor(y_train, dtype=torch.float32)
  X_val = torch.tensor(X_val, dtype=torch.float32)
  y_val = torch.tensor(y_val, dtype=torch.float32)
  X_test = torch.tensor(X_test, dtype=torch.float32)
  y_test = torch.tensor(y_test, dtype=torch.float32)

  train_dataset = TensorDataset(X_train, y_train)
  validation_dataset = TensorDataset(X_val, y_val)
  test_dataset = TensorDataset(X_test, y_test)

  # 데이터 로더 생성
  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  val_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

  return train_loader, val_loader, test_loader

# %% [markdown]
# ### 2. 하이퍼파라미터 불러오기

# %%
import json

# 1. 저장된 하이퍼파라미터 불러오기
with open("/content/drive/MyDrive/deep-uav/best_hyperparameters_1014.json", "r") as f:
    best_params = json.load(f)

print("Loaded best hyperparameters:", best_params)
# Out:
# Loaded best hyperparameters: {'n_layers': 1, 'n_units_l0': 202, 'learning_rate': 0.0014729861305493907, 'batch_size': 26}

# %% [markdown]
# ## 학습

# %% [markdown]
# 1. 시퀀스 생성
# 2. Train, Validation, Test 분리
# 3. DataLoader에 load

# %% [markdown]
# ### 1. 최적의 파라미터로 모델 학습

# %%
# 최적의 모델 학습
# best_params = study.best_params

train_loader, val_loader, test_loader = prepare_dataloader(df, best_params['batch_size'])

best_model = GRUModel(input_size=3, hidden_units=best_params['n_units_l0'], output_size=3, num_layers=best_params['n_layers'])
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
best_model = best_model.to(device)

optimizer = torch.optim.Adam(best_model.parameters(), lr=best_params['learning_rate'])
criterion = torch.nn.MSELoss()

# %%
import time
import torch

best_model.train()
total_train_time = 0  # 총 학습 시간 기록 변수
history = {'train_loss': [], 'val_loss': []}

num_epochs = 300
for epoch in range(num_epochs):  # 최종 모델 학습
    best_model.train()
    train_loss = 0.0
    epoch_start_time = time.time()  # 에포크 시작 시간 기록
    for batch_x, batch_y in train_loader:
        batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
        batch_y = batch_y.to(device)
        optimizer.zero_grad()

        output = best_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    # history가 주어지면 학습 손실 기록
    history['train_loss'].append(train_loss / len(train_loader))

    epoch_end_time = time.time()  # 에포크 종료 시간 기록
    epoch_duration = epoch_end_time - epoch_start_time  # 한 에포크의 학습 시간
    total_train_time += epoch_duration  # 총 학습 시간에 추가

    # Validation set에서 성능 측정
    best_model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch_x, batch_y in val_loader:
            batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
            batch_y = batch_y.to(device)
            output = best_model(batch_x)
            loss = criterion(output, batch_y)
            val_loss += loss.item()


    # history가 주어지면 학습 손실 기록
    history['val_loss'].append(val_loss / len(val_loader))

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

    # 모델 저장
    model_save_path = f"/content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_{epoch+1}.pth"
    torch.save({
      'model_state_dict': best_model.state_dict(),
      'train_losses': history['train_loss'],
      'val_losses': history['val_loss']
    }, model_save_path)
    print(f"Model saved: {model_save_path}")

    print(f"Epoch {epoch+1}/{num_epochs} completed in {epoch_duration:.2f} seconds.")

print(f"Total training time: {total_train_time:.2f} seconds.")
# Out:
# Epoch [1/300], Train Loss: 0.0289, Val Loss: 0.0100
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_1.pth
# Epoch 1/300 completed in 3.99 seconds.
# Epoch [2/300], Train Loss: 0.0120, Val Loss: 0.0053
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_2.pth
# Epoch 2/300 completed in 4.57 seconds.
# Epoch [3/300], Train Loss: 0.0103, Val Loss: 0.0065
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_3.pth
# Epoch 3/300 completed in 3.64 seconds.
# Epoch [4/300], Train Loss: 0.0086, Val Loss: 0.0040
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_4.pth
# Epoch 4/300 completed in 3.65 seconds.
# Epoch [5/300], Train Loss: 0.0075, Val Loss: 0.0027
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_5.pth
# Epoch 5/300 completed in 5.08 seconds.
# Epoch [6/300], Train Loss: 0.0085, Val Loss: 0.0025
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_6.pth
# Epoch 6/300 completed in 3.59 seconds.
# Epoch [7/300], Train Loss: 0.0066, Val Loss: 0.0021
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_7.pth
# Epoch 7/300 completed in 3.59 seconds.
# Epoch [8/300], Train Loss: 0.0056, Val Loss: 0.0019
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_8.pth
# Epoch 8/300 completed in 4.98 seconds.
# Epoch [9/300], Train Loss: 0.0052, Val Loss: 0.0056
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch
Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_171.pth
# Epoch 171/300 completed in 3.76 seconds.
# Epoch [172/300], Train Loss: 0.0018, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_172.pth
# Epoch 172/300 completed in 4.81 seconds.
# Epoch [173/300], Train Loss: 0.0018, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_173.pth
# Epoch 173/300 completed in 3.64 seconds.
# Epoch [174/300], Train Loss: 0.0018, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_174.pth
# Epoch 174/300 completed in 3.61 seconds.
# Epoch [175/300], Train Loss: 0.0020, Val Loss: 0.0030
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_175.pth
# Epoch 175/300 completed in 5.16 seconds.
# Epoch [176/300], Train Loss: 0.0028, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_176.pth
# Epoch 176/300 completed in 3.58 seconds.
# Epoch [177/300], Train Loss: 0.0017, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_177.pth
# Epoch 177/300 completed in 3.61 seconds.
# Epoch [178/300], Train Loss: 0.0016, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_178.pth
# Epoch 178/300 completed in 4.62 seconds.
# Epoch [179/300], Train Loss: 0.0017, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_179.pth
# Epoch 179/300 completed in 3.91 seconds.
# Epoch [180/300], Train Loss: 0.0017, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_180.pth
# Epoch 180/300 completed in 3.60 seconds.
# Epoch [181/300], Train Loss: 0.0018, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_181.pth
# Epoch 181/300 completed in 4.02 seconds.
# Epoch [182/300], Train Loss: 0.0020, Val Loss: 0.0015
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_182.pth
# Epoch 182/300 completed in 4.47 seconds.
# Epoch [183/300], Train Loss: 0.0018, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_183.pth
# Epoch 183/300 completed in 3.59 seconds.
# Epoch [184/300], Train Loss: 0.0019, Val Loss: 0.0007
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_184.pth
# Epoch 184/300 completed in 3.61 seconds.
# Epoch [185/300], Train Loss: 0.0018, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_185.pth
# Epoch 185/300 completed in 4.88 seconds.
# Epoch [186/300], Train Loss: 0.0023, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_186.pth
# Epoch 186/300 completed in 3.57 seconds.
# Epoch [187/300], Train Loss: 0.0018, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_187.pth
# Epoch 187/300 completed in 3.61 seconds.
# Epoch [188/300], Train Loss: 0.0019, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_188.pth
# Epoch 188/300 completed in 5.15 seconds.
# Epoch [189/300], Train Loss: 0.0017, Val Loss: 0.0017
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_189.pth
# Epoch 189/300 completed in 3.57 seconds.
# Epoch [190/300], Train Loss: 0.0019, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_190.pth
# Epoch 190/300 completed in 3.55 seconds.
# Epoch [191/300], Train Loss: 0.0020, Val Loss: 0.0035
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_191.pth
# Epoch 191/300 completed in 4.43 seconds.
# Epoch [192/300], Train Loss: 0.0023, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_192.pth
# Epoch 192/300 completed in 4.09 seconds.
# Epoch [193/300], Train Loss: 0.0017, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_193.pth
# Epoch 193/300 completed in 3.58 seconds.
# Epoch [194/300], Train Loss: 0.0019, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_194.pth
# Epoch 194/300 completed in 3.88 seconds.
# Epoch [195/300], Train Loss: 0.0017, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_195.pth
# Epoch 195/300 completed in 4.55 seconds.
# Epoch [196/300], Train Loss: 0.0018, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_196.pth
# Epoch 196/300 completed in 3.57 seconds.
# Epoch [197/300], Train Loss: 0.0021, Val Loss: 0.0025
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_197.pth
# Epoch 197/300 completed in 3.58 seconds.
# Epoch [198/300], Train Loss: 0.0021, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_198.pth
# Epoch 198/300 completed in 5.00 seconds.
# Epoch [199/300], Train Loss: 0.0017, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_199.pth
# Epoch 199/300 completed in 3.56 seconds.
# Epoch [200/300], Train Loss: 0.0018, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_200.pth
# Epoch 200/300 completed in 3.59 seconds.
# Epoch [201/300], Train Loss: 0.0021, Val Loss: 0.0017
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_201.pth
# Epoch 201/300 completed in 4.93 seconds.
# Epoch [202/300], Train Loss: 0.0020, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_202.pth
# Epoch 202/300 completed in 3.61 seconds.
# Epoch [203/300], Train Loss: 0.0018, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_203.pth
# Epoch 203/300 completed in 3.54 seconds.
# Epoch [204/300], Train Loss: 0.0018, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_204.pth
# Epoch 204/300 completed in 4.26 seconds.
# Epoch [205/300], Train Loss: 0.0020, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_205.pth
# Epoch 205/300 completed in 4.29 seconds.
# Epoch [206/300], Train Loss: 0.0018, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_206.pth
# Epoch 206/300 completed in 3.51 seconds.
# Epoch [207/300], Train Loss: 0.0017, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_207.pth
# Epoch 207/300 completed in 3.73 seconds.
# Epoch [208/300], Train Loss: 0.0019, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_208.pth
# Epoch 208/300 completed in 6.08 seconds.
# Epoch [209/300], Train Loss: 0.0018, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_209.pth
# Epoch 209/300 completed in 4.06 seconds.
# Epoch [210/300], Train Loss: 0.0018, Val Loss: 0.0015
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_210.pth
# Epoch 210/300 completed in 3.59 seconds.
# Epoch [211/300], Train Loss: 0.0018, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_211.pth
# Epoch 211/300 completed in 4.00 seconds.
# Epoch [212/300], Train Loss: 0.0019, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_212.pth
# Epoch 212/300 completed in 4.51 seconds.
# Epoch [213/300], Train Loss: 0.0017, Val Loss: 0.0015
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_213.pth
# Epoch 213/300 completed in 3.60 seconds.
# Epoch [214/300], Train Loss: 0.0019, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_214.pth
# Epoch 214/300 completed in 3.66 seconds.
# Epoch [215/300], Train Loss: 0.0018, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_215.pth
# Epoch 215/300 completed in 5.15 seconds.
# Epoch [216/300], Train Loss: 0.0016, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_216.pth
# Epoch 216/300 completed in 3.56 seconds.
# Epoch [217/300], Train Loss: 0.0020, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_217.pth
# Epoch 217/300 completed in 3.57 seconds.
# Epoch [218/300], Train Loss: 0.0017, Val Loss: 0.0015
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_218.pth
# Epoch 218/300 completed in 4.90 seconds.
# Epoch [219/300], Train Loss: 0.0017, Val Loss: 0.0026
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_219.pth
# Epoch 219/300 completed in 3.59 seconds.
# Epoch [220/300], Train Loss: 0.0022, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_220.pth
# Epoch 220/300 completed in 3.58 seconds.
# Epoch [221/300], Train Loss: 0.0017, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_221.pth
# Epoch 221/300 completed in 4.38 seconds.
# Epoch [222/300], Train Loss: 0.0018, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_222.pth
# Epoch 222/300 completed in 4.12 seconds.
# Epoch [223/300], Train Loss: 0.0017, Val Loss: 0.0018
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_223.pth
# Epoch 223/300 completed in 3.54 seconds.
# Epoch [224/300], Train Loss: 0.0017, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_224.pth
# Epoch 224/300 completed in 3.87 seconds.
# Epoch [225/300], Train Loss: 0.0019, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_225.pth
# Epoch 225/300 completed in 4.50 seconds.
# Epoch [226/300], Train Loss: 0.0016, Val Loss: 0.0008
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_226.pth
# Epoch 226/300 completed in 3.56 seconds.
# Epoch [227/300], Train Loss: 0.0017, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_227.pth
# Epoch 227/300 completed in 3.58 seconds.
# Epoch [228/300], Train Loss: 0.0017, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_228.pth
# Epoch 228/300 completed in 5.17 seconds.
# Epoch [229/300], Train Loss: 0.0018, Val Loss: 0.0015
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_229.pth
# Epoch 229/300 completed in 3.60 seconds.
# Epoch [230/300], Train Loss: 0.0019, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_230.pth
# Epoch 230/300 completed in 3.53 seconds.
# Epoch [231/300], Train Loss: 0.0018, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_231.pth
# Epoch 231/300 completed in 4.78 seconds.
# Epoch [232/300], Train Loss: 0.0018, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_232.pth
# Epoch 232/300 completed in 3.67 seconds.
# Epoch [233/300], Train Loss: 0.0016, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_233.pth
# Epoch 233/300 completed in 3.54 seconds.
# Epoch [234/300], Train Loss: 0.0016, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_234.pth
# Epoch 234/300 completed in 4.29 seconds.
# Epoch [235/300], Train Loss: 0.0018, Val Loss: 0.0016
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_235.pth
# Epoch 235/300 completed in 4.32 seconds.
# Epoch [236/300], Train Loss: 0.0016, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_236.pth
# Epoch 236/300 completed in 3.58 seconds.
# Epoch [237/300], Train Loss: 0.0018, Val Loss: 0.0017
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_237.pth
# Epoch 237/300 completed in 3.73 seconds.
# Epoch [238/300], Train Loss: 0.0028, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_238.pth
# Epoch 238/300 completed in 4.91 seconds.
# Epoch [239/300], Train Loss: 0.0020, Val Loss: 0.0054
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_239.pth
# Epoch 239/300 completed in 3.59 seconds.
# Epoch [240/300], Train Loss: 0.0021, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_240.pth
# Epoch 240/300 completed in 3.60 seconds.
# Epoch [241/300], Train Loss: 0.0016, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_241.pth
# Epoch 241/300 completed in 5.20 seconds.
# Epoch [242/300], Train Loss: 0.0018, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_242.pth
# Epoch 242/300 completed in 3.55 seconds.
# Epoch [243/300], Train Loss: 0.0017, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_243.pth
# Epoch 243/300 completed in 3.55 seconds.
# Epoch [244/300], Train Loss: 0.0018, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_244.pth
# Epoch 244/300 completed in 4.47 seconds.
# Epoch [245/300], Train Loss: 0.0016, Val Loss: 0.0018
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_245.pth
# Epoch 245/300 completed in 4.07 seconds.
# Epoch [246/300], Train Loss: 0.0017, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_246.pth
# Epoch 246/300 completed in 3.55 seconds.
# Epoch [247/300], Train Loss: 0.0018, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_247.pth
# Epoch 247/300 completed in 3.84 seconds.
# Epoch [248/300], Train Loss: 0.0017, Val Loss: 0.0015
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_248.pth
# Epoch 248/300 completed in 4.80 seconds.
# Epoch [249/300], Train Loss: 0.0016, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_249.pth
# Epoch 249/300 completed in 3.57 seconds.
# Epoch [250/300], Train Loss: 0.0017, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_250.pth
# Epoch 250/300 completed in 3.57 seconds.
# Epoch [251/300], Train Loss: 0.0018, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_251.pth
# Epoch 251/300 completed in 5.13 seconds.
# Epoch [252/300], Train Loss: 0.0017, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_252.pth
# Epoch 252/300 completed in 3.59 seconds.
# Epoch [253/300], Train Loss: 0.0019, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_253.pth
# Epoch 253/300 completed in 3.58 seconds.
# Epoch [254/300], Train Loss: 0.0016, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_254.pth
# Epoch 254/300 completed in 4.75 seconds.
# Epoch [255/300], Train Loss: 0.0017, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_255.pth
# Epoch 255/300 completed in 3.73 seconds.
# Epoch [256/300], Train Loss: 0.0016, Val Loss: 0.0025
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_256.pth
# Epoch 256/300 completed in 3.63 seconds.
# Epoch [257/300], Train Loss: 0.0018, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_257.pth
# Epoch 257/300 completed in 4.13 seconds.
# Epoch [258/300], Train Loss: 0.0018, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_258.pth
# Epoch 258/300 completed in 4.51 seconds.
# Epoch [259/300], Train Loss: 0.0018, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_259.pth
# Epoch 259/300 completed in 3.60 seconds.
# Epoch [260/300], Train Loss: 0.0016, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_260.pth
# Epoch 260/300 completed in 3.61 seconds.
# Epoch [261/300], Train Loss: 0.0016, Val Loss: 0.0009
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_261.pth
# Epoch 261/300 completed in 5.01 seconds.
# Epoch [262/300], Train Loss: 0.0031, Val Loss: 0.0017
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_262.pth
# Epoch 262/300 completed in 3.62 seconds.
# Epoch [263/300], Train Loss: 0.0016, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_263.pth
# Epoch 263/300 completed in 3.56 seconds.
# Epoch [264/300], Train Loss: 0.0017, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_264.pth
# Epoch 264/300 completed in 5.05 seconds.
# Epoch [265/300], Train Loss: 0.0017, Val Loss: 0.0018
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_265.pth
# Epoch 265/300 completed in 3.56 seconds.
# Epoch [266/300], Train Loss: 0.0016, Val Loss: 0.0016
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_266.pth
# Epoch 266/300 completed in 3.53 seconds.
# Epoch [267/300], Train Loss: 0.0016, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_267.pth
# Epoch 267/300 completed in 4.27 seconds.
# Epoch [268/300], Train Loss: 0.0015, Val Loss: 0.0016
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_268.pth
# Epoch 268/300 completed in 4.21 seconds.
# Epoch [269/300], Train Loss: 0.0016, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_269.pth
# Epoch 269/300 completed in 3.61 seconds.
# Epoch [270/300], Train Loss: 0.0016, Val Loss: 0.0017
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_270.pth
# Epoch 270/300 completed in 3.71 seconds.
# Epoch [271/300], Train Loss: 0.0017, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_271.pth
# Epoch 271/300 completed in 4.87 seconds.
# Epoch [272/300], Train Loss: 0.0015, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_272.pth
# Epoch 272/300 completed in 3.58 seconds.
# Epoch [273/300], Train Loss: 0.0017, Val Loss: 0.0016
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_273.pth
# Epoch 273/300 completed in 3.58 seconds.
# Epoch [274/300], Train Loss: 0.0016, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_274.pth
# Epoch 274/300 completed in 5.09 seconds.
# Epoch [275/300], Train Loss: 0.0017, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_275.pth
# Epoch 275/300 completed in 3.58 seconds.
# Epoch [276/300], Train Loss: 0.0016, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_276.pth
# Epoch 276/300 completed in 3.58 seconds.
# Epoch [277/300], Train Loss: 0.0018, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_277.pth
# Epoch 277/300 completed in 4.64 seconds.
# Epoch [278/300], Train Loss: 0.0019, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_278.pth
# Epoch 278/300 completed in 5.70 seconds.
# Epoch [279/300], Train Loss: 0.0016, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_279.pth
# Epoch 279/300 completed in 3.56 seconds.
# Epoch [280/300], Train Loss: 0.0020, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_280.pth
# Epoch 280/300 completed in 3.53 seconds.
# Epoch [281/300], Train Loss: 0.0019, Val Loss: 0.0028
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_281.pth
# Epoch 281/300 completed in 4.99 seconds.
# Epoch [282/300], Train Loss: 0.0018, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_282.pth
# Epoch 282/300 completed in 3.59 seconds.
# Epoch [283/300], Train Loss: 0.0016, Val Loss: 0.0015
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_283.pth
# Epoch 283/300 completed in 3.57 seconds.
# Epoch [284/300], Train Loss: 0.0015, Val Loss: 0.0010
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_284.pth
# Epoch 284/300 completed in 4.98 seconds.
# Epoch [285/300], Train Loss: 0.0017, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_285.pth
# Epoch 285/300 completed in 3.58 seconds.
# Epoch [286/300], Train Loss: 0.0016, Val Loss: 0.0016
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_286.pth
# Epoch 286/300 completed in 3.65 seconds.
# Epoch [287/300], Train Loss: 0.0016, Val Loss: 0.0011
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_287.pth
# Epoch 287/300 completed in 4.46 seconds.
# Epoch [288/300], Train Loss: 0.0015, Val Loss: 0.0014
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_288.pth
# Epoch 288/300 completed in 4.22 seconds.
# Epoch [289/300], Train Loss: 0.0017, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_289.pth
# Epoch 289/300 completed in 3.60 seconds.
# Epoch [290/300], Train Loss: 0.0016, Val Loss: 0.0015
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_290.pth
# Epoch 290/300 completed in 3.88 seconds.
# Epoch [291/300], Train Loss: 0.0018, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_291.pth
# Epoch 291/300 completed in 4.73 seconds.
# Epoch [292/300], Train Loss: 0.0017, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_292.pth
# Epoch 292/300 completed in 3.61 seconds.
# Epoch [293/300], Train Loss: 0.0016, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_293.pth
# Epoch 293/300 completed in 3.59 seconds.
# Epoch [294/300], Train Loss: 0.0016, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_294.pth
# Epoch 294/300 completed in 5.19 seconds.
# Epoch [295/300], Train Loss: 0.0018, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_295.pth
# Epoch 295/300 completed in 3.62 seconds.
# Epoch [296/300], Train Loss: 0.0017, Val Loss: 0.0015
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_296.pth
# Epoch 296/300 completed in 3.68 seconds.
# Epoch [297/300], Train Loss: 0.0018, Val Loss: 0.0023
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_297.pth
# Epoch 297/300 completed in 4.82 seconds.
# Epoch [298/300], Train Loss: 0.0018, Val Loss: 0.0013
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_298.pth
# Epoch 298/300 completed in 3.77 seconds.
# Epoch [299/300], Train Loss: 0.0017, Val Loss: 0.0012
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_299.pth
# Epoch 299/300 completed in 3.61 seconds.
# Epoch [300/300], Train Loss: 0.0018, Val Loss: 0.0028
# Model saved: /content/drive/MyDrive/deep-uav/1014_lookback30_forward0/best_model_epoch_300.pth
# Epoch 300/300 completed in 4.26 seconds.
# Total training time: 1211.27 seconds.

# %%
import matplotlib.pyplot as plt
import numpy as np

# 학습 후 손실 그래프 그리기
plt.figure(figsize=(8, 6))
plt.plot(history['train_losses'], label='Train Loss', color='blue')
plt.plot(history['val_losses'], label='Validation Loss', color='orange')
plt.title('Train and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

# y축 범위 설정
plt.ylim(0, 0.00035)

# y축 눈금 설정 (0.0003까지 표시)
plt.yticks(np.arange(0, 0.00031, 0.00005))

# 격자 없애기
plt.grid(False)

plt.legend()
plt.show()

# %%
from torchinfo import summary

summary(best_model, (1, 10, 3), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# GRUModel                                 [1, 3]                    --
# ├─GRU: 1-1                               [1, 10, 202]              125,442
# ├─Linear: 1-2                            [1, 3]                    609
# ==========================================================================================
# Total params: 126,051
# Trainable params: 126,051
# Non-trainable params: 0
# Total mult-adds (M): 1.26
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.50
# Estimated Total Size (MB): 0.52
# ==========================================================================================

# %% [markdown]
# ## 테스트

# %% [markdown]
# ### 1. 테스트 결과 생성

# %% [markdown]
# #### .pth 에서 불러와서 사용할 때

# %%
# history = torch.load("/content/drive/MyDrive/deep-uav/1014_lookback10_forward0/best_model_1014_epoch_300.pth", map_location=device)
# Out:
# <ipython-input-60-7fe8048717b6>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   history = torch.load("/content/drive/MyDrive/deep-uav/1014_lookback10_forward0/best_model_1014_epoch_300.pth", map_location=device)

# %%
# # 모델 초기화 (저장할 때 사용한 것과 동일한 구조로)
# model = GRUModel(input_size=3, hidden_units=best_params['n_units_l0'], output_size=3, num_layers=best_params['n_layers'])

# # GPU 사용 가능 시 모델을 GPU로 이동
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = model.to(device)

# # 저장된 모델 가중치 불러오기
# model.load_state_dict(torch.load("/content/drive/MyDrive/deep-uav/1014_lookback10_forward0/best_model_1014_epoch_300.pth", map_location=device)["model_state_dict"])

# # 평가 모드로 전환 (dropout 등을 비활성화)
# model.eval()
# Out:
# <ipython-input-65-38ba871d47c5>:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/content/drive/MyDrive/deep-uav/best_model_1014_epoch_150.pth", map_location=device)["model_state_dict"])
# GRUModel(
#   (gru): GRU(3, 202, batch_first=True)
#   (fc): Linear(in_features=202, out_features=3, bias=True)
# )

# %% [markdown]
# #### pth 말고 학습하고 바로 사용할 때

# %%
model = best_model
# train_loader, val_loader, test_loader = prepare_dataloader(df, 17, 10)
# criterion = torch.nn.MSELoss()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import torch

# 모델 예측 및 성능 평가
model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

test_loss = 0
y_true_list = []
y_pred_list = []

prediction_start_time = time.time()

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        # 예측 수행
        output = model(batch_x)

        # 손실 계산
        loss = criterion(output, batch_y)
        test_loss += loss.item()

        # 예측값과 실제값 저장
        y_pred_list.append(output.cpu().numpy())  # 예측값을 CPU로 이동하여 numpy 배열로 변환
        y_true_list.append(batch_y.cpu().numpy())  # 실제값을 CPU로 이동하여 numpy 배열로 변환

prediction_end_time = time.time()
prediction_time = prediction_end_time - prediction_start_time

# 리스트를 numpy 배열로 변환
y_pred = np.concatenate(y_pred_list, axis=0)
y_true = np.concatenate(y_true_list, axis=0)

# 성능 평가
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')

print(f"Total prediction time: {prediction_time:.2f} seconds.")
# Out:
# Mean Squared Error (MSE): 4.1561899706721306e-05
# Mean Absolute Error (MAE): 0.004865639843046665

# %% [markdown]
# ### 2. 결과 시각화

# %%
prediction_visualization(y_true, y_pred)

# %% [markdown]
# #### 3. raw 데이터와 predict 데이터 비교

# %%
y_pred_original = scaler.inverse_transform(y_pred)

y_test_original = scaler.inverse_transform(y_true.reshape(-1, 3))

prediction_visualization(y_test_original, y_pred_original)
