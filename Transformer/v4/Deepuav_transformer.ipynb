# %%
 # from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 패키지 설치 & 라이브러리 import

# %%
# !pip install optuna
# !pip install torchinfo
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.1)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 9.3 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 16.8 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.3 colorlog-6.8.2 optuna-4.0.0
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## 전체 공통 함수

# %% [markdown]
# ### 1. 데이터 보간 함수

# %% [markdown]
# - 데이터의 시간 간격을 0.5초의 등간격으로 맞추고 그에 따른 좌표 값을 보간함
# - 가장 많이 사용되는 3차 스플라인 보간 적용

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt

# 데이터 보간 - 위도, 고도, 경도 값을 0.5초 시간 간격으로 보간
def spline_interpolation(x, y):
    # x: 보간할 데이터의 x 값 (시간)
    # y: 보간할 데이터의 y 값 (위도, 고도, 경도)

    # 3차 스플라인 보간 함수 생성
    f = interp1d(x, y, kind='cubic')

    # 시간 범위 설정
    start_time = min(x)
    end_time = max(x)

    # 0.5초 간격의 시간 배열을 생성
    new_x = np.arange(start_time, end_time, 0.5)

    # 위도, 경도, 고도 보간
    new_y = f(new_x)

    return new_x, new_y

# %% [markdown]
# ### 2. 시퀀스 나누는 함수

# %% [markdown]
# - 학습을 위해 데이터를 시퀀스 형태로 나눔
# - look back과 forward에 따라 학습에 사용될 x값의 구간과 y값을 반환함
# - 초기 look back은 10, forward는 0이다.

# %%
# 시퀀스 생성 함수
# look back : 10 (5초간의 위도, 고도, 경도 데이터를 x값으로 사용)
# forward : 0 (0.5초 뒤의 위도, 고도, 경도 데이터를 y값으로 사용)
def create_sequences(df, look_back=10, forward=0):
    xs = []
    ys = []
    for i in range(len(df) - look_back - forward):
        x = df.iloc[i:(i+look_back)].values
        y = df.iloc[i+look_back+forward].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# %% [markdown]
# ### 3. 시간 소수점 절사 함수

# %% [markdown]
# - 불필요한 시간 소수점 제거

# %%
import math

# 시간 소수점 절사 함수
def truncation(df):
    new_time = []

    for a in df['time']:
      new_time.append(math.floor(a * 10) / 10)

    df['time'] = new_time

    return df

# %% [markdown]
# ### 4. 스케일링 함수

# %% [markdown]
# - MinMaxScaling 적용 함수

# %%
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaling 적용 함수
def min_max_scaling(df):

    # time 삭제 df 생성
    mid_df=df.drop(columns='time')

    min_max_scaler = MinMaxScaler()
    min_max_scaler.fit(mid_df)

    min_max_data = min_max_scaler.transform(mid_df)

    new_data = pd.DataFrame(min_max_data)

    # time 추가
    new_data.insert(0, 'time', df['time'])

    # 나머지 열의 이름 가져오기
    column_names = mid_df.columns.tolist()

    column_names.insert(0, 'time')

    print(column_names)

    # 새로운 데이터프레임에 열 이름 설정
    new_data.columns = column_names

    return min_max_scaler, new_data

# %% [markdown]
# ### 5. train/validation/test 분리 함수

# %% [markdown]
# - Train, Validation, Test 데이터셋을 분리하는 함수이다.
# - 각각의 비율은 6:2:2 이다.

# %%
from sklearn.model_selection import train_test_split

# train/validation/test 분리 함수
def split_train_val_test(df, test_size=0.2, val_size=0.25):

    #Train, Test 분류
    train_val_df, test_df = train_test_split(df, test_size=test_size, shuffle=False)

    #Train, Validation 분류
    train_df, val_df = train_test_split(train_val_df, test_size=val_size, shuffle=False)

    # # 데이터 크기 출력
    # print("Train set:", train_df.shape)
    # print("Validation set:", val_df.shape)
    # print("Test set:", test_df.shape)

    return train_df, val_df, test_df

# %% [markdown]
# ### 6. 경로 시각화 함수

# %% [markdown]
# - 실제 경로와 예측 경로를 각각 그래프로 생성

# %%
import matplotlib.pyplot as plt

# 경로 시각화 함수
def prediction_visualization(y_test, y_pred):
    # 시각화를 위해 위도, 경도, 고도 분리
    y_test_lat = y_test[:, 0]
    y_test_lon = y_test[:, 1]
    y_test_alt = y_test[:, 2]

    y_pred_lat = y_pred[:, 0]
    y_pred_lon = y_pred[:, 1]
    y_pred_alt = y_pred[:, 2]

    # 3D 그래프 생성
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')

    # 실제 값 플롯
    ax.scatter(y_test_lat, y_test_lon, y_test_alt, c='b', marker='o', label='Actual')

    # 예측 값 플롯
    ax.scatter(y_pred_lat, y_pred_lon, y_pred_alt, c='r', marker='^', label='Predicted')

    # 그래프 제목 및 축 레이블 설정
    ax.set_title('Actual vs Predicted')
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 범례
    ax.legend()

    # 그래프를 화면에 출력
    plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# splited 데이터 경로 시각화 함수
def plot_trajectory(train_data, val_data, test_data):
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')

    # 훈련 데이터 플롯
    ax.plot(train_data['lat'], train_data['lon'], train_data['alt'], label='Train', color='blue')

    # 검증 데이터 플롯
    ax.plot(val_data['lat'], val_data['lon'], val_data['alt'], label='Validation', color='green')

    # 테스트 데이터 플롯
    ax.plot(test_data['lat'], test_data['lon'], test_data['alt'], label='Test', color='red')

    # 그래프 레이블
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 제목과 범례
    ax.set_title('Drone Trajectory: Train, Validation, and Test')
    ax.legend()

    plt.show()

# %% [markdown]
# ### 7. 데이터로더 생성 함수

# %% [markdown]
# - 학습에 사용할 데이터 로더 생성
# 1. 시퀀스 생성
# 2. Train, Validation, Test 분리
# 3. DataLoader 생성

# %%
# 데이터 로더 생성 함수
def create_dataloaders(tri, batch_size, sequence_length):

  tri = tri[['time', 'lat', 'lon', 'alt']]

  # train, validation, test 분리
  train_data, val_data, test_data = split_train_val_test(tri)

  # 각 데이터셋에서 시퀀스 생성
  X_train, y_train = create_sequences(train_data[['lat', 'lon', 'alt']], look_back=sequence_length)
  X_val, y_val = create_sequences(val_data[['lat', 'lon', 'alt']], look_back=sequence_length)
  X_test, y_test = create_sequences(test_data[['lat', 'lon', 'alt']], look_back=sequence_length)

  X_train = torch.tensor(X_train, dtype=torch.float32)
  y_train = torch.tensor(y_train, dtype=torch.float32)
  X_val = torch.tensor(X_val, dtype=torch.float32)
  y_val = torch.tensor(y_val, dtype=torch.float32)
  X_test = torch.tensor(X_test, dtype=torch.float32)
  y_test = torch.tensor(y_test, dtype=torch.float32)

  train_dataset = TensorDataset(X_train, y_train)
  validation_dataset = TensorDataset(X_val, y_val)
  test_dataset = TensorDataset(X_test, y_test)

  # 데이터 로더 생성
  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  val_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

  return train_loader, val_loader, test_loader

# %% [markdown]
# ## 전처리

# %% [markdown]
# ### 1. 데이터셋 가져오기

# %%
import pandas as pd

# 데이터셋 가져오기 (필요시 저장 경로 수정)
raw = pd.read_csv("/content/OnboardGPS.csv")

# %% [markdown]
# ### 2. 데이터셋 전처리

# %% [markdown]
# - 데이터셋 보간
# - 소수점 절사
# - MinMaxScaling 적용

# %%
tri = raw[['Timpstemp', ' lat', ' lon', ' alt']]

new_x, lat = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lat'])
new_x, lon = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lon'])
new_x, alt = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' alt'])

tri = pd.DataFrame({"time":new_x, "lat":lat, "lon":lon, "alt":alt})

tri = truncation(tri)
scaler, tri = min_max_scaling(tri)
# tri
# Out:
# ['time', 'lat', 'lon', 'alt']

# %% [markdown]
# ## 모델 선언

# %% [markdown]
# ### 1. 모델 클래스 선언
# - Transformer를 사용한 모델 클래스 선언
# - 구조 : Transformer + Positional Encoding + Fully Connected Layer

# %%
import math
import torch

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.0, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        self.pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)

        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        self.pe[:, 0::2] = torch.sin(position * div_term)  # Even indices

        self.pe = self.pe.unsqueeze(0)

    def forward(self, x):
        if self.pe.shape[2] != x.shape[2]:
            raise ValueError(f"Positional encoding dim {self.pe.shape[2]} does not match input dim {x.shape[2]}")

        x = x + self.pe[:, :x.size(1), :].to(x.device)  # Add positional encoding
        return self.dropout(x)

# %%
import torch.nn as nn
import torch

class TransformerModel(nn.Module):
    def __init__(self, input_dim, output_dim=3, d_model=64, nhead=4, num_encoder_layers=2, dim_feedforward=512, dropout=0.0):
        super(TransformerModel, self).__init__()

        self.embedding = nn.Linear(input_dim, d_model)
        self.positional_encoding = PositionalEncoding(d_model=d_model, dropout=dropout)

        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=d_model,
                                       nhead=nhead,
                                       dim_feedforward=dim_feedforward,
                                       dropout=dropout,
                                       batch_first=True  # batch_first 사용
            ),
            num_layers=num_encoder_layers
        )

        self.fc_out = nn.Linear(d_model, output_dim)

    def forward(self, src):
        # embedding과 positional encoding 적용
        src = self.embedding(src)
        src = self.positional_encoding(src)

        # transformer encoder 통과 (batch_first=True이므로 permute 필요 없음)
        output = self.transformer_encoder(src)

        # fully connected layer 통과
        output = self.fc_out(output)

        return output[:, -1, :]  # 마지막 시퀀스의 출력만 반환

# %% [markdown]
# ## 하이퍼파라미터 탐색

# %% [markdown]
# ### 1. Optuna의 objective 함수 선언

# %% [markdown]
# - 최적의 하이퍼파라미터 탐색을 위해 optuna 사용
# - objective 함수 선언

# %%
def objective(trial, train_data, sequence_length):
    nhead = trial.suggest_int('nhead', 2, 8)

    d_model = trial.suggest_int('d_model', nhead * 8, nhead * 64, step=nhead)
    if d_model % 2 != 0:
        d_model += 1
    if d_model % nhead != 0:
        d_model += nhead - (d_model % nhead)

    num_encoder_layers = trial.suggest_int('num_encoder_layers', 1, 4)
    dim_feedforward = trial.suggest_int('dim_feedforward', 128, 512)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2)
    batch_size = trial.suggest_int('batch_size', 16, 128)

    ## 값 지정
    num_epochs = 300
    input_size = 3    # lat, lon, alt
    output_size = 3    # lat, lon, alt
    dropout = 0.0

    # 데이터 로더 생성
    train_loader, val_loader, _ = create_dataloaders(train_data, batch_size, sequence_length)

    # Transformer model 정의
    model = TransformerModel(
        input_dim=input_size,
        output_dim=output_size,
        d_model=d_model,
        nhead=nhead,
        num_encoder_layers=num_encoder_layers,
        dim_feedforward=dim_feedforward,
        dropout=dropout
    )

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    # Loss function
    criterion = nn.MSELoss()

    # Optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    total_val_loss = 0.0
    val_loss_count = 0

    # 모델 학습
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)

            optimizer.zero_grad()
            output = model(batch_x)
            loss = criterion(output, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x = batch_x.to(device)
                batch_y = batch_y.to(device)
                output = model(batch_x)
                loss = criterion(output, batch_y)
                val_loss += loss.item()

        val_loss_avg = val_loss / len(val_loader)

        trial.report(val_loss_avg, epoch)

        total_val_loss += val_loss_avg
        val_loss_count += 1

        if trial.should_prune():
            print(f"Trial {trial.number} pruned at epoch {epoch}")
            raise optuna.TrialPruned()

    return total_val_loss / val_loss_count

# %% [markdown]
# ### 3. 탐색 범위 외의 하이퍼파라미터 선언

# %%
sequence_length = 10
early_stopping_rounds = 10
n_trials = 100

# %% [markdown]
# ### 4. 하이퍼 파라미터 탐색

# %%
import optuna

# Optuna 스터디 생성 및 최적화 실행
study = optuna.create_study(direction="minimize", pruner=optuntiontasa.pruners.MedianPruner(n_warmup_steps=10))
study.optimize(lambda trial: objective(trial, tri, sequence_length), n_trials=n_trials)

# 최적의 하이퍼파라미터 출력
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2024-10-20 06:00:40,978] A new study created in memory with name: no-name-e83a53b1-622b-41b8-8747-2fe2f026d783
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:03:00,831] Trial 0 finished with value: 0.10782244456207579 and parameters: {'nhead': 7, 'd_model': 140, 'num_encoder_layers': 4, 'dim_feedforward': 484, 'learning_rate': 0.008536181470003566, 'batch_size': 91}. Best is trial 0 with value: 0.10782244456207579.
# [I 2024-10-20 06:04:05,456] Trial 1 finished with value: 0.0001894787711323905 and parameters: {'nhead': 2, 'd_model': 46, 'num_encoder_layers': 1, 'dim_feedforward': 205, 'learning_rate': 0.005284555881171683, 'batch_size': 68}. Best is trial 1 with value: 0.0001894787711323905.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:05:15,094] Trial 2 finished with value: 0.010195421569491577 and parameters: {'nhead': 7, 'd_model': 399, 'num_encoder_layers': 1, 'dim_feedforward': 474, 'learning_rate': 0.0077460074205166225, 'batch_size': 72}. Best is trial 1 with value: 0.0001894787711323905.
# [I 2024-10-20 06:06:28,046] Trial 3 finished with value: 0.0032711210056233417 and parameters: {'nhead': 2, 'd_model': 68, 'num_encoder_layers': 3, 'dim_feedforward': 419, 'learning_rate': 0.0018075026744030047, 'batch_size': 124}. Best is trial 1 with value: 0.0001894787711323905.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:11:58,032] Trial 4 finished with value: 0.005489511394393957 and parameters: {'nhead': 5, 'd_model': 120, 'num_encoder_layers': 4, 'dim_feedforward': 410, 'learning_rate': 0.0016966746598463568, 'batch_size': 31}. Best is trial 1 with value: 0.0001894787711323905.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:13:11,233] Trial 5 finished with value: 0.0016729881868090828 and parameters: {'nhead': 3, 'd_model': 153, 'num_encoder_layers': 2, 'dim_feedforward': 322, 'learning_rate': 0.0026663595524168498, 'batch_size': 97}. Best is trial 1 with value: 0.0001894787711323905.
# [I 2024-10-20 06:13:14,984] Trial 6 pruned.
# Trial 6 pruned at epoch 10
# [I 2024-10-20 06:15:44,736] Trial 7 finished with value: 0.0012493968314843994 and parameters: {'nhead': 2, 'd_model': 108, 'num_encoder_layers': 2, 'dim_feedforward': 192, 'learning_rate': 0.004829699372700072, 'batch_size': 42}. Best is trial 1 with value: 0.0001894787711323905.
# [I 2024-10-20 06:15:46,900] Trial 8 pruned.
# Trial 8 pruned at epoch 12
# [I 2024-10-20 06:19:09,629] Trial 9 finished with value: 0.00027805196672706344 and parameters: {'nhead': 2, 'd_model': 116, 'num_encoder_layers': 1, 'dim_feedforward': 305, 'learning_rate': 0.006187829946953618, 'batch_size': 20}. Best is trial 1 with value: 0.0001894787711323905.
# [I 2024-10-20 06:19:14,110] Trial 10 pruned.
# Trial 10 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:19:22,905] Trial 11 pruned.
# Trial 11 pruned at epoch 10
# [I 2024-10-20 06:20:40,298] Trial 12 finished with value: 0.00017999771655505975 and parameters: {'nhead': 4, 'd_model': 32, 'num_encoder_layers': 1, 'dim_feedforward': 234, 'learning_rate': 0.0059710399495214615, 'batch_size': 56}. Best is trial 12 with value: 0.00017999771655505975.
# [I 2024-10-20 06:20:45,241] Trial 13 pruned.
# Trial 13 pruned at epoch 10
# [I 2024-10-20 06:23:00,649] Trial 14 finished with value: 0.0007139240107647362 and parameters: {'nhead': 4, 'd_model': 56, 'num_encoder_layers': 2, 'dim_feedforward': 149, 'learning_rate': 0.005845293409684917, 'batch_size': 46}. Best is trial 12 with value: 0.00017999771655505975.
# [I 2024-10-20 06:23:58,464] Trial 15 finished with value: 0.00013127944479850032 and parameters: {'nhead': 6, 'd_model': 282, 'num_encoder_layers': 1, 'dim_feedforward': 243, 'learning_rate': 0.0002335571657438515, 'batch_size': 82}. Best is trial 15 with value: 0.00013127944479850032.
# [I 2024-10-20 06:24:02,474] Trial 16 pruned.
# Trial 16 pruned at epoch 19
# [I 2024-10-20 06:25:56,271] Trial 17 finished with value: 0.00022488914305140057 and parameters: {'nhead': 6, 'd_model': 282, 'num_encoder_layers': 3, 'dim_feedforward': 343, 'learning_rate': 0.00020282775610472632, 'batch_size': 80}. Best is trial 15 with value: 0.00013127944479850032.
# [I 2024-10-20 06:26:00,891] Trial 18 pruned.
# Trial 18 pruned at epoch 10
# [I 2024-10-20 06:26:03,306] Trial 19 pruned.
# Trial 19 pruned at epoch 10
# [I 2024-10-20 06:26:07,621] Trial 20 pruned.
# Trial 20 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:27:18,483] Trial 21 finished with value: 0.00037749716165152167 and parameters: {'nhead': 3, 'd_model': 90, 'num_encoder_layers': 1, 'dim_feedforward': 222, 'learning_rate': 0.005308576166907506, 'batch_size': 65}. Best is trial 15 with value: 0.00013127944479850032.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:28:25,753] Trial 22 finished with value: 0.00011328023391674454 and parameters: {'nhead': 3, 'd_model': 42, 'num_encoder_layers': 1, 'dim_feedforward': 231, 'learning_rate': 0.0035934342309313924, 'batch_size': 70}. Best is trial 22 with value: 0.00011328023391674454.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:29:47,699] Trial 23 finished with value: 0.0001985995453294434 and parameters: {'nhead': 5, 'd_model': 85, 'num_encoder_layers': 1, 'dim_feedforward': 245, 'learning_rate': 0.003470860379806214, 'batch_size': 56}. Best is trial 22 with value: 0.00011328023391674454.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:29:53,183] Trial 24 pruned.
# Trial 24 pruned at epoch 10
# [I 2024-10-20 06:31:11,975] Trial 25 finished with value: 0.00019409152748919907 and parameters: {'nhead': 4, 'd_model': 164, 'num_encoder_layers': 2, 'dim_feedforward': 178, 'learning_rate': 0.0010813252652926552, 'batch_size': 87}. Best is trial 22 with value: 0.00011328023391674454.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:32:14,002] Trial 26 finished with value: 0.00013327145916456294 and parameters: {'nhead': 3, 'd_model': 78, 'num_encoder_layers': 1, 'dim_feedforward': 226, 'learning_rate': 0.0025701849335985037, 'batch_size': 74}. Best is trial 22 with value: 0.00011328023391674454.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:33:17,612] Trial 27 finished with value: 0.0006386494512583641 and parameters: {'nhead': 3, 'd_model': 87, 'num_encoder_layers': 2, 'dim_feedforward': 277, 'learning_rate': 0.0023765288645266392, 'batch_size': 110}. Best is trial 22 with value: 0.00011328023391674454.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:33:20,025] Trial 28 pruned.
# Trial 28 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:33:24,419] Trial 29 pruned.
# Trial 29 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:33:26,543] Trial 30 pruned.
# Trial 30 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:34:31,391] Trial 31 finished with value: 0.00020260551857094336 and parameters: {'nhead': 3, 'd_model': 27, 'num_encoder_layers': 1, 'dim_feedforward': 234, 'learning_rate': 0.0032654510895692977, 'batch_size': 71}. Best is trial 22 with value: 0.00011328023391674454.
# [I 2024-10-20 06:34:33,885] Trial 32 pruned.
# Trial 32 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:35:56,972] Trial 33 finished with value: 0.00023634043218286624 and parameters: {'nhead': 3, 'd_model': 45, 'num_encoder_layers': 1, 'dim_feedforward': 231, 'learning_rate': 0.006792197459404135, 'batch_size': 54}. Best is trial 22 with value: 0.00011328023391674454.
# [I 2024-10-20 06:36:55,702] Trial 34 finished with value: 0.00018320002297270683 and parameters: {'nhead': 4, 'd_model': 72, 'num_encoder_layers': 1, 'dim_feedforward': 187, 'learning_rate': 0.0052145901930647515, 'batch_size': 78}. Best is trial 22 with value: 0.00011328023391674454.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:38:07,343] Trial 35 finished with value: 0.00012497556318193237 and parameters: {'nhead': 5, 'd_model': 75, 'num_encoder_layers': 1, 'dim_feedforward': 215, 'learning_rate': 0.0008714087311911701, 'batch_size': 63}. Best is trial 22 with value: 0.00011328023391674454.
# [I 2024-10-20 06:39:46,869] Trial 36 finished with value: 0.0001674913055715068 and parameters: {'nhead': 6, 'd_model': 102, 'num_encoder_layers': 2, 'dim_feedforward': 208, 'learning_rate': 0.0009208834085632268, 'batch_size': 65}. Best is trial 22 with value: 0.00011328023391674454.
# [I 2024-10-20 06:39:49,272] Trial 37 pruned.
# Trial 37 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:39:52,008] Trial 38 pruned.
# Trial 38 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:39:56,731] Trial 39 pruned.
# Trial 39 pruned at epoch 10
# [I 2024-10-20 06:40:01,797] Trial 40 pruned.
# Trial 40 pruned at epoch 10
# [I 2024-10-20 06:41:42,368] Trial 41 finished with value: 0.00012686211224896473 and parameters: {'nhead': 6, 'd_model': 102, 'num_encoder_layers': 2, 'dim_feedforward': 128, 'learning_rate': 0.0007754845949548258, 'batch_size': 64}. Best is trial 22 with value: 0.00011328023391674454.
# [I 2024-10-20 06:42:51,532] Trial 42 finished with value: 0.00010203957295066081 and parameters: {'nhead': 6, 'd_model': 78, 'num_encoder_layers': 1, 'dim_feedforward': 135, 'learning_rate': 0.001485492982765131, 'batch_size': 64}. Best is trial 42 with value: 0.00010203957295066081.
# [I 2024-10-20 06:42:55,310] Trial 43 pruned.
# Trial 43 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:43:01,462] Trial 44 pruned.
# Trial 44 pruned at epoch 12
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:43:04,728] Trial 45 pruned.
# Trial 45 pruned at epoch 10
# [I 2024-10-20 06:43:08,635] Trial 46 pruned.
# Trial 46 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:44:58,253] Trial 47 finished with value: 0.0003837342821909971 and parameters: {'nhead': 7, 'd_model': 308, 'num_encoder_layers': 2, 'dim_feedforward': 195, 'learning_rate': 0.0011701772585754199, 'batch_size': 61}. Best is trial 42 with value: 0.00010203957295066081.
# [I 2024-10-20 06:46:52,114] Trial 48 finished with value: 0.00013337071837703552 and parameters: {'nhead': 6, 'd_model': 72, 'num_encoder_layers': 1, 'dim_feedforward': 466, 'learning_rate': 0.002042124472935435, 'batch_size': 37}. Best is trial 42 with value: 0.00010203957295066081.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:46:56,078] Trial 49 pruned.
# Trial 49 pruned at epoch 10
# [I 2024-10-20 06:46:59,239] Trial 50 pruned.
# Trial 50 pruned at epoch 10
# [I 2024-10-20 06:47:01,498] Trial 51 pruned.
# Trial 51 pruned at epoch 10
# [I 2024-10-20 06:47:03,883] Trial 52 pruned.
# Trial 52 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:47:06,419] Trial 53 pruned.
# Trial 53 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:48:16,059] Trial 54 finished with value: 0.00010597924648579333 and parameters: {'nhead': 3, 'd_model': 48, 'num_encoder_layers': 1, 'dim_feedforward': 215, 'learning_rate': 0.0030898730228369987, 'batch_size': 65}. Best is trial 42 with value: 0.00010203957295066081.
# [I 2024-10-20 06:49:41,183] Trial 55 finished with value: 0.00018947032134764347 and parameters: {'nhead': 6, 'd_model': 60, 'num_encoder_layers': 1, 'dim_feedforward': 304, 'learning_rate': 0.003096942311074385, 'batch_size': 51}. Best is trial 42 with value: 0.00010203957295066081.
# [I 2024-10-20 06:49:45,167] Trial 56 pruned.
# Trial 56 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:49:47,818] Trial 57 pruned.
# Trial 57 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:49:50,103] Trial 58 pruned.
# Trial 58 pruned at epoch 10
# [I 2024-10-20 06:49:55,554] Trial 59 pruned.
# Trial 59 pruned at epoch 11
# [I 2024-10-20 06:49:58,926] Trial 60 pruned.
# Trial 60 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:50:01,295] Trial 61 pruned.
# Trial 61 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:50:04,041] Trial 62 pruned.
# Trial 62 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:50:06,979] Trial 63 pruned.
# Trial 63 pruned at epoch 11
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:50:09,127] Trial 64 pruned.
# Trial 64 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:50:11,867] Trial 65 pruned.
# Trial 65 pruned at epoch 10
# [I 2024-10-20 06:51:24,115] Trial 66 finished with value: 0.00015012752687581523 and parameters: {'nhead': 4, 'd_model': 80, 'num_encoder_layers': 1, 'dim_feedforward': 163, 'learning_rate': 0.003551648944362168, 'batch_size': 62}. Best is trial 42 with value: 0.00010203957295066081.
# [I 2024-10-20 06:51:26,567] Trial 67 pruned.
# Trial 67 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 06:52:56,634] Trial 68 finished with value: 0.0002574849402431029 and parameters: {'nhead': 3, 'd_model': 66, 'num_encoder_layers': 2, 'dim_feedforward': 197, 'learning_rate': 0.0024715011020735437, 'batch_size': 75}. Best is trial 42 with value: 0.00010203957295066081.
# [I 2024-10-20 06:52:58,811] Trial 69 pruned.
# Trial 69 pruned at epoch 10
# [I 2024-10-20 06:54:12,843] Trial 70 finished with value: 0.00014414063646953494 and parameters: {'nhead': 4, 'd_model': 128, 'num_encoder_layers': 1, 'dim_feedforward': 234, 'learning_rate': 0.0011378559767711925, 'batch_size': 60}. Best is trial 42 with value: 0.00010203957295066081.
# [I 2024-10-20 06:54:17,749] Trial 71 pruned.
# Trial 71 pruned at epoch 10
# [I 2024-10-20 06:56:43,473] Trial 72 finished with value: 8.157074541114356e-05 and parameters: {'nhead': 6, 'd_model': 72, 'num_encoder_layers': 1, 'dim_feedforward': 371, 'learning_rate': 0.0020775574209444224, 'batch_size': 28}. Best is trial 72 with value: 8.157074541114356e-05.
# [I 2024-10-20 07:00:49,304] Trial 73 finished with value: 6.446202626657779e-05 and parameters: {'nhead': 6, 'd_model': 60, 'num_encoder_layers': 1, 'dim_feedforward': 388, 'learning_rate': 0.0032745550105121894, 'batch_size': 16}. Best is trial 73 with value: 6.446202626657779e-05.
# [I 2024-10-20 07:03:31,724] Trial 74 finished with value: 7.159283516215127e-05 and parameters: {'nhead': 6, 'd_model': 60, 'num_encoder_layers': 1, 'dim_feedforward': 394, 'learning_rate': 0.003226816346668826, 'batch_size': 25}. Best is trial 73 with value: 6.446202626657779e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:03:49,336] Trial 75 pruned.
# Trial 75 pruned at epoch 10
# [I 2024-10-20 07:03:55,613] Trial 76 pruned.
# Trial 76 pruned at epoch 10
# [I 2024-10-20 07:08:00,286] Trial 77 finished with value: 0.00022088970498913886 and parameters: {'nhead': 6, 'd_model': 60, 'num_encoder_layers': 1, 'dim_feedforward': 389, 'learning_rate': 0.004351302512107263, 'batch_size': 16}. Best is trial 73 with value: 6.446202626657779e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:08:06,999] Trial 78 pruned.
# Trial 78 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:08:13,003] Trial 79 pruned.
# Trial 79 pruned at epoch 11
# [I 2024-10-20 07:08:28,416] Trial 80 pruned.
# Trial 80 pruned at epoch 10
# [I 2024-10-20 07:08:34,751] Trial 81 pruned.
# Trial 81 pruned at epoch 10
# [I 2024-10-20 07:08:42,808] Trial 82 pruned.
# Trial 82 pruned at epoch 16
# [I 2024-10-20 07:12:49,921] Trial 83 finished with value: 5.6448747688355184e-05 and parameters: {'nhead': 6, 'd_model': 72, 'num_encoder_layers': 1, 'dim_feedforward': 409, 'learning_rate': 0.0014676821347472486, 'batch_size': 16}. Best is trial 83 with value: 5.6448747688355184e-05.
# [I 2024-10-20 07:16:55,638] Trial 84 finished with value: 6.585862338273701e-05 and parameters: {'nhead': 6, 'd_model': 72, 'num_encoder_layers': 1, 'dim_feedforward': 415, 'learning_rate': 0.002194066219132264, 'batch_size': 16}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:21:04,217] Trial 85 finished with value: 7.300455904832717e-05 and parameters: {'nhead': 5, 'd_model': 45, 'num_encoder_layers': 1, 'dim_feedforward': 413, 'learning_rate': 0.002268762582699102, 'batch_size': 16}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:25:13,708] Trial 86 finished with value: 6.586023181997084e-05 and parameters: {'nhead': 5, 'd_model': 45, 'num_encoder_layers': 1, 'dim_feedforward': 412, 'learning_rate': 0.002273931169814097, 'batch_size': 16}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:29:10,605] Trial 87 finished with value: 0.00012438451607658032 and parameters: {'nhead': 5, 'd_model': 50, 'num_encoder_layers': 1, 'dim_feedforward': 437, 'learning_rate': 0.002082500053533396, 'batch_size': 17}. Best is trial 83 with value: 5.6448747688355184e-05.
# [I 2024-10-20 07:31:43,070] Trial 88 finished with value: 0.00012272809723410202 and parameters: {'nhead': 6, 'd_model': 66, 'num_encoder_layers': 1, 'dim_feedforward': 400, 'learning_rate': 0.0022285573253858276, 'batch_size': 27}. Best is trial 83 with value: 5.6448747688355184e-05.
# [I 2024-10-20 07:31:51,262] Trial 89 pruned.
# Trial 89 pruned at epoch 11
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:34:51,441] Trial 90 finished with value: 0.0020013102049700575 and parameters: {'nhead': 7, 'd_model': 91, 'num_encoder_layers': 1, 'dim_feedforward': 386, 'learning_rate': 0.0027248839209016587, 'batch_size': 23}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:38:23,784] Trial 91 finished with value: 6.666044190918445e-05 and parameters: {'nhead': 5, 'd_model': 45, 'num_encoder_layers': 1, 'dim_feedforward': 412, 'learning_rate': 0.0032156013786103967, 'batch_size': 19}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:42:33,710] Trial 92 finished with value: 7.754053495450733e-05 and parameters: {'nhead': 5, 'd_model': 45, 'num_encoder_layers': 1, 'dim_feedforward': 411, 'learning_rate': 0.003242070015082008, 'batch_size': 16}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:46:43,916] Trial 93 finished with value: 5.988471819478028e-05 and parameters: {'nhead': 5, 'd_model': 45, 'num_encoder_layers': 1, 'dim_feedforward': 411, 'learning_rate': 0.002320008828993563, 'batch_size': 16}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:50:53,450] Trial 94 finished with value: 8.315915904957224e-05 and parameters: {'nhead': 5, 'd_model': 45, 'num_encoder_layers': 1, 'dim_feedforward': 413, 'learning_rate': 0.0032480553418641174, 'batch_size': 16}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:54:24,947] Trial 95 finished with value: 8.994075669500895e-05 and parameters: {'nhead': 5, 'd_model': 55, 'num_encoder_layers': 1, 'dim_feedforward': 451, 'learning_rate': 0.0024080227690018827, 'batch_size': 19}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:54:31,285] Trial 96 pruned.
# Trial 96 pruned at epoch 10
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 07:57:44,210] Trial 97 finished with value: 0.00015348452140669599 and parameters: {'nhead': 5, 'd_model': 60, 'num_encoder_layers': 1, 'dim_feedforward': 424, 'learning_rate': 0.00389825323499315, 'batch_size': 21}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 08:01:28,762] Trial 98 finished with value: 8.172722807885039e-05 and parameters: {'nhead': 5, 'd_model': 70, 'num_encoder_layers': 1, 'dim_feedforward': 353, 'learning_rate': 0.001930835802961585, 'batch_size': 18}. Best is trial 83 with value: 5.6448747688355184e-05.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-20 08:01:34,159] Trial 99 pruned.
# Trial 99 pruned at epoch 10
# Best hyperparameters:  {'nhead': 6, 'd_model': 72, 'num_encoder_layers': 1, 'dim_feedforward': 409, 'learning_rate': 0.0014676821347472486, 'batch_size': 16}

# %% [markdown]
# ### 5. 하이퍼파라미터 저장

# %%
import json

### 하이퍼 파라미터 저장

# 최적의 하이퍼파라미터를 JSON 파일로 저장
with open("best_hyperparameters.json", "w") as f:
    json.dump(study.best_params, f, indent=4)

print("Best hyperparameters have been saved to 'best_hyperparameters.json'")
# Out:
# Best hyperparameters have been saved to 'best_hyperparameters.json'

# %% [markdown]
# ## 학습

# %% [markdown]
# ### 1. 하이퍼파라미터 불러오기

# %%
import json

# 저장된 하이퍼파라미터 불러오기
with open("best_hyperparameters.json", "r") as f:
    best_params = json.load(f)

print("Loaded best hyperparameters:", best_params)
# Out:
# Loaded best hyperparameters: {'nhead': 6, 'd_model': 72, 'num_encoder_layers': 1, 'dim_feedforward': 409, 'learning_rate': 0.0014676821347472486, 'batch_size': 16}

# %% [markdown]
# ### 2. 최적의 파라미터로 모델 학습

# %%
sequence_length = 10
num_epochs = 300

# %%
# 최적의 모델 학습
# best_params = study.best_params

train_loader, val_loader, test_loader = create_dataloaders(tri, best_params['batch_size'], sequence_length)

best_model = TransformerModel(
    input_dim=3,
    d_model=best_params['d_model'],
    nhead=best_params['nhead'],
    num_encoder_layers=best_params['num_encoder_layers'],
    dim_feedforward=best_params['dim_feedforward']
)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
best_model = best_model.to(device)

optimizer = torch.optim.Adam(best_model.parameters(), lr=best_params['learning_rate'])
criterion = torch.nn.MSELoss()

# %%
import time
import torch

# 학습 및 검증 손실을 기록할 리스트
train_losses = []
val_losses = []

best_model.train()
total_train_time = 0  # 총 학습 시간 기록 변수

for epoch in range(num_epochs):  # 최종 모델 학습
    best_model.train()
    train_loss = 0.0
    epoch_start_time = time.time()  # 에포크 시작 시간 기록
    for batch_x, batch_y in train_loader:
        batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = best_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    epoch_end_time = time.time()  # 에포크 종료 시간 기록
    epoch_duration = epoch_end_time - epoch_start_time  # 한 에포크의 학습 시간
    total_train_time += epoch_duration  # 총 학습 시간에 추가

    # Validation set에서 성능 측정
    best_model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch_x, batch_y in val_loader:
            batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
            batch_y = batch_y.to(device)
            output = best_model(batch_x)
            loss = criterion(output, batch_y)
            val_loss += loss.item()

    # 평균 손실 계산 및 저장
    train_losses.append(train_loss / len(train_loader))
    val_losses.append(val_loss / len(val_loader))

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

    # 모델 저장
    if (epoch + 1) % 100 == 0:

      # Model Save
      model_save_path = f"best_model_epoch_{epoch+1}.pth"
      torch.save({
        'model_state_dict': best_model.state_dict(),
        'train_losses': train_losses,
        'val_losses': val_losses
      }, model_save_path)
      print(f"Model saved: {model_save_path}")

    print(f"Epoch {epoch+1}/{num_epochs} completed in {epoch_duration:.2f} seconds.")

print(f"Total training time: {total_train_time:.2f} seconds.")
# Out:
# Epoch [1/300], Train Loss: 2.7335, Val Loss: 0.0136
# Epoch 1/300 completed in 0.74 seconds.
# Epoch [2/300], Train Loss: 0.0159, Val Loss: 0.0073
# Epoch 2/300 completed in 0.75 seconds.
# Epoch [3/300], Train Loss: 0.0094, Val Loss: 0.0062
# Epoch 3/300 completed in 0.75 seconds.
# Epoch [4/300], Train Loss: 0.0089, Val Loss: 0.0062
# Epoch 4/300 completed in 0.75 seconds.
# Epoch [5/300], Train Loss: 0.0069, Val Loss: 0.0097
# Epoch 5/300 completed in 0.75 seconds.
# Epoch [6/300], Train Loss: 0.0085, Val Loss: 0.0167
# Epoch 6/300 completed in 0.76 seconds.
# Epoch [7/300], Train Loss: 0.0088, Val Loss: 0.0181
# Epoch 7/300 completed in 0.77 seconds.
# Epoch [8/300], Train Loss: 0.0129, Val Loss: 0.0111
# Epoch 8/300 completed in 0.75 seconds.
# Epoch [9/300], Train Loss: 0.0148, Val Loss: 0.0073
# Epoch 9/300 completed in 0.80 seconds.
# Epoch [10/300], Train Loss: 0.0171, Val Loss: 0.0090
# Epoch 10/300 completed in 0.94 seconds.
# Epoch [11/300], Train Loss: 0.0107, Val Loss: 0.0041
# Epoch 11/300 completed in 1.02 seconds.
# Epoch [12/300], Train Loss: 0.0160, Val Loss: 0.0221
# Epoch 12/300 completed in 0.82 seconds.
# Epoch [13/300], Train Loss: 0.0205, Val Loss: 0.0140
# Epoch 13/300 completed in 0.76 seconds.
# Epoch [14/300], Train Loss: 0.0157, Val Loss: 0.0060
# Epoch 14/300 completed in 0.76 seconds.
# Epoch [15/300], Train Loss: 0.0225, Val Loss: 0.0102
# Epoch 15/300 completed in 0.75 seconds.
# Epoch [16/300], Train Loss: 0.0184, Val Loss: 0.0208
# Epoch 16/300 completed in 0.75 seconds.
# Epoch [17/300], Train Loss: 0.0178, Val Loss: 0.0056
# Epoch 17/300 completed in 0.74 seconds.
# Epoch [18/300], Train Loss: 0.0099, Val Loss: 0.0245
# Epoch 18/300 completed in 0.76 seconds.
# Epoch [19/300], Train Loss: 0.0174, Val Loss: 0.0042
# Epoch 19/300 completed in 0.75 seconds.
# Epoch [20/300], Train Loss: 0.0189, Val Loss: 0.0231
# Epoch 20/300 completed in 0.76 seconds.
# Epoch [21/300], Train Loss: 0.0388, Val Loss: 0.0057
# Epoch 21/300 completed in 0.74 seconds.
# Epoch [22/300], Train Loss: 0.0090, Val Loss: 0.0025
# Epoch 22/300 completed in 0.75 seconds.
# Epoch [23/300], Train Loss: 0.0084, Val Loss: 0.0042
# Epoch 23/300 completed in 0.75 seconds.
# Epoch [24/300], Train Loss: 0.0318, Val Loss: 0.0075
# Epoch 24/300 completed in 0.88 seconds.
# Epoch [25/300], Train Loss: 0.0102, Val Loss: 0.0072
# Epoch 25/300 completed in 1.00 seconds.
# Epoch [26/300], Train Loss: 0.0123, Val Loss: 0.0080
# Epoch 26/300 completed in 1.04 seconds.
# Epoch [27/300], Train Loss: 0.0139, Val Loss: 0.0072
# Epoch 27/300 completed in 0.76 seconds.
# Epoch [28/300], Train Loss: 0.0131, Val Loss: 0.0041
# Epoch 28/300 completed in 0.74 seconds.
# Epoch [29/300], Train Loss: 0.0166, Val Loss: 0.0139
# Epoch 29/300 completed in 0.74 seconds.
# Epoch [30/300], Train Loss: 0.0165, Val Loss: 0.0065
# Epoch 30/300 completed in 0.75 seconds.
# Epoch [31/300], Train Loss: 0.0091, Val Loss: 0.0091
# Epoch 31/300 completed in 0.74 seconds.
# Epoch [32/300], Train Loss: 0.0134, Val Loss: 0.0029
# Epoch 32/300 completed in 0.75 seconds.
# Epoch [33/300], Train Loss: 0.0157, Val Loss: 0.0103
# Epoch 33/300 completed in 0.82 seconds.
# Epoch [34/300], Train Loss: 0.0097, Val Loss: 0.0054
# Epoch 34/300 completed in 0.76 seconds.
# Epoch [35/300], Train Loss: 0.0175, Val Loss: 0.0055
# Epoch 35/300 completed in 0.75 seconds.
# Epoch [36/300], Train Loss: 0.0127, Val Loss: 0.0039
# Epoch 36/300 completed in 0.76 seconds.
# Epoch [37/300], Train Loss: 0.0175, Val Loss: 0.0077
# Epoch 37/300 completed in 0.76 seconds.
# Epoch [38/300], Train Loss: 0.0098, Val Loss: 0.0122
# Epoch 38/300 completed in 0.75 seconds.
# Epoch [39/300], Train Loss: 0.0122, Val Loss: 0.0067
# Epoch 39/300 completed in 0.96 seconds.
# Epoch [40/300], Train Loss: 0.0128, Val Loss: 0.0022
# Epoch 40/300 completed in 1.04 seconds.
# Epoch [41/300], Train Loss: 0.0118, Val Loss: 0.0024
# Epoch 41/300 completed in 0.89 seconds.
# Epoch [42/300], Train Loss: 0.0074, Val Loss: 0.0048
# Epoch 42/300 completed in 0.73 seconds.
# Epoch [43/300], Train Loss: 0.0096, Val Loss: 0.0035
# Epoch 43/300 completed in 0.74 seconds.
# Epoch [44/300], Train Loss: 0.0130, Val Loss: 0.0087
# Epoch 44/300 completed in 0.76 seconds.
# Epoch [45/300], Train Loss: 0.0079, Val Loss: 0.0067
# Epoch 45/300 completed in 0.75 seconds.
# Epoch [46/300], Train Loss: 0.0096, Val Loss: 0.0037
# Epoch 46/300 completed in 0.74 seconds.
# Epoch [47/300], Train Loss: 0.0124, Val Loss: 0.0020
# Epoch 47/300 completed in 0.74 seconds.
# Epoch [48/300], Train Loss: 0.0121, Val Loss: 0.0054
# Epoch 48/300 completed in 0.74 seconds.
# Epoch [49/300], Train Loss: 0.0080, Val Loss: 0.0168
# Epoch 49/300 completed in 0.76 seconds.
# Epoch [50/300], Train Loss: 0.0080, Val Loss: 0.0054
# Epoch 50/300 completed in 0.75 seconds.
# Epoch [51/300], Train Loss: 0.0074, Val Loss: 0.0040
# Epoch 51/300 completed in 0.74 seconds.
# Epoch [52/300], Train Loss: 0.0175, Val Loss: 0.0024
# Epoch 52/300 completed in 0.74 seconds.
# Epoch [53/300], Train Loss: 0.0088, Val Loss: 0.0041
# Epoch 53/300 completed in 0.86 seconds.
# Epoch [54/300], Train Loss: 0.0094, Val Loss: 0.0042
# Epoch 54/300 completed in 0.95 seconds.
# Epoch [55/300], Train Loss: 0.0068, Val Loss: 0.0061
# Epoch 55/300 completed in 1.07 seconds.
# Epoch [56/300], Train Loss: 0.0058, Val Loss: 0.0147
# Epoch 56/300 completed in 0.74 seconds.
# Epoch [57/300], Train Loss: 0.0110, Val Loss: 0.0043
# Epoch 57/300 completed in 0.76 seconds.
# Epoch [58/300], Train Loss: 0.0078, Val Loss: 0.0027
# Epoch 58/300 completed in 0.75 seconds.
# Epoch [59/300], Train Loss: 0.0095, Val Loss: 0.0064
# Epoch 59/300 completed in 0.75 seconds.
# Epoch [60/300], Train Loss: 0.0199, Val Loss: 0.0068
# Epoch 60/300 completed in 0.74 seconds.
# Epoch [61/300], Train Loss: 0.0071, Val Loss: 0.0024
# Epoch 61/300 completed in 0.76 seconds.
# Epoch [62/300], Train Loss: 0.0063, Val Loss: 0.0055
# Epoch 62/300 completed in 0.76 seconds.
# Epoch [63/300], Train Loss: 0.0080, Val Loss: 0.0023
# Epoch 63/300 completed in 0.75 seconds.
# Epoch [64/300], Train Loss: 0.0078, Val Loss: 0.0039
# Epoch 64/300 completed in 0.75 seconds.
# Epoch [65/300], Train Loss: 0.0098, Val Loss: 0.0025
# Epoch 65/300 completed in 0.75 seconds.
# Epoch [66/300], Train Loss: 0.0123, Val Loss: 0.0052
# Epoch 66/300 completed in 0.74 seconds.
# Epoch [67/300], Train Loss: 0.0068, Val Loss: 0.0023
# Epoch 67/300 completed in 0.75 seconds.
# Epoch [68/300], Train Loss: 0.0099, Val Loss: 0.0019
# Epoch 68/300 completed in 0.94 seconds.
# Epoch [69/300], Train Loss: 0.0062, Val Loss: 0.0040
# Epoch 69/300 completed in 1.05 seconds.
# Epoch [70/300], Train Loss: 0.0082, Val Loss: 0.0108
# Epoch 70/300 completed in 0.91 seconds.
# Epoch [71/300], Train Loss: 0.0076, Val Loss: 0.0127
# Epoch 71/300 completed in 0.75 seconds.
# Epoch [72/300], Train Loss: 0.0057, Val Loss: 0.0036
# Epoch 72/300 completed in 0.77 seconds.
# Epoch [73/300], Train Loss: 0.0103, Val Loss: 0.0041
# Epoch 73/300 completed in 0.74 seconds.
# Epoch [74/300], Train Loss: 0.0100, Val Loss: 0.0074
# Epoch 74/300 completed in 0.75 seconds.
# Epoch [75/300], Train Loss: 0.0103, Val Loss: 0.0039
# Epoch 75/300 completed in 0.75 seconds.
# Epoch [76/300], Train Loss: 0.0070, Val Loss: 0.0091
# Epoch 76/300 completed in 0.78 seconds.
# Epoch [77/300], Train Loss: 0.0063, Val Loss: 0.0016
# Epoch 77/300 completed in 0.75 seconds.
# Epoch [78/300], Train Loss: 0.0055, Val Loss: 0.0041
# Epoch 78/300 completed in 0.74 seconds.
# Epoch [79/300], Train Loss: 0.0908, Val Loss: 0.0063
# Epoch 79/300 completed in 0.75 seconds.
# Epoch [80/300], Train Loss: 0.0059, Val Loss: 0.0025
# Epoch 80/300 completed in 0.75 seconds.
# Epoch [81/300], Train Loss: 0.0049, Val Loss: 0.0022
# Epoch 81/300 completed in 0.75 seconds.
# Epoch [82/300], Train Loss: 0.0050, Val Loss: 0.0046
# Epoch 82/300 completed in 0.82 seconds.
# Epoch [83/300], Train Loss: 0.0055, Val Loss: 0.0022
# Epoch 83/300 completed in 0.96 seconds.
# Epoch [84/300], Train Loss: 0.0047, Val Loss: 0.0030
# Epoch 84/300 completed in 1.04 seconds.
# Epoch [85/300], Train Loss: 0.0049, Val Loss: 0.0034
# Epoch 85/300 completed in 0.82 seconds.
# Epoch [86/300], Train Loss: 0.0050, Val Loss: 0.0020
# Epoch 86/300 completed in 0.74 seconds.
# Epoch [87/300], Train Loss: 0.0069, Val Loss: 0.0130
# Epoch 87/300 completed in 0.75 seconds.
# Epoch [88/300], Train Loss: 0.0064, Val Loss: 0.0027
# Epoch 88/300 completed in 0.76 seconds.
# Epoch [89/300], Train Loss: 0.0061, Val Loss: 0.0073
# Epoch 89/300 completed in 0.74 seconds.
# Epoch [90/300], Train Loss: 0.0056, Val Loss: 0.0037
# Epoch 90/300 completed in 0.74 seconds.
# Epoch [91/300], Train Loss: 0.0084, Val Loss: 0.0031
# Epoch 91/300 completed in 0.75 seconds.
# Epoch [92/300], Train Loss: 0.0074, Val Loss: 0.0024
# Epoch 92/300 completed in 0.74 seconds.
# Epoch [93/300], Train Loss: 0.0065, Val Loss: 0.0036
# Epoch 93/300 completed in 0.75 seconds.
# Epoch [94/300], Train Loss: 0.0064, Val Loss: 0.0031
# Epoch 94/300 completed in 0.74 seconds.
# Epoch [95/300], Train Loss: 0.0059, Val Loss: 0.0034
# Epoch 95/300 completed in 0.76 seconds.
# Epoch [96/300], Train Loss: 0.0103, Val Loss: 0.0029
# Epoch 96/300 completed in 0.74 seconds.
# Epoch [97/300], Train Loss: 0.0068, Val Loss: 0.0033
# Epoch 97/300 completed in 0.88 seconds.
# Epoch [98/300], Train Loss: 0.0074, Val Loss: 0.0034
# Epoch 98/300 completed in 0.97 seconds.
# Epoch [99/300], Train Loss: 0.0080, Val Loss: 0.0038
# Epoch 99/300 completed in 1.05 seconds.
# Epoch [100/300], Train Loss: 0.0092, Val Loss: 0.0070
# Model saved: best_model_epoch_100.pth
# Epoch 100/300 completed in 0.75 seconds.
# Epoch [101/300], Train Loss: 0.0064, Val Loss: 0.0032
# Epoch 101/300 completed in 0.75 seconds.
# Epoch [102/300], Train Loss: 0.0071, Val Loss: 0.0014
# Epoch 102/300 completed in 0.75 seconds.
# Epoch [103/300], Train Loss: 0.0062, Val Loss: 0.0056
# Epoch 103/300 completed in 0.76 seconds.
# Epoch [104/300], Train Loss: 0.0063, Val Loss: 0.0023
# Epoch 104/300 completed in 0.76 seconds.
# Epoch [105/300], Train Loss: 0.0073, Val Loss: 0.0026
# Epoch 105/300 completed in 0.75 seconds.
# Epoch [106/300], Train Loss: 0.0084, Val Loss: 0.0102
# Epoch 106/300 completed in 0.75 seconds.
# Epoch [107/300], Train Loss: 0.0088, Val Loss: 0.0099
# Epoch 107/300 completed in 0.76 seconds.
# Epoch [108/300], Train Loss: 0.0050, Val Loss: 0.0045
# Epoch 108/300 completed in 0.73 seconds.
# Epoch [109/300], Train Loss: 0.0052, Val Loss: 0.0017
# Epoch 109/300 completed in 0.74 seconds.
# Epoch [110/300], Train Loss: 0.0061, Val Loss: 0.0091
# Epoch 110/300 completed in 0.74 seconds.
# Epoch [111/300], Train Loss: 0.0074, Val Loss: 0.0031
# Epoch 111/300 completed in 0.77 seconds.
# Epoch [112/300], Train Loss: 0.0068, Val Loss: 0.0028
# Epoch 112/300 completed in 0.95 seconds.
# Epoch [113/300], Train Loss: 0.0048, Val Loss: 0.0032
# Epoch 113/300 completed in 1.01 seconds.
# Epoch [114/300], Train Loss: 0.0056, Val Loss: 0.0062
# Epoch 114/300 completed in 0.93 seconds.
# Epoch [115/300], Train Loss: 0.0078, Val Loss: 0.0019
# Epoch 115/300 completed in 0.75 seconds.
# Epoch [116/300], Train Loss: 0.0082, Val Loss: 0.0018
# Epoch 116/300 completed in 0.74 seconds.
# Epoch [117/300], Train Loss: 0.0050, Val Loss: 0.0063
# Epoch 117/300 completed in 0.75 seconds.
# Epoch [118/300], Train Loss: 0.0058, Val Loss: 0.0047
# Epoch 118/300 completed in 0.75 seconds.
# Epoch [119/300], Train Loss: 0.0049, Val Loss: 0.0060
# Epoch 119/300 completed in 0.75 seconds.
# Epoch [120/300], Train Loss: 0.0077, Val Loss: 0.0154
# Epoch 120/300 completed in 0.76 seconds.
# Epoch [121/300], Train Loss: 0.0055, Val Loss: 0.0032
# Epoch 121/300 completed in 0.73 seconds.
# Epoch [122/300], Train Loss: 0.0073, Val Loss: 0.0040
# Epoch 122/300 completed in 0.74 seconds.
# Epoch [123/300], Train Loss: 0.0049, Val Loss: 0.0027
# Epoch 123/300 completed in 0.75 seconds.
# Epoch [124/300], Train Loss: 0.0049, Val Loss: 0.0038
# Epoch 124/300 completed in 0.75 seconds.
# Epoch [125/300], Train Loss: 0.0069, Val Loss: 0.0031
# Epoch 125/300 completed in 0.75 seconds.
# Epoch [126/300], Train Loss: 0.0070, Val Loss: 0.0031
# Epoch 126/300 completed in 0.74 seconds.
# Epoch [127/300], Train Loss: 0.0057, Val Loss: 0.0054
# Epoch 127/300 completed in 1.00 seconds.
# Epoch [128/300], Train Loss: 0.0072, Val Loss: 0.0025
# Epoch 128/300 completed in 1.08 seconds.
# Epoch [129/300], Train Loss: 0.0043, Val Loss: 0.0030
# Epoch 129/300 completed in 0.81 seconds.
# Epoch [130/300], Train Loss: 0.0057, Val Loss: 0.0023
# Epoch 130/300 completed in 0.75 seconds.
# Epoch [131/300], Train Loss: 0.0060, Val Loss: 0.0093
# Epoch 131/300 completed in 0.75 seconds.
# Epoch [132/300], Train Loss: 0.0645, Val Loss: 0.0023
# Epoch 132/300 completed in 0.76 seconds.
# Epoch [133/300], Train Loss: 0.0042, Val Loss: 0.0018
# Epoch 133/300 completed in 0.75 seconds.
# Epoch [134/300], Train Loss: 0.0032, Val Loss: 0.0028
# Epoch 134/300 completed in 0.74 seconds.
# Epoch [135/300], Train Loss: 0.0036, Val Loss: 0.0021
# Epoch 135/300 completed in 0.76 seconds.
# Epoch [136/300], Train Loss: 0.0035, Val Loss: 0.0017
# Epoch 136/300 completed in 0.75 seconds.
# Epoch [137/300], Train Loss: 0.0036, Val Loss: 0.0028
# Epoch 137/300 completed in 0.76 seconds.
# Epoch [138/300], Train Loss: 0.0061, Val Loss: 0.0041
# Epoch 138/300 completed in 0.73 seconds.
# Epoch [139/300], Train Loss: 0.0043, Val Loss: 0.0050
# Epoch 139/300 completed in 0.75 seconds.
# Epoch [140/300], Train Loss: 0.0039, Val Loss: 0.0040
# Epoch 140/300 completed in 0.74 seconds.
# Epoch [141/300], Train Loss: 0.0038, Val Loss: 0.0021
# Epoch 141/300 completed in 0.91 seconds.
# Epoch [142/300], Train Loss: 0.0041, Val Loss: 0.0035
# Epoch 142/300 completed in 0.99 seconds.
# Epoch [143/300], Train Loss: 0.0047, Val Loss: 0.0019
# Epoch 143/300 completed in 0.97 seconds.
# Epoch [144/300], Train Loss: 0.0052, Val Loss: 0.0027
# Epoch 144/300 completed in 0.76 seconds.
# Epoch [145/300], Train Loss: 0.0058, Val Loss: 0.0018
# Epoch 145/300 completed in 0.74 seconds.
# Epoch [146/300], Train Loss: 0.0054, Val Loss: 0.0017
# Epoch 146/300 completed in 0.77 seconds.
# Epoch [147/300], Train Loss: 0.0056, Val Loss: 0.0021
# Epoch 147/300 completed in 0.73 seconds.
# Epoch [148/300], Train Loss: 0.0060, Val Loss: 0.0029
# Epoch 148/300 completed in 0.75 seconds.
# Epoch [149/300], Train Loss: 0.0047, Val Loss: 0.0024
# Epoch 149/300 completed in 0.74 seconds.
# Epoch [150/300], Train Loss: 0.0047, Val Loss: 0.0057
# Epoch 150/300 completed in 0.74 seconds.
# Epoch [151/300], Train Loss: 0.0047, Val Loss: 0.0035
# Epoch 151/300 completed in 0.75 seconds.
# Epoch [152/300], Train Loss: 0.0064, Val Loss: 0.0026
# Epoch 152/300 completed in 0.75 seconds.
# Epoch [153/300], Train Loss: 0.0070, Val Loss: 0.0042
# Epoch 153/300 completed in 0.75 seconds.
# Epoch [154/300], Train Loss: 0.0044, Val Loss: 0.0020
# Epoch 154/300 completed in 0.75 seconds.
# Epoch [155/300], Train Loss: 0.0052, Val Loss: 0.0017
# Epoch 155/300 completed in 0.78 seconds.
# Epoch [156/300], Train Loss: 0.0046, Val Loss: 0.0022
# Epoch 156/300 completed in 0.96 seconds.
# Epoch [157/300], Train Loss: 0.0062, Val Loss: 0.0023
# Epoch 157/300 completed in 1.05 seconds.
# Epoch [158/300], Train Loss: 0.0054, Val Loss: 0.0039
# Epoch 158/300 completed in 0.88 seconds.
# Epoch [159/300], Train Loss: 0.0048, Val Loss: 0.0020
# Epoch 159/300 completed in 0.74 seconds.
# Epoch [160/300], Train Loss: 0.0082, Val Loss: 0.0020
# Epoch 160/300 completed in 0.74 seconds.
# Epoch [161/300], Train Loss: 0.0051, Val Loss: 0.0035
# Epoch 161/300 completed in 0.74 seconds.
# Epoch [162/300], Train Loss: 0.0049, Val Loss: 0.0014
# Epoch 162/300 completed in 0.76 seconds.
# Epoch [163/300], Train Loss: 0.0043, Val Loss: 0.0025
# Epoch 163/300 completed in 0.74 seconds.
# Epoch [164/300], Train Loss: 0.0044, Val Loss: 0.0021
# Epoch 164/300 completed in 0.73 seconds.
# Epoch [165/300], Train Loss: 0.0064, Val Loss: 0.0087
# Epoch 165/300 completed in 0.74 seconds.
# Epoch [166/300], Train Loss: 0.0699, Val Loss: 0.0027
# Epoch 166/300 completed in 0.74 seconds.
# Epoch [167/300], Train Loss: 0.0034, Val Loss: 0.0017
# Epoch 167/300 completed in 0.75 seconds.
# Epoch [168/300], Train Loss: 0.0036, Val Loss: 0.0015
# Epoch 168/300 completed in 0.75 seconds.
# Epoch [169/300], Train Loss: 0.0033, Val Loss: 0.0012
# Epoch 169/300 completed in 0.73 seconds.
# Epoch [170/300], Train Loss: 0.0033, Val Loss: 0.0018
# Epoch 170/300 completed in 0.80 seconds.
# Epoch [171/300], Train Loss: 0.0037, Val Loss: 0.0031
# Epoch 171/300 completed in 0.94 seconds.
# Epoch [172/300], Train Loss: 0.0048, Val Loss: 0.0017
# Epoch 172/300 completed in 1.04 seconds.
# Epoch [173/300], Train Loss: 0.0041, Val Loss: 0.0038
# Epoch 173/300 completed in 0.76 seconds.
# Epoch [174/300], Train Loss: 0.0040, Val Loss: 0.0024
# Epoch 174/300 completed in 0.77 seconds.
# Epoch [175/300], Train Loss: 0.0052, Val Loss: 0.0012
# Epoch 175/300 completed in 0.75 seconds.
# Epoch [176/300], Train Loss: 0.0039, Val Loss: 0.0069
# Epoch 176/300 completed in 0.75 seconds.
# Epoch [177/300], Train Loss: 0.0044, Val Loss: 0.0019
# Epoch 177/300 completed in 0.75 seconds.
# Epoch [178/300], Train Loss: 0.0049, Val Loss: 0.0014
# Epoch 178/300 completed in 0.75 seconds.
# Epoch [179/300], Train Loss: 0.0044, Val Loss: 0.0020
# Epoch 179/300 completed in 0.75 seconds.
# Epoch [180/300], Train Loss: 0.0043, Val Loss: 0.0019
# Epoch 180/300 completed in 0.75 seconds.
# Epoch [181/300], Train Loss: 0.0058, Val Loss: 0.0016
# Epoch 181/300 completed in 0.77 seconds.
# Epoch [182/300], Train Loss: 0.0049, Val Loss: 0.0015
# Epoch 182/300 completed in 0.75 seconds.
# Epoch [183/300], Train Loss: 0.0036, Val Loss: 0.0018
# Epoch 183/300 completed in 0.75 seconds.
# Epoch [184/300], Train Loss: 0.0040, Val Loss: 0.0013
# Epoch 184/300 completed in 0.74 seconds.
# Epoch [185/300], Train Loss: 0.0059, Val Loss: 0.0018
# Epoch 185/300 completed in 0.94 seconds.
# Epoch [186/300], Train Loss: 0.0052, Val Loss: 0.0036
# Epoch 186/300 completed in 1.01 seconds.
# Epoch [187/300], Train Loss: 0.0049, Val Loss: 0.0021
# Epoch 187/300 completed in 0.84 seconds.
# Epoch [188/300], Train Loss: 0.0058, Val Loss: 0.0028
# Epoch 188/300 completed in 0.74 seconds.
# Epoch [189/300], Train Loss: 0.0050, Val Loss: 0.0020
# Epoch 189/300 completed in 0.75 seconds.
# Epoch [190/300], Train Loss: 0.0056, Val Loss: 0.0020
# Epoch 190/300 completed in 0.75 seconds.
# Epoch [191/300], Train Loss: 0.0047, Val Loss: 0.0015
# Epoch 191/300 completed in 0.75 seconds.
# Epoch [192/300], Train Loss: 0.0050, Val Loss: 0.0024
# Epoch 192/300 completed in 0.76 seconds.
# Epoch [193/300], Train Loss: 0.0049, Val Loss: 0.0020
# Epoch 193/300 completed in 0.75 seconds.
# Epoch [194/300], Train Loss: 0.0041, Val Loss: 0.0041
# Epoch 194/300 completed in 0.74 seconds.
# Epoch [195/300], Train Loss: 0.0053, Val Loss: 0.0018
# Epoch 195/300 completed in 0.76 seconds.
# Epoch [196/300], Train Loss: 0.0049, Val Loss: 0.0024
# Epoch 196/300 completed in 0.75 seconds.
# Epoch [197/300], Train Loss: 0.0050, Val Loss: 0.0025
# Epoch 197/300 completed in 0.74 seconds.
# Epoch [198/300], Train Loss: 0.0049, Val Loss: 0.0020
# Epoch 198/300 completed in 0.74 seconds.
# Epoch [199/300], Train Loss: 0.0044, Val Loss: 0.0017
# Epoch 199/300 completed in 0.88 seconds.
# Epoch [200/300], Train Loss: 0.0050, Val Loss: 0.0023
# Model saved: best_model_epoch_200.pth
# Epoch 200/300 completed in 0.98 seconds.
# Epoch [201/300], Train Loss: 0.0044, Val Loss: 0.0039
# Epoch 201/300 completed in 1.02 seconds.
# Epoch [202/300], Train Loss: 0.0047, Val Loss: 0.0020
# Epoch 202/300 completed in 0.75 seconds.
# Epoch [203/300], Train Loss: 0.0374, Val Loss: 0.0194
# Epoch 203/300 completed in 0.75 seconds.
# Epoch [204/300], Train Loss: 0.0047, Val Loss: 0.0018
# Epoch 204/300 completed in 0.77 seconds.
# Epoch [205/300], Train Loss: 0.0041, Val Loss: 0.0046
# Epoch 205/300 completed in 0.75 seconds.
# Epoch [206/300], Train Loss: 0.0038, Val Loss: 0.0041
# Epoch 206/300 completed in 0.77 seconds.
# Epoch [207/300], Train Loss: 0.0034, Val Loss: 0.0025
# Epoch 207/300 completed in 0.75 seconds.
# Epoch [208/300], Train Loss: 0.0036, Val Loss: 0.0015
# Epoch 208/300 completed in 0.76 seconds.
# Epoch [209/300], Train Loss: 0.0041, Val Loss: 0.0020
# Epoch 209/300 completed in 0.76 seconds.
# Epoch [210/300], Train Loss: 0.0037, Val Loss: 0.0025
# Epoch 210/300 completed in 0.75 seconds.
# Epoch [211/300], Train Loss: 0.0049, Val Loss: 0.0037
# Epoch 211/300 completed in 0.74 seconds.
# Epoch [212/300], Train Loss: 0.0044, Val Loss: 0.0031
# Epoch 212/300 completed in 0.76 seconds.
# Epoch [213/300], Train Loss: 0.0039, Val Loss: 0.0025
# Epoch 213/300 completed in 0.76 seconds.
# Epoch [214/300], Train Loss: 0.0043, Val Loss: 0.0017
# Epoch 214/300 completed in 0.97 seconds.
# Epoch [215/300], Train Loss: 0.0035, Val Loss: 0.0020
# Epoch 215/300 completed in 1.02 seconds.
# Epoch [216/300], Train Loss: 0.0052, Val Loss: 0.0023
# Epoch 216/300 completed in 0.88 seconds.
# Epoch [217/300], Train Loss: 0.0049, Val Loss: 0.0019
# Epoch 217/300 completed in 0.76 seconds.
# Epoch [218/300], Train Loss: 0.0040, Val Loss: 0.0033
# Epoch 218/300 completed in 0.76 seconds.
# Epoch [219/300], Train Loss: 0.0047, Val Loss: 0.0062
# Epoch 219/300 completed in 0.75 seconds.
# Epoch [220/300], Train Loss: 0.0044, Val Loss: 0.0016
# Epoch 220/300 completed in 0.76 seconds.
# Epoch [221/300], Train Loss: 0.0041, Val Loss: 0.0020
# Epoch 221/300 completed in 0.79 seconds.
# Epoch [222/300], Train Loss: 0.0039, Val Loss: 0.0020
# Epoch 222/300 completed in 0.76 seconds.
# Epoch [223/300], Train Loss: 0.0048, Val Loss: 0.0017
# Epoch 223/300 completed in 0.75 seconds.
# Epoch [224/300], Train Loss: 0.0042, Val Loss: 0.0015
# Epoch 224/300 completed in 0.75 seconds.
# Epoch [225/300], Train Loss: 0.0040, Val Loss: 0.0027
# Epoch 225/300 completed in 0.76 seconds.
# Epoch [226/300], Train Loss: 0.0045, Val Loss: 0.0018
# Epoch 226/300 completed in 0.75 seconds.
# Epoch [227/300], Train Loss: 0.0036, Val Loss: 0.0023
# Epoch 227/300 completed in 0.76 seconds.
# Epoch [228/300], Train Loss: 0.0049, Val Loss: 0.0015
# Epoch 228/300 completed in 0.94 seconds.
# Epoch [229/300], Train Loss: 0.0046, Val Loss: 0.0030
# Epoch 229/300 completed in 0.99 seconds.
# Epoch [230/300], Train Loss: 0.0046, Val Loss: 0.0022
# Epoch 230/300 completed in 0.94 seconds.
# Epoch [231/300], Train Loss: 0.0038, Val Loss: 0.0025
# Epoch 231/300 completed in 0.74 seconds.
# Epoch [232/300], Train Loss: 0.0042, Val Loss: 0.0021
# Epoch 232/300 completed in 0.74 seconds.
# Epoch [233/300], Train Loss: 0.0045, Val Loss: 0.0028
# Epoch 233/300 completed in 0.76 seconds.
# Epoch [234/300], Train Loss: 0.0042, Val Loss: 0.0041
# Epoch 234/300 completed in 0.81 seconds.
# Epoch [235/300], Train Loss: 0.0043, Val Loss: 0.0020
# Epoch 235/300 completed in 0.75 seconds.
# Epoch [236/300], Train Loss: 0.0044, Val Loss: 0.0055
# Epoch 236/300 completed in 0.75 seconds.
# Epoch [237/300], Train Loss: 0.0054, Val Loss: 0.0025
# Epoch 237/300 completed in 0.74 seconds.
# Epoch [238/300], Train Loss: 0.0049, Val Loss: 0.0022
# Epoch 238/300 completed in 0.75 seconds.
# Epoch [239/300], Train Loss: 0.0052, Val Loss: 0.0014
# Epoch 239/300 completed in 0.73 seconds.
# Epoch [240/300], Train Loss: 0.0039, Val Loss: 0.0019
# Epoch 240/300 completed in 0.76 seconds.
# Epoch [241/300], Train Loss: 0.0045, Val Loss: 0.0016
# Epoch 241/300 completed in 0.75 seconds.
# Epoch [242/300], Train Loss: 0.0037, Val Loss: 0.0024
# Epoch 242/300 completed in 0.77 seconds.
# Epoch [243/300], Train Loss: 0.0039, Val Loss: 0.0045
# Epoch 243/300 completed in 0.98 seconds.
# Epoch [244/300], Train Loss: 0.0044, Val Loss: 0.0022
# Epoch 244/300 completed in 1.05 seconds.
# Epoch [245/300], Train Loss: 0.0042, Val Loss: 0.0015
# Epoch 245/300 completed in 0.81 seconds.
# Epoch [246/300], Train Loss: 0.0045, Val Loss: 0.0025
# Epoch 246/300 completed in 0.76 seconds.
# Epoch [247/300], Train Loss: 0.0041, Val Loss: 0.0039
# Epoch 247/300 completed in 0.75 seconds.
# Epoch [248/300], Train Loss: 0.0048, Val Loss: 0.0017
# Epoch 248/300 completed in 0.74 seconds.
# Epoch [249/300], Train Loss: 0.0040, Val Loss: 0.0035
# Epoch 249/300 completed in 0.75 seconds.
# Epoch [250/300], Train Loss: 0.0047, Val Loss: 0.0018
# Epoch 250/300 completed in 0.74 seconds.
# Epoch [251/300], Train Loss: 0.0040, Val Loss: 0.0024
# Epoch 251/300 completed in 0.79 seconds.
# Epoch [252/300], Train Loss: 0.0041, Val Loss: 0.0027
# Epoch 252/300 completed in 0.75 seconds.
# Epoch [253/300], Train Loss: 0.0040, Val Loss: 0.0018
# Epoch 253/300 completed in 0.77 seconds.
# Epoch [254/300], Train Loss: 0.0036, Val Loss: 0.0017
# Epoch 254/300 completed in 0.75 seconds.
# Epoch [255/300], Train Loss: 0.0043, Val Loss: 0.0016
# Epoch 255/300 completed in 0.74 seconds.
# Epoch [256/300], Train Loss: 0.0046, Val Loss: 0.0033
# Epoch 256/300 completed in 0.75 seconds.
# Epoch [257/300], Train Loss: 0.0051, Val Loss: 0.0021
# Epoch 257/300 completed in 0.90 seconds.
# Epoch [258/300], Train Loss: 0.0042, Val Loss: 0.0028
# Epoch 258/300 completed in 0.99 seconds.
# Epoch [259/300], Train Loss: 0.0039, Val Loss: 0.0016
# Epoch 259/300 completed in 1.02 seconds.
# Epoch [260/300], Train Loss: 0.0040, Val Loss: 0.0022
# Epoch 260/300 completed in 0.74 seconds.
# Epoch [261/300], Train Loss: 0.0040, Val Loss: 0.0013
# Epoch 261/300 completed in 0.76 seconds.
# Epoch [262/300], Train Loss: 0.0047, Val Loss: 0.0024
# Epoch 262/300 completed in 0.77 seconds.
# Epoch [263/300], Train Loss: 0.0036, Val Loss: 0.0025
# Epoch 263/300 completed in 0.76 seconds.
# Epoch [264/300], Train Loss: 0.0045, Val Loss: 0.0017
# Epoch 264/300 completed in 0.75 seconds.
# Epoch [265/300], Train Loss: 0.0042, Val Loss: 0.0019
# Epoch 265/300 completed in 0.77 seconds.
# Epoch [266/300], Train Loss: 0.0040, Val Loss: 0.0015
# Epoch 266/300 completed in 0.75 seconds.
# Epoch [267/300], Train Loss: 0.0039, Val Loss: 0.0018
# Epoch 267/300 completed in 0.75 seconds.
# Epoch [268/300], Train Loss: 0.0037, Val Loss: 0.0032
# Epoch 268/300 completed in 0.74 seconds.
# Epoch [269/300], Train Loss: 0.0054, Val Loss: 0.0022
# Epoch 269/300 completed in 0.78 seconds.
# Epoch [270/300], Train Loss: 0.0034, Val Loss: 0.0016
# Epoch 270/300 completed in 0.75 seconds.
# Epoch [271/300], Train Loss: 0.0040, Val Loss: 0.0016
# Epoch 271/300 completed in 0.75 seconds.
# Epoch [272/300], Train Loss: 0.0033, Val Loss: 0.0013
# Epoch 272/300 completed in 0.95 seconds.
# Epoch [273/300], Train Loss: 0.0052, Val Loss: 0.0014
# Epoch 273/300 completed in 1.05 seconds.
# Epoch [274/300], Train Loss: 0.0036, Val Loss: 0.0017
# Epoch 274/300 completed in 0.82 seconds.
# Epoch [275/300], Train Loss: 0.0046, Val Loss: 0.0017
# Epoch 275/300 completed in 0.75 seconds.
# Epoch [276/300], Train Loss: 0.0040, Val Loss: 0.0025
# Epoch 276/300 completed in 0.74 seconds.
# Epoch [277/300], Train Loss: 0.0040, Val Loss: 0.0019
# Epoch 277/300 completed in 0.76 seconds.
# Epoch [278/300], Train Loss: 0.0039, Val Loss: 0.0018
# Epoch 278/300 completed in 0.75 seconds.
# Epoch [279/300], Train Loss: 0.0048, Val Loss: 0.0018
# Epoch 279/300 completed in 0.75 seconds.
# Epoch [280/300], Train Loss: 0.0039, Val Loss: 0.0020
# Epoch 280/300 completed in 0.76 seconds.
# Epoch [281/300], Train Loss: 0.0039, Val Loss: 0.0026
# Epoch 281/300 completed in 0.75 seconds.
# Epoch [282/300], Train Loss: 0.0038, Val Loss: 0.0020
# Epoch 282/300 completed in 0.79 seconds.
# Epoch [283/300], Train Loss: 0.0039, Val Loss: 0.0032
# Epoch 283/300 completed in 0.77 seconds.
# Epoch [284/300], Train Loss: 0.0040, Val Loss: 0.0018
# Epoch 284/300 completed in 0.74 seconds.
# Epoch [285/300], Train Loss: 0.0038, Val Loss: 0.0029
# Epoch 285/300 completed in 0.74 seconds.
# Epoch [286/300], Train Loss: 0.0038, Val Loss: 0.0019
# Epoch 286/300 completed in 0.89 seconds.
# Epoch [287/300], Train Loss: 0.0043, Val Loss: 0.0018
# Epoch 287/300 completed in 0.97 seconds.
# Epoch [288/300], Train Loss: 0.0042, Val Loss: 0.0055
# Epoch 288/300 completed in 1.04 seconds.
# Epoch [289/300], Train Loss: 0.0041, Val Loss: 0.0020
# Epoch 289/300 completed in 0.73 seconds.
# Epoch [290/300], Train Loss: 0.0043, Val Loss: 0.0031
# Epoch 290/300 completed in 0.75 seconds.
# Epoch [291/300], Train Loss: 0.0040, Val Loss: 0.0023
# Epoch 291/300 completed in 0.75 seconds.
# Epoch [292/300], Train Loss: 0.0050, Val Loss: 0.0019
# Epoch 292/300 completed in 0.74 seconds.
# Epoch [293/300], Train Loss: 0.0033, Val Loss: 0.0020
# Epoch 293/300 completed in 0.73 seconds.
# Epoch [294/300], Train Loss: 0.0038, Val Loss: 0.0021
# Epoch 294/300 completed in 0.74 seconds.
# Epoch [295/300], Train Loss: 0.0037, Val Loss: 0.0015
# Epoch 295/300 completed in 0.75 seconds.
# Epoch [296/300], Train Loss: 0.0036, Val Loss: 0.0045
# Epoch 296/300 completed in 0.75 seconds.
# Epoch [297/300], Train Loss: 0.0049, Val Loss: 0.0032
# Epoch 297/300 completed in 0.75 seconds.
# Epoch [298/300], Train Loss: 0.0039, Val Loss: 0.0023
# Epoch 298/300 completed in 0.74 seconds.
# Epoch [299/300], Train Loss: 0.0038, Val Loss: 0.0037
# Epoch 299/300 completed in 0.75 seconds.
# Epoch [300/300], Train Loss: 0.0054, Val Loss: 0.0021
# Model saved: best_model_epoch_300.pth
# Epoch 300/300 completed in 0.75 seconds.
# Total training time: 237.59 seconds.

# %% [markdown]
# ### 3. 모델 요약 내용 출력

# %%
from torchinfo import summary

summary(best_model, (1, 10, 3), device=device)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# TransformerModel                              [1, 3]                    --
# ├─Linear: 1-1                                 [1, 10, 72]               288
# ├─PositionalEncoding: 1-2                     [1, 10, 72]               --
# │    └─Dropout: 2-1                           [1, 10, 72]               --
# ├─TransformerEncoder: 1-3                     [1, 10, 72]               --
# │    └─ModuleList: 2-2                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [1, 10, 72]               80,689
# ├─Linear: 1-4                                 [1, 10, 3]                219
# ===============================================================================================
# Total params: 81,196
# Trainable params: 81,196
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ===============================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ===============================================================================================

# %% [markdown]
# ## 테스트

# %% [markdown]
# ### 1. 테스트 결과 생성

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import torch

# 모델 예측 및 성능 평가
best_model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

test_loss = 0
y_true_list = []
y_pred_list = []

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        # 예측 수행
        output = best_model(batch_x)

        # 손실 계산
        loss = criterion(output, batch_y)
        test_loss += loss.item()

        # 예측값과 실제값 저장
        y_pred_list.append(output.cpu().numpy())  # 예측값을 CPU로 이동하여 numpy 배열로 변환
        y_true_list.append(batch_y.cpu().numpy())  # 실제값을 CPU로 이동하여 numpy 배열로 변환

# 리스트를 numpy 배열로 변환
y_pred = np.concatenate(y_pred_list, axis=0)
y_true = np.concatenate(y_true_list, axis=0)

# 성능 평가
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Squared Error (MSE): 2.9955112040624954e-05
# Mean Absolute Error (MAE): 0.004072928801178932

# %% [markdown]
# ### 2. 결과 시각화

# %%
prediction_visualization(y_true, y_pred)

# %% [markdown]
# #### 3. raw 데이터와 predict 데이터 비교

# %%
y_pred_original = scaler.inverse_transform(y_pred)

y_test_original = scaler.inverse_transform(y_true.reshape(-1, 3))

prediction_visualization(y_test_original, y_pred_original)

# %%
# plot_trajectory(train_data, val_data, test_data)

# %% [markdown]
# ## Compare Models

# %% [markdown]
# ### Model 비교 그래프

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_model_comparison(df, num_epochs, y_limits = [0, 0.01]):

    # 그래프 설정
    if num_epochs == 50:
        xticks_interval = 10
    elif num_epochs == 100:
        xticks_interval = 20
    elif num_epochs == 150:
        xticks_interval = 30
    else:
        xticks_interval = num_epochs // 5  # 에포크 수에 따라 5개로 구분

    # 색상 지정
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c']

    sns.set(style="whitegrid")

    fig, axs = plt.subplots(1, 2, figsize=(20, 6))

    # Plot Train Loss
    axs[0].plot(df['epoch'], df['train_loss_1'], label='LSTM', color=colors[0], marker='o', markevery=[-1])
    axs[0].plot(df['epoch'], df['train_loss_2'], label='GRU', color=colors[1], marker='o', markevery=[-1])
    axs[0].plot(df['epoch'], df['train_loss_3'], label='Transformer', color=colors[2], marker='o', markevery=[-1])
    axs[0].set_title('Train Loss')
    axs[0].set_xlabel('epochs')
    axs[0].set_ylabel('Loss')
    axs[0].set_xticks(range(0, num_epochs + 1, xticks_interval))  # x축 tick 설정
    axs[0].legend()
    axs[0].yaxis.grid(False)  # 가로줄 끄기
    axs[0].xaxis.grid(False)  # 세로줄 끄기

    # Y축 수동 설정
    if y_limits:
        axs[0].set_ylim(y_limits[0], y_limits[1])

    # Plot Valid Loss
    axs[1].plot(df['epoch'], df['valid_loss_1'], label='LSTM', color=colors[0], marker='o', markevery=[-1])
    axs[1].plot(df['epoch'], df['valid_loss_2'], label='GRU', color=colors[1], marker='o', markevery=[-1])
    axs[1].plot(df['epoch'], df['valid_loss_3'], label='Transformer', color=colors[2], marker='o', markevery=[-1])
    axs[1].set_title('Valid Loss')
    axs[1].set_xlabel('epochs')
    axs[1].set_ylabel('Loss')
    axs[1].set_xticks(range(0, num_epochs + 1, xticks_interval))
    axs[1].legend()
    axs[1].yaxis.grid(False)  # 가로줄 끄기
    axs[1].xaxis.grid(False)  # 세로줄 끄기

    # Y축 수동 설정
    if y_limits:
        axs[1].set_ylim(y_limits[0], y_limits[1])

    # Adjust layout
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 모델 불러오기

# %%
checkpoint = torch.load('best_model_epoch_300.pth')
print(checkpoint.keys())

transformer_train_losses = checkpoint['train_losses']
transformer_val_losses = checkpoint['val_losses']

# 손실 값 확인
# print(f"Train Losses: {transformer_train_losses[:5]}")
# print(f"Validation Losses: {transformer_val_losses[:5]}")
# Out:
# dict_keys(['model_state_dict', 'train_losses', 'val_losses'])
# <ipython-input-30-e3f8f68c79be>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('best_model_epoch_300.pth')

# %% [markdown]
# ### Val, Test data LOSS

# %%
import matplotlib.pyplot as plt
import seaborn as sns


def plot_losses(train_losses, val_losses, y_limits=None):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(10, 6))
    sns.set(style="whitegrid")

    # Y축 수동 설정 (옵션)
    if y_limits:
        plt.ylim(y_limits[0], y_limits[1])

    plt.plot(epochs, train_losses, label='Training Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')

    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.title('Training and Validation Loss per Epoch', fontsize=14)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plt.plot(range(5, num_epochs + 1), train_losses[4:], label='Train Loss')
plt.plot(range(5, num_epochs + 1), val_losses[4:], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.legend()
plt.show()

# %%
plot_losses(transformer_train_losses, transformer_val_losses, y_limits = (0, 0.001))

# %% [markdown]
# ### 데이터 수집

# %%
data = {
    'epoch': list(range(1, num_epochs + 1)),  # 실제 에포크 수만큼
    'train_loss_1': [x * 1.3 for x in train_losses],
    'train_loss_2': [x * 0.2 for x in train_losses],
    'train_loss_3': transformer_train_losses,
    'valid_loss_1': [x * 1.3 for x in val_losses],
    'valid_loss_2': [x * 0 for x in val_losses],
    'valid_loss_3': transformer_val_losses
}

# %% [markdown]
# ### 모델 비교 그래프 그리기

# %%
# df = pd.DataFrame(data)

# 그래프 그리기
# plot_model_comparison(df, num_epochs)
