# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 패키지 설치 & 라이브러리 import

# %%
# !pip install optuna
# !pip install torchinfo
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.35)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 7.0 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 17.1 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.3 colorlog-6.8.2 optuna-4.0.0
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## 전체 공통 함수

# %% [markdown]
# ### 1. 데이터 보간 함수

# %% [markdown]
# - 데이터의 시간 간격을 0.5초의 등간격으로 맞추고 그에 따른 좌표 값을 보간함
# - 가장 많이 사용되는 3차 스플라인 보간 적용

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt

# 데이터 보간 - 위도, 고도, 경도 값을 0.5초 시간 간격으로 보간
def spline_interpolation(x, y):
    # x: 보간할 데이터의 x 값 (시간)
    # y: 보간할 데이터의 y 값 (위도, 고도, 경도)

    # 3차 스플라인 보간 함수 생성
    f = interp1d(x, y, kind='cubic')

    # 시간 범위 설정
    start_time = min(x)
    end_time = max(x)

    # 0.5초 간격의 시간 배열을 생성
    new_x = np.arange(start_time, end_time, 0.5)

    # 위도, 경도, 고도 보간
    new_y = f(new_x)

    return new_x, new_y

# %% [markdown]
# ### 2. 시퀀스 나누는 함수

# %% [markdown]
# - 학습을 위해 데이터를 시퀀스 형태로 나눔
# - look back과 forward에 따라 학습에 사용될 x값의 구간과 y값을 반환함
# - 초기 look back은 10, forward는 0이다.

# %%
# 시퀀스 생성 함수
# look back : 10 (5초간의 위도, 고도, 경도 데이터를 x값으로 사용)
# forward : 0 (0.5초 뒤의 위도, 고도, 경도 데이터를 y값으로 사용)
def create_sequences(df, look_back=10, forward=0):
    xs = []
    ys = []
    for i in range(len(df) - look_back - forward):
        x = df.iloc[i:(i+look_back)].values
        y = df.iloc[i+look_back+forward].values
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# %% [markdown]
# ### 3. 시간 소수점 절사 함수

# %% [markdown]
# - 불필요한 시간 소수점 제거

# %%
import math

# 시간 소수점 절사 함수
def truncation(df):
    new_time = []

    for a in df['time']:
      new_time.append(math.floor(a * 10) / 10)

    df['time'] = new_time

    return df

# %% [markdown]
# ### 4. 스케일링 함수

# %% [markdown]
# - MinMaxScaling 적용 함수

# %%
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaling 적용 함수
def min_max_scaling(df):

    # time 삭제 df 생성
    mid_df=df.drop(columns='time')

    min_max_scaler = MinMaxScaler()
    min_max_scaler.fit(mid_df)

    min_max_data = min_max_scaler.transform(mid_df)

    new_data = pd.DataFrame(min_max_data)

    # time 추가
    new_data.insert(0, 'time', df['time'])

    # 나머지 열의 이름 가져오기
    column_names = mid_df.columns.tolist()

    column_names.insert(0, 'time')

    print(column_names)

    # 새로운 데이터프레임에 열 이름 설정
    new_data.columns = column_names

    return min_max_scaler, new_data

# %% [markdown]
# ### 5. train/validation/test 분리 함수

# %% [markdown]
# - Train, Validation, Test 데이터셋을 분리하는 함수이다.
# - 각각의 비율은 6:2:2 이다.

# %%
from sklearn.model_selection import train_test_split

# train/validation/test 분리 함수
def split_train_val_test(df, test_size=0.2, val_size=0.25):

    #Train, Test 분류
    train_val_df, test_df = train_test_split(df, test_size=test_size, shuffle=False)

    #Train, Validation 분류
    train_df, val_df = train_test_split(train_val_df, test_size=val_size, shuffle=False)

    # # 데이터 크기 출력
    # print("Train set:", train_df.shape)
    # print("Validation set:", val_df.shape)
    # print("Test set:", test_df.shape)

    return train_df, val_df, test_df

# %% [markdown]
# ### 6. 경로 시각화 함수

# %% [markdown]
# - 실제 경로와 예측 경로를 각각 그래프로 생성

# %%
import matplotlib.pyplot as plt

# 경로 시각화 함수
def prediction_visualization(y_test, y_pred):
    # 시각화를 위해 위도, 경도, 고도 분리
    y_test_lat = y_test[:, 0]
    y_test_lon = y_test[:, 1]
    y_test_alt = y_test[:, 2]

    y_pred_lat = y_pred[:, 0]
    y_pred_lon = y_pred[:, 1]
    y_pred_alt = y_pred[:, 2]

    # 3D 그래프 생성
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')

    # 실제 값 플롯
    ax.scatter(y_test_lat, y_test_lon, y_test_alt, c='b', marker='o', label='Actual')

    # 예측 값 플롯
    ax.scatter(y_pred_lat, y_pred_lon, y_pred_alt, c='r', marker='^', label='Predicted')

    # 그래프 제목 및 축 레이블 설정
    ax.set_title('Actual vs Predicted')
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 범례
    ax.legend()

    # 그래프를 화면에 출력
    plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# splited 데이터 경로 시각화 함수
def plot_trajectory(train_data, val_data, test_data):
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')

    # 훈련 데이터 플롯
    ax.plot(train_data['lat'], train_data['lon'], train_data['alt'], label='Train', color='blue')

    # 검증 데이터 플롯
    ax.plot(val_data['lat'], val_data['lon'], val_data['alt'], label='Validation', color='green')

    # 테스트 데이터 플롯
    ax.plot(test_data['lat'], test_data['lon'], test_data['alt'], label='Test', color='red')

    # 그래프 레이블
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Altitude')

    # 제목과 범례
    ax.set_title('Drone Trajectory: Train, Validation, and Test')
    ax.legend()

    plt.show()

# %% [markdown]
# ### 7. 데이터로더 생성 함수

# %% [markdown]
# - 학습에 사용할 데이터 로더 생성
# 1. 시퀀스 생성
# 2. Train, Validation, Test 분리
# 3. DataLoader 생성

# %%
# 데이터 로더 생성 함수
def create_dataloaders(tri, batch_size, sequence_length):

  tri = tri[['time', 'lat', 'lon', 'alt']]

  # train, validation, test 분리
  train_df, val_df, test_df = split_train_val_test(tri[['lat', 'lon', 'alt']])

  # 각 데이터에 대해 시퀀스 생성
  train_x, train_y = create_sequences(train_df, sequence_length)
  val_x, val_y = create_sequences(val_df, sequence_length)
  test_x, test_y = create_sequences(test_df, sequence_length)

  X_train = torch.tensor(train_x, dtype=torch.float32)
  y_train = torch.tensor(train_y, dtype=torch.float32)
  X_val = torch.tensor(val_x, dtype=torch.float32)
  y_val = torch.tensor(val_y, dtype=torch.float32)
  X_test = torch.tensor(test_x, dtype=torch.float32)
  y_test = torch.tensor(test_y, dtype=torch.float32)

  train_dataset = TensorDataset(X_train, y_train)
  validation_dataset = TensorDataset(X_val, y_val)
  test_dataset = TensorDataset(X_test, y_test)

  # 데이터 로더 생성
  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  val_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

  return train_loader, val_loader, test_loader

# %% [markdown]
# ## 전처리

# %% [markdown]
# ### 1. 데이터셋 가져오기

# %%
import pandas as pd

# 데이터셋 가져오기 (필요시 저장 경로 수정)
raw = pd.read_csv("/content/OnboardGPS.csv")

# %% [markdown]
# ### 2. 데이터셋 전처리

# %% [markdown]
# - 데이터셋 보간
# - 소수점 절사
# - MinMaxScaling 적용

# %%
tri = raw[['Timpstemp', ' lat', ' lon', ' alt']]

new_x, lat = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lat'])
new_x, lon = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' lon'])
new_x, alt = spline_interpolation(tri['Timpstemp'] / 1e6 , tri[' alt'])

tri = pd.DataFrame({"time":new_x, "lat":lat, "lon":lon, "alt":alt})

tri = truncation(tri)
scaler, tri = min_max_scaling(tri)
# tri
# Out:
# ['time', 'lat', 'lon', 'alt']

# %% [markdown]
# ## 모델 선언

# %% [markdown]
# ### 1. 모델 클래스 선언
# - Transformer를 사용한 모델 클래스 선언
# - 구조 : Transformer + Positional Encoding + Fully Connected Layer

# %%
import math
import torch

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return x

# %%
import torch.nn as nn

class TransformerModel(nn.Module):
    def __init__(self, input_dim, seq_length, d_model, nhead, num_encoder_layers, dim_feedforward):
        super(TransformerModel, self).__init__()
        self.embedding = nn.Linear(input_dim, d_model)  # input_dim에서 d_model로 변환
        self.positional_encoding = PositionalEncoding(d_model)  # 포지셔널 인코딩 추가
        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(
                d_model=d_model,
                nhead=nhead,
                dim_feedforward=dim_feedforward,
                dropout=0.0 ),
            num_layers=num_encoder_layers
        )
        self.fc_out = nn.Linear(d_model, input_dim)  # d_model에서 input_dim으로 변환

    def forward(self, src):
        src = self.embedding(src)  # 입력 차원 -> d_model로 변환
        src = self.positional_encoding(src)
        src = src.permute(1, 0, 2)  # (batch_size, seq_length, d_model) -> (seq_length, batch_size, d_model)
        output = self.transformer_encoder(src)  # Transformer Encoder 통과
        output = self.fc_out(output)  # (seq_length, batch_size, d_model) -> (seq_length, batch_size, input_dim)

        # 마지막 시점의 출력만 반환
        return output[-1, :, :]  # shape: (batch_size, input_dim)

# %% [markdown]
# ## 하이퍼파라미터 탐색

# %% [markdown]
# ### 1. Optuna의 objective 함수 선언

# %% [markdown]
# - 최적의 하이퍼파라미터 탐색을 위해 optuna 사용
# - objective 함수 선언

# %%
import optuna

def objective(trial, tri, sequence_length):
    # 탐색할 하이퍼파라미터 값 결정
    nhead = trial.suggest_int('nhead', 2, 8)
    d_model = trial.suggest_int('d_model', nhead * 8, nhead * 64, step=nhead) # d_model을 nhead의 배수로 설정하여 짝수 보장
    if d_model % 2 != 0:     # d_model이 홀수인 경우 짝수로 조정
        d_model += 1

    if d_model % nhead != 0: # d_model이 nhead의 배수가 아닌 경우 강제로 배수로 조정
        d_model += nhead - (d_model % nhead)

    num_encoder_layers = trial.suggest_int('num_encoder_layers', 1, 4)
    dim_feedforward = trial.suggest_int('dim_feedforward', 128, 512)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-2, log=True)
    batch_size = trial.suggest_int("batch_size", 16, 128)

    num_epochs = 300
    intput_size = 3

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # 데이터셋 로더
    train_loader, val_loader, _ = create_dataloaders(tri, batch_size, sequence_length)

    # 모델 정의: Transformer Model
    model = TransformerModel(
        input_dim=intput_size,
        seq_length=sequence_length,
        d_model=d_model,
        nhead=nhead,
        num_encoder_layers=num_encoder_layers,
        dim_feedforward=dim_feedforward
    ).to(device)  # GPU 사용

    # 손실 함수
    criterion = nn.MSELoss()

    # 최적화 함수
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    total_val_loss = 0.0  # 모든 epoch에서의 validation loss의 합
    val_loss_count = 0    # 평균을 계산하기 위한 epoch 수

    # 모델 학습
    for epoch in range(num_epochs):
        # Train set으로 학습
        model.train()
        train_loss = 0.0
        for batch_X, batch_y in train_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)  # 데이터도 GPU로 이동
            optimizer.zero_grad()
            output = model(batch_X)  # 출력 형태: (batch_size, input_dim)

            # Loss 계산
            loss = criterion(output, batch_y)  # y의 형태: (batch_size, input_dim)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        # Validation set에서 성능 측정
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                batch_X, batch_y = batch_X.to(device), batch_y.to(device)
                output = model(batch_X)

                # Loss 계산
                loss = criterion(output, batch_y)
                val_loss += loss.item()

        # 배치 수로 나눠서 평균 validation 손실 계산
        val_loss_avg = val_loss / len(val_loader)

        # Optuna에 중간 값 보고
        trial.report(val_loss_avg, epoch)

        # 총 validation 손실 계산
        total_val_loss += val_loss_avg
        val_loss_count += 1

        # Pruning 조건 확인
        if trial.should_prune():
            print(f"Trial {trial.number} pruned at epoch {epoch}")
            print(f"Validation Loss at prune: {val_loss_avg:.4f}")  # Prune 시점에서 validation loss 출력

            raise optuna.TrialPruned()

    # 모든 epoch에서의 validation Loss avg 반환
    return total_val_loss / val_loss_count

# %% [markdown]
# ### 3. 탐색 범위 외의 하이퍼파라미터 선언

# %%
sequence_length = 10
early_stopping_rounds = 10
n_trials = 100

# %% [markdown]
# ### 4. 하이퍼 파라미터 탐색

# %%
import optuna

# Optuna 스터디 생성 및 최적화 실행
study = optuna.create_study(direction='minimize')
study.optimize(lambda trial: objective(trial, tri, sequence_length), n_trials=n_trials)

# 최적의 하이퍼파라미터 출력
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2024-10-07 07:16:23,929] A new study created in memory with name: no-name-f3dc5ca8-3924-460a-bcc6-e582879ee3ec
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:17:47,250] Trial 0 finished with value: 0.0006438341001942011 and parameters: {'nhead': 7, 'd_model': 182, 'num_encoder_layers': 3, 'dim_feedforward': 227, 'learning_rate': 0.0010628763419017358, 'batch_size': 128}. Best is trial 0 with value: 0.0006438341001942011.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:19:33,883] Trial 1 finished with value: 0.0031546455354195635 and parameters: {'nhead': 6, 'd_model': 144, 'num_encoder_layers': 4, 'dim_feedforward': 243, 'learning_rate': 0.0014913365553848566, 'batch_size': 107}. Best is trial 0 with value: 0.0006438341001942011.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:22:18,540] Trial 2 finished with value: 0.0002449544481864638 and parameters: {'nhead': 6, 'd_model': 246, 'num_encoder_layers': 4, 'dim_feedforward': 406, 'learning_rate': 8.799442437184197e-05, 'batch_size': 65}. Best is trial 2 with value: 0.0002449544481864638.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:23:08,259] Trial 3 finished with value: 0.0032402582665274557 and parameters: {'nhead': 5, 'd_model': 305, 'num_encoder_layers': 1, 'dim_feedforward': 324, 'learning_rate': 0.0012618891453629807, 'batch_size': 100}. Best is trial 2 with value: 0.0002449544481864638.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:25:18,748] Trial 4 finished with value: 0.0007026051059120599 and parameters: {'nhead': 3, 'd_model': 42, 'num_encoder_layers': 3, 'dim_feedforward': 492, 'learning_rate': 0.0009509879411889636, 'batch_size': 64}. Best is trial 2 with value: 0.0002449544481864638.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:25:19,938] Trial 5 pruned.
# Trial 5 pruned at epoch 1
# Validation Loss at prune: 0.0070
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:25:20,519] Trial 6 pruned.
# Trial 6 pruned at epoch 0
# Validation Loss at prune: 0.0892
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:25:21,988] Trial 7 pruned.
# Trial 7 pruned at epoch 0
# Validation Loss at prune: 0.1661
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:26:32,920] Trial 8 finished with value: 0.00010919231935576146 and parameters: {'nhead': 2, 'd_model': 110, 'num_encoder_layers': 1, 'dim_feedforward': 277, 'learning_rate': 0.0003447120426190648, 'batch_size': 64}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:26:34,229] Trial 9 pruned.
# Trial 9 pruned at epoch 1
# Validation Loss at prune: 0.0052
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:26:35,897] Trial 10 pruned.
# Trial 10 pruned at epoch 2
# Validation Loss at prune: 0.0022
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:26:36,679] Trial 11 pruned.
# Trial 11 pruned at epoch 1
# Validation Loss at prune: 0.0060
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:26:39,278] Trial 12 pruned.
# Trial 12 pruned at epoch 5
# Validation Loss at prune: 0.0009
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:26:40,287] Trial 13 pruned.
# Trial 13 pruned at epoch 0
# Validation Loss at prune: 0.1443
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:26:41,638] Trial 14 pruned.
# Trial 14 pruned at epoch 2
# Validation Loss at prune: 0.0015
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:29:09,822] Trial 15 finished with value: 0.00014041886968671263 and parameters: {'nhead': 8, 'd_model': 296, 'num_encoder_layers': 2, 'dim_feedforward': 301, 'learning_rate': 0.00016773257696154966, 'batch_size': 43}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:29:12,599] Trial 16 pruned.
# Trial 16 pruned at epoch 6
# Validation Loss at prune: 0.0013
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:29:13,985] Trial 17 pruned.
# Trial 17 pruned at epoch 0
# Validation Loss at prune: 0.1919
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:30:40,172] Trial 18 finished with value: 0.0003093308361359382 and parameters: {'nhead': 4, 'd_model': 100, 'num_encoder_layers': 1, 'dim_feedforward': 183, 'learning_rate': 0.003126769059737577, 'batch_size': 51}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:32:03,987] Trial 19 pruned.
# Trial 19 pruned at epoch 130
# Validation Loss at prune: 0.0001
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:32:06,974] Trial 20 pruned.
# Trial 20 pruned at epoch 10
# Validation Loss at prune: 0.0004
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:32:07,864] Trial 21 pruned.
# Trial 21 pruned at epoch 1
# Validation Loss at prune: 0.0051
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:32:08,698] Trial 22 pruned.
# Trial 22 pruned at epoch 0
# Validation Loss at prune: 0.0502
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:33:10,718] Trial 23 pruned.
# Trial 23 pruned at epoch 70
# Validation Loss at prune: 0.0004
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:33:45,192] Trial 24 pruned.
# Trial 24 pruned at epoch 89
# Validation Loss at prune: 0.0006
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:33:45,989] Trial 25 pruned.
# Trial 25 pruned at epoch 0
# Validation Loss at prune: 0.0279
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:33:47,420] Trial 26 pruned.
# Trial 26 pruned at epoch 4
# Validation Loss at prune: 0.0008
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:34:01,969] Trial 27 pruned.
# Trial 27 pruned at epoch 18
# Validation Loss at prune: 0.0003
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:37:23,428] Trial 28 finished with value: 0.00013328298072450538 and parameters: {'nhead': 4, 'd_model': 164, 'num_encoder_layers': 2, 'dim_feedforward': 385, 'learning_rate': 0.00029354207651968776, 'batch_size': 31}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:40:56,095] Trial 29 finished with value: 0.00012916223557130912 and parameters: {'nhead': 2, 'd_model': 84, 'num_encoder_layers': 2, 'dim_feedforward': 220, 'learning_rate': 0.000698351304892892, 'batch_size': 29}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:44:21,231] Trial 30 finished with value: 0.0001813792926673664 and parameters: {'nhead': 2, 'd_model': 86, 'num_encoder_layers': 2, 'dim_feedforward': 155, 'learning_rate': 0.0008724310288866076, 'batch_size': 30}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:50:34,211] Trial 31 finished with value: 0.000156848370222204 and parameters: {'nhead': 3, 'd_model': 147, 'num_encoder_layers': 2, 'dim_feedforward': 253, 'learning_rate': 0.0003312685242608983, 'batch_size': 16}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:53:17,212] Trial 32 finished with value: 0.0001880008122257672 and parameters: {'nhead': 2, 'd_model': 66, 'num_encoder_layers': 2, 'dim_feedforward': 243, 'learning_rate': 0.0020155624416867343, 'batch_size': 38}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:53:19,097] Trial 33 pruned.
# Trial 33 pruned at epoch 1
# Validation Loss at prune: 0.0006
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:53:20,271] Trial 34 pruned.
# Trial 34 pruned at epoch 1
# Validation Loss at prune: 0.0007
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:53:21,210] Trial 35 pruned.
# Trial 35 pruned at epoch 0
# Validation Loss at prune: 0.0092
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:54:45,963] Trial 36 pruned.
# Trial 36 pruned at epoch 103
# Validation Loss at prune: 0.0003
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:54:46,558] Trial 37 pruned.
# Trial 37 pruned at epoch 0
# Validation Loss at prune: 0.1121
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:54:48,251] Trial 38 pruned.
# Trial 38 pruned at epoch 1
# Validation Loss at prune: 0.0008
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:54:49,280] Trial 39 pruned.
# Trial 39 pruned at epoch 0
# Validation Loss at prune: 0.0596
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:54:50,171] Trial 40 pruned.
# Trial 40 pruned at epoch 0
# Validation Loss at prune: 0.0045
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:54:53,585] Trial 41 pruned.
# Trial 41 pruned at epoch 1
# Validation Loss at prune: 0.0007
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 07:59:41,045] Trial 42 finished with value: 0.00021532190097596008 and parameters: {'nhead': 3, 'd_model': 150, 'num_encoder_layers': 2, 'dim_feedforward': 263, 'learning_rate': 0.00028131154036344726, 'batch_size': 21}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:05:52,407] Trial 43 finished with value: 0.0005786519923293441 and parameters: {'nhead': 3, 'd_model': 96, 'num_encoder_layers': 2, 'dim_feedforward': 229, 'learning_rate': 0.0006802144033020469, 'batch_size': 16}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:05:52,893] Trial 44 pruned.
# Trial 44 pruned at epoch 0
# Validation Loss at prune: 0.1101
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:05:54,011] Trial 45 pruned.
# Trial 45 pruned at epoch 0
# Validation Loss at prune: 0.0022
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:06:00,431] Trial 46 pruned.
# Trial 46 pruned at epoch 6
# Validation Loss at prune: 0.0003
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:06:01,084] Trial 47 pruned.
# Trial 47 pruned at epoch 0
# Validation Loss at prune: 0.1596
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:06:02,069] Trial 48 pruned.
# Trial 48 pruned at epoch 0
# Validation Loss at prune: 0.0069
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:06:03,090] Trial 49 pruned.
# Trial 49 pruned at epoch 0
# Validation Loss at prune: 0.0031
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:06:03,725] Trial 50 pruned.
# Trial 50 pruned at epoch 0
# Validation Loss at prune: 0.0958
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:09:28,578] Trial 51 finished with value: 0.00012162886693317898 and parameters: {'nhead': 2, 'd_model': 90, 'num_encoder_layers': 2, 'dim_feedforward': 128, 'learning_rate': 0.0009565205953281017, 'batch_size': 30}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:09:32,743] Trial 52 pruned.
# Trial 52 pruned at epoch 3
# Validation Loss at prune: 0.0005
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:13:34,526] Trial 53 finished with value: 0.00011287842317326498 and parameters: {'nhead': 3, 'd_model': 105, 'num_encoder_layers': 2, 'dim_feedforward': 154, 'learning_rate': 0.0005344300720766331, 'batch_size': 25}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:13:35,585] Trial 54 pruned.
# Trial 54 pruned at epoch 0
# Validation Loss at prune: 0.0013
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:13:36,377] Trial 55 pruned.
# Trial 55 pruned at epoch 0
# Validation Loss at prune: 0.0036
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:13:37,377] Trial 56 pruned.
# Trial 56 pruned at epoch 0
# Validation Loss at prune: 0.0162
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:13:38,009] Trial 57 pruned.
# Trial 57 pruned at epoch 0
# Validation Loss at prune: 0.0113
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:13:38,483] Trial 58 pruned.
# Trial 58 pruned at epoch 0
# Validation Loss at prune: 0.0419
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:13:39,150] Trial 59 pruned.
# Trial 59 pruned at epoch 0
# Validation Loss at prune: 0.0932
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:13:39,803] Trial 60 pruned.
# Trial 60 pruned at epoch 0
# Validation Loss at prune: 0.0293
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:15:33,872] Trial 61 pruned.
# Trial 61 pruned at epoch 108
# Validation Loss at prune: 0.0004
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:20:04,688] Trial 62 finished with value: 0.00013139642739712189 and parameters: {'nhead': 3, 'd_model': 81, 'num_encoder_layers': 2, 'dim_feedforward': 320, 'learning_rate': 0.0003950149677625295, 'batch_size': 22}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:24:35,375] Trial 63 finished with value: 0.00011140574812509462 and parameters: {'nhead': 4, 'd_model': 76, 'num_encoder_layers': 2, 'dim_feedforward': 328, 'learning_rate': 0.00044925863727133776, 'batch_size': 22}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:24:36,670] Trial 64 pruned.
# Trial 64 pruned at epoch 0
# Validation Loss at prune: 0.0012
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:33,648] Trial 65 finished with value: 0.00014245941085157284 and parameters: {'nhead': 3, 'd_model': 78, 'num_encoder_layers': 2, 'dim_feedforward': 316, 'learning_rate': 0.0004463105777637852, 'batch_size': 20}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:34,861] Trial 66 pruned.
# Trial 66 pruned at epoch 0
# Validation Loss at prune: 0.0027
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:35,536] Trial 67 pruned.
# Trial 67 pruned at epoch 0
# Validation Loss at prune: 0.0060
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:36,867] Trial 68 pruned.
# Trial 68 pruned at epoch 0
# Validation Loss at prune: 0.1161
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:37,954] Trial 69 pruned.
# Trial 69 pruned at epoch 0
# Validation Loss at prune: 0.0051
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:38,565] Trial 70 pruned.
# Trial 70 pruned at epoch 0
# Validation Loss at prune: 0.0526
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:40,557] Trial 71 pruned.
# Trial 71 pruned at epoch 1
# Validation Loss at prune: 0.0016
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:41,416] Trial 72 pruned.
# Trial 72 pruned at epoch 0
# Validation Loss at prune: 0.0011
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:42,364] Trial 73 pruned.
# Trial 73 pruned at epoch 0
# Validation Loss at prune: 0.0019
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:29:43,458] Trial 74 pruned.
# Trial 74 pruned at epoch 0
# Validation Loss at prune: 0.0205
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:34:59,201] Trial 75 finished with value: 0.0001466223030058279 and parameters: {'nhead': 2, 'd_model': 88, 'num_encoder_layers': 2, 'dim_feedforward': 173, 'learning_rate': 0.0002638583841431142, 'batch_size': 20}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:34:59,934] Trial 76 pruned.
# Trial 76 pruned at epoch 0
# Validation Loss at prune: 0.0204
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:35:00,740] Trial 77 pruned.
# Trial 77 pruned at epoch 0
# Validation Loss at prune: 0.0039
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:35:01,725] Trial 78 pruned.
# Trial 78 pruned at epoch 0
# Validation Loss at prune: 0.0009
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:35:03,246] Trial 79 pruned.
# Trial 79 pruned at epoch 0
# Validation Loss at prune: 0.0010
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:35:03,943] Trial 80 pruned.
# Trial 80 pruned at epoch 0
# Validation Loss at prune: 0.0367
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:35:05,506] Trial 81 pruned.
# Trial 81 pruned at epoch 0
# Validation Loss at prune: 0.0018
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:35:07,333] Trial 82 pruned.
# Trial 82 pruned at epoch 0
# Validation Loss at prune: 0.0013
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:35:08,829] Trial 83 pruned.
# Trial 83 pruned at epoch 0
# Validation Loss at prune: 0.0011
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:38:58,038] Trial 84 finished with value: 0.00013855843799188066 and parameters: {'nhead': 3, 'd_model': 96, 'num_encoder_layers': 2, 'dim_feedforward': 372, 'learning_rate': 0.0007506827559845248, 'batch_size': 29}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:42:44,574] Trial 85 finished with value: 0.00014886081914401142 and parameters: {'nhead': 2, 'd_model': 98, 'num_encoder_layers': 2, 'dim_feedforward': 398, 'learning_rate': 0.0009463993127568905, 'batch_size': 29}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:42:46,388] Trial 86 pruned.
# Trial 86 pruned at epoch 1
# Validation Loss at prune: 0.0006
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:42:47,195] Trial 87 pruned.
# Trial 87 pruned at epoch 0
# Validation Loss at prune: 0.0104
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:42:48,091] Trial 88 pruned.
# Trial 88 pruned at epoch 0
# Validation Loss at prune: 0.0089
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:42:52,775] Trial 89 pruned.
# Trial 89 pruned at epoch 2
# Validation Loss at prune: 0.0004
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:42:53,480] Trial 90 pruned.
# Trial 90 pruned at epoch 0
# Validation Loss at prune: 0.0163
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:42:54,694] Trial 91 pruned.
# Trial 91 pruned at epoch 0
# Validation Loss at prune: 0.0015
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:47:58,175] Trial 92 finished with value: 0.00022735791481844338 and parameters: {'nhead': 3, 'd_model': 81, 'num_encoder_layers': 2, 'dim_feedforward': 308, 'learning_rate': 0.0005219554763148627, 'batch_size': 20}. Best is trial 8 with value: 0.00010919231935576146.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:47:59,566] Trial 93 pruned.
# Trial 93 pruned at epoch 0
# Validation Loss at prune: 0.0039
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:48:01,282] Trial 94 pruned.
# Trial 94 pruned at epoch 0
# Validation Loss at prune: 0.0038
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:48:02,211] Trial 95 pruned.
# Trial 95 pruned at epoch 0
# Validation Loss at prune: 0.0018
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:48:02,886] Trial 96 pruned.
# Trial 96 pruned at epoch 0
# Validation Loss at prune: 0.0190
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:48:03,665] Trial 97 pruned.
# Trial 97 pruned at epoch 0
# Validation Loss at prune: 0.0198
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:48:04,830] Trial 98 pruned.
# Trial 98 pruned at epoch 0
# Validation Loss at prune: 0.0017
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [I 2024-10-07 08:48:06,908] Trial 99 pruned.
# Trial 99 pruned at epoch 1
# Validation Loss at prune: 0.0005
# Best hyperparameters:  {'nhead': 2, 'd_model': 110, 'num_encoder_layers': 1, 'dim_feedforward': 277, 'learning_rate': 0.0003447120426190648, 'batch_size': 64}

# %% [markdown]
# ### 5. 하이퍼파라미터 저장

# %%
import json

### 하이퍼 파라미터 저장

# 최적의 하이퍼파라미터를 JSON 파일로 저장
with open("best_hyperparameters.json", "w") as f:
    json.dump(study.best_params, f, indent=4)

print("Best hyperparameters have been saved to 'best_hyperparameters.json'")
# Out:
# Best hyperparameters have been saved to 'best_hyperparameters.json'

# %% [markdown]
# ## 학습

# %% [markdown]
# ### 1. 하이퍼파라미터 불러오기

# %%
import json

# 저장된 하이퍼파라미터 불러오기
with open("best_hyperparameters.json", "r") as f:
    best_params = json.load(f)

print("Loaded best hyperparameters:", best_params)
# Out:
# Loaded best hyperparameters: {'nhead': 2, 'd_model': 110, 'num_encoder_layers': 1, 'dim_feedforward': 277, 'learning_rate': 0.0003447120426190648, 'batch_size': 64}

# %% [markdown]
# ### 2. 최적의 파라미터로 모델 학습

# %%
sequence_length = 10
num_epochs = 300

# %%
# 최적의 모델 학습
# best_params = study.best_params

train_loader, val_loader, test_loader = create_dataloaders(tri, best_params['batch_size'], sequence_length)

best_model = TransformerModel(
    input_dim=3,
    seq_length=10,
    d_model=best_params['d_model'],
    nhead=best_params['nhead'],
    num_encoder_layers=best_params['num_encoder_layers'],
    dim_feedforward=best_params['dim_feedforward']
)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
best_model = best_model.to(device)

optimizer = torch.optim.Adam(best_model.parameters(), lr=best_params['learning_rate'])
criterion = torch.nn.MSELoss()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
import time
import torch

best_model.train()
total_train_time = 0  # 총 학습 시간 기록 변수

train_losses = [] # 손실 저장할 리스트
val_losses = []

for epoch in range(num_epochs):  # 최종 모델 학습
    best_model.train()
    train_loss = 0.0
    epoch_start_time = time.time()  # 에포크 시작 시간 기록
    for batch_x, batch_y in train_loader:
        batch_x = batch_x.to(device)  # 입력 데이터 차원 조정
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = best_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    epoch_end_time = time.time()  # 에포크 종료 시간 기록
    epoch_duration = epoch_end_time - epoch_start_time  # 한 에포크의 학습 시간
    total_train_time += epoch_duration  # 총 학습 시간에 추가

    # Validation set에서 성능 측정
    best_model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch_x, batch_y in val_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)  # 입력 데이터 차원 조정
            output = best_model(batch_x)
            loss = criterion(output, batch_y)
            val_loss += loss.item()

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
    print(f"Epoch {epoch+1}/{num_epochs} completed in {epoch_duration:.2f} seconds.")

print(f"Total training time: {total_train_time:.2f} seconds.")

# Model Save
model_save_path = f"best_model_with_losses.pth"
torch.save({
    'model_state_dict': best_model.state_dict(),
    'train_losses': train_losses,
    'val_losses': val_losses
    }, model_save_path)
print(f"Model saved: {model_save_path}")
# Out:
# Epoch [1/300], Train Loss: 2.8468, Val Loss: 0.8876
# Epoch 1/300 completed in 1.10 seconds.
# Epoch [2/300], Train Loss: 0.2618, Val Loss: 0.0284
# Epoch 2/300 completed in 0.99 seconds.
# Epoch [3/300], Train Loss: 0.0372, Val Loss: 0.0100
# Epoch 3/300 completed in 0.98 seconds.
# Epoch [4/300], Train Loss: 0.0138, Val Loss: 0.0080
# Epoch 4/300 completed in 0.98 seconds.
# Epoch [5/300], Train Loss: 0.0104, Val Loss: 0.0058
# Epoch 5/300 completed in 0.97 seconds.
# Epoch [6/300], Train Loss: 0.0090, Val Loss: 0.0052
# Epoch 6/300 completed in 1.13 seconds.
# Epoch [7/300], Train Loss: 0.0086, Val Loss: 0.0051
# Epoch 7/300 completed in 1.47 seconds.
# Epoch [8/300], Train Loss: 0.0077, Val Loss: 0.0045
# Epoch 8/300 completed in 1.47 seconds.
# Epoch [9/300], Train Loss: 0.0073, Val Loss: 0.0041
# Epoch 9/300 completed in 0.98 seconds.
# Epoch [10/300], Train Loss: 0.0069, Val Loss: 0.0051
# Epoch 10/300 completed in 0.96 seconds.
# Epoch [11/300], Train Loss: 0.0064, Val Loss: 0.0044
# Epoch 11/300 completed in 0.97 seconds.
# Epoch [12/300], Train Loss: 0.0057, Val Loss: 0.0038
# Epoch 12/300 completed in 0.98 seconds.
# Epoch [13/300], Train Loss: 0.0061, Val Loss: 0.0038
# Epoch 13/300 completed in 0.98 seconds.
# Epoch [14/300], Train Loss: 0.0053, Val Loss: 0.0043
# Epoch 14/300 completed in 0.98 seconds.
# Epoch [15/300], Train Loss: 0.0055, Val Loss: 0.0039
# Epoch 15/300 completed in 0.97 seconds.
# Epoch [16/300], Train Loss: 0.0049, Val Loss: 0.0038
# Epoch 16/300 completed in 0.97 seconds.
# Epoch [17/300], Train Loss: 0.0054, Val Loss: 0.0031
# Epoch 17/300 completed in 0.98 seconds.
# Epoch [18/300], Train Loss: 0.0048, Val Loss: 0.0030
# Epoch 18/300 completed in 1.40 seconds.
# Epoch [19/300], Train Loss: 0.0041, Val Loss: 0.0032
# Epoch 19/300 completed in 1.48 seconds.
# Epoch [20/300], Train Loss: 0.0037, Val Loss: 0.0027
# Epoch 20/300 completed in 1.21 seconds.
# Epoch [21/300], Train Loss: 0.0042, Val Loss: 0.0028
# Epoch 21/300 completed in 1.00 seconds.
# Epoch [22/300], Train Loss: 0.0046, Val Loss: 0.0038
# Epoch 22/300 completed in 0.98 seconds.
# Epoch [23/300], Train Loss: 0.0037, Val Loss: 0.0028
# Epoch 23/300 completed in 0.99 seconds.
# Epoch [24/300], Train Loss: 0.0038, Val Loss: 0.0033
# Epoch 24/300 completed in 0.98 seconds.
# Epoch [25/300], Train Loss: 0.0042, Val Loss: 0.0040
# Epoch 25/300 completed in 0.98 seconds.
# Epoch [26/300], Train Loss: 0.0035, Val Loss: 0.0036
# Epoch 26/300 completed in 1.00 seconds.
# Epoch [27/300], Train Loss: 0.0033, Val Loss: 0.0026
# Epoch 27/300 completed in 0.99 seconds.
# Epoch [28/300], Train Loss: 0.0030, Val Loss: 0.0027
# Epoch 28/300 completed in 0.98 seconds.
# Epoch [29/300], Train Loss: 0.0042, Val Loss: 0.0027
# Epoch 29/300 completed in 1.19 seconds.
# Epoch [30/300], Train Loss: 0.0028, Val Loss: 0.0023
# Epoch 30/300 completed in 1.50 seconds.
# Epoch [31/300], Train Loss: 0.0043, Val Loss: 0.0025
# Epoch 31/300 completed in 1.30 seconds.
# Epoch [32/300], Train Loss: 0.0027, Val Loss: 0.0033
# Epoch 32/300 completed in 0.98 seconds.
# Epoch [33/300], Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 33/300 completed in 0.98 seconds.
# Epoch [34/300], Train Loss: 0.0036, Val Loss: 0.0039
# Epoch 34/300 completed in 0.99 seconds.
# Epoch [35/300], Train Loss: 0.0039, Val Loss: 0.0048
# Epoch 35/300 completed in 0.99 seconds.
# Epoch [36/300], Train Loss: 0.0034, Val Loss: 0.0020
# Epoch 36/300 completed in 0.99 seconds.
# Epoch [37/300], Train Loss: 0.0029, Val Loss: 0.0035
# Epoch 37/300 completed in 1.01 seconds.
# Epoch [38/300], Train Loss: 0.0025, Val Loss: 0.0020
# Epoch 38/300 completed in 1.00 seconds.
# Epoch [39/300], Train Loss: 0.0026, Val Loss: 0.0023
# Epoch 39/300 completed in 0.99 seconds.
# Epoch [40/300], Train Loss: 0.0022, Val Loss: 0.0019
# Epoch 40/300 completed in 1.13 seconds.
# Epoch [41/300], Train Loss: 0.0027, Val Loss: 0.0026
# Epoch 41/300 completed in 1.48 seconds.
# Epoch [42/300], Train Loss: 0.0020, Val Loss: 0.0021
# Epoch 42/300 completed in 1.30 seconds.
# Epoch [43/300], Train Loss: 0.0023, Val Loss: 0.0018
# Epoch 43/300 completed in 0.97 seconds.
# Epoch [44/300], Train Loss: 0.0022, Val Loss: 0.0036
# Epoch 44/300 completed in 0.96 seconds.
# Epoch [45/300], Train Loss: 0.0026, Val Loss: 0.0024
# Epoch 45/300 completed in 0.99 seconds.
# Epoch [46/300], Train Loss: 0.0019, Val Loss: 0.0018
# Epoch 46/300 completed in 1.01 seconds.
# Epoch [47/300], Train Loss: 0.0019, Val Loss: 0.0019
# Epoch 47/300 completed in 1.00 seconds.
# Epoch [48/300], Train Loss: 0.0024, Val Loss: 0.0019
# Epoch 48/300 completed in 0.99 seconds.
# Epoch [49/300], Train Loss: 0.0030, Val Loss: 0.0024
# Epoch 49/300 completed in 0.98 seconds.
# Epoch [50/300], Train Loss: 0.0025, Val Loss: 0.0036
# Epoch 50/300 completed in 0.99 seconds.
# Epoch [51/300], Train Loss: 0.0028, Val Loss: 0.0027
# Epoch 51/300 completed in 1.07 seconds.
# Epoch [52/300], Train Loss: 0.0031, Val Loss: 0.0045
# Epoch 52/300 completed in 1.49 seconds.
# Epoch [53/300], Train Loss: 0.0028, Val Loss: 0.0030
# Epoch 53/300 completed in 1.49 seconds.
# Epoch [54/300], Train Loss: 0.0021, Val Loss: 0.0023
# Epoch 54/300 completed in 0.98 seconds.
# Epoch [55/300], Train Loss: 0.0025, Val Loss: 0.0017
# Epoch 55/300 completed in 0.99 seconds.
# Epoch [56/300], Train Loss: 0.0020, Val Loss: 0.0019
# Epoch 56/300 completed in 1.00 seconds.
# Epoch [57/300], Train Loss: 0.0026, Val Loss: 0.0020
# Epoch 57/300 completed in 1.01 seconds.
# Epoch [58/300], Train Loss: 0.0023, Val Loss: 0.0018
# Epoch 58/300 completed in 0.99 seconds.
# Epoch [59/300], Train Loss: 0.0027, Val Loss: 0.0066
# Epoch 59/300 completed in 1.01 seconds.
# Epoch [60/300], Train Loss: 0.0047, Val Loss: 0.0052
# Epoch 60/300 completed in 0.98 seconds.
# Epoch [61/300], Train Loss: 0.0033, Val Loss: 0.0018
# Epoch 61/300 completed in 0.99 seconds.
# Epoch [62/300], Train Loss: 0.0022, Val Loss: 0.0015
# Epoch 62/300 completed in 0.99 seconds.
# Epoch [63/300], Train Loss: 0.0026, Val Loss: 0.0021
# Epoch 63/300 completed in 1.44 seconds.
# Epoch [64/300], Train Loss: 0.0025, Val Loss: 0.0036
# Epoch 64/300 completed in 1.48 seconds.
# Epoch [65/300], Train Loss: 0.0025, Val Loss: 0.0016
# Epoch 65/300 completed in 1.07 seconds.
# Epoch [66/300], Train Loss: 0.0024, Val Loss: 0.0015
# Epoch 66/300 completed in 0.98 seconds.
# Epoch [67/300], Train Loss: 0.0021, Val Loss: 0.0034
# Epoch 67/300 completed in 0.98 seconds.
# Epoch [68/300], Train Loss: 0.0024, Val Loss: 0.0023
# Epoch 68/300 completed in 1.57 seconds.
# Epoch [69/300], Train Loss: 0.0021, Val Loss: 0.0028
# Epoch 69/300 completed in 1.93 seconds.
# Epoch [70/300], Train Loss: 0.0019, Val Loss: 0.0016
# Epoch 70/300 completed in 1.01 seconds.
# Epoch [71/300], Train Loss: 0.0024, Val Loss: 0.0025
# Epoch 71/300 completed in 0.99 seconds.
# Epoch [72/300], Train Loss: 0.0032, Val Loss: 0.0020
# Epoch 72/300 completed in 1.06 seconds.
# Epoch [73/300], Train Loss: 0.0021, Val Loss: 0.0019
# Epoch 73/300 completed in 1.44 seconds.
# Epoch [74/300], Train Loss: 0.0018, Val Loss: 0.0017
# Epoch 74/300 completed in 1.48 seconds.
# Epoch [75/300], Train Loss: 0.0027, Val Loss: 0.0020
# Epoch 75/300 completed in 0.98 seconds.
# Epoch [76/300], Train Loss: 0.0029, Val Loss: 0.0018
# Epoch 76/300 completed in 0.97 seconds.
# Epoch [77/300], Train Loss: 0.0026, Val Loss: 0.0015
# Epoch 77/300 completed in 0.98 seconds.
# Epoch [78/300], Train Loss: 0.0018, Val Loss: 0.0018
# Epoch 78/300 completed in 0.96 seconds.
# Epoch [79/300], Train Loss: 0.0024, Val Loss: 0.0018
# Epoch 79/300 completed in 0.96 seconds.
# Epoch [80/300], Train Loss: 0.0021, Val Loss: 0.0014
# Epoch 80/300 completed in 0.95 seconds.
# Epoch [81/300], Train Loss: 0.0034, Val Loss: 0.0019
# Epoch 81/300 completed in 0.98 seconds.
# Epoch [82/300], Train Loss: 0.0021, Val Loss: 0.0013
# Epoch 82/300 completed in 0.96 seconds.
# Epoch [83/300], Train Loss: 0.0034, Val Loss: 0.0054
# Epoch 83/300 completed in 0.97 seconds.
# Epoch [84/300], Train Loss: 0.0047, Val Loss: 0.0015
# Epoch 84/300 completed in 1.34 seconds.
# Epoch [85/300], Train Loss: 0.0032, Val Loss: 0.0022
# Epoch 85/300 completed in 1.49 seconds.
# Epoch [86/300], Train Loss: 0.0023, Val Loss: 0.0022
# Epoch 86/300 completed in 1.25 seconds.
# Epoch [87/300], Train Loss: 0.0021, Val Loss: 0.0019
# Epoch 87/300 completed in 0.98 seconds.
# Epoch [88/300], Train Loss: 0.0026, Val Loss: 0.0017
# Epoch 88/300 completed in 0.97 seconds.
# Epoch [89/300], Train Loss: 0.0018, Val Loss: 0.0017
# Epoch 89/300 completed in 0.98 seconds.
# Epoch [90/300], Train Loss: 0.0028, Val Loss: 0.0017
# Epoch 90/300 completed in 0.97 seconds.
# Epoch [91/300], Train Loss: 0.0021, Val Loss: 0.0018
# Epoch 91/300 completed in 0.96 seconds.
# Epoch [92/300], Train Loss: 0.0025, Val Loss: 0.0015
# Epoch 92/300 completed in 0.98 seconds.
# Epoch [93/300], Train Loss: 0.0016, Val Loss: 0.0017
# Epoch 93/300 completed in 0.97 seconds.
# Epoch [94/300], Train Loss: 0.0032, Val Loss: 0.0019
# Epoch 94/300 completed in 0.99 seconds.
# Epoch [95/300], Train Loss: 0.0031, Val Loss: 0.0027
# Epoch 95/300 completed in 1.05 seconds.
# Epoch [96/300], Train Loss: 0.0020, Val Loss: 0.0018
# Epoch 96/300 completed in 1.44 seconds.
# Epoch [97/300], Train Loss: 0.0024, Val Loss: 0.0015
# Epoch 97/300 completed in 1.49 seconds.
# Epoch [98/300], Train Loss: 0.0025, Val Loss: 0.0017
# Epoch 98/300 completed in 0.98 seconds.
# Epoch [99/300], Train Loss: 0.0028, Val Loss: 0.0020
# Epoch 99/300 completed in 0.96 seconds.
# Epoch [100/300], Train Loss: 0.0021, Val Loss: 0.0025
# Epoch 100/300 completed in 0.97 seconds.
# Epoch [101/300], Train Loss: 0.0026, Val Loss: 0.0020
# Epoch 101/300 completed in 0.98 seconds.
# Epoch [102/300], Train Loss: 0.0021, Val Loss: 0.0030
# Epoch 102/300 completed in 0.98 seconds.
# Epoch [103/300], Train Loss: 0.0017, Val Loss: 0.0018
# Epoch 103/300 completed in 0.97 seconds.
# Epoch [104/300], Train Loss: 0.0027, Val Loss: 0.0027
# Epoch 104/300 completed in 0.97 seconds.
# Epoch [105/300], Train Loss: 0.0029, Val Loss: 0.0022
# Epoch 105/300 completed in 0.96 seconds.
# Epoch [106/300], Train Loss: 0.0023, Val Loss: 0.0023
# Epoch 106/300 completed in 0.99 seconds.
# Epoch [107/300], Train Loss: 0.0024, Val Loss: 0.0025
# Epoch 107/300 completed in 1.31 seconds.
# Epoch [108/300], Train Loss: 0.0026, Val Loss: 0.0017
# Epoch 108/300 completed in 1.48 seconds.
# Epoch [109/300], Train Loss: 0.0028, Val Loss: 0.0014
# Epoch 109/300 completed in 1.24 seconds.
# Epoch [110/300], Train Loss: 0.0025, Val Loss: 0.0021
# Epoch 110/300 completed in 0.99 seconds.
# Epoch [111/300], Train Loss: 0.0029, Val Loss: 0.0017
# Epoch 111/300 completed in 0.97 seconds.
# Epoch [112/300], Train Loss: 0.0028, Val Loss: 0.0018
# Epoch 112/300 completed in 0.99 seconds.
# Epoch [113/300], Train Loss: 0.0020, Val Loss: 0.0020
# Epoch 113/300 completed in 1.00 seconds.
# Epoch [114/300], Train Loss: 0.0022, Val Loss: 0.0018
# Epoch 114/300 completed in 0.98 seconds.
# Epoch [115/300], Train Loss: 0.0021, Val Loss: 0.0019
# Epoch 115/300 completed in 0.96 seconds.
# Epoch [116/300], Train Loss: 0.0026, Val Loss: 0.0021
# Epoch 116/300 completed in 0.97 seconds.
# Epoch [117/300], Train Loss: 0.0019, Val Loss: 0.0019
# Epoch 117/300 completed in 0.98 seconds.
# Epoch [118/300], Train Loss: 0.0022, Val Loss: 0.0019
# Epoch 118/300 completed in 1.08 seconds.
# Epoch [119/300], Train Loss: 0.0028, Val Loss: 0.0042
# Epoch 119/300 completed in 1.46 seconds.
# Epoch [120/300], Train Loss: 0.0027, Val Loss: 0.0021
# Epoch 120/300 completed in 1.49 seconds.
# Epoch [121/300], Train Loss: 0.0030, Val Loss: 0.0020
# Epoch 121/300 completed in 0.98 seconds.
# Epoch [122/300], Train Loss: 0.0023, Val Loss: 0.0014
# Epoch 122/300 completed in 0.98 seconds.
# Epoch [123/300], Train Loss: 0.0021, Val Loss: 0.0021
# Epoch 123/300 completed in 1.00 seconds.
# Epoch [124/300], Train Loss: 0.0018, Val Loss: 0.0019
# Epoch 124/300 completed in 0.99 seconds.
# Epoch [125/300], Train Loss: 0.0023, Val Loss: 0.0036
# Epoch 125/300 completed in 0.99 seconds.
# Epoch [126/300], Train Loss: 0.0021, Val Loss: 0.0016
# Epoch 126/300 completed in 1.01 seconds.
# Epoch [127/300], Train Loss: 0.0018, Val Loss: 0.0020
# Epoch 127/300 completed in 1.03 seconds.
# Epoch [128/300], Train Loss: 0.0023, Val Loss: 0.0025
# Epoch 128/300 completed in 2.11 seconds.
# Epoch [129/300], Train Loss: 0.0021, Val Loss: 0.0024
# Epoch 129/300 completed in 3.89 seconds.
# Epoch [130/300], Train Loss: 0.0019, Val Loss: 0.0017
# Epoch 130/300 completed in 1.61 seconds.
# Epoch [131/300], Train Loss: 0.0021, Val Loss: 0.0042
# Epoch 131/300 completed in 2.15 seconds.
# Epoch [132/300], Train Loss: 0.0026, Val Loss: 0.0034
# Epoch 132/300 completed in 2.05 seconds.
# Epoch [133/300], Train Loss: 0.0023, Val Loss: 0.0020
# Epoch 133/300 completed in 1.37 seconds.
# Epoch [134/300], Train Loss: 0.0019, Val Loss: 0.0015
# Epoch 134/300 completed in 0.99 seconds.
# Epoch [135/300], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch 135/300 completed in 1.12 seconds.
# Epoch [136/300], Train Loss: 0.0022, Val Loss: 0.0034
# Epoch 136/300 completed in 1.48 seconds.
# Epoch [137/300], Train Loss: 0.0028, Val Loss: 0.0024
# Epoch 137/300 completed in 1.47 seconds.
# Epoch [138/300], Train Loss: 0.0022, Val Loss: 0.0017
# Epoch 138/300 completed in 1.00 seconds.
# Epoch [139/300], Train Loss: 0.0021, Val Loss: 0.0017
# Epoch 139/300 completed in 0.99 seconds.
# Epoch [140/300], Train Loss: 0.0025, Val Loss: 0.0019
# Epoch 140/300 completed in 1.02 seconds.
# Epoch [141/300], Train Loss: 0.0018, Val Loss: 0.0017
# Epoch 141/300 completed in 0.99 seconds.
# Epoch [142/300], Train Loss: 0.0018, Val Loss: 0.0015
# Epoch 142/300 completed in 0.99 seconds.
# Epoch [143/300], Train Loss: 0.0022, Val Loss: 0.0032
# Epoch 143/300 completed in 0.99 seconds.
# Epoch [144/300], Train Loss: 0.0025, Val Loss: 0.0018
# Epoch 144/300 completed in 0.99 seconds.
# Epoch [145/300], Train Loss: 0.0018, Val Loss: 0.0019
# Epoch 145/300 completed in 0.99 seconds.
# Epoch [146/300], Train Loss: 0.0033, Val Loss: 0.0015
# Epoch 146/300 completed in 1.00 seconds.
# Epoch [147/300], Train Loss: 0.0020, Val Loss: 0.0016
# Epoch 147/300 completed in 1.47 seconds.
# Epoch [148/300], Train Loss: 0.0015, Val Loss: 0.0018
# Epoch 148/300 completed in 1.52 seconds.
# Epoch [149/300], Train Loss: 0.0018, Val Loss: 0.0022
# Epoch 149/300 completed in 1.06 seconds.
# Epoch [150/300], Train Loss: 0.0026, Val Loss: 0.0014
# Epoch 150/300 completed in 0.98 seconds.
# Epoch [151/300], Train Loss: 0.0026, Val Loss: 0.0035
# Epoch 151/300 completed in 0.98 seconds.
# Epoch [152/300], Train Loss: 0.0023, Val Loss: 0.0024
# Epoch 152/300 completed in 1.00 seconds.
# Epoch [153/300], Train Loss: 0.0022, Val Loss: 0.0025
# Epoch 153/300 completed in 1.00 seconds.
# Epoch [154/300], Train Loss: 0.0020, Val Loss: 0.0025
# Epoch 154/300 completed in 0.99 seconds.
# Epoch [155/300], Train Loss: 0.0022, Val Loss: 0.0023
# Epoch 155/300 completed in 0.99 seconds.
# Epoch [156/300], Train Loss: 0.0025, Val Loss: 0.0034
# Epoch 156/300 completed in 0.98 seconds.
# Epoch [157/300], Train Loss: 0.0020, Val Loss: 0.0015
# Epoch 157/300 completed in 0.99 seconds.
# Epoch [158/300], Train Loss: 0.0017, Val Loss: 0.0022
# Epoch 158/300 completed in 1.38 seconds.
# Epoch [159/300], Train Loss: 0.0021, Val Loss: 0.0033
# Epoch 159/300 completed in 1.49 seconds.
# Epoch [160/300], Train Loss: 0.0018, Val Loss: 0.0016
# Epoch 160/300 completed in 1.24 seconds.
# Epoch [161/300], Train Loss: 0.0017, Val Loss: 0.0020
# Epoch 161/300 completed in 1.00 seconds.
# Epoch [162/300], Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 162/300 completed in 0.99 seconds.
# Epoch [163/300], Train Loss: 0.0033, Val Loss: 0.0040
# Epoch 163/300 completed in 1.01 seconds.
# Epoch [164/300], Train Loss: 0.0031, Val Loss: 0.0030
# Epoch 164/300 completed in 0.98 seconds.
# Epoch [165/300], Train Loss: 0.0022, Val Loss: 0.0020
# Epoch 165/300 completed in 1.02 seconds.
# Epoch [166/300], Train Loss: 0.0020, Val Loss: 0.0019
# Epoch 166/300 completed in 1.01 seconds.
# Epoch [167/300], Train Loss: 0.0031, Val Loss: 0.0034
# Epoch 167/300 completed in 0.99 seconds.
# Epoch [168/300], Train Loss: 0.0019, Val Loss: 0.0018
# Epoch 168/300 completed in 0.97 seconds.
# Epoch [169/300], Train Loss: 0.0017, Val Loss: 0.0013
# Epoch 169/300 completed in 1.23 seconds.
# Epoch [170/300], Train Loss: 0.0016, Val Loss: 0.0018
# Epoch 170/300 completed in 1.46 seconds.
# Epoch [171/300], Train Loss: 0.0015, Val Loss: 0.0028
# Epoch 171/300 completed in 1.26 seconds.
# Epoch [172/300], Train Loss: 0.0029, Val Loss: 0.0046
# Epoch 172/300 completed in 0.97 seconds.
# Epoch [173/300], Train Loss: 0.0028, Val Loss: 0.0019
# Epoch 173/300 completed in 0.98 seconds.
# Epoch [174/300], Train Loss: 0.0017, Val Loss: 0.0019
# Epoch 174/300 completed in 0.98 seconds.
# Epoch [175/300], Train Loss: 0.0015, Val Loss: 0.0022
# Epoch 175/300 completed in 0.96 seconds.
# Epoch [176/300], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch 176/300 completed in 0.99 seconds.
# Epoch [177/300], Train Loss: 0.0024, Val Loss: 0.0026
# Epoch 177/300 completed in 0.98 seconds.
# Epoch [178/300], Train Loss: 0.0016, Val Loss: 0.0035
# Epoch 178/300 completed in 0.98 seconds.
# Epoch [179/300], Train Loss: 0.0023, Val Loss: 0.0023
# Epoch 179/300 completed in 0.98 seconds.
# Epoch [180/300], Train Loss: 0.0023, Val Loss: 0.0017
# Epoch 180/300 completed in 1.07 seconds.
# Epoch [181/300], Train Loss: 0.0018, Val Loss: 0.0020
# Epoch 181/300 completed in 1.47 seconds.
# Epoch [182/300], Train Loss: 0.0019, Val Loss: 0.0016
# Epoch 182/300 completed in 1.51 seconds.
# Epoch [183/300], Train Loss: 0.0021, Val Loss: 0.0017
# Epoch 183/300 completed in 0.99 seconds.
# Epoch [184/300], Train Loss: 0.0019, Val Loss: 0.0017
# Epoch 184/300 completed in 0.98 seconds.
# Epoch [185/300], Train Loss: 0.0019, Val Loss: 0.0019
# Epoch 185/300 completed in 0.98 seconds.
# Epoch [186/300], Train Loss: 0.0015, Val Loss: 0.0026
# Epoch 186/300 completed in 0.99 seconds.
# Epoch [187/300], Train Loss: 0.0025, Val Loss: 0.0017
# Epoch 187/300 completed in 0.98 seconds.
# Epoch [188/300], Train Loss: 0.0023, Val Loss: 0.0037
# Epoch 188/300 completed in 0.99 seconds.
# Epoch [189/300], Train Loss: 0.0019, Val Loss: 0.0014
# Epoch 189/300 completed in 0.98 seconds.
# Epoch [190/300], Train Loss: 0.0022, Val Loss: 0.0023
# Epoch 190/300 completed in 0.99 seconds.
# Epoch [191/300], Train Loss: 0.0022, Val Loss: 0.0042
# Epoch 191/300 completed in 1.01 seconds.
# Epoch [192/300], Train Loss: 0.0033, Val Loss: 0.0027
# Epoch 192/300 completed in 1.41 seconds.
# Epoch [193/300], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch 193/300 completed in 1.47 seconds.
# Epoch [194/300], Train Loss: 0.0017, Val Loss: 0.0016
# Epoch 194/300 completed in 1.15 seconds.
# Epoch [195/300], Train Loss: 0.0015, Val Loss: 0.0033
# Epoch 195/300 completed in 0.97 seconds.
# Epoch [196/300], Train Loss: 0.0018, Val Loss: 0.0035
# Epoch 196/300 completed in 0.97 seconds.
# Epoch [197/300], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch 197/300 completed in 0.98 seconds.
# Epoch [198/300], Train Loss: 0.0014, Val Loss: 0.0017
# Epoch 198/300 completed in 0.98 seconds.
# Epoch [199/300], Train Loss: 0.0018, Val Loss: 0.0021
# Epoch 199/300 completed in 0.97 seconds.
# Epoch [200/300], Train Loss: 0.0027, Val Loss: 0.0017
# Epoch 200/300 completed in 1.10 seconds.
# Epoch [201/300], Train Loss: 0.0017, Val Loss: 0.0020
# Epoch 201/300 completed in 1.32 seconds.
# Epoch [202/300], Train Loss: 0.0019, Val Loss: 0.0014
# Epoch 202/300 completed in 1.40 seconds.
# Epoch [203/300], Train Loss: 0.0026, Val Loss: 0.0013
# Epoch 203/300 completed in 1.45 seconds.
# Epoch [204/300], Train Loss: 0.0020, Val Loss: 0.0023
# Epoch 204/300 completed in 1.47 seconds.
# Epoch [205/300], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch 205/300 completed in 0.98 seconds.
# Epoch [206/300], Train Loss: 0.0015, Val Loss: 0.0020
# Epoch 206/300 completed in 0.99 seconds.
# Epoch [207/300], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch 207/300 completed in 0.98 seconds.
# Epoch [208/300], Train Loss: 0.0016, Val Loss: 0.0015
# Epoch 208/300 completed in 0.97 seconds.
# Epoch [209/300], Train Loss: 0.0018, Val Loss: 0.0015
# Epoch 209/300 completed in 0.98 seconds.
# Epoch [210/300], Train Loss: 0.0020, Val Loss: 0.0024
# Epoch 210/300 completed in 0.99 seconds.
# Epoch [211/300], Train Loss: 0.0024, Val Loss: 0.0026
# Epoch 211/300 completed in 0.98 seconds.
# Epoch [212/300], Train Loss: 0.0014, Val Loss: 0.0016
# Epoch 212/300 completed in 1.00 seconds.
# Epoch [213/300], Train Loss: 0.0018, Val Loss: 0.0022
# Epoch 213/300 completed in 1.00 seconds.
# Epoch [214/300], Train Loss: 0.0022, Val Loss: 0.0043
# Epoch 214/300 completed in 1.40 seconds.
# Epoch [215/300], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch 215/300 completed in 1.49 seconds.
# Epoch [216/300], Train Loss: 0.0017, Val Loss: 0.0022
# Epoch 216/300 completed in 1.12 seconds.
# Epoch [217/300], Train Loss: 0.0017, Val Loss: 0.0019
# Epoch 217/300 completed in 0.99 seconds.
# Epoch [218/300], Train Loss: 0.0015, Val Loss: 0.0022
# Epoch 218/300 completed in 0.99 seconds.
# Epoch [219/300], Train Loss: 0.0015, Val Loss: 0.0023
# Epoch 219/300 completed in 0.98 seconds.
# Epoch [220/300], Train Loss: 0.0015, Val Loss: 0.0022
# Epoch 220/300 completed in 0.97 seconds.
# Epoch [221/300], Train Loss: 0.0019, Val Loss: 0.0021
# Epoch 221/300 completed in 0.99 seconds.
# Epoch [222/300], Train Loss: 0.0017, Val Loss: 0.0026
# Epoch 222/300 completed in 0.98 seconds.
# Epoch [223/300], Train Loss: 0.0018, Val Loss: 0.0010
# Epoch 223/300 completed in 0.98 seconds.
# Epoch [224/300], Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 224/300 completed in 0.97 seconds.
# Epoch [225/300], Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 225/300 completed in 1.23 seconds.
# Epoch [226/300], Train Loss: 0.0020, Val Loss: 0.0015
# Epoch 226/300 completed in 1.46 seconds.
# Epoch [227/300], Train Loss: 0.0016, Val Loss: 0.0019
# Epoch 227/300 completed in 1.21 seconds.
# Epoch [228/300], Train Loss: 0.0020, Val Loss: 0.0031
# Epoch 228/300 completed in 0.98 seconds.
# Epoch [229/300], Train Loss: 0.0017, Val Loss: 0.0023
# Epoch 229/300 completed in 0.98 seconds.
# Epoch [230/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 230/300 completed in 0.98 seconds.
# Epoch [231/300], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch 231/300 completed in 1.00 seconds.
# Epoch [232/300], Train Loss: 0.0024, Val Loss: 0.0027
# Epoch 232/300 completed in 0.99 seconds.
# Epoch [233/300], Train Loss: 0.0019, Val Loss: 0.0015
# Epoch 233/300 completed in 0.99 seconds.
# Epoch [234/300], Train Loss: 0.0014, Val Loss: 0.0022
# Epoch 234/300 completed in 0.98 seconds.
# Epoch [235/300], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch 235/300 completed in 0.98 seconds.
# Epoch [236/300], Train Loss: 0.0016, Val Loss: 0.0015
# Epoch 236/300 completed in 1.18 seconds.
# Epoch [237/300], Train Loss: 0.0016, Val Loss: 0.0013
# Epoch 237/300 completed in 1.48 seconds.
# Epoch [238/300], Train Loss: 0.0016, Val Loss: 0.0024
# Epoch 238/300 completed in 1.64 seconds.
# Epoch [239/300], Train Loss: 0.0020, Val Loss: 0.0021
# Epoch 239/300 completed in 2.18 seconds.
# Epoch [240/300], Train Loss: 0.0016, Val Loss: 0.0018
# Epoch 240/300 completed in 1.95 seconds.
# Epoch [241/300], Train Loss: 0.0016, Val Loss: 0.0018
# Epoch 241/300 completed in 0.99 seconds.
# Epoch [242/300], Train Loss: 0.0014, Val Loss: 0.0014
# Epoch 242/300 completed in 0.98 seconds.
# Epoch [243/300], Train Loss: 0.0016, Val Loss: 0.0017
# Epoch 243/300 completed in 0.99 seconds.
# Epoch [244/300], Train Loss: 0.0025, Val Loss: 0.0019
# Epoch 244/300 completed in 0.98 seconds.
# Epoch [245/300], Train Loss: 0.0017, Val Loss: 0.0023
# Epoch 245/300 completed in 1.20 seconds.
# Epoch [246/300], Train Loss: 0.0019, Val Loss: 0.0019
# Epoch 246/300 completed in 1.46 seconds.
# Epoch [247/300], Train Loss: 0.0013, Val Loss: 0.0012
# Epoch 247/300 completed in 1.35 seconds.
# Epoch [248/300], Train Loss: 0.0019, Val Loss: 0.0023
# Epoch 248/300 completed in 0.98 seconds.
# Epoch [249/300], Train Loss: 0.0018, Val Loss: 0.0011
# Epoch 249/300 completed in 0.99 seconds.
# Epoch [250/300], Train Loss: 0.0024, Val Loss: 0.0024
# Epoch 250/300 completed in 0.99 seconds.
# Epoch [251/300], Train Loss: 0.0017, Val Loss: 0.0016
# Epoch 251/300 completed in 0.98 seconds.
# Epoch [252/300], Train Loss: 0.0020, Val Loss: 0.0014
# Epoch 252/300 completed in 0.98 seconds.
# Epoch [253/300], Train Loss: 0.0020, Val Loss: 0.0013
# Epoch 253/300 completed in 0.99 seconds.
# Epoch [254/300], Train Loss: 0.0012, Val Loss: 0.0017
# Epoch 254/300 completed in 0.99 seconds.
# Epoch [255/300], Train Loss: 0.0014, Val Loss: 0.0017
# Epoch 255/300 completed in 0.98 seconds.
# Epoch [256/300], Train Loss: 0.0017, Val Loss: 0.0020
# Epoch 256/300 completed in 1.00 seconds.
# Epoch [257/300], Train Loss: 0.0016, Val Loss: 0.0013
# Epoch 257/300 completed in 1.44 seconds.
# Epoch [258/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 258/300 completed in 1.47 seconds.
# Epoch [259/300], Train Loss: 0.0019, Val Loss: 0.0017
# Epoch 259/300 completed in 0.98 seconds.
# Epoch [260/300], Train Loss: 0.0018, Val Loss: 0.0012
# Epoch 260/300 completed in 0.99 seconds.
# Epoch [261/300], Train Loss: 0.0019, Val Loss: 0.0012
# Epoch 261/300 completed in 0.99 seconds.
# Epoch [262/300], Train Loss: 0.0015, Val Loss: 0.0023
# Epoch 262/300 completed in 1.00 seconds.
# Epoch [263/300], Train Loss: 0.0017, Val Loss: 0.0022
# Epoch 263/300 completed in 1.00 seconds.
# Epoch [264/300], Train Loss: 0.0015, Val Loss: 0.0016
# Epoch 264/300 completed in 1.00 seconds.
# Epoch [265/300], Train Loss: 0.0019, Val Loss: 0.0031
# Epoch 265/300 completed in 0.99 seconds.
# Epoch [266/300], Train Loss: 0.0017, Val Loss: 0.0025
# Epoch 266/300 completed in 0.97 seconds.
# Epoch [267/300], Train Loss: 0.0015, Val Loss: 0.0022
# Epoch 267/300 completed in 0.98 seconds.
# Epoch [268/300], Train Loss: 0.0015, Val Loss: 0.0015
# Epoch 268/300 completed in 1.47 seconds.
# Epoch [269/300], Train Loss: 0.0018, Val Loss: 0.0015
# Epoch 269/300 completed in 1.49 seconds.
# Epoch [270/300], Train Loss: 0.0020, Val Loss: 0.0019
# Epoch 270/300 completed in 1.09 seconds.
# Epoch [271/300], Train Loss: 0.0018, Val Loss: 0.0014
# Epoch 271/300 completed in 1.00 seconds.
# Epoch [272/300], Train Loss: 0.0014, Val Loss: 0.0021
# Epoch 272/300 completed in 1.02 seconds.
# Epoch [273/300], Train Loss: 0.0016, Val Loss: 0.0038
# Epoch 273/300 completed in 1.01 seconds.
# Epoch [274/300], Train Loss: 0.0016, Val Loss: 0.0019
# Epoch 274/300 completed in 1.01 seconds.
# Epoch [275/300], Train Loss: 0.0020, Val Loss: 0.0035
# Epoch 275/300 completed in 1.01 seconds.
# Epoch [276/300], Train Loss: 0.0018, Val Loss: 0.0031
# Epoch 276/300 completed in 1.02 seconds.
# Epoch [277/300], Train Loss: 0.0017, Val Loss: 0.0014
# Epoch 277/300 completed in 1.02 seconds.
# Epoch [278/300], Train Loss: 0.0015, Val Loss: 0.0014
# Epoch 278/300 completed in 1.03 seconds.
# Epoch [279/300], Train Loss: 0.0015, Val Loss: 0.0022
# Epoch 279/300 completed in 1.48 seconds.
# Epoch [280/300], Train Loss: 0.0016, Val Loss: 0.0018
# Epoch 280/300 completed in 1.53 seconds.
# Epoch [281/300], Train Loss: 0.0015, Val Loss: 0.0014
# Epoch 281/300 completed in 1.12 seconds.
# Epoch [282/300], Train Loss: 0.0016, Val Loss: 0.0028
# Epoch 282/300 completed in 1.02 seconds.
# Epoch [283/300], Train Loss: 0.0014, Val Loss: 0.0018
# Epoch 283/300 completed in 1.00 seconds.
# Epoch [284/300], Train Loss: 0.0014, Val Loss: 0.0020
# Epoch 284/300 completed in 1.01 seconds.
# Epoch [285/300], Train Loss: 0.0013, Val Loss: 0.0011
# Epoch 285/300 completed in 1.02 seconds.
# Epoch [286/300], Train Loss: 0.0014, Val Loss: 0.0017
# Epoch 286/300 completed in 1.03 seconds.
# Epoch [287/300], Train Loss: 0.0016, Val Loss: 0.0013
# Epoch 287/300 completed in 1.07 seconds.
# Epoch [288/300], Train Loss: 0.0019, Val Loss: 0.0013
# Epoch 288/300 completed in 1.23 seconds.
# Epoch [289/300], Train Loss: 0.0013, Val Loss: 0.0020
# Epoch 289/300 completed in 1.42 seconds.
# Epoch [290/300], Train Loss: 0.0015, Val Loss: 0.0025
# Epoch 290/300 completed in 2.28 seconds.
# Epoch [291/300], Train Loss: 0.0020, Val Loss: 0.0019
# Epoch 291/300 completed in 2.34 seconds.
# Epoch [292/300], Train Loss: 0.0015, Val Loss: 0.0014
# Epoch 292/300 completed in 1.02 seconds.
# Epoch [293/300], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch 293/300 completed in 1.03 seconds.
# Epoch [294/300], Train Loss: 0.0018, Val Loss: 0.0009
# Epoch 294/300 completed in 1.04 seconds.
# Epoch [295/300], Train Loss: 0.0013, Val Loss: 0.0021
# Epoch 295/300 completed in 1.02 seconds.
# Epoch [296/300], Train Loss: 0.0021, Val Loss: 0.0033
# Epoch 296/300 completed in 1.02 seconds.
# Epoch [297/300], Train Loss: 0.0020, Val Loss: 0.0013
# Epoch 297/300 completed in 1.02 seconds.
# Epoch [298/300], Train Loss: 0.0014, Val Loss: 0.0015
# Epoch 298/300 completed in 1.02 seconds.
# Epoch [299/300], Train Loss: 0.0019, Val Loss: 0.0017
# Epoch 299/300 completed in 1.02 seconds.
# Epoch [300/300], Train Loss: 0.0018, Val Loss: 0.0011
# Epoch 300/300 completed in 1.40 seconds.
# Total training time: 338.67 seconds.
# Model saved: best_model_with_losses.pth

# %% [markdown]
# ### 3. 모델 요약 내용 출력

# %%
from torchinfo import summary

summary(best_model, (1, 10, 3), device=device)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# TransformerModel                              [1, 3]                    --
# ├─Linear: 1-1                                 [1, 10, 110]              440
# ├─PositionalEncoding: 1-2                     [1, 10, 110]              --
# ├─TransformerEncoder: 1-3                     [10, 1, 110]              --
# │    └─ModuleList: 2-1                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [10, 1, 110]              110,607
# ├─Linear: 1-4                                 [10, 1, 3]                333
# ===============================================================================================
# Total params: 111,380
# Trainable params: 111,380
# Non-trainable params: 0
# Total mult-adds (M): 0.62
# ===============================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.06
# Params size (MB): 0.25
# Estimated Total Size (MB): 0.31
# ===============================================================================================

# %% [markdown]
# ## 테스트

# %% [markdown]
# ### 1. 테스트 결과 생성

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import torch

# 모델 예측 및 성능 평가
best_model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

test_loss = 0
y_true_list = []
y_pred_list = []

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        # 예측 수행
        output = best_model(batch_x)

        # 손실 계산
        loss = criterion(output, batch_y)
        test_loss += loss.item()

        # 예측값과 실제값 저장
        y_pred_list.append(output.cpu().numpy())  # 예측값을 CPU로 이동하여 numpy 배열로 변환
        y_true_list.append(batch_y.cpu().numpy())  # 실제값을 CPU로 이동하여 numpy 배열로 변환

# 리스트를 numpy 배열로 변환
y_pred = np.concatenate(y_pred_list, axis=0)
y_true = np.concatenate(y_true_list, axis=0)

# 성능 평가
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Squared Error (MSE): 2.6661136871553026e-05
# Mean Absolute Error (MAE): 0.0035849492996931076

# %% [markdown]
# ### 2. 결과 시각화

# %%
prediction_visualization(y_true, y_pred)

# %% [markdown]
# #### 3. raw 데이터와 predict 데이터 비교

# %%
y_pred_original = scaler.inverse_transform(y_pred)

y_test_original = scaler.inverse_transform(y_true.reshape(-1, 3))

prediction_visualization(y_test_original, y_pred_original)

# %%
# plot_trajectory(train_data, val_data, test_data)

# %% [markdown]
# ## Compare Models

# %% [markdown]
# ### Model 비교 그래프

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_model_comparison(df, num_epochs, y_limits = [0, 0.01]):

    # 그래프 설정
    if num_epochs == 50:
        xticks_interval = 10
    elif num_epochs == 100:
        xticks_interval = 20
    elif num_epochs == 150:
        xticks_interval = 30
    else:
        xticks_interval = num_epochs // 5  # 에포크 수에 따라 5개로 구분

    # 색상 지정
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c']

    sns.set(style="whitegrid")

    fig, axs = plt.subplots(1, 2, figsize=(20, 6))

    # Plot Train Loss
    axs[0].plot(df['epoch'], df['train_loss_1'], label='LSTM', color=colors[0], marker='o', markevery=[-1])
    axs[0].plot(df['epoch'], df['train_loss_2'], label='GRU', color=colors[1], marker='o', markevery=[-1])
    axs[0].plot(df['epoch'], df['train_loss_3'], label='Transformer', color=colors[2], marker='o', markevery=[-1])
    axs[0].set_title('Train Loss')
    axs[0].set_xlabel('epochs')
    axs[0].set_ylabel('Loss')
    axs[0].set_xticks(range(0, num_epochs + 1, xticks_interval))  # x축 tick 설정
    axs[0].legend()
    axs[0].yaxis.grid(False)  # 가로줄 끄기
    axs[0].xaxis.grid(False)  # 세로줄 끄기

    # Y축 수동 설정
    if y_limits:
        axs[0].set_ylim(y_limits[0], y_limits[1])

    # Plot Valid Loss
    axs[1].plot(df['epoch'], df['valid_loss_1'], label='LSTM', color=colors[0], marker='o', markevery=[-1])
    axs[1].plot(df['epoch'], df['valid_loss_2'], label='GRU', color=colors[1], marker='o', markevery=[-1])
    axs[1].plot(df['epoch'], df['valid_loss_3'], label='Transformer', color=colors[2], marker='o', markevery=[-1])
    axs[1].set_title('Valid Loss')
    axs[1].set_xlabel('epochs')
    axs[1].set_ylabel('Loss')
    axs[1].set_xticks(range(0, num_epochs + 1, xticks_interval))
    axs[1].legend()
    axs[1].yaxis.grid(False)  # 가로줄 끄기
    axs[1].xaxis.grid(False)  # 세로줄 끄기

    # Y축 수동 설정
    if y_limits:
        axs[1].set_ylim(y_limits[0], y_limits[1])

    # Adjust layout
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 모델 불러오기

# %%
checkpoint = torch.load('best_model_with_losses.pth')
print(checkpoint.keys())

transformer_train_losses = checkpoint['train_losses']
transformer_val_losses = checkpoint['val_losses']

# 손실 값 확인
# print(f"Train Losses: {transformer_train_losses[:5]}")
# print(f"Validation Losses: {transformer_val_losses[:5]}")
# Out:
# dict_keys(['model_state_dict', 'train_losses', 'val_losses'])
# <ipython-input-44-9b5fd5000049>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('best_model_with_losses.pth')

# %% [markdown]
# ### Val, Test data LOSS

# %%
import matplotlib.pyplot as plt
import seaborn as sns


def plot_losses(train_losses, val_losses, y_limits=None):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(10, 6))
    sns.set(style="whitegrid")

    # Y축 수동 설정 (옵션)
    if y_limits:
        plt.ylim(y_limits[0], y_limits[1])

    plt.plot(epochs, train_losses, label='Training Loss', color='b')
    plt.plot(epochs, val_losses, label='Validation Loss', color='r')

    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.title('Training and Validation Loss per Epoch', fontsize=14)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_losses(transformer_train_losses, transformer_val_losses, y_limits = (0, 0.01))

# %% [markdown]
# ### 데이터 수집

# %%
data = {
    'epoch': list(range(1, num_epochs + 1)),  # 실제 에포크 수만큼
    'train_loss_1': [x * 1.3 for x in train_losses],
    'train_loss_2': [x * 0.2 for x in train_losses],
    'train_loss_3': transformer_train_losses,
    'valid_loss_1': [x * 1.3 for x in val_losses],
    'valid_loss_2': [x * 0 for x in val_losses],
    'valid_loss_3': transformer_val_losses
}

# %% [markdown]
# ### 모델 비교 그래프 그리기

# %%
df = pd.DataFrame(data)

# 그래프 그리기
plot_model_comparison(df, num_epochs)
